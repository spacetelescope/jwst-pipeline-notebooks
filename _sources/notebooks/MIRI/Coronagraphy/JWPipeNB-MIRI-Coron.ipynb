# %% [markdown]
# <img style="float: center;" src='https://github.com/spacetelescope/jwst-pipeline-notebooks/raw/main/_static/stsci_header.png' alt="stsci_logo" width="900px"/>

# %% [markdown]
# <a id="title_ID"></a>
# # MIRI Coronagraphy Pipeline Notebook #

# %% [markdown]
# **Authors**: B. Nickson; MIRI branch, A. L. Carter; NIRISS branch<br>
# **Last Updated**: April 17, 2026<br>
# **Pipeline Version**: 2.0.0 (Build 12.3)

# %% [markdown]
# **Purpose**: <br>
# This notebook provides a framework for processing generic Mid-Infrared Instrument (MIRI) Coronagraphic data through all three James Webb Space Telescope (JWST) pipeline stages. Data is assumed to be located in separate observation folders according to the paths set up below. Editing cells other than those in the [Configuration](#1.-Configuration) should not be necessary unless the standard pipeline processing options are modified.
#
# **Data**: <br>
# This example is set up to use F1550C coronagraphic observations of the super-Jupiter exoplanet HIP 65426 b, obtained by [Program ID](https://www.stsci.edu/jwst/science-execution/program-information) 1386 (PI: S. Hinkley). It incorporates observations of the exoplanet host star HIP 65426 at two separate roll angles (1 exposure each); a PSF reference observation of the nearby star HIP 65219, taken with a 9-pt small grid dither pattern (9 exposures total); a background observation associated with the target star, taken with a 2-pt dither (two exposures); and a background observation associated with the PSF reference target, taken with a 2-pt dither (two exposures).
#
# The relevant observation numbers are:
#
# - Science observations: 8, 9<br>
# - Science backgrounds: 30<br>
# - Reference observations: 7<br>
# - Reference backgrounds: 31<br>
#
# Example input data to use will be downloaded automatically unless disabled (i.e., to use local files instead).
#
#
# **[JWST pipeline version and CRDS context](#Set-CRDS-Context-and-Server)**:<br>
# This notebook was written for the above-specified pipeline version and associated build context for this version of the JWST Calibration Pipeline. Information about this and other contexts can be found in the JWST Calibration Reference Data System (CRDS [server](https://jwst-crds.stsci.edu/)). If you use different pipeline versions, please refer to the table [here](https://jwst-crds.stsci.edu/display_build_contexts/) to determine what context to use. To learn more about the differences for the pipeline, read the relevant [documentation](https://jwst-docs.stsci.edu/jwst-science-calibration-pipeline/jwst-operations-pipeline-build-information#references).<br>
#
# Please note that pipeline software development is a continuous process, so results in some cases may be slightly different if a subsequent version is used. **For optimal results, users are strongly encouraged to reprocess their data using the most recent pipeline version and [associated CRDS context](https://jwst-crds.stsci.edu/display_build_contexts/), taking advantage of bug fixes and algorithm improvements.**
# Any [known issues](https://jwst-docs.stsci.edu/known-issues-with-jwst-data/nirspec-known-issues/nirspec-mos-known-issues#NIRSpecFSKnownIssues-Resamplingof2-Dspectra&gsc.tab=0:~:text=MOS%20Known%20Issues-,NIRSpec%20MOS%20Known%20Issues,-Known%20issues%20specific) for this build are noted in the notebook.
#
# **Updates**:<br>
# This notebook is regularly updated as improvements are made to the pipeline. Find the most up to date version of this notebook at:
# [https://github.com/spacetelescope/jwst-pipeline-notebooks/](https://github.com/spacetelescope/jwst-pipeline-notebooks/)
#
# **Recent Changes**:<br>
# Jan 28, 2025: Migrate from the `Coronagraphy_ExampleNB` notebook, update to Build 11.2 (jwst 1.17.1).<br>
# May 5, 2025: Updated to jwst 1.18.0 (no significant changes)<br>
# July 16, 2025: Updated to jwst 1.19.1 (no significant changes)<br>
# November 10, 2025: Updated to jwst 1.20.2 (no significant changes)<br>
# March 27, 2026: Updated to demonstrate PSF library subtraction<br>
# April 17, 2026: Updated to jwst 2.0.0 (no significant changes)

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ## Table of Contents
#
# 1. [Configuration](#1.-Configuration)
# 2. [Package Imports](#2.-Package-Imports)
# 3. [Demo Mode Setup](#3.-Demo-Mode-Setup-(ignore-if-not-using-demo-data))
# 4. [Directory Setup](#4.-Directory-Setup)
# 5. [Detector1 Pipeline](#5.-Detector1-Pipeline)
# 6. [Image2 Pipeline](#6.-Image2-Pipeline)
# 7. [Coron3 Pipeline](#7.-Coron3-Pipeline)
# 8. [Plot the spectra](#8.-Plot-the-spectra)
# 9. [Advanced Usage- PSF Reference Library](#9.-Advanced-Usage--PSF-Reference-Library)
# 10. [Advanced Usage - Examine the output](#10.-Advanced-Usage--Examine-the-output)

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ## 1.-Configuration
# ------------------
# Set basic parameters to use with this notebook. These will affect what data is used, where data is located (if already in disk), and pipeline modules run on this data. The list of parameters are as follows:
#
# * demo_mode
# * directories with data
# * mask
# * filter
# * pipeline modules

# %%
# Basic import necessary for configuration
import os

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Note that <code>demo_mode</code> must be set appropriately below.
# </div>
#
# Set <code>demo_mode = True</code> to run in demonstration mode. In this mode, this
# notebook will download example data from the
# Barbara A. Mikulski Archive for Space Telescopes [(MAST)](https://archive.stsci.edu/) and process it through the pipeline.
# This will all happen in a local directory unless modified
# in [Section 3](#3.-Demo-Mode-Setup-(ignore-if-not-using-demo-data)) below.
#
# Set <code>demo_mode = False</code> if you want to process your own data that has already
# been downloaded and provide the location of the data.<br>

# %%
# Set parameters for demo_mode, mask, filter, data mode directories, and 
# processing steps.

# -------------------------------Demo Mode---------------------------------
demo_mode = True

if demo_mode:
    print('Running in demonstration mode using online example data!')

# -------------------------Data Mode Directories---------------------------
# If demo_mode = False, look for user data in these paths
if not demo_mode:
    # Set directory paths for processing specific data; these will need
    # to be changed to your local directory setup (below are given as
    # examples)
    basedir = os.path.join(os.path.expanduser('~'), 'FlightData1386/')

    # Point to where science observation data are
    # Assumes uncalibrated data in sci_r1_dir/uncal/ and sci_r2_dir/uncal/, 
    # and results in stage1, stage2, stage3 directories
    sci_r1_dir = os.path.join(basedir, 'sci_r1/')
    sci_r2_dir = os.path.join(basedir, 'sci_r2/')

    # Point to where reference target observation data are
    # Assumes uncalibrated data in ref_dir/uncal/ and results in stage1,
    # stage2, stage3 directories
    ref_targ_dir = os.path.join(basedir, 'ref_targ/')

    # Point to where background observation data are
    # Assumes uncalibrated data in sci_bg_dir/uncal/ and ref_targ_bg_dir/uncal/,
    # and results in stage1, stage2 directories
    bg_sci_dir = os.path.join(basedir, 'bg_sci/')
    bg_ref_targ_dir = os.path.join(basedir, 'bg_ref_targ/')

# --------------------------Set Processing Steps--------------------------
# Whether or not to process only data from a given coronagraphic mask/
# filter (useful if overriding reference files) 
# Note that BOTH parameters must be set in order to work
use_mask = '4QPM_1550'  # '4QPM_1065', '4QPM_1140', '4QPM_1550', or 'LYOT_2300'
use_filter = 'F1550C'  # 'F1065C', 'F1140C', 'F1550C', or 'F2300C'

# Individual pipeline stages can be turned on/off here. Note that a later
# stage won't be able to run unless data products have already been
# produced from the prior stage.

# Science processing
dodet1 = True  # calwebb_detector1
doimage2 = True  # calwebb_image2
docoron3 = True  # calwebb_coron3
docoron3_psflib = True #calwebb_coron3 with larger PSF library

# Background processing
dodet1bg = True  # calwebb_detector1
doimage2bg = True  # calwebb_image2
# Out:
# Running in demonstration mode using online example data!

# %% [markdown]
# ### Set CRDS context and server
# Before importing <code>CRDS</code> and <code>JWST</code> modules, we need to configure our environment. This includes defining a CRDS cache directory in which to keep the reference files that will be used by the calibration pipeline.
#
# If the root directory for the local CRDS cache directory has not been set already, it will be set to create one in the home directory.

# %%
# ------------------------Set CRDS context and paths----------------------
# Each version of the calibration pipeline is associated with a specific CRDS
# context file. The pipeline will select the appropriate context file behind
# the scenes while running. However, if you wish to override the default context
# file and run the pipeline with a different context, you can set that using
# the CRDS_CONTEXT environment variable. Here we show how this is done,
# although we leave the line commented out in order to use the default context.
# If you wish to specify a different context, uncomment the line below.
#%env CRDS_CONTEXT jwst_1322.pmap

# Check whether the local CRDS cache directory has been set.
# If not, set it to the user home directory
if (os.getenv('CRDS_PATH') is None):
    os.environ['CRDS_PATH'] = os.path.join(os.path.expanduser('~'), 'crds')

# Check whether the CRDS server URL has been set.  If not, set it.
if (os.getenv('CRDS_SERVER_URL') is None):
    os.environ['CRDS_SERVER_URL'] = 'https://jwst-crds.stsci.edu'

# Echo CRDS path in use
print('CRDS local filepath:', os.environ['CRDS_PATH'])
print('CRDS file server:', os.environ['CRDS_SERVER_URL'])
# Out:
# CRDS local filepath: /home/runner/crds
# CRDS file server: https://jwst-crds.stsci.edu

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ## 2.-Package Imports
# ------------------

# %%
# Use the entire available screen width for this notebook
from IPython.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
# Basic system utilities for interacting with files
# ----------------------General Imports------------------------------------
import glob, importlib
#import copy
import time
from pathlib import Path
from collections import defaultdict
import re

# Numpy for doing calculations
import numpy as np

# -----------------------Astropy Imports-----------------------------------
# Astropy utilities for opening FITS and ASCII files, and downloading demo files
from astropy.io import fits
from astropy.wcs import WCS
from astropy.coordinates import SkyCoord

#from astropy import time
from astroquery.mast import Observations

# -----------------------Plotting Imports----------------------------------
# Matplotlib for making plots
import matplotlib.pyplot as plt

# %%
# --------------JWST Calibration Pipeline Imports---------------------------
# Import the base JWST and calibration reference files packages
import jwst
import crds

# JWST pipelines (each encompassing many steps)
from jwst.pipeline import Detector1Pipeline
from jwst.pipeline import Image2Pipeline
from jwst.pipeline import Coron3Pipeline

# JWST pipeline utilities
from jwst import datamodels  # JWST datamodels
from jwst.associations import asn_from_list as afl  # Tools for creating association files
from jwst.associations.lib.rules_level2_base import DMSLevel2bBase  # Definition of a Lvl2 association file
from jwst.associations.lib.rules_level3_base import DMS_Level3_Base  # Definition of a Lvl3 association file

from jwst.stpipe import Step  # Import the wrapper class for pipeline steps

# Echo pipeline version and CRDS context in use
print("JWST Calibration Pipeline Version = {}".format(jwst.__version__))
print("Using CRDS Context = {}".format(crds.get_context_name('jwst')))
# Out:
# JWST Calibration Pipeline Version = 2.0.0
# CRDS - INFO -  Calibration SW Found: jwst 2.0.0 (/home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages/jwst-2.0.0.dist-info)
# Using CRDS Context = jwst_1535.pmap

# %% [markdown]
# ### Define convenience functions
#
# Define a convenience function to select only files of a given coronagraph mask/filter from an input set

# %%
# Define a convenience function to select only files of a given coronagraph mask/filter from an input set
def select_mask_filter_files(files, use_mask, use_filter):
    """
    Filter FITS files based on mask and filter criteria from their headers.

    Parameters:
    -----------
    files : array-like
        List of FITS file paths to process
    use_mask : str
        Mask value to match in FITS header 'CORONMSK' key
    use_filter : str
        Filter value to match in FITS header 'FILTER' key

    Returns:
    --------
    numpy.ndarray
        Filtered array of file paths matching the criteria
    """

    # Make paths absolute paths
    for i in range(len(files)):
        files[i] = os.path.abspath(files[i])

    # Convert files to numpy array if it isn't already
    files = np.asarray(files)

    # If either mask or filter is empty, return all files
    if not use_mask or not use_filter:
        return files

    try:
        # Initialize boolean array for keeping track of matches
        keep = np.zeros(len(files), dtype=bool)

        # Process each file
        for i in range(len(files)):
            try:
                with fits.open(files[i]) as hdu:
                    hdu.verify()
                    hdr = hdu[0].header

                    # Check if requred header keywords exist
                    if ('CORONMSK' in hdr and 'FILTER' in hdr):
                        if hdr['CORONMSK'] == use_mask and hdr['FILTER'] == use_filter:
                            keep[i] = True
                            files[i] = os.path.abspath(files[i])
            except (OSError, ValueError) as e:
                print(f" Warning: could not process file {files[i]}: {str(e)}")

        # Return filtered files
        indx = np.where(keep)
        return files[indx]

    except Exception as e:
        print(f"Error processing files: {str(e)}")
        return files  # Return original array in case of failure

# %%
# Start a timer to keep track of runtime
time0 = time.perf_counter()

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ## 3.-Demo Mode Setup (ignore if not using demo data)
# ------------------
#
# If running in demonstration mode, set up the program information to
# retrieve the uncalibrated data automatically from MAST using
# [astroquery](https://astroquery.readthedocs.io/en/latest/mast/mast.html).
# MAST allows for flexibility of searching by the proposal ID and the
# observation ID instead of just filenames.<br>
#
# For illustrative purposes, we focus on data taken through the MIRI
# [F1550C filter](https://jwst-docs.stsci.edu/jwst-mid-infrared-instrument/miri-observing-modes/miri-coronagraphic-imaging#MIRICoronagraphicImaging-CoronFiltersCoronagraphfilters)
# and start with uncalibrated raw data products (`uncal.fits`). The files use the following naming schema:
# `jw01386<obs>001_04101_0000<dith>_mirimage_uncal.fits`, where *obs* refers to the observation number and *dith* refers to the
# dither step number.
#
#
# More information about the JWST file naming conventions can be found at:
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/data_products/file_naming.html

# %%
# Set up the program information and paths for demo program
if demo_mode:
    print('Running in demonstration mode and will download example data from MAST!')
    program = "01386"
    sci_r1_observtn = "008"  
    sci_r2_observtn = "009"  
    ref_targ_observtn = "007"      
    bg_sci_observtn = "030"  
    bg_ref_targ_observtn = "031"

    # ----------Define the base and observation directories----------
    basedir = os.path.join('.', 'miri_coro_demo_data')
    download_dir = basedir
    sci_r1_dir = os.path.join(basedir, 'Obs' + sci_r1_observtn)
    sci_r2_dir = os.path.join(basedir, 'Obs' + sci_r2_observtn)
    ref_targ_dir = os.path.join(basedir, 'Obs' + ref_targ_observtn)
    bg_sci_dir = os.path.join(basedir, 'Obs' + bg_sci_observtn)
    bg_ref_targ_dir = os.path.join(basedir, 'Obs' + bg_ref_targ_observtn)

    uncal_sci_r1_dir = os.path.join(sci_r1_dir, 'uncal')
    uncal_sci_r2_dir = os.path.join(sci_r2_dir, 'uncal')
    uncal_ref_targ_dir = os.path.join(ref_targ_dir, 'uncal')
    uncal_bg_sci_dir = os.path.join(bg_sci_dir, 'uncal')
    uncal_bg_ref_targ_dir = os.path.join(bg_ref_targ_dir, 'uncal')
    
    # Ensure filepaths for input data exist
    input_dirs = [uncal_sci_r1_dir, uncal_sci_r2_dir, uncal_ref_targ_dir, uncal_bg_sci_dir, uncal_bg_ref_targ_dir]

    for dir in input_dirs:
        if not os.path.exists(dir):
            os.makedirs(dir)
# Out:
# Running in demonstration mode and will download example data from MAST!

# %% [markdown]
# Identify list of uncalibrated files associated with visits.

# %%
# Obtain a list of observation IDs for the specified demo program
if demo_mode:
    obs_id_table = Observations.query_criteria(instrument_name=["MIRI/CORON"],
                                               provenance_name=["CALJWST"],
                                               proposal_id=[program])

# %%
# Turn the list of visits into a list of uncalibrated data files
if demo_mode:
    # Define types of files to select
    file_dict = {'uncal': {'product_type': 'SCIENCE', 'productSubGroupDescription': 'UNCAL', 'calib_level': [1]}}

    # Loop over visits identifying uncalibrated files that are associated with them
    files_to_download = []
    for exposure in (obs_id_table):
        products = Observations.get_product_list(exposure)
        for filetype, query_dict in file_dict.items():
            filtered_products = Observations.filter_products(products, productType=query_dict['product_type'],
                                                             productSubGroupDescription=query_dict['productSubGroupDescription'],
                                                             calib_level=query_dict['calib_level'])
            files_to_download.extend(filtered_products['dataURI'])

    # Cull to a unique list of files for each observation type 
    # Science roll 1 
    sci_r1_files_to_download = []
    sci_r1_files_to_download = np.unique([i for i in files_to_download if str(program + sci_r1_observtn) in i])

    # Science roll 2 
    sci_r2_files_to_download = []
    sci_r2_files_to_download = np.unique([i for i in files_to_download if str(program + sci_r2_observtn) in i])

    # PSF Reference taraget data
    ref_targ_files_to_download = []
    ref_targ_files_to_download = np.unique([i for i in files_to_download if str(program + ref_targ_observtn) in i])

    # Background files (science assoc.)
    bg_sci_files_to_download = []
    bg_sci_files_to_download = np.unique([i for i in files_to_download if str(program + bg_sci_observtn) in i])

    # Background files (reference target assoc.)
    bg_ref_targ_files_to_download = []  
    bg_ref_targ_files_to_download = np.unique([i for i in files_to_download if str(program + bg_ref_targ_observtn) in i])

    print("Science files selected for downloading: ", len(sci_r1_files_to_download) + len(sci_r1_files_to_download))
    print("PSF Reference target files selected for downloading: ", len(ref_targ_files_to_download))
    print("Background selected for downloading: ", len(bg_sci_files_to_download) + len(bg_ref_targ_files_to_download))
# Out:
# Science files selected for downloading:  6
# PSF Reference target files selected for downloading:  11
# Background selected for downloading:  4

# %% [markdown]
# For the demo example, there should be 6 Science files, 11 PSF Reference files and 4 Background files selected for downloading.
#
#
# Download all the uncal files and place them into the appropriate directories.
#
# <div class="alert alert-block alert-warning">
# Warning: If this notebook is halted during this step the downloaded file may be incomplete, and cause crashes later on!
# </div>

# %%
if demo_mode:
    for filename in sci_r1_files_to_download:
        sci_r1_manifest = Observations.download_file(filename, local_path=os.path.join(uncal_sci_r1_dir, Path(filename).name))
    for filename in sci_r2_files_to_download:
        sci_r2_manifest = Observations.download_file(filename, local_path=os.path.join(uncal_sci_r2_dir, Path(filename).name))
    for filename in ref_targ_files_to_download:
        ref_targ_manifest = Observations.download_file(filename, local_path=os.path.join(uncal_ref_targ_dir, Path(filename).name))
    for filename in bg_sci_files_to_download:
        bg_manifest = Observations.download_file(filename, local_path=os.path.join(uncal_bg_sci_dir, Path(filename).name))
    for filename in bg_ref_targ_files_to_download:
        bg_ref_targ_manifest = Observations.download_file(filename, local_path=os.path.join(uncal_bg_ref_targ_dir, Path(filename).name))
# Out:
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386008001_02101_00001_mirimage_uncal.fits to ./miri_coro_demo_data/Obs008/uncal/jw01386008001_02101_00001_mirimage_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386008001_02101_00002_mirimage_uncal.fits to ./miri_coro_demo_data/Obs008/uncal/jw01386008001_02101_00002_mirimage_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386008001_04101_00001_mirimage_uncal.fits to ./miri_coro_demo_data/Obs008/uncal/jw01386008001_04101_00001_mirimage_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386009001_02101_00001_mirimage_uncal.fits to ./miri_coro_demo_data/Obs009/uncal/jw01386009001_02101_00001_mirimage_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386009001_02101_00002_mirimage_uncal.fits to ./miri_coro_demo_data/Obs009/uncal/jw01386009001_02101_00002_mirimage_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386009001_04101_00001_mirimage_uncal.fits to ./miri_coro_demo_data/Obs009/uncal/jw01386009001_04101_00001_mirimage_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386007001_02101_00001_mirimage_uncal.fits to ./miri_coro_demo_data/Obs007/uncal/jw01386007001_02101_00001_mirimage_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386007001_02101_00002_mirimage_uncal.fits to ./miri_coro_demo_data/Obs007/uncal/jw01386007001_02101_00002_mirimage_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386007001_04101_00001_mirimage_uncal.fits to ./miri_coro_demo_data/Obs007/uncal/jw01386007001_04101_00001_mirimage_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386007001_04101_00002_mirimage_uncal.fits to ./miri_coro_demo_data/Obs007/uncal/jw01386007001_04101_00002_mirimage_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386007001_04101_00003_mirimage_uncal.fits to ./miri_coro_demo_data/Obs007/uncal/jw01386007001_04101_00003_mirimage_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386007001_04101_00004_mirimage_uncal.fits to ./miri_coro_demo_data/Obs007/uncal/jw01386007001_04101_00004_mirimage_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386007001_04101_00005_mirimage_uncal.fits to ./miri_coro_demo_data/Obs007/uncal/jw01386007001_04101_00005_mirimage_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386007001_04101_00006_mirimage_uncal.fits to ./miri_coro_demo_data/Obs007/uncal/jw01386007001_04101_00006_mirimage_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386007001_04101_00007_mirimage_uncal.fits to ./miri_coro_demo_data/Obs007/uncal/jw01386007001_04101_00007_mirimage_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386007001_04101_00008_mirimage_uncal.fits to ./miri_coro_demo_data/Obs007/uncal/jw01386007001_04101_00008_mirimage_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386007001_04101_00009_mirimage_uncal.fits to ./miri_coro_demo_data/Obs007/uncal/jw01386007001_04101_00009_mirimage_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386030001_02101_00001_mirimage_uncal.fits to ./miri_coro_demo_data/Obs030/uncal/jw01386030001_02101_00001_mirimage_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386030001_03101_00001_mirimage_uncal.fits to ./miri_coro_demo_data/Obs030/uncal/jw01386030001_03101_00001_mirimage_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386031001_02101_00001_mirimage_uncal.fits to ./miri_coro_demo_data/Obs031/uncal/jw01386031001_02101_00001_mirimage_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386031001_03101_00001_mirimage_uncal.fits to ./miri_coro_demo_data/Obs031/uncal/jw01386031001_03101_00001_mirimage_uncal.fits ...
#  [Done]

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ## 4.-Directory Setup
# ------------------
# Set up detailed paths to input/output stages here. We will set up individual `stage1/` and `stage2/` sub directories for each observation, but a single `stage3/` directory for the combined [calwebb_coron3 output products](https://jwst-pipeline.readthedocs.io/en/stable/jwst/pipeline/calwebb_coron3.html).

# %%
# Define output subdirectories to keep science data products organized
# Sci Roll 1
uncal_sci_r1_dir = os.path.join(sci_r1_dir, 'uncal') # uncal inputs go here
det1_sci_r1_dir = os.path.join(sci_r1_dir, 'stage1')  # calwebb_detector1 pipeline outputs will go here
image2_sci_r1_dir = os.path.join(sci_r1_dir, 'stage2')  # calwebb_image2 pipeline outputs will go here

# Sci Roll 2
uncal_sci_r2_dir = os.path.join(sci_r2_dir, 'uncal') # uncal inputs go here
det1_sci_r2_dir = os.path.join(sci_r2_dir, 'stage1')  # calwebb_detector1 pipeline outputs will go here
image2_sci_r2_dir = os.path.join(sci_r2_dir, 'stage2')  # calwebb_image2 pipeline outputs will go here

# Define output subdirectories to keep PSF reference target data products organized
uncal_ref_targ_dir = os.path.join(ref_targ_dir, 'uncal') # uncal inputs go here
det1_ref_targ_dir = os.path.join(ref_targ_dir, 'stage1')  # calwebb_detector1 pipeline outputs will go here
image2_ref_targ_dir = os.path.join(ref_targ_dir, 'stage2')  # calwebb_image2 pipeline outputs will go here

# Define output subdirectories to keep background data products organized
# Sci Bkg
uncal_bg_sci_dir = os.path.join(bg_sci_dir, 'uncal') # uncal inputs go here
det1_bg_sci_dir = os.path.join(bg_sci_dir, 'stage1')  # calwebb_detector1 pipeline outputs will go here
image2_bg_sci_dir = os.path.join(bg_sci_dir, 'stage2')  # calwebb_image2 pipeline outputs will go here

# Ref target Bkg
uncal_bg_ref_targ_dir = os.path.join(bg_ref_targ_dir, 'uncal') # uncal inputs go here
det1_bg_ref_targ_dir = os.path.join(bg_ref_targ_dir, 'stage1')  # calwebb_detector1 pipeline outputs will go here
image2_bg_ref_targ_dir = os.path.join(bg_ref_targ_dir, 'stage2')  # calwebb_image2 pipeline outputs will go here

coron3_dir = os.path.join(basedir, 'stage3')
coron3_psflib_dir = os.path.join(basedir, 'stage3_psflib/') # calwebb_coron3 pipeline outputs using the PSF library will go here

# We need to check that the desired output directories exist, and if not create them
det1_dirs = [det1_sci_r1_dir, det1_sci_r2_dir, det1_ref_targ_dir, det1_bg_sci_dir, det1_bg_ref_targ_dir]
image2_dirs = [image2_sci_r1_dir, image2_sci_r2_dir, image2_ref_targ_dir, image2_bg_sci_dir, image2_bg_ref_targ_dir]

for dir in det1_dirs:
    if not os.path.exists(dir):
        os.makedirs(dir)
for dir in image2_dirs:
    if not os.path.exists(dir):
        os.makedirs(dir)
if not os.path.exists(coron3_dir):
    os.makedirs(coron3_dir)
if not os.path.exists(coron3_psflib_dir):
    os.makedirs(coron3_psflib_dir)

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
# Out:
# Runtime so far: 104.7396 seconds

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ## 5.-Detector1 Pipeline
# ------------------
# In this section, we process our uncalibrated data through the calwebb_detector1 pipeline to create Stage 1 data products. For coronagraphic exposures, these data products include a `*_rate.fits` file (a 2D countrate product, based on averaging over all integrations in the exposure), but specifically also a `*_rateints.fits` file, a 3D countrate product, that contains the individual results of each integration, wherein 2D countrate images for each integration are stacked along the 3rd axis of the data cubes (ncols x nrows x nints). These data products have units of DN/s.
#
# See https://jwst-docs.stsci.edu/jwst-science-calibration-pipeline/stages-of-jwst-data-processing/calwebb_detector1
#
# By default, all steps in the calwebb_detector1 are run for MIRI except: the [ipc](https://jwst-pipeline.readthedocs.io/en/stable/jwst/ipc/index.html#ipc-step) and [charge_migration](https://jwst-pipeline.readthedocs.io/en/stable/jwst/charge_migration/index.html#charge-migration-step) steps. There are also several steps performed for MIRI data that are not performed for other instruments. These include: [emicorr](https://jwst-pipeline.readthedocs.io/en/latest/jwst/emicorr/index.html#emicorr-step), [firstframe](https://jwst-pipeline.readthedocs.io/en/latest/jwst/firstframe/index.html#firstframe-step), [lastframe](https://jwst-pipeline.readthedocs.io/en/latest/jwst/lastframe/index.html#lastframe-step), [reset](https://jwst-pipeline.readthedocs.io/en/latest/jwst/reset/index.html#reset-step) and [rscd](https://jwst-pipeline.readthedocs.io/en/latest/jwst/rscd/index.html#rscd-step).

# %% [markdown]
# <div class="alert alert-block alert-warning">
# To override certain steps and reference files, use the examples provided below.<br>
# E.g., turn on detection of cosmic ray showers.
# </div>

# %%
# Set up a dictionary to define how the Detector1 pipeline should be configured

# Boilerplate dictionary setup
det1dict = defaultdict(dict)

# Overrides for whether or not certain steps should be skipped (example)
# skipping refpix step
#det1dict['refpix']['skip'] = True

# Overrides for various reference files
# Files should be in the base local directory or provide full path
#det1dict['dq_init']['override_mask'] = 'myfile.fits' # Bad pixel mask
#det1dict['saturation']['override_saturation'] = 'myfile.fits'  # Saturation
#det1dict['reset']['override_reset'] = 'myfile.fits'  # Reset
#det1dict['linearity']['override_linearity'] = 'myfile.fits'  # Linearity
#det1dict['rscd']['override_rscd'] = 'myfile.fits'  # RSCD
#det1dict['dark_current']['override_dark'] = 'myfile.fits'  # Dark current subtraction
#det1dict['jump']['override_gain'] = 'myfile.fits'  # Gain used by jump step
#det1dict['ramp_fit']['override_gain'] = 'myfile.fits'  # Gain used by ramp fitting step
#det1dict['jump']['override_readnoise'] = 'myfile.fits'  # Read noise used by jump step
#det1dict['ramp_fit']['override_readnoise'] = 'myfile.fits'  # Read noise used by ramp fitting step

# Turn on multi-core processing (off by default).  Choose what fraction of cores to use (quarter, half, or all)
det1dict['jump']['maximum_cores'] = 'half' 

# Save the frame-averaged dark data created during the dark current subtraction step
#det1dict['dark_current']['dark_output'] = 'dark.fits'  # Frame-averaged dark 

# Turn on detection of cosmic ray showers (off by default)
#det1dict['jump']['find_showers'] = True

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Below an example of how to insert custom pipeline steps using the
# pre-hook/post-hook framework.
#
# For more information see [Tips and Trick for working with the JWST Pipeline](https://jwst-docs.stsci.edu/jwst-science-calibration-pipeline/tips-and-tricks-for-working-with-the-jwst-pipeline)
#     </div>

# %%
# Define a new step called XplyStep that multiplies everything by 1.0
# I.e., it does nothing, but could be changed to do something more interesting.
class XplyStep(Step):
    spec = '''
    '''
    class_alias = 'xply'

    def process(self, input_data):
        with datamodels.open(input_data) as model:
            result = model.copy()
        sci = result.data
        sci = sci * 1.0
        result.data = sci
        self.log.info('Multiplied everything by one in custom step!')
        return result


# And here we'll insert it into our pipeline dictionary to be run at the end right after the gain_scale step
det1dict['gain_scale']['post_hooks'] = [XplyStep]

# %%
# Let's also define a pre-hook for the ramp_fit step that sets the left, right, bottom, and top edges to DO_NOT_USE.
class EdgeMaskStep(Step):
    spec = '''
    '''
    class_alias = 'edgemask'

    def process(self, input_data):
        with datamodels.open(input_data) as model:
            result = model.copy()

        # For ramp_fit we want to flag groups as unusable, so operate on the 3-D
        # GROUPDQ array: (nint, ngroup, ny, nx)
        gdq = result.groupdq

        do_not_use = 2**0  # DQ flag bit 0
        mod = 50
        # Set left and right edges to DO_NOT_USE (all ints, all groups)
        gdq[:, :, :, 0:13+mod] = gdq[:, :, :, 0:13+mod] | do_not_use  # Left edge
        gdq[:, :, :, -60-mod:] = gdq[:, :, :, -60-mod:] | do_not_use  # Right edge

        # Set bottom and top edges to DO_NOT_USE
        gdq[:, :, 0:7+mod, :] = gdq[:, :, 0:7+mod, :] | do_not_use  # Bottom edge
        gdq[:, :, -7-mod:, :] = gdq[:, :, -7-mod:, :] | do_not_use  # Top edge

        result.groupdq = gdq
        self.log.info('Set the edges to DO_NOT_USE in custom pre-hook (GROUPDQ)!')
        return result

# det1dict['ramp_fit']['pre_hooks'] = [EdgeMaskStep]

# %% [markdown]
# ### Calibrating Science Files
# Look for input science files and run calwebb_detector1 pipeline using the call method. For the demo example there should be 2 input science files, one for the observation at roll 1 (Obs 8) and one for the observation at roll 2 (Obs 9).

# %%
uncal_sci_r1_dir
# Out:
# './miri_coro_demo_data/Obs008/uncal'

# %%
# Look for input files of the form *uncal.fits from the science observation
sstring1 = os.path.join(uncal_sci_r1_dir, 'jw*mirimage*uncal.fits')
sstring2 = os.path.join(uncal_sci_r2_dir, 'jw*mirimage*uncal.fits')

uncal_sci_r1_files = sorted(glob.glob(sstring1))
uncal_sci_r2_files = sorted(glob.glob(sstring2))

# Check that these are the correct mask/filter to use
uncal_sci_r1_files = select_mask_filter_files(uncal_sci_r1_files, use_mask, use_filter)
uncal_sci_r2_files = select_mask_filter_files(uncal_sci_r2_files, use_mask, use_filter)

print('Found ' + str((len(uncal_sci_r1_files) + len(uncal_sci_r2_files))) + ' science input files')
# Out:
# Found 2 science input files

# %%
# Run the pipeline on these input files by a simple loop over files using
# our custom parameter dictionary
if dodet1:
    for file in uncal_sci_r1_files:
        Detector1Pipeline.call(file, steps=det1dict, save_results=True, output_dir=det1_sci_r1_dir)

    for file in uncal_sci_r2_files:
        Detector1Pipeline.call(file, steps=det1dict, save_results=True, output_dir=det1_sci_r2_dir)
else:
    print('Skipping Detector1 processing for SCI data')
# Out:
# 2026-04-15 18:02:19,557 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_system_datalvl_0002.rmap      694 bytes  (1 / 224 files) (0 / 796.2 K bytes)
# 2026-04-15 18:02:19,640 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_system_calver_0069.rmap    5.8 K bytes  (2 / 224 files) (694 / 796.2 K bytes)
# 2026-04-15 18:02:19,745 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_system_0064.imap        385 bytes  (3 / 224 files) (6.5 K / 796.2 K bytes)
# 2026-04-15 18:02:19,806 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec
- CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_linearity_0015.rmap      925 bytes  (214 / 224 files) (775.0 K / 796.2 K bytes)
# 2026-04-15 18:02:29,557 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_ipc_0003.rmap       614 bytes  (215 / 224 files) (775.9 K / 796.2 K bytes)
# 2026-04-15 18:02:29,601 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_gain_0010.rmap      890 bytes  (216 / 224 files) (776.5 K / 796.2 K bytes)
# 2026-04-15 18:02:29,642 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_flat_0009.rmap    1.1 K bytes  (217 / 224 files) (777.4 K / 796.2 K bytes)
# 2026-04-15 18:02:29,688 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_distortion_0011.rmap    1.2 K bytes  (218 / 224 files) (778.6 K / 796.2 K bytes)
# 2026-04-15 18:02:29,728 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_dark_0017.rmap    4.3 K bytes  (219 / 224 files) (779.8 K / 796.2 K bytes)
# 2026-04-15 18:02:29,768 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_area_0010.rmap    1.2 K bytes  (220 / 224 files) (784.1 K / 796.2 K bytes)
# 2026-04-15 18:02:29,813 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_apcorr_0004.rmap    4.0 K bytes  (221 / 224 files) (785.2 K / 796.2 K bytes)
# 2026-04-15 18:02:29,853 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_abvegaoffset_0002.rmap    1.3 K bytes  (222 / 224 files) (789.2 K / 796.2 K bytes)
# 2026-04-15 18:02:29,896 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_0125.imap         5.1 K bytes  (223 / 224 files) (790.5 K / 796.2 K bytes)
# 2026-04-15 18:02:29,936 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_1535.pmap               580 bytes  (224 / 224 files) (795.6 K / 796.2 K bytes)
# 2026-04-15 18:02:30,571 - CRDS - INFO -  Fetching  /home/runner/crds/references/jwst/miri/jwst_miri_pars-emicorrstep_0003.asdf    1.0 K bytes  (1 / 1 files) (0 / 1.0 K bytes)
# 2026-04-15 18:02:30,611 - stpipe.step - INFO - PARS-EMICORRSTEP parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-emicorrstep_0003.asdf
# 2026-04-15 18:02:30,629 - CRDS - INFO -  Fetching  /home/runner/crds/references/jwst/miri/jwst_miri_pars-darkcurrentstep_0001.asdf      936 bytes  (1 / 1 files) (0 / 936 bytes)
# 2026-04-15 18:02:30,673 - stpipe.step - INFO - PARS-DARKCURRENTSTEP parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-darkcurrentstep_0001.asdf
# 2026-04-15 18:02:30,684 - CRDS - INFO -  Fetching  /home/runner/crds/references/jwst/miri/jwst_miri_pars-jumpstep_0004.asdf    1.9 K bytes  (1 / 1 files) (0 / 1.9 K bytes)
# 2026-04-15 18:02:30,725 - stpipe.step - INFO - PARS-JUMPSTEP parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-jumpstep_0004.asdf
# 2026-04-15 18:02:30,740 - CRDS - INFO -  Fetching  /home/runner/crds/references/jwst/miri/jwst_miri_pars-detector1pipeline_0008.asdf    1.7 K bytes  (1 / 1 files) (0 / 1.7 K bytes)
# 2026-04-15 18:02:30,782 - stpipe.pipeline - INFO - PARS-DETECTOR1PIPELINE parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-detector1pipeline_0008.asdf
# 2026-04-15 18:02:30,799 - stpipe.step - INFO - Detector1Pipeline instance created.
# 2026-04-15 18:02:30,800 - stpipe.step - INFO - GroupScaleStep instance created.
# 2026-04-15 18:02:30,800 - stpipe.step - INFO - DQInitStep instance created.
# 2026-04-15 18:02:30,801 - stpipe.step - INFO - EmiCorrStep instance created.
# 2026-04-15 18:02:30,802 - stpipe.step - INFO - SaturationStep instance created.
# 2026-04-15 18:02:30,803 - stpipe.step - INFO - IPCStep instance created.
# 2026-04-15 18:02:30,804 - stpipe.step - INFO - SuperBiasStep instance created.
# 2026-04-15 18:02:30,805 - stpipe.step - INFO - RefPixStep instance created.
# 2026-04-15 18:02:30,805 - stpipe.step - INFO - RscdStep instance created.
# 2026-04-15 18:02:30,806 - stpipe.step - INFO - FirstFrameStep instance created.
# 2026-04-15 18:02:30,807 - stpipe.step - INFO - LastFrameStep instance created.
# 2026-04-15 18:02:30,808 - stpipe.step - INFO - LinearityStep instance created.
# 2026-04-15 18:02:30,809 - stpipe.step - INFO - DarkCurrentStep instance created.
# 2026-04-15 18:02:30,809 - stpipe.step - INFO - ResetStep instance created.
# 2026-04-15 18:02:30,810 - stpipe.step - INFO - PersistenceStep instance created.
# 2026-04-15 18:02:30,811 - stpipe.step - INFO - ChargeMigrationStep instance created.
# 2026-04-15 18:02:30,812 - stpipe.step - INFO - JumpStep instance created.
# 2026-04-15 18:02:30,813 - stpipe.step - INFO - PictureFrameStep instance created.
# 2026-04-15 18:02:30,814 - stpipe.step - INFO - CleanFlickerNoiseStep instance created.
# 2026-04-15 18:02:30,815 - stpipe.step - INFO - RampFitStep instance created.
# 2026-04-15 18:02:30,815 - stpipe.step - INFO - GainScaleStep instance created.
# 2026-04-15 18:02:30,817 - stpipe.step - INFO - XplyStep instance created.
# 2026-04-15 18:02:30,947 - stpipe.step - INFO - Step Detector1Pipeline running with args (np.str_('/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs008/uncal/jw01386008001_04101_00001_mirimage_uncal.fits'),).
# 2026-04-15 18:02:30,968 - stpipe.step - INFO - Step Detector1Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./miri_coro_demo_data/Obs008/stage1
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_calibrated_ramp: False
#   steps:
#     group_scale:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dq_init:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       user_supplied_dq: None
#     emicorr:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: joint
#       nints_to_phase: None
#       nbins: None
#       scale_reference: True
#       onthefly_corr_freq: None
#       use_n_cycles: 3
#       fit_ints_separately: False
#       user_supplied_reffile: None
#       save_intermediate_results: False
#     saturation:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       n_pix_grow_sat: 1
#       use_readpatt: True
#     ipc:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     superbias:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     refpix:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       odd_even_columns: True
#       use_side_ref_pixels: True
#       side_smoothing_length: 11
#       side_gain: 1.0
#       odd_even_rows: True
#       ovr_corr_mitigation_ftr: 3.0
#       preserve_irs2_refpix: False
#       irs2_mean_subtraction: False
#       refpix_algorithm: median
#       sigreject: 4.0
#       gaussmooth: 1.0
#       halfwidth: 30
#     rscd:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     firstframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bright_use_group1: True
#     lastframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     linearity:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dark_current:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       dark_output: None
#       average_dark_current: 1.0
#     reset:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     persistence:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
# ...
# 2026-04-15 18:06:02,281 - stpipe.pipeline - INFO - Prefetch for READNOISE reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_readnoise_0085.fits'.
# 2026-04-15 18:06:02,281 - stpipe.pipeline - INFO - Prefetch for RESET reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_reset_0065.fits'.
# 2026-04-15 18:06:02,282 - stpipe.pipeline - INFO - Prefetch for RSCD reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_rscd_0022.fits'.
# 2026-04-15 18:06:02,282 - stpipe.pipeline - INFO - Prefetch for SATURATION reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_saturation_0034.fits'.
# 2026-04-15 18:06:02,283 - stpipe.pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2026-04-15 18:06:02,283 - stpipe.pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2026-04-15 18:06:02,284 - stpipe.pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2026-04-15 18:06:02,285 - jwst.pipeline.calwebb_detector1 - INFO - Starting calwebb_detector1 ...
# 2026-04-15 18:06:06,422 - stpipe.step - INFO - Step group_scale running with args (<RampModel(60, 250, 224, 288) from jw01386009001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:06:06,423 - jwst.group_scale.group_scale_step - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2026-04-15 18:06:06,424 - jwst.group_scale.group_scale_step - INFO - Step will be skipped
# 2026-04-15 18:06:06,426 - stpipe.step - INFO - Step group_scale done
# 2026-04-15 18:06:06,556 - stpipe.step - INFO - Step dq_init running with args (<RampModel(60, 250, 224, 288) from jw01386009001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:06:06,559 - jwst.dq_init.dq_init_step - INFO - Using MASK reference file /home/runner/crds/references/jwst/miri/jwst_miri_mask_0036.fits
# 2026-04-15 18:06:06,590 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:06:06,591 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:06:06,601 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:06:06,609 - jwst.dq_init.dq_initialization - INFO - Extracting mask subarray to match science data
# 2026-04-15 18:06:06,913 - stpipe.step - INFO - Step dq_init done
# 2026-04-15 18:06:07,052 - stpipe.step - INFO - Step emicorr running with args (<RampModel(60, 250, 224, 288) from jw01386009001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:06:07,055 - jwst.emicorr.emicorr_step - INFO - Using EMICORR reference file: /home/runner/crds/references/jwst/miri/jwst_miri_emicorr_0003.asdf
# 2026-04-15 18:06:07,070 - jwst.emicorr.emicorr - INFO - Using reference file to get subarray case.
# 2026-04-15 18:06:07,071 - jwst.emicorr.emicorr - INFO - With configuration: Subarray=MASK1550, Read_pattern=FASTR1, Detector=MIRIMAGE
# 2026-04-15 18:06:07,071 - jwst.emicorr.emicorr - INFO - Will correct data for the following 2 frequencies:
# 2026-04-15 18:06:07,072 - jwst.emicorr.emicorr - INFO -    ['Hz390', 'Hz10']
# 2026-04-15 18:06:07,073 - jwst.emicorr.emicorr - INFO - Running EMI fit with algorithm = 'joint'.
# 2026-04-15 18:07:21,049 - stpipe.step - INFO - Step emicorr done
# 2026-04-15 18:07:21,190 - stpipe.step - INFO - Step saturation running with args (<RampModel(60, 250, 224, 288) from jw01386009001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:07:21,194 - jwst.saturation.saturation_step - INFO - Using SATURATION reference file /home/runner/crds/references/jwst/miri/jwst_miri_saturation_0034.fits
# 2026-04-15 18:07:21,195 - jwst.saturation.saturation_step - INFO - Using SUPERBIAS reference file N/A
# 2026-04-15 18:07:21,228 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:07:21,229 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:07:21,239 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:07:21,246 - jwst.saturation.saturation - INFO - Extracting reference file subarray to match science data
# 2026-04-15 18:07:21,265 - jwst.saturation.saturation - INFO - Using read_pattern with nframes 1
# 2026-04-15 18:07:27,565 - stcal.saturation.saturation - INFO - Detected 672 saturated pixels
# 2026-04-15 18:07:27,732 - stcal.saturation.saturation - INFO - Detected 7 A/D floor pixels
# 2026-04-15 18:07:27,746 - stpipe.step - INFO - Step saturation done
# 2026-04-15 18:07:27,884 - stpipe.step - INFO - Step ipc running with args (<RampModel(60, 250, 224, 288) from jw01386009001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:07:27,885 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:07:28,013 - stpipe.step - INFO - Step firstframe running with args (<RampModel(60, 250, 224, 288) from jw01386009001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:07:28,014 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:07:28,138 - stpipe.step - INFO - Step lastframe running with args (<RampModel(60, 250, 224, 288) from jw01386009001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:07:28,140 - stpipe.step - INFO - Step lastframe done
# 2026-04-15 18:07:28,273 - stpipe.step - INFO - Step reset running with args (<RampModel(60, 250, 224, 288) from jw01386009001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:07:28,276 - jwst.reset.reset_step - INFO - Using RESET reference file /home/runner/crds/references/jwst/miri/jwst_miri_reset_0065.fits
# 2026-04-15 18:07:28,313 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:07:28,314 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:07:28,317 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:07:28,632 - stpipe.step - INFO - Step reset done
# 2026-04-15 18:07:28,771 - stpipe.step - INFO - Step linearity running with args (<RampModel(60, 250, 224, 288) from jw01386009001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:07:28,774 - jwst.linearity.linearity_step - INFO - Using Linearity reference file /home/runner/crds/references/jwst/miri/jwst_miri_linearity_0032.fits
# 2026-04-15 18:07:28,809 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:07:28,810 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:07:28,819 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:07:31,320 - stpipe.step - INFO - Step linearity done
# 2026-04-15 18:07:31,457 - stpipe.step - INFO - Step rscd running with args (<RampModel(60, 250, 224, 288) from jw01386009001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:07:31,460 - jwst.rscd.rscd_step - INFO - Using RSCD reference file /home/runner/crds/references/jwst/miri/jwst_miri_rscd_0022.fits
# 2026-04-15 18:07:31,476 - jwst.rscd.rscd_sub - INFO - # groups from RSCD reference file for int 1 to flag: 6
# 2026-04-15 18:07:31,476 - jwst.rscd.rscd_sub - INFO - # groups from RSCD reference file for int 2 and higher to flag: 3
# 2026-04-15 18:07:31,477 - jwst.rscd.rscd_sub - INFO -  There are 54 saturated pixels that require the number of rscd groups flagged to be lowered
# 2026-04-15 18:07:31,478 - jwst.rscd.rscd_sub - INFO - Flagged 54 pixels as FLUX_ESTIMATED due to RSCD back-off.
# 2026-04-15 18:07:31,488 - jwst.rscd.rscd_sub - INFO - Number of usable bright pixels with rscd flag groups not set to DO_NOT_USE: 54
# 2026-04-15 18:07:31,493 - jwst.rscd.rscd_sub - INFO -  There are 0 saturated pixels that require the number of rscd groups flagged to be lowered
# 2026-04-15 18:07:32,113 - jwst.rscd.rscd_sub - INFO - Number of usable bright pixels with rscd flag groups not set to DO_NOT_USE: 0
# 2026-04-15 18:07:32,117 - stpipe.step - INFO - Step rscd done
# 2026-04-15 18:07:32,259 - stpipe.step - INFO - Step dark_current running with args (<RampModel(60, 250, 224, 288) from jw01386009001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:07:32,262 - jwst.dark_current.dark_current_step - INFO - Using DARK reference file /home/runner/crds/references/jwst/miri/jwst_miri_dark_0098.fits
# 2026-04-15 18:07:32,389 - stdatamodels.dynamicdq - WARNING - Keyword UNDERSAMP does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:07:32,390 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:07:32,394 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:07:32,404 - jwst.dark_current.dark_current_step - INFO - Using Poisson noise from average dark current 1.0 e-/sec
# 2026-04-15 18:07:32,405 - stcal.dark_current.dark_sub - INFO - Science data nints=60, ngroups=250, nframes=1, groupgap=0
# 2026-04-15 18:07:32,406 - stcal.dark_current.dark_sub - INFO - Dark data nints=3, ngroups=500, nframes=1, groupgap=0
# 2026-04-15 18:07:33,330 - stpipe.step - INFO - Step dark_current done
# 2026-04-15 18:07:33,471 - stpipe.step - INFO - Step refpix running with args (<RampModel(60, 250, 224, 288) from jw01386009001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:07:33,472 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:07:33,611 - stpipe.step - INFO - Step charge_migration running with args (<RampModel(60, 250, 224, 288) from jw01386009001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:07:33,612 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:07:33,756 - stpipe.step - INFO - Step jump running with args (<RampModel(60, 250, 224, 288) from jw01386009001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:07:33,757 - jwst.jump.jump_step - INFO - CR rejection threshold = 4 sigma
# 2026-04-15 18:07:33,758 - jwst.jump.jump_step - INFO - Maximum cores to use = half
# 2026-04-15 18:07:33,760 - jwst.jump.jump_step - INFO - Using GAIN reference file: /home/runner/crds/references/jwst/miri/jwst_miri_gain_0032.fits
# 2026-04-15 18:07:33,763 - jwst.jump.jump_step - INFO - Using READNOISE reference file: /home/runner/crds/references/jwst/miri/jwst_miri_readnoise_0085.fits
# 2026-04-15 18:07:33,794 - jwst.jump.jump_step - INFO - Extracting gain subarray to match science data
# 2026-04-15 18:07:33,807 - jwst.jump.jump_step - INFO - Extracting readnoise subarray to match science data
# 2026-04-15 18:07:34,365 - stcal.jump.jump - INFO - Executing two-point difference method
# 2026-04-15 18:07:34,366 - stcal.jump.jump - INFO - Creating 4 processes for jump detection
# 2026-04-15 18:07:56,259 - stcal.jump.jump - INFO - Total elapsed time = 21.8937 sec
# 2026-04-15 18:07:56,427 - jwst.jump.jump_step - INFO - The execution time in seconds: 22.669699
# 2026-04-15 18:07:56,430 - stpipe.step - INFO - Step jump done
# 2026-04-15 18:07:56,575 - stpipe.step - INFO - Step picture_frame running with args (<RampModel(60, 250, 224, 288) from jw01386009001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:07:56,576 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:07:56,708 - stpipe.step - INFO - Step clean_flicker_noise running with args (<RampModel(60, 250, 224, 288) from jw01386009001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:07:56,709 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:07:56,843 - stpipe.step - INFO - Step ramp_fit running with args (<RampModel(60, 250, 224, 288) from jw01386009001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:07:56,848 - jwst.ramp_fitting.ramp_fit_step - INFO - Using READNOISE reference file: /home/runner/crds/references/jwst/miri/jwst_miri_readnoise_0085.fits
# 2026-04-15 18:07:56,849 - jwst.ramp_fitting.ramp_fit_step - INFO - Using GAIN reference file: /home/runner/crds/references/jwst/miri/jwst_miri_gain_0032.fits
# 2026-04-15 18:07:56,881 - jwst.ramp_fitting.ramp_fit_step - INFO - Extracting gain subarray to match science data
# 2026-04-15 18:07:56,895 - jwst.ramp_fitting.ramp_fit_step - INFO - Extracting readnoise subarray to match science data
# 2026-04-15 18:07:56,908 - jwst.ramp_fitting.ramp_fit_step - INFO - Using algorithm = OLS_C
# 2026-04-15 18:07:56,909 - jwst.ramp_fitting.ramp_fit_step - INFO - Using weighting = optimal
# 2026-04-15 18:07:58,686 - stcal.ramp_fitting.ols_fit - INFO - Number of multiprocessing slices: 1
# 2026-04-15 18:07:58,734 - stcal.ramp_fitting.ols_fit - INFO - Number of leading groups that are flagged as DO_NOT_USE: 3
# 2026-04-15 18:07:58,735 - stcal.ramp_fitting.ols_fit - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2026-04-15 18:09:15,421 - stcal.ramp_fitting.ols_fit - INFO - Ramp Fitting C Time: 76.68461203575134
# 2026-04-15 18:09:15,547 - stpipe.step - INFO - Step ramp_fit done
# 2026-04-15 18:09:15,710 - stpipe.step - INFO - Step gain_scale running with args (<ImageModel(224, 288) from jw01386009001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:09:15,713 - jwst.gain_scale.gain_scale_step - INFO - Using GAIN reference file: /home/runner/crds/references/jwst/miri/jwst_miri_gain_0032.fits
# 2026-04-15 18:09:15,731 - jwst.gain_scale.gain_scale_step - INFO - GAINFACT not found in gain reference file
# 2026-04-15 18:09:15,732 - jwst.gain_scale.gain_scale_step - INFO - Step will be skipped
# 2026-04-15 18:09:15,871 - stpipe.step - INFO - Step xply running with args (<ImageModel(224, 288) from jw01386009001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:09:15,889 - py.warnings - WARNING - /tmp/ipykernel_3146/3735983842.py:14: DeprecationWarning: The Step.log attribute is deprecated and will be removed in a future release. Please use a local logger, retrieved via logging.getLogger.
#   self.log.info('Multiplied everything by one in custom step!')
# 2026-04-15 18:09:15,890 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Multiplied everything by one in custom step!
# 2026-04-15 18:09:15,891 - stpipe.step - INFO - Step xply done
# 2026-04-15 18:09:15,894 - stpipe.step - INFO - Step gain_scale done
# 2026-04-15 18:09:16,040 - stpipe.step - INFO - Step gain_scale running with args (<CubeModel(60, 224, 288) from jw01386009001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:09:16,043 - jwst.gain_scale.gain_scale_step - INFO - Using GAIN reference file: /home/runner/crds/references/jwst/miri/jwst_miri_gain_0032.fits
# 2026-04-15 18:09:16,061 - jwst.gain_scale.gain_scale_step - INFO - GAINFACT not found in gain reference file
# 2026-04-15 18:09:16,062 - jwst.gain_scale.gain_scale_step - INFO - Step will be skipped
# 2026-04-15 18:09:16,200 - stpipe.step - INFO - Step xply running with args (<CubeModel(60, 224, 288) from jw01386009001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:09:16,226 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Multiplied everything by one in custom step!
# 2026-04-15 18:09:16,228 - stpipe.step - INFO - Step xply done
# 2026-04-15 18:09:16,231 - stpipe.step - INFO - Step gain_scale done
# 2026-04-15 18:09:16,313 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs009/stage1/jw01386009001_04101_00001_mirimage_rateints.fits
# 2026-04-15 18:09:16,314 - jwst.pipeline.calwebb_detector1 - INFO - ... ending calwebb_detector1
# 2026-04-15 18:09:16,315 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1535.pmap
# 2026-04-15 18:09:16,366 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs009/stage1/jw01386009001_04101_00001_mirimage_rate.fits
# 2026-04-15 18:09:16,367 - stpipe.step - INFO - Step Detector1Pipeline done
# 2026-04-15 18:09:16,368 - jwst.stpipe.core - INFO - Results used jwst version: 2.0.0

# %% [markdown]
# ### Calibrating PSF Reference Target Files
# Look for input PSF Reference Target files. For the demo example there should be 9 files in total, one for each exposure of the PSF reference target taken in the 9-point dither pattern.

# %%
# Now let's look for input files of the form *uncal.fits from the background
# observations
sstring = os.path.join(uncal_ref_targ_dir, 'jw*mirimage*uncal.fits')
uncal_ref_targ_files = sorted(glob.glob(sstring))

# Check that these are the band/channel to use
uncal_ref_targ_files = select_mask_filter_files(uncal_ref_targ_files, use_mask, use_filter)

print('Found ' + str(len(uncal_ref_targ_files)) + ' PSF reference input files')
# Out:
# Found 9 PSF reference input files

# %% [markdown]
# Runs calwebb_detector1 module on the reference target files using the same custom parameter dictionary.

# %%
# Run the pipeline on these input files by a simple loop over files using
# our custom parameter dictionary
if dodet1:
    for file in uncal_ref_targ_files:
        print(file)
        Detector1Pipeline.call(file, steps=det1dict, save_results=True, output_dir=det1_ref_targ_dir)
else:
    print('Skipping Detector1 processing for PSF reference data')
# Out:
# 2026-04-15 18:09:16,497 - stpipe.step - INFO - PARS-EMICORRSTEP parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-emicorrstep_0003.asdf
# 2026-04-15 18:09:16,513 - stpipe.step - INFO - PARS-DARKCURRENTSTEP parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-darkcurrentstep_0001.asdf
# 2026-04-15 18:09:16,523 - stpipe.step - INFO - PARS-JUMPSTEP parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-jumpstep_0004.asdf
# 2026-04-15 18:09:16,537 - stpipe.pipeline - INFO - PARS-DETECTOR1PIPELINE parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-detector1pipeline_0008.asdf
# 2026-04-15 18:09:16,553 - stpipe.step - INFO - Detector1Pipeline instance created.
# 2026-04-15 18:09:16,554 - stpipe.step - INFO - GroupScaleStep instance created.
# 2026-04-15 18:09:16,555 - stpipe.step - INFO - DQInitStep instance created.
# 2026-04-15 18:09:16,556 - stpipe.step - INFO - EmiCorrStep instance created.
# 2026-04-15 18:09:16,557 - stpipe.step - INFO - SaturationStep instance created.
# 2026-04-15 18:09:16,558 - stpipe.step - INFO - IPCStep instance created.
# 2026-04-15 18:09:16,559 - stpipe.step - INFO - SuperBiasStep instance created.
# 2026-04-15 18:09:16,560 - stpipe.step - INFO - RefPixStep instance created.
# 2026-04-15 18:09:16,561 - stpipe.step - INFO - RscdStep instance created.
# 2026-04-15 18:09:16,561 - stpipe.step - INFO - FirstFrameStep instance created.
# 2026-04-15 18:09:16,562 - stpipe.step - INFO - LastFrameStep instance created.
# 2026-04-15 18:09:16,563 - stpipe.step - INFO - LinearityStep instance created.
# 2026-04-15 18:09:16,564 - stpipe.step - INFO - DarkCurrentStep instance created.
# 2026-04-15 18:09:16,564 - stpipe.step - INFO - ResetStep instance created.
# 2026-04-15 18:09:16,566 - stpipe.step - INFO - PersistenceStep instance created.
# 2026-04-15 18:09:16,567 - stpipe.step - INFO - ChargeMigrationStep instance created.
# 2026-04-15 18:09:16,568 - stpipe.step - INFO - JumpStep instance created.
# 2026-04-15 18:09:16,569 - stpipe.step - INFO - PictureFrameStep instance created.
# 2026-04-15 18:09:16,570 - stpipe.step - INFO - CleanFlickerNoiseStep instance created.
# 2026-04-15 18:09:16,571 - stpipe.step - INFO - RampFitStep instance created.
# 2026-04-15 18:09:16,571 - stpipe.step - INFO - GainScaleStep instance created.
# 2026-04-15 18:09:16,572 - stpipe.step - INFO - XplyStep instance created.
# /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs007/uncal/jw01386007001_04101_00001_mirimage_uncal.fits
# 2026-04-15 18:09:16,713 - stpipe.step - INFO - Step Detector1Pipeline running with args (np.str_('/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs007/uncal/jw01386007001_04101_00001_mirimage_uncal.fits'),).
# 2026-04-15 18:09:16,734 - stpipe.step - INFO - Step Detector1Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./miri_coro_demo_data/Obs007/stage1
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_calibrated_ramp: False
#   steps:
#     group_scale:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dq_init:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       user_supplied_dq: None
#     emicorr:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: joint
#       nints_to_phase: None
#       nbins: None
#       scale_reference: True
#       onthefly_corr_freq: None
#       use_n_cycles: 3
#       fit_ints_separately: False
#       user_supplied_reffile: None
#       save_intermediate_results: False
#     saturation:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       n_pix_grow_sat: 1
#       use_readpatt: True
#     ipc:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     superbias:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     refpix:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       odd_even_columns: True
#       use_side_ref_pixels: True
#       side_smoothing_length: 11
#       side_gain: 1.0
#       odd_even_rows: True
#       ovr_corr_mitigation_ftr: 3.0
#       preserve_irs2_refpix: False
#       irs2_mean_subtraction: False
#       refpix_algorithm: median
#       sigreject: 4.0
#       gaussmooth: 1.0
#       halfwidth: 30
#     rscd:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     firstframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bright_use_group1: True
#     lastframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     linearity:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dark_current:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       dark_output: None
#       average_dark_current: 1.0
#     reset:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     persistence:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       input_trapsfilled: ''
#       flag_pers_cutoff: 40.0
#       save_persistence: False
#       save_trapsfilled: True
#       modify_input: False
#     charge_migration:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       signal_threshold: 25000.0
#     jump:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       rejection_threshold: 4.0
#       three_group_rejection_threshold: 6.0
#       four_group_rejection_threshold: 5.0
#       maximum_cores: half
#       flag_4_neighbors: True
#       max_jump_to_flag_neighbors: 1000
#       min_jump_to_flag_neighbors: 30
#       after_jump_flag_dn1: 500
#       after_jump_flag_time1: 15
#       after_jump_flag_dn2: 1000
#       after_jump_flag_time2: 3000
#       expand_large_events: False
#       min_sat_area: 1
#       min_jump_area: 0
#       expand_factor: 0
#       use_ellipses: False
#       sat_required_snowball: False
#       min_sat_radius_extend: 0.0
#       sat_expand: 0
#       edge_size: 0
#       mask_snowball_core_next_int: True
#       snowball_time_masked_next_int: 4000
#       find_showers: False
#       max_shower_amplitude: 4.0
#       extend_snr_threshold: 3.0
#       extend_min_area: 50
#       extend_inner_radius: 1
#       extend_outer_radius: 2.6
#       extend_ellipse_expand_ratio: 1.1
#       time_masked_after_shower: 30
#       min_diffs_single_pass: 10
#       max_extended_radius: 200
#       minimum_groups: 3
#       minimum_sigclip_groups: 100
#       only_use_ints: True
#     picture_frame:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       mask_science_regions: True
#       n_sigma: 2.0
#       save_mask: False
#       save_correction: False
#     clean_flicker_noise:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       autoparam: False
#       fit_method: median
#       fit_by_channel: False
#       background_method: median
#       background_box_size: None
#       mask_science_regions: False
#       apply_flat_field: False
#       n_sigma: 2.0
#       fit_histogram: False
#       single_mask: True
#       user_mask: None
#       save_mask: False
#       save_background: False
#       save_noise: False
#     ramp_fit:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: OLS_C
#       int_name: ''
#       save_opt: False
#       opt_name: ''
#       suppress_one_group: True
#       firstgroup: None
#       lastgroup: None
#       maximum_cores: '1'
#     gain_scale:
#       pre_hooks: []
#       post_hooks:
#       - !!python/name:__main__.XplyStep ''
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
# 2026-04-15 18:09:16,760 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386007001_04101_00001_mirimage_uncal.fits' reftypes = ['dark', 'emicorr', 'gain', 'linearity', 'mask', 'persat', 'readnoise', 'reset', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# 2026-04-15 18:09:16,763 - stpipe.pipeline - INFO - Prefetch for DARK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_dark_0098.fits'.
# 2026-04-15 18:09:16,764 - stpipe.pipeline - INFO - Prefetch for EMICORR reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_emicorr_0003.asdf'.
# 2026-04-15 18:09:16,764 - stpipe.pipeline - INFO - Prefetch for GAIN reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_gain_0032.fits'.
# 2026-04-15 18:09:16,765 - stpipe.pipeline - INFO - Prefetch for LINEARITY reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_linearity_0032.fits'.
# 2026-04-15 18:09:16,765 - stpipe.pipeline - INFO - Prefetch for MASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_mask_0036.fits'.
# 2026-04-15 18:09:16,766 - stpipe.pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2026-04-15 18:09:16,766 - stpipe.pipeline - INFO - Prefetch for READNOISE reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_readnoise_0085.fits'.
# 2026-04-15 18:09:16,767 - stpipe.pipeline - INFO - Prefetch for RESET reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_reset_0065.fits'.
# 2026-04-15 18:09:16,768 - stpipe.pipeline - INFO - Prefetch for RSCD reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_rscd_0022.fits'.
# 2026-04-15 18:09:16,769 - stpipe.pipeline - INFO - Prefetch for SATURATION reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_saturation_0034.fits'.
# 2026-04-15 18:09:16,769 - stpipe.pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2026-04-15 18:09:16,770 - stpipe.pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2026-04-15 18:09:16,770 - stpipe.pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2026-04-15 18:09:16,771 - jwst.pipeline.calwebb_detector1 - INFO - Starting calwebb_detector1 ...
# 2026-04-15 18:09:17,299 - stpipe.step - INFO - Step group_scale running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:09:17,300 - jwst.group_scale.group_scale_step - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2026-04-15 18:09:17,301 - jwst.group_scale.group_scale_step - INFO - Step will be skipped
# 2026-04-15 18:09:17,303 - stpipe.step - INFO - Step group_scale done
# 2026-04-15 18:09:17,435 - stpipe.step - INFO - Step dq_init running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:09:17,438 - jwst.dq_init.dq_init_step - INFO - Using MASK reference file /home/runner/crds/references/jwst/miri/jwst_miri_mask_0036.fits
# 2026-04-15 18:09:17,469 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:09:17,470 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:09:17,480 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:09:17,488 - jwst.dq_init.dq_initialization - INFO - Extracting mask subarray to match science data
# 2026-04-15 18:09:17,548 - stpipe.step - INFO - Step dq_init done
# 2026-04-15 18:09:17,688 - stpipe.step - INFO - Step emicorr running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:09:17,691 - jwst.emicorr.emicorr_step - INFO - Using EMICORR reference file: /home/runner/crds/references/jwst/miri/jwst_miri_emicorr_0003.asdf
# 2026-04-15 18:09:17,706 - jwst.emicorr.emicorr - INFO - Using reference file to get subarray case.
# 2026-04-15 18:09:17,707 - jwst.emicorr.emicorr - INFO - With configuration: Subarray=MASK1550, Read_pattern=FASTR1, Detector=MIRIMAGE
# 2026-04-15 18:09:17,707 - jwst.emicorr.emicorr - INFO - Will correct data for the following 2 frequencies:
# 2026-04-15 18:09:17,708 - jwst.emicorr.emicorr - INFO -    ['Hz390', 'Hz10']
# 2026-04-15 18:09:17,708 - jwst.emicorr.emicorr - INFO - Running EMI fit with algorithm = 'joint'.
# 2026-04-15 18:09:30,095 - stpipe.step - INFO - Step emicorr done
# 2026-04-15 18:09:30,237 - stpipe.step - INFO - Step saturation running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:09:30,241 - jwst.saturation.saturation_step - INFO - Using SATURATION reference file /home/runner/crds/references/jwst/miri/jwst_miri_saturation_0034.fits
# 2026-04-15 18:09:30,242 - jwst.saturation.saturation_step - INFO - Using SUPERBIAS reference file N/A
# 2026-04-15 18:09:30,276 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:09:30,277 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:09:30,286 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:09:30,293 - jwst.saturation.saturation - INFO - Extracting reference file subarray to match science data
# 2026-04-15 18:09:30,312 - jwst.saturation.saturation - INFO - Using read_pattern with nframes 1
# 2026-04-15 18:09:31,118 - stcal.saturation.saturation - INFO - Detected 672 saturated pixels
# 2026-04-15 18:09:31,140 - stcal.saturation.saturation - INFO - Detected 3 A/D floor pixels
# 2026-04-15 18:09:31,154 - stpipe.step - INFO - Step saturation done
# 2026-04-15 18:09:31,294 - stpipe.step - INFO - Step ipc running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:09:31,295 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:09:31,424 - stpipe.step - INFO - Step firstframe running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:09:31,425 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:09:31,560 - stpipe.step - INFO - Step lastframe running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:09:31,563 - stpipe.step - INFO - Step lastframe done
# 2026-04-15 18:09:31,700 - stpipe.step - INFO - Step reset running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:09:31,703 - jwst.reset.reset_step - INFO - Using RESET reference file /home/runner/crds/references/jwst/miri/jwst_miri_reset_0065.fits
# 2026-04-15 18:09:31,740 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:09:31,741 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:09:31,744 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:09:31,849 - stpipe.step - INFO - Step reset done
# 2026-04-15 18:09:31,993 - stpipe.step - INFO - Step linearity running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:09:31,996 - jwst.linearity.linearity_step - INFO - Using Linearity reference file /home/runner/crds/references/jwst/miri/jwst_miri_linearity_0032.fits
# 2026-04-15 18:09:32,031 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:09:32,032 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:09:32,041 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:09:32,390 - stpipe.step - INFO - Step linearity done
# 2026-04-15 18:09:32,532 - stpipe.step - INFO - Step rscd running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:09:32,535 - jwst.rscd.rscd_step - INFO - Using RSCD reference file /home/runner/crds/references/jwst/miri/jwst_miri_rscd_0022.fits
# 2026-04-15 18:09:32,551 - jwst.rscd.rscd_sub - INFO - # groups from RSCD reference file for int 1 to flag: 6
# 2026-04-15 18:09:32,552 - jwst.rscd.rscd_sub - INFO - # groups from RSCD reference file for int 2 and higher to flag: 3
# 2026-04-15 18:09:32,553 - jwst.rscd.rscd_sub - INFO -  There are 78 saturated pixels that require the number of rscd groups flagged to be lowered
# 2026-04-15 18:09:32,554 - jwst.rscd.rscd_sub - INFO - Flagged 78 pixels as FLUX_ESTIMATED due to RSCD back-off.
# 2026-04-15 18:09:32,559 - jwst.rscd.rscd_sub - INFO - Number of usable bright pixels with rscd flag groups not set to DO_NOT_USE: 78
# 2026-04-15 18:09:32,561 - jwst.rscd.rscd_sub - INFO -  There are 0 saturated pixels that require the number of rscd groups flagged to be lowered
# 2026-04-15 18:09:32,639 - jwst.rscd.rscd_sub - INFO - Number of usable bright pixels with rscd flag groups not set to DO_NOT_USE: 0
# 2026-04-15 18:09:32,642 - stpipe.step - INFO - Step rscd done
# 2026-04-15 18:09:32,786 - stpipe.step - INFO - Step dark_current running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:09:32,790 - jwst.dark_current.dark_current_step - INFO - Using DARK reference file /home/runner/crds/references/jwst/miri/jwst_miri_dark_0098.fits
# 2026-04-15 18:09:32,917 - stdatamodels.dynamicdq - WARNING - Keyword UNDERSAMP does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:09:32,918 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:09:32,921 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:09:32,932 - jwst.dark_current.dark_current_step - INFO - Using Poisson noise from average dark current 1.0 e-/sec
# 2026-04-15 18:09:32,933 - stcal.dark_current.dark_sub - INFO - Science data nints=19, ngroups=100, nframes=1, groupgap=0
# 2026-04-15 18:09:32,933 - stcal.dark_current.dark_sub - INFO - Dark data nints=3, ngroups=500, nframes=1, groupgap=0
# 2026-04-15 18:09:33,102 - stpipe.step - INFO - Step dark_current done
# 2026-04-15 18:09:33,243 - stpipe.step - INFO - Step refpix running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:09:33,244 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:09:33,373 - stpipe.step - INFO - Step charge_migration running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:09:33,374 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:09:33,504 - stpipe.step - INFO - Step jump running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:09:33,505 - jwst.jump.jump_step - INFO - CR rejection threshold = 4 sigma
# 2026-04-15 18:09:33,506 - jwst.jump.jump_step - INFO - Maximum cores to use = half
# 2026-04-15 18:09:33,509 - jwst.jump.jump_step - INFO - Using GAIN reference file: /home/runner/crds/references/jwst/miri/jwst_miri_gain_0032.fits
# 2026-04-15 18:09:33,511 - jwst.jump.jump_step - INFO - Using READNOISE reference file: /home/runner/crds/references/jwst/miri/jwst_miri_readnoise_0085.fits
# 2026-04-15 18:09:33,543 - jwst.jump.jump_step - INFO - Extracting gain subarray to match science data
# 2026-04-15 18:09:33,556 - jwst.jump.jump_step - INFO - Extracting readnoise subarray to match science data
# 2026-04-15 18:09:33,639 - stcal.jump.jump - INFO - Executing two-point difference method
# 2026-04-15 18:09:33,640 - stcal.jump.jump - INFO - Creating 4 processes for jump detection
# 2026-04-15 18:09:36,854 - stcal.jump.jump - INFO - Total elapsed time = 3.21346 sec
# 2026-04-15 18:09:36,886 - jwst.jump.jump_step - INFO - The execution time in seconds: 3.380642
# 2026-04-15 18:09:36,889 - stpipe.step - INFO - Step jump done
# 2026-04-15 18:09:37,028 - stpipe.step - INFO - Step picture_frame running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:09:37,029 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:09:37,165 - stpipe.step - INFO - Step clean_flicker_noise running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:09:37,166 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:09:37,298 - stpipe.step - INFO - Step ramp_fit running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:09:37,303 - jwst.ramp_fitting.ramp_fit_step - INFO - Using READNOISE reference file: /home/runner/crds/references/jwst/miri/jwst_miri_readnoise_0085.fits
# 2026-04-15 18:09:37,304 - jwst.ramp_fitting.ramp_fit_step - INFO - Using GAIN reference file: /home/runner/crds/references/jwst/miri/jwst_miri_gain_0032.fits
# 2026-04-15 18:09:37,335 - jwst.ramp_fitting.ramp_fit_step - INFO - Extracting gain subarray to match science data
# 2026-04-15 18:09:37,349 - jwst.ramp_fitting.ramp_fit_step - INFO - Extracting readnoise subarray to match science data
# 2026-04-15 18:09:37,362 - jwst.ramp_fitting.ramp_fit_step - INFO - Using algorithm = OLS_C
# 2026-04-15 18:09:37,363 - jwst.ramp_fitting.ramp_fit_step - INFO - Using weighting = optimal
# 2026-04-15 18:09:37,582 - stcal.ramp_fitting.ols_fit - INFO - Number of multiprocessing slices: 1
# 2026-04-15 18:09:37,593 - stcal.ramp_fitting.ols_fit - INFO - Number of leading groups that are flagged as DO_NOT_USE: 2
# 2026-04-15 18:09:37,594 - stcal.ramp_fitting.ols_fit - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2026-04-15 18:09:45,406 - stcal.ramp_fitting.ols_fit - INFO - Ramp Fitting C Time: 7.810795783996582
# 2026-04-15 18:09:45,526 - stpipe.step - INFO - Step ramp_fit done
# 2026-04-15 18:09:45,668 - stpipe.step - INFO - Step gain_scale running with args (<ImageModel(224, 288) from jw01386007001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:09:45,671 - jwst.gain_scale.gain_scale_step - INFO - Using GAIN reference file: /home/runner/crds/references/jwst/miri/jwst_miri_gain_0032.fits
# 2026-04-15 18:09:45,688 - jwst.gain_scale.gain_scale_step - INFO - GAINFACT not found in gain reference file
# 2026-04-15 18:09:45,689 - jwst.gain_scale.gain_scale_step - INFO - Step will be skipped
# 2026-04-15 18:09:45,830 - stpipe.step - INFO - Step xply running with args (<ImageModel(224, 288) from jw01386007001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:09:45,847 - py.warnings - WARNING - /tmp/ipykernel_3146/3735983842.py:14: DeprecationWarning: The Step.log attribute is deprecated and will be removed in a future release. Please use a local logger, retrieved via logging.getLogger.
#   self.log.info('Multiplied everything by one in custom step!')
# 2026-04-15 18:09:45,848 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Multiplied everything by one in custom step!
# 2026-04-15 18:09:45,850 - stpipe.step - INFO - Step xply done
# 2026-04-15 18:09:45,853 - stpipe.step - INFO - Step gain_scale done
# 2026-04-15 18:09:45,984 - stpipe.step - INFO - Step gain_scale running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:09:45,987 - jwst.gain_scale.gain_scale_step - INFO - Using GAIN reference file: /home/runner/crds/references/jwst/miri/jwst_miri_gain_0032.fits
# 2026-04-15 18:09:46,005 - jwst.gain_scale.gain_scale_step - INFO - GAINFACT not found in gain reference file
# 2026-04-15 18:09:46,006 - jwst.gain_scale.gain_scale_step - INFO - Step will be skipped
# 2026-04-15 18:09:46,144 - stpipe.step - INFO - Step xply running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:09:46,163 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Multiplied everything by one in custom step!
# 2026-04-15 18:09:46,164 - stpipe.step - INFO - Step xply done
# 2026-04-15 18:09:46,168 - stpipe.step - INFO - Step gain_scale done
# 2026-04-15 18:09:46,229 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs007/stage1/jw01386007001_04101_00001_mirimage_rateints.fits
# 2026-04-15 18:09:46,230 - jwst.pipeline.calwebb_detector1 - INFO - ... ending calwebb_detector1
# 2026-04-15 18:09:46,230 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1535.pmap
# 2026-04-15 18:09:46,279 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs007/stage1/jw01386007001_04101_00001_mirimage_rate.fits
# 2026-04-15 18:09:46,280 - stpipe.step - INFO - Step Detector1Pipeline done
# 2026-04-15 18:09:46,280 - jwst.stpipe.core - INFO - Results used jwst version: 2.0.0
# 2026-04-15 18:09:46,303 - stpipe.step - INFO - PARS-EMICORRSTEP parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-emicorrstep_0003.asdf
# 2026-04-15 18:09:46,318 - stpipe.step - INFO - PARS-DARKCURRENTSTEP parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-darkcurrentstep_0001.asdf
# 2026-04-15 18:09:46,329 - stpipe.step - INFO - PARS-JUMPSTEP parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-jumpstep_0004.asdf
# 2026-04-15 18:09:46,343 - stpipe.pipeline - INFO - PARS-DETECTOR1PIPELINE parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-detector1pipeline_0008.asdf
# 2026-04-15 18:09:46,359 - stpipe.step - INFO - Detector1Pipeline instance created.
# 2026-04-15 18:09:46,360 - stpipe.step - INFO - GroupScaleStep instance created.
# 2026-04-15 18:09:46,360 - stpipe.step - INFO - DQInitStep instance created.
# 2026-04-15 18:09:46,361 - stpipe.step - INFO - EmiCorrStep instance created.
# 2026-04-15 18:09:46,362 - stpipe.step - INFO - SaturationStep instance created.
# 2026-04-15 18:09:46,363 - stpipe.step - INFO - IPCStep instance created.
# 2026-04-15 18:09:46,364 - stpipe.step - INFO - SuperBiasStep instance created.
# 2026-04-15 18:09:46,365 - stpipe.step - INFO - RefPixStep instance created.
# 2026-04-15 18:09:46,365 - stpipe.step - INFO - RscdStep instance created.
# 2026-04-15 18:09:46,366 - stpipe.step - INFO - FirstFrameStep instance created.
# 2026-04-15 18:09:46,367 - stpipe.step - INFO - LastFrameStep instance created.
# 2026-04-15 18:09:46,368 - stpipe.step - INFO - LinearityStep instance created.
# 2026-04-15 18:09:46,368 - stpipe.step - INFO - DarkCurrentStep instance created.
# 2026-04-15 18:09:46,369 - stpipe.step - INFO - ResetStep instance created.
# 2026-04-15 18:09:46,370 - stpipe.step - INFO - PersistenceStep instance created.
# 2026-04-15 18:09:46,371 - stpipe.step - INFO - ChargeMigrationStep instance created.
# 2026-04-15 18:09:46,372 - stpipe.step - INFO - JumpStep instance created.
# 2026-04-15 18:09:46,373 - stpipe.step - INFO - PictureFrameStep instance created.
# 2026-04-15 18:09:46,374 - stpipe.step - INFO - CleanFlickerNoiseStep instance created.
# 2026-04-15 18:09:46,375 - stpipe.step - INFO - RampFitStep instance created.
# 2026-04-15 18:09:46,375 - stpipe.step - INFO - GainScaleStep instance created.
# 2026-04-15 18:09:46,376 - stpipe.step - INFO - XplyStep instance created.
# 2026-04-15 18:09:46,517 - stpipe.step - INFO - Step Detector1Pipeline running with args (np.str_('/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs007/uncal/jw01386007001_04101_00002_mirimage_uncal.fits'),).
# /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs007/uncal/jw01386007001_04101_00002_mirimage_uncal.fits
# 2026-04-15 18:09:46,538 - stpipe.step - INFO - Step Detector1Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./miri_coro_demo_data/Obs007/stage1
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_calibrated_ramp: False
#   steps:
#     group_scale:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dq_init:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       user_supplied_dq: None
#     emicorr:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: joint
#       nints_to_phase: None
#       nbins: None
#       scale_reference: True
#       onthefly_corr_freq: None
#       use_n_cycles: 3
#       fit_ints_separately: False
#       user_supplied_reffile: None
#       save_intermediate_results: False
#     saturation:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       n_pix_grow_sat: 1
#       use_readpatt: True
#     ipc:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     superbias:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     refpix:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       odd_even_columns: True
#       use_side_ref_pixels: True
#       side_smoothing_length: 11
#       side_gain: 1.0
#       odd_even_rows: True
#       ovr_corr_mitigation_ftr: 3.0
#       preserve_irs2_refpix: False
#       irs2_mean_subtraction: False
#       refpix_algorithm: median
#       sigreject: 4.0
#       gaussmooth: 1.0
#       halfwidth: 30
#     rscd:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     firstframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bright_use_group1: True
#     lastframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     linearity:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dark_current:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       dark_output: None
#       average_dark_current: 1.0
#     reset:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     persistence:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       input_trapsfilled: ''
#       flag_pers_cutoff: 40.0
#       save_persistence: False
#       save_trapsfilled: True
#       modify_input: False
#     charge_migration:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       signal_threshold: 25000.0
#     jump:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       rejection_threshold: 4.0
#       three_group_rejection_threshold: 6.0
#       four_group_rejection_threshold: 5.0
#       maximum_cores: half
#       flag_4_neighbors: True
#       max_jump_to_flag_neighbors: 1000
#       min_jump_to_flag_neighbors: 30
#       after_jump_flag_dn1: 500
#       after_jump_flag_time1: 15
#       after_jump_flag_dn2: 1000
#       after_jump_flag_time2: 3000
#       expand_large_events: False
#       min_sat_area: 1
#       min_jump_area: 0
#       expand_factor: 0
#       use_ellipses: False
#       sat_required_snowball: False
#       min_sat_radius_extend: 0.0
#       sat_expand: 0
#       edge_size: 0
#       mask_snowball_core_next_int: True
#       snowball_time_masked_next_int: 4000
#       find_showers: False
#       max_shower_amplitude: 4.0
#       extend_snr_threshold: 3.0
#       extend_min_area: 50
#       extend_inner_radius: 1
#       extend_outer_radius: 2.6
#       extend_ellipse_expand_ratio: 1.1
#       time_masked_after_shower: 30
#       min_diffs_single_pass: 10
#       max_extended_radius: 200
#       minimum_groups: 3
#       minimum_sigclip_groups: 100
#       only_use_ints: True
#     picture_frame:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       mask_science_regions: True
#       n_sigma: 2.0
#       save_mask: False
#       save_correction: False
#     clean_flicker_noise:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       autoparam: False
#       fit_method: median
#       fit_by_channel: False
#       background_method: median
#       background_box_size: None
#       mask_science_regions: False
#       apply_flat_field: False
#       n_sigma: 2.0
#       fit_histogram: False
#       single_mask: True
#       user_mask: None
#       save_mask: False
#       save_background: False
#       save_noise: False
#     ramp_fit:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: OLS_C
#       int_name: ''
#       save_opt: False
#       opt_name: ''
#       suppress_one_group: True
#       firstgroup: None
#       lastgroup: None
#       maximum_cores: '1'
#     gain_scale:
#       pre_hooks: []
#       post_hooks:
#       - !!python/name:__main__.XplyStep ''
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
# 2026-04-15 18:09:46,564 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386007001_04101_00002_mirimage_uncal.fits' reftypes = ['dark', 'emicorr', 'gain', 'linearity', 'mask', 'persat', 'readnoise', 'reset', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# 2026-04-15 18:09:46,567 - stpipe.pipeline - INFO - Prefetch for DARK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_dark_0098.fits'.
# 2026-04-15 18:09:46,567 - stpipe.pipeline - INFO - Prefetch for EMICORR reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_emicorr_0003.asdf'.
# 2026-04-15 18:09:46,568 - stpipe.pipeline - INFO - Prefetch for GAIN reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_gain_0032.fits'.
# 2026-04-15 18:09:46,568 - stpipe.pipeline - INFO - Prefetch for LINEARITY reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_linearity_0032.fits'.
# 2026-04-15 18:09:46,569 - stpipe.pipeline - INFO - Prefetch for MASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_mask_0036.fits'.
# 2026-04-15 18:09:46,569 - stpipe.pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2026-04-15 18:09:46,569 - stpipe.pipeline - INFO - Prefetch for READNOISE reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_readnoise_0085.fits'.
# 2026-04-15 18:09:46,570 - stpipe.pipeline - INFO - Prefetch for RESET reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_reset_0065.fits'.
# 2026-04-15 18:09:46,571 - stpipe.pipeline - INFO - Prefetch for RSCD reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_rscd_0022.fits'.
# 2026-04-15 18:09:46,571 - stpipe.pipeline - INFO - Prefetch for SATURATION reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_saturation_0034.fits'.
# 2026-04-15 18:09:46,572 - stpipe.pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2026-04-15 18:09:46,572 - stpipe.pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2026-04-15 18:09:46,573 - stpipe.pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2026-04-15 18:09:46,573 - jwst.pipeline.calwebb_detector1 - INFO - Starting calwebb_detector1 ...
# 2026-04-15 18:09:47,072 - stpipe.step - INFO - Step group_scale running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00002_mirimage_uncal.fits>,).
# 2026-04-15 18:09:47,073 - jwst.group_scale.group_scale_step - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2026-04-15 18:09:47,074 - jwst.group_scale.group_scale_step - INFO - Step will be skipped
# 2026-04-15 18:09:47,075 - stpipe.step - INFO - Step group_scale done
# 2026-04-15 18:09:47,213 - stpipe.step - INFO - Step dq_init running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00002_mirimage_uncal.fits>,).
# 2026-04-15 18:09:47,215 - jwst.dq_init.dq_init_step - INFO - Using MASK reference file /home/runner/crds/references/jwst/miri/jwst_miri_mask_0036.fits
# 2026-04-15 18:09:47,247 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:09:47,248 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:09:47,258 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:09:47,265 - jwst.dq_init.dq_initialization - INFO - Extracting mask subarray to match science data
# 2026-04-15 18:09:47,326 - stpipe.step - INFO - Step dq_init done
# 2026-04-15 18:09:47,465 - stpipe.step - INFO - Step emicorr running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00002_mirimage_uncal.fits>,).
# 2026-04-15 18:09:47,468 - jwst.emicorr.emicorr_step - INFO - Using EMICORR reference file: /home/runner/crds/references/jwst/miri/jwst_miri_emicorr_0003.asdf
# 2026-04-15 18:09:47,483 - jwst.emicorr.emicorr - INFO - Using reference file to get subarray case.
# 2026-04-15 18:09:47,484 - jwst.emicorr.emicorr - INFO - With configuration: Subarray=MASK1550, Read_pattern=FASTR1, Detector=MIRIMAGE
# 2026-04-15 18:09:47,485 - jwst.emicorr.emicorr - INFO - Will correct data for the following 2 frequencies:
# 2026-04-15 18:09:47,485 - jwst.emicorr.emicorr - INFO -    ['Hz390', 'Hz10']
# 2026-04-15 18:09:47,486 - jwst.emicorr.emicorr - INFO - Running EMI fit with algorithm = 'joint'.
# 2026-04-15 18:09:59,949 - stpipe.step - INFO - Step emicorr done
# 2026-04-15 18:10:00,096 - stpipe.step - INFO - Step saturation running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00002_mirimage_uncal.fits>,).
# 2026-04-15 18:10:00,100 - jwst.saturation.saturation_step - INFO - Using SATURATION reference file /home/runner/crds/references/jwst/miri/jwst_miri_saturation_0034.fits
# 2026-04-15 18:10:00,101 - jwst.saturation.saturation_step - INFO - Using SUPERBIAS reference file N/A
# 2026-04-15 18:10:00,134 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:10:00,135 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:10:00,144 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:10:00,151 - jwst.saturation.saturation - INFO - Extracting reference file subarray to match science data
# 2026-04-15 18:10:00,169 - jwst.saturation.saturation - INFO - Using read_pattern with nframes 1
# 2026-04-15 18:10:00,985 - stcal.saturation.saturation - INFO - Detected 663 saturated pixels
# 2026-04-15 18:10:01,008 - stcal.saturation.saturation - INFO - Detected 0 A/D floor pixels
# 2026-04-15 18:10:01,021 - stpipe.step - INFO - Step saturation done
# 2026-04-15 18:10:01,161 - stpipe.step - INFO - Step ipc running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00002_mirimage_uncal.fits>,).
# 2026-04-15 18:10:01,162 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:10:01,297 - stpipe.step - INFO - Step firstframe running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00002_mirimage_uncal.fits>,).
# 2026-04-15 18:10:01,298 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:10:01,433 - stpipe.step - INFO - Step lastframe running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00002_mirimage_uncal.fits>,).
# 2026-04-15 18:10:01,436 - stpipe.step - INFO - Step lastframe done
# 2026-04-15 18:10:01,570 - stpipe.step - INFO - Step reset running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00002_mirimage_uncal.fits>,).
# 2026-04-15 18:10:01,573 - jwst.reset.reset_step - INFO - Using RESET reference file /home/runner/crds/references/jwst/miri/jwst_miri_reset_0065.fits
# ...
# 2026-04-15 18:13:16,518 - stpipe.pipeline - INFO - Prefetch for READNOISE reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_readnoise_0085.fits'.
# 2026-04-15 18:13:16,519 - stpipe.pipeline - INFO - Prefetch for RESET reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_reset_0065.fits'.
# 2026-04-15 18:13:16,519 - stpipe.pipeline - INFO - Prefetch for RSCD reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_rscd_0022.fits'.
# 2026-04-15 18:13:16,519 - stpipe.pipeline - INFO - Prefetch for SATURATION reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_saturation_0034.fits'.
# 2026-04-15 18:13:16,520 - stpipe.pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2026-04-15 18:13:16,520 - stpipe.pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2026-04-15 18:13:16,521 - stpipe.pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2026-04-15 18:13:16,521 - jwst.pipeline.calwebb_detector1 - INFO - Starting calwebb_detector1 ...
# 2026-04-15 18:13:17,060 - stpipe.step - INFO - Step group_scale running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00009_mirimage_uncal.fits>,).
# 2026-04-15 18:13:17,061 - jwst.group_scale.group_scale_step - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2026-04-15 18:13:17,062 - jwst.group_scale.group_scale_step - INFO - Step will be skipped
# 2026-04-15 18:13:17,064 - stpipe.step - INFO - Step group_scale done
# 2026-04-15 18:13:17,203 - stpipe.step - INFO - Step dq_init running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00009_mirimage_uncal.fits>,).
# 2026-04-15 18:13:17,206 - jwst.dq_init.dq_init_step - INFO - Using MASK reference file /home/runner/crds/references/jwst/miri/jwst_miri_mask_0036.fits
# 2026-04-15 18:13:17,238 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:13:17,239 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:13:17,249 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:13:17,256 - jwst.dq_init.dq_initialization - INFO - Extracting mask subarray to match science data
# 2026-04-15 18:13:17,318 - stpipe.step - INFO - Step dq_init done
# 2026-04-15 18:13:17,463 - stpipe.step - INFO - Step emicorr running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00009_mirimage_uncal.fits>,).
# 2026-04-15 18:13:17,466 - jwst.emicorr.emicorr_step - INFO - Using EMICORR reference file: /home/runner/crds/references/jwst/miri/jwst_miri_emicorr_0003.asdf
# 2026-04-15 18:13:17,482 - jwst.emicorr.emicorr - INFO - Using reference file to get subarray case.
# 2026-04-15 18:13:17,482 - jwst.emicorr.emicorr - INFO - With configuration: Subarray=MASK1550, Read_pattern=FASTR1, Detector=MIRIMAGE
# 2026-04-15 18:13:17,483 - jwst.emicorr.emicorr - INFO - Will correct data for the following 2 frequencies:
# 2026-04-15 18:13:17,484 - jwst.emicorr.emicorr - INFO -    ['Hz390', 'Hz10']
# 2026-04-15 18:13:17,484 - jwst.emicorr.emicorr - INFO - Running EMI fit with algorithm = 'joint'.
# 2026-04-15 18:13:29,972 - stpipe.step - INFO - Step emicorr done
# 2026-04-15 18:13:30,121 - stpipe.step - INFO - Step saturation running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00009_mirimage_uncal.fits>,).
# 2026-04-15 18:13:30,125 - jwst.saturation.saturation_step - INFO - Using SATURATION reference file /home/runner/crds/references/jwst/miri/jwst_miri_saturation_0034.fits
# 2026-04-15 18:13:30,126 - jwst.saturation.saturation_step - INFO - Using SUPERBIAS reference file N/A
# 2026-04-15 18:13:30,159 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:13:30,160 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:13:30,169 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:13:30,176 - jwst.saturation.saturation - INFO - Extracting reference file subarray to match science data
# 2026-04-15 18:13:30,195 - jwst.saturation.saturation - INFO - Using read_pattern with nframes 1
# 2026-04-15 18:13:31,011 - stcal.saturation.saturation - INFO - Detected 648 saturated pixels
# 2026-04-15 18:13:31,033 - stcal.saturation.saturation - INFO - Detected 0 A/D floor pixels
# 2026-04-15 18:13:31,047 - stpipe.step - INFO - Step saturation done
# 2026-04-15 18:13:31,196 - stpipe.step - INFO - Step ipc running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00009_mirimage_uncal.fits>,).
# 2026-04-15 18:13:31,197 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:13:31,333 - stpipe.step - INFO - Step firstframe running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00009_mirimage_uncal.fits>,).
# 2026-04-15 18:13:31,334 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:13:31,472 - stpipe.step - INFO - Step lastframe running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00009_mirimage_uncal.fits>,).
# 2026-04-15 18:13:31,475 - stpipe.step - INFO - Step lastframe done
# 2026-04-15 18:13:31,604 - stpipe.step - INFO - Step reset running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00009_mirimage_uncal.fits>,).
# 2026-04-15 18:13:31,607 - jwst.reset.reset_step - INFO - Using RESET reference file /home/runner/crds/references/jwst/miri/jwst_miri_reset_0065.fits
# 2026-04-15 18:13:31,645 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:13:31,646 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:13:31,648 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:13:31,754 - stpipe.step - INFO - Step reset done
# 2026-04-15 18:13:31,895 - stpipe.step - INFO - Step linearity running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00009_mirimage_uncal.fits>,).
# 2026-04-15 18:13:31,898 - jwst.linearity.linearity_step - INFO - Using Linearity reference file /home/runner/crds/references/jwst/miri/jwst_miri_linearity_0032.fits
# 2026-04-15 18:13:31,933 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:13:31,934 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:13:31,942 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:13:32,301 - stpipe.step - INFO - Step linearity done
# 2026-04-15 18:13:32,446 - stpipe.step - INFO - Step rscd running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00009_mirimage_uncal.fits>,).
# 2026-04-15 18:13:32,449 - jwst.rscd.rscd_step - INFO - Using RSCD reference file /home/runner/crds/references/jwst/miri/jwst_miri_rscd_0022.fits
# 2026-04-15 18:13:32,465 - jwst.rscd.rscd_sub - INFO - # groups from RSCD reference file for int 1 to flag: 6
# 2026-04-15 18:13:32,466 - jwst.rscd.rscd_sub - INFO - # groups from RSCD reference file for int 2 and higher to flag: 3
# 2026-04-15 18:13:32,466 - jwst.rscd.rscd_sub - INFO -  There are 33 saturated pixels that require the number of rscd groups flagged to be lowered
# 2026-04-15 18:13:32,468 - jwst.rscd.rscd_sub - INFO - Flagged 33 pixels as FLUX_ESTIMATED due to RSCD back-off.
# 2026-04-15 18:13:32,472 - jwst.rscd.rscd_sub - INFO - Number of usable bright pixels with rscd flag groups not set to DO_NOT_USE: 33
# 2026-04-15 18:13:32,475 - jwst.rscd.rscd_sub - INFO -  There are 0 saturated pixels that require the number of rscd groups flagged to be lowered
# 2026-04-15 18:13:32,553 - jwst.rscd.rscd_sub - INFO - Number of usable bright pixels with rscd flag groups not set to DO_NOT_USE: 0
# 2026-04-15 18:13:32,557 - stpipe.step - INFO - Step rscd done
# 2026-04-15 18:13:32,702 - stpipe.step - INFO - Step dark_current running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00009_mirimage_uncal.fits>,).
# 2026-04-15 18:13:32,705 - jwst.dark_current.dark_current_step - INFO - Using DARK reference file /home/runner/crds/references/jwst/miri/jwst_miri_dark_0098.fits
# 2026-04-15 18:13:32,832 - stdatamodels.dynamicdq - WARNING - Keyword UNDERSAMP does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:13:32,833 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:13:32,836 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:13:32,847 - jwst.dark_current.dark_current_step - INFO - Using Poisson noise from average dark current 1.0 e-/sec
# 2026-04-15 18:13:32,848 - stcal.dark_current.dark_sub - INFO - Science data nints=19, ngroups=100, nframes=1, groupgap=0
# 2026-04-15 18:13:32,849 - stcal.dark_current.dark_sub - INFO - Dark data nints=3, ngroups=500, nframes=1, groupgap=0
# 2026-04-15 18:13:33,021 - stpipe.step - INFO - Step dark_current done
# 2026-04-15 18:13:33,166 - stpipe.step - INFO - Step refpix running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00009_mirimage_uncal.fits>,).
# 2026-04-15 18:13:33,167 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:13:33,301 - stpipe.step - INFO - Step charge_migration running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00009_mirimage_uncal.fits>,).
# 2026-04-15 18:13:33,302 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:13:33,437 - stpipe.step - INFO - Step jump running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00009_mirimage_uncal.fits>,).
# 2026-04-15 18:13:33,438 - jwst.jump.jump_step - INFO - CR rejection threshold = 4 sigma
# 2026-04-15 18:13:33,439 - jwst.jump.jump_step - INFO - Maximum cores to use = half
# 2026-04-15 18:13:33,442 - jwst.jump.jump_step - INFO - Using GAIN reference file: /home/runner/crds/references/jwst/miri/jwst_miri_gain_0032.fits
# 2026-04-15 18:13:33,445 - jwst.jump.jump_step - INFO - Using READNOISE reference file: /home/runner/crds/references/jwst/miri/jwst_miri_readnoise_0085.fits
# 2026-04-15 18:13:33,476 - jwst.jump.jump_step - INFO - Extracting gain subarray to match science data
# 2026-04-15 18:13:33,490 - jwst.jump.jump_step - INFO - Extracting readnoise subarray to match science data
# 2026-04-15 18:13:33,575 - stcal.jump.jump - INFO - Executing two-point difference method
# 2026-04-15 18:13:33,576 - stcal.jump.jump - INFO - Creating 4 processes for jump detection
# 2026-04-15 18:13:36,891 - stcal.jump.jump - INFO - Total elapsed time = 3.31546 sec
# 2026-04-15 18:13:36,923 - jwst.jump.jump_step - INFO - The execution time in seconds: 3.484874
# 2026-04-15 18:13:36,927 - stpipe.step - INFO - Step jump done
# 2026-04-15 18:13:37,069 - stpipe.step - INFO - Step picture_frame running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00009_mirimage_uncal.fits>,).
# 2026-04-15 18:13:37,070 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:13:37,215 - stpipe.step - INFO - Step clean_flicker_noise running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00009_mirimage_uncal.fits>,).
# 2026-04-15 18:13:37,216 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:13:37,349 - stpipe.step - INFO - Step ramp_fit running with args (<RampModel(19, 100, 224, 288) from jw01386007001_04101_00009_mirimage_uncal.fits>,).
# 2026-04-15 18:13:37,355 - jwst.ramp_fitting.ramp_fit_step - INFO - Using READNOISE reference file: /home/runner/crds/references/jwst/miri/jwst_miri_readnoise_0085.fits
# 2026-04-15 18:13:37,356 - jwst.ramp_fitting.ramp_fit_step - INFO - Using GAIN reference file: /home/runner/crds/references/jwst/miri/jwst_miri_gain_0032.fits
# 2026-04-15 18:13:37,388 - jwst.ramp_fitting.ramp_fit_step - INFO - Extracting gain subarray to match science data
# 2026-04-15 18:13:37,402 - jwst.ramp_fitting.ramp_fit_step - INFO - Extracting readnoise subarray to match science data
# 2026-04-15 18:13:37,415 - jwst.ramp_fitting.ramp_fit_step - INFO - Using algorithm = OLS_C
# 2026-04-15 18:13:37,416 - jwst.ramp_fitting.ramp_fit_step - INFO - Using weighting = optimal
# 2026-04-15 18:13:37,639 - stcal.ramp_fitting.ols_fit - INFO - Number of multiprocessing slices: 1
# 2026-04-15 18:13:37,650 - stcal.ramp_fitting.ols_fit - INFO - Number of leading groups that are flagged as DO_NOT_USE: 2
# 2026-04-15 18:13:37,651 - stcal.ramp_fitting.ols_fit - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2026-04-15 18:13:45,460 - stcal.ramp_fitting.ols_fit - INFO - Ramp Fitting C Time: 7.808351039886475
# 2026-04-15 18:13:45,581 - stpipe.step - INFO - Step ramp_fit done
# 2026-04-15 18:13:45,726 - stpipe.step - INFO - Step gain_scale running with args (<ImageModel(224, 288) from jw01386007001_04101_00009_mirimage_uncal.fits>,).
# 2026-04-15 18:13:45,729 - jwst.gain_scale.gain_scale_step - INFO - Using GAIN reference file: /home/runner/crds/references/jwst/miri/jwst_miri_gain_0032.fits
# 2026-04-15 18:13:45,746 - jwst.gain_scale.gain_scale_step - INFO - GAINFACT not found in gain reference file
# 2026-04-15 18:13:45,747 - jwst.gain_scale.gain_scale_step - INFO - Step will be skipped
# 2026-04-15 18:13:45,886 - stpipe.step - INFO - Step xply running with args (<ImageModel(224, 288) from jw01386007001_04101_00009_mirimage_uncal.fits>,).
# 2026-04-15 18:13:45,903 - py.warnings - WARNING - /tmp/ipykernel_3146/3735983842.py:14: DeprecationWarning: The Step.log attribute is deprecated and will be removed in a future release. Please use a local logger, retrieved via logging.getLogger.
#   self.log.info('Multiplied everything by one in custom step!')
# 2026-04-15 18:13:45,904 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Multiplied everything by one in custom step!
# 2026-04-15 18:13:45,906 - stpipe.step - INFO - Step xply done
# 2026-04-15 18:13:45,909 - stpipe.step - INFO - Step gain_scale done
# 2026-04-15 18:13:46,046 - stpipe.step - INFO - Step gain_scale running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00009_mirimage_uncal.fits>,).
# 2026-04-15 18:13:46,049 - jwst.gain_scale.gain_scale_step - INFO - Using GAIN reference file: /home/runner/crds/references/jwst/miri/jwst_miri_gain_0032.fits
# 2026-04-15 18:13:46,067 - jwst.gain_scale.gain_scale_step - INFO - GAINFACT not found in gain reference file
# 2026-04-15 18:13:46,068 - jwst.gain_scale.gain_scale_step - INFO - Step will be skipped
# 2026-04-15 18:13:46,211 - stpipe.step - INFO - Step xply running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00009_mirimage_uncal.fits>,).
# 2026-04-15 18:13:46,230 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Multiplied everything by one in custom step!
# 2026-04-15 18:13:46,232 - stpipe.step - INFO - Step xply done
# 2026-04-15 18:13:46,235 - stpipe.step - INFO - Step gain_scale done
# 2026-04-15 18:13:46,295 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs007/stage1/jw01386007001_04101_00009_mirimage_rateints.fits
# 2026-04-15 18:13:46,296 - jwst.pipeline.calwebb_detector1 - INFO - ... ending calwebb_detector1
# 2026-04-15 18:13:46,297 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1535.pmap
# 2026-04-15 18:13:46,346 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs007/stage1/jw01386007001_04101_00009_mirimage_rate.fits
# 2026-04-15 18:13:46,346 - stpipe.step - INFO - Step Detector1Pipeline done
# 2026-04-15 18:13:46,347 - jwst.stpipe.core - INFO - Results used jwst version: 2.0.0

# %% [markdown]
# ### Calibrating Background Files
# Look for input background files and run calwebb_detector1
# pipeline using the call method.
#
# For the demo example there should be 4 background files in total: two exposures of the background target associated with the science target (taken in the 2-point dither) and two exposures of the background target associated with the PSF reference target (taken in the 2-point dither).

# %%
# Look for input files of the form *uncal.fits from the background
# observations
sstring1 = os.path.join(uncal_bg_sci_dir, 'jw*mirimage*uncal.fits')
sstring2 = os.path.join(uncal_bg_ref_targ_dir, 'jw*mirimage*uncal.fits')

uncal_bg_sci_files = sorted(glob.glob(sstring1))
uncal_bg_ref_targ_files = sorted(glob.glob(sstring2))

# Check that these are the filter to use
uncal_bg_sci_files = select_mask_filter_files(uncal_bg_sci_files, use_mask, use_filter)
uncal_bg_ref_targ_files = select_mask_filter_files(uncal_bg_ref_targ_files, use_mask, use_filter)

print('Found ' + str((len(uncal_bg_sci_files) + len(uncal_bg_ref_targ_files))) + ' background input files')
# Out:
# Found 4 background input files

# %%
# Run the pipeline on these input files by a simple loop over files using
# our custom parameter dictionary
if dodet1bg:
    for file in uncal_bg_sci_files:
        Detector1Pipeline.call(file, steps=det1dict, save_results=True, output_dir=det1_bg_sci_dir)
    for file in uncal_bg_ref_targ_files:
        Detector1Pipeline.call(file, steps=det1dict, save_results=True, output_dir=det1_bg_ref_targ_dir)
else:
    print('Skipping Detector1 processing for BG data')
# Out:
# 2026-04-15 18:13:46,411 - stpipe.step - INFO - PARS-EMICORRSTEP parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-emicorrstep_0003.asdf
# 2026-04-15 18:13:46,426 - stpipe.step - INFO - PARS-DARKCURRENTSTEP parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-darkcurrentstep_0001.asdf
# 2026-04-15 18:13:46,437 - stpipe.step - INFO - PARS-JUMPSTEP parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-jumpstep_0004.asdf
# 2026-04-15 18:13:46,450 - stpipe.pipeline - INFO - PARS-DETECTOR1PIPELINE parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-detector1pipeline_0008.asdf
# 2026-04-15 18:13:46,467 - stpipe.step - INFO - Detector1Pipeline instance created.
# 2026-04-15 18:13:46,468 - stpipe.step - INFO - GroupScaleStep instance created.
# 2026-04-15 18:13:46,469 - stpipe.step - INFO - DQInitStep instance created.
# 2026-04-15 18:13:46,470 - stpipe.step - INFO - EmiCorrStep instance created.
# 2026-04-15 18:13:46,471 - stpipe.step - INFO - SaturationStep instance created.
# 2026-04-15 18:13:46,471 - stpipe.step - INFO - IPCStep instance created.
# 2026-04-15 18:13:46,472 - stpipe.step - INFO - SuperBiasStep instance created.
# 2026-04-15 18:13:46,473 - stpipe.step - INFO - RefPixStep instance created.
# 2026-04-15 18:13:46,474 - stpipe.step - INFO - RscdStep instance created.
# 2026-04-15 18:13:46,475 - stpipe.step - INFO - FirstFrameStep instance created.
# 2026-04-15 18:13:46,476 - stpipe.step - INFO - LastFrameStep instance created.
# 2026-04-15 18:13:46,476 - stpipe.step - INFO - LinearityStep instance created.
# 2026-04-15 18:13:46,477 - stpipe.step - INFO - DarkCurrentStep instance created.
# 2026-04-15 18:13:46,478 - stpipe.step - INFO - ResetStep instance created.
# 2026-04-15 18:13:46,479 - stpipe.step - INFO - PersistenceStep instance created.
# 2026-04-15 18:13:46,480 - stpipe.step - INFO - ChargeMigrationStep instance created.
# 2026-04-15 18:13:46,482 - stpipe.step - INFO - JumpStep instance created.
# 2026-04-15 18:13:46,482 - stpipe.step - INFO - PictureFrameStep instance created.
# 2026-04-15 18:13:46,484 - stpipe.step - INFO - CleanFlickerNoiseStep instance created.
# 2026-04-15 18:13:46,484 - stpipe.step - INFO - RampFitStep instance created.
# 2026-04-15 18:13:46,485 - stpipe.step - INFO - GainScaleStep instance created.
# 2026-04-15 18:13:46,486 - stpipe.step - INFO - XplyStep instance created.
# 2026-04-15 18:13:46,627 - stpipe.step - INFO - Step Detector1Pipeline running with args (np.str_('/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs030/uncal/jw01386030001_02101_00001_mirimage_uncal.fits'),).
# 2026-04-15 18:13:46,648 - stpipe.step - INFO - Step Detector1Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./miri_coro_demo_data/Obs030/stage1
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_calibrated_ramp: False
#   steps:
#     group_scale:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dq_init:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       user_supplied_dq: None
#     emicorr:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: joint
#       nints_to_phase: None
#       nbins: None
#       scale_reference: True
#       onthefly_corr_freq: None
#       use_n_cycles: 3
#       fit_ints_separately: False
#       user_supplied_reffile: None
#       save_intermediate_results: False
#     saturation:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       n_pix_grow_sat: 1
#       use_readpatt: True
#     ipc:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     superbias:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     refpix:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       odd_even_columns: True
#       use_side_ref_pixels: True
#       side_smoothing_length: 11
#       side_gain: 1.0
#       odd_even_rows: True
#       ovr_corr_mitigation_ftr: 3.0
#       preserve_irs2_refpix: False
#       irs2_mean_subtraction: False
#       refpix_algorithm: median
#       sigreject: 4.0
#       gaussmooth: 1.0
#       halfwidth: 30
#     rscd:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     firstframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bright_use_group1: True
#     lastframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     linearity:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dark_current:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       dark_output: None
#       average_dark_current: 1.0
#     reset:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     persistence:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       input_trapsfilled: ''
#       flag_pers_cutoff: 40.0
#       save_persistence: False
#       save_trapsfilled: True
#       modify_input: False
#     charge_migration:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       signal_threshold: 25000.0
#     jump:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       rejection_threshold: 4.0
#       three_group_rejection_threshold: 6.0
#       four_group_rejection_threshold: 5.0
#       maximum_cores: half
#       flag_4_neighbors: True
#       max_jump_to_flag_neighbors: 1000
#       min_jump_to_flag_neighbors: 30
#       after_jump_flag_dn1: 500
#       after_jump_flag_time1: 15
#       after_jump_flag_dn2: 1000
#       after_jump_flag_time2: 3000
#       expand_large_events: False
#       min_sat_area: 1
#       min_jump_area: 0
#       expand_factor: 0
#       use_ellipses: False
#       sat_required_snowball: False
#       min_sat_radius_extend: 0.0
#       sat_expand: 0
#       edge_size: 0
#       mask_snowball_core_next_int: True
#       snowball_time_masked_next_int: 4000
#       find_showers: False
#       max_shower_amplitude: 4.0
#       extend_snr_threshold: 3.0
#       extend_min_area: 50
#       extend_inner_radius: 1
#       extend_outer_radius: 2.6
#       extend_ellipse_expand_ratio: 1.1
#       time_masked_after_shower: 30
#       min_diffs_single_pass: 10
#       max_extended_radius: 200
#       minimum_groups: 3
#       minimum_sigclip_groups: 100
#       only_use_ints: True
#     picture_frame:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       mask_science_regions: True
#       n_sigma: 2.0
#       save_mask: False
#       save_correction: False
#     clean_flicker_noise:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       autoparam: False
#       fit_method: median
#       fit_by_channel: False
#       background_method: median
#       background_box_size: None
#       mask_science_regions: False
#       apply_flat_field: False
#       n_sigma: 2.0
#       fit_histogram: False
#       single_mask: True
#       user_mask: None
#       save_mask: False
#       save_background: False
#       save_noise: False
#     ramp_fit:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: OLS_C
#       int_name: ''
#       save_opt: False
#       opt_name: ''
#       suppress_one_group: True
#       firstgroup: None
#       lastgroup: None
#       maximum_cores: '1'
#     gain_scale:
#       pre_hooks: []
#       post_hooks:
#       - !!python/name:__main__.XplyStep ''
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
# 2026-04-15 18:13:46,674 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386030001_02101_00001_mirimage_uncal.fits' reftypes = ['dark', 'emicorr', 'gain', 'linearity', 'mask', 'persat', 'readnoise', 'reset', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# 2026-04-15 18:13:46,677 - stpipe.pipeline - INFO - Prefetch for DARK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_dark_0098.fits'.
# 2026-04-15 18:13:46,678 - stpipe.pipeline - INFO - Prefetch for EMICORR reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_emicorr_0003.asdf'.
# 2026-04-15 18:13:46,678 - stpipe.pipeline - INFO - Prefetch for GAIN reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_gain_0032.fits'.
# 2026-04-15 18:13:46,679 - stpipe.pipeline - INFO - Prefetch for LINEARITY reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_linearity_0032.fits'.
# 2026-04-15 18:13:46,679 - stpipe.pipeline - INFO - Prefetch for MASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_mask_0036.fits'.
# 2026-04-15 18:13:46,680 - stpipe.pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2026-04-15 18:13:46,681 - stpipe.pipeline - INFO - Prefetch for READNOISE reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_readnoise_0085.fits'.
# 2026-04-15 18:13:46,681 - stpipe.pipeline - INFO - Prefetch for RESET reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_reset_0065.fits'.
# 2026-04-15 18:13:46,682 - stpipe.pipeline - INFO - Prefetch for RSCD reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_rscd_0022.fits'.
# 2026-04-15 18:13:46,682 - stpipe.pipeline - INFO - Prefetch for SATURATION reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_saturation_0034.fits'.
# 2026-04-15 18:13:46,683 - stpipe.pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2026-04-15 18:13:46,683 - stpipe.pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2026-04-15 18:13:46,683 - stpipe.pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2026-04-15 18:13:46,684 - jwst.pipeline.calwebb_detector1 - INFO - Starting calwebb_detector1 ...
# 2026-04-15 18:13:50,799 - stpipe.step - INFO - Step group_scale running with args (<RampModel(60, 250, 224, 288) from jw01386030001_02101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:13:50,800 - jwst.group_scale.group_scale_step - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2026-04-15 18:13:50,801 - jwst.group_scale.group_scale_step - INFO - Step will be skipped
# 2026-04-15 18:13:50,803 - stpipe.step - INFO - Step group_scale done
# 2026-04-15 18:13:50,930 - stpipe.step - INFO - Step dq_init running with args (<RampModel(60, 250, 224, 288) from jw01386030001_02101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:13:50,933 - jwst.dq_init.dq_init_step - INFO - Using MASK reference file /home/runner/crds/references/jwst/miri/jwst_miri_mask_0036.fits
# 2026-04-15 18:13:50,965 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:13:50,966 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:13:50,976 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:13:50,984 - jwst.dq_init.dq_initialization - INFO - Extracting mask subarray to match science data
# 2026-04-15 18:13:51,288 - stpipe.step - INFO - Step dq_init done
# 2026-04-15 18:13:51,427 - stpipe.step - INFO - Step emicorr running with args (<RampModel(60, 250, 224, 288) from jw01386030001_02101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:13:51,430 - jwst.emicorr.emicorr_step - INFO - Using EMICORR reference file: /home/runner/crds/references/jwst/miri/jwst_miri_emicorr_0003.asdf
# 2026-04-15 18:13:51,446 - jwst.emicorr.emicorr - INFO - Using reference file to get subarray case.
# 2026-04-15 18:13:51,446 - jwst.emicorr.emicorr - INFO - With configuration: Subarray=MASK1550, Read_pattern=FASTR1, Detector=MIRIMAGE
# 2026-04-15 18:13:51,447 - jwst.emicorr.emicorr - INFO - Will correct data for the following 2 frequencies:
# 2026-04-15 18:13:51,447 - jwst.emicorr.emicorr - INFO -    ['Hz390', 'Hz10']
# 2026-04-15 18:13:51,448 - jwst.emicorr.emicorr - INFO - Running EMI fit with algorithm = 'joint'.
# 2026-04-15 18:15:05,251 - stpipe.step - INFO - Step emicorr done
# 2026-04-15 18:15:05,398 - stpipe.step - INFO - Step saturation running with args (<RampModel(60, 250, 224, 288) from jw01386030001_02101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:15:05,402 - jwst.saturation.saturation_step - INFO - Using SATURATION reference file /home/runner/crds/references/jwst/miri/jwst_miri_saturation_0034.fits
# 2026-04-15 18:15:05,402 - jwst.saturation.saturation_step - INFO - Using SUPERBIAS reference file N/A
# 2026-04-15 18:15:05,436 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:15:05,437 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:15:05,446 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:15:05,453 - jwst.saturation.saturation - INFO - Extracting reference file subarray to match science data
# 2026-04-15 18:15:05,473 - jwst.saturation.saturation - INFO - Using read_pattern with nframes 1
# 2026-04-15 18:15:11,747 - stcal.saturation.saturation - INFO - Detected 672 saturated pixels
# 2026-04-15 18:15:11,908 - stcal.saturation.saturation - INFO - Detected 4 A/D floor pixels
# 2026-04-15 18:15:11,921 - stpipe.step - INFO - Step saturation done
# 2026-04-15 18:15:12,062 - stpipe.step - INFO - Step ipc running with args (<RampModel(60, 250, 224, 288) from jw01386030001_02101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:15:12,062 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:15:12,193 - stpipe.step - INFO - Step firstframe running with args (<RampModel(60, 250, 224, 288) from jw01386030001_02101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:15:12,194 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:15:12,322 - stpipe.step - INFO - Step lastframe running with args (<RampModel(60, 250, 224, 288) from jw01386030001_02101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:15:12,325 - stpipe.step - INFO - Step lastframe done
# 2026-04-15 18:15:12,452 - stpipe.step - INFO - Step reset running with args (<RampModel(60, 250, 224, 288) from jw01386030001_02101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:15:12,454 - jwst.reset.reset_step - INFO - Using RESET reference file /home/runner/crds/references/jwst/miri/jwst_miri_reset_0065.fits
# 2026-04-15 18:15:12,492 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:15:12,493 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:15:12,495 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:15:12,809 - stpipe.step - INFO - Step reset done
# 2026-04-15 18:15:12,954 - stpipe.step - INFO - Step linearity running with args (<RampModel(60, 250, 224, 288) from jw01386030001_02101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:15:12,957 - jwst.linearity.linearity_step - INFO - Using Linearity reference file /home/runner/crds/references/jwst/miri/jwst_miri_linearity_0032.fits
# 2026-04-15 18:15:12,992 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:15:12,992 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:15:13,001 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:15:15,434 - stpipe.step - INFO - Step linearity done
# 2026-04-15 18:15:15,572 - stpipe.step - INFO - Step rscd running with args (<RampModel(60, 250, 224, 288) from jw01386030001_02101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:15:15,575 - jwst.rscd.rscd_step - INFO - Using RSCD reference file /home/runner/crds/references/jwst/miri/jwst_miri_rscd_0022.fits
# 2026-04-15 18:15:15,591 - jwst.rscd.rscd_sub - INFO - # groups from RSCD reference file for int 1 to flag: 6
# 2026-04-15 18:15:15,592 - jwst.rscd.rscd_sub - INFO - # groups from RSCD reference file for int 2 and higher to flag: 3
# 2026-04-15 18:15:15,593 - jwst.rscd.rscd_sub - INFO -  There are 63 saturated pixels that require the number of rscd groups flagged to be lowered
# 2026-04-15 18:15:15,594 - jwst.rscd.rscd_sub - INFO - Flagged 63 pixels as FLUX_ESTIMATED due to RSCD back-off.
# 2026-04-15 18:15:15,605 - jwst.rscd.rscd_sub - INFO - Number of usable bright pixels with rscd flag groups not set to DO_NOT_USE: 63
# 2026-04-15 18:15:15,609 - jwst.rscd.rscd_sub - INFO -  There are 0 saturated pixels that require the number of rscd groups flagged to be lowered
# 2026-04-15 18:15:16,222 - jwst.rscd.rscd_sub - INFO - Number of usable bright pixels with rscd flag groups not set to DO_NOT_USE: 0
# 2026-04-15 18:15:16,226 - stpipe.step - INFO - Step rscd done
# 2026-04-15 18:15:16,374 - stpipe.step - INFO - Step dark_current running with args (<RampModel(60, 250, 224, 288) from jw01386030001_02101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:15:16,378 - jwst.dark_current.dark_current_step - INFO - Using DARK reference file /home/runner/crds/references/jwst/miri/jwst_miri_dark_0098.fits
# 2026-04-15 18:15:16,504 - stdatamodels.dynamicdq - WARNING - Keyword UNDERSAMP does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:15:16,505 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:15:16,509 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:15:16,519 - jwst.dark_current.dark_current_step - INFO - Using Poisson noise from average dark current 1.0 e-/sec
# 2026-04-15 18:15:16,520 - stcal.dark_current.dark_sub - INFO - Science data nints=60, ngroups=250, nframes=1, groupgap=0
# 2026-04-15 18:15:16,521 - stcal.dark_current.dark_sub - INFO - Dark data nints=3, ngroups=500, nframes=1, groupgap=0
# 2026-04-15 18:15:17,436 - stpipe.step - INFO - Step dark_current done
# 2026-04-15 18:15:17,577 - stpipe.step - INFO - Step refpix running with args (<RampModel(60, 250, 224, 288) from jw01386030001_02101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:15:17,578 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:15:17,708 - stpipe.step - INFO - Step charge_migration running with args (<RampModel(60, 250, 224, 288) from jw01386030001_02101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:15:17,709 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:15:17,836 - stpipe.step - INFO - Step jump running with args (<RampModel(60, 250, 224, 288) from jw01386030001_02101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:15:17,837 - jwst.jump.jump_step - INFO - CR rejection threshold = 4 sigma
# 2026-04-15 18:15:17,838 - jwst.jump.jump_step - INFO - Maximum cores to use = half
# 2026-04-15 18:15:17,841 - jwst.jump.jump_step - INFO - Using GAIN reference file: /home/runner/crds/references/jwst/miri/jwst_miri_gain_0032.fits
# 2026-04-15 18:15:17,843 - jwst.jump.jump_step - INFO - Using READNOISE reference file: /home/runner/crds/references/jwst/miri/jwst_miri_readnoise_0085.fits
# 2026-04-15 18:15:17,875 - jwst.jump.jump_step - INFO - Extracting gain subarray to match science data
# 2026-04-15 18:15:17,888 - jwst.jump.jump_step - INFO - Extracting readnoise subarray to match science data
# 2026-04-15 18:15:18,428 - stcal.jump.jump - INFO - Executing two-point difference method
# 2026-04-15 18:15:18,429 - stcal.jump.jump - INFO - Creating 4 processes for jump detection
# 2026-04-15 18:15:40,280 - stcal.jump.jump - INFO - Total elapsed time = 21.8509 sec
# 2026-04-15 18:15:40,449 - jwst.jump.jump_step - INFO - The execution time in seconds: 22.612270
# 2026-04-15 18:15:40,453 - stpipe.step - INFO - Step jump done
# 2026-04-15 18:15:40,589 - stpipe.step - INFO - Step picture_frame running with args (<RampModel(60, 250, 224, 288) from jw01386030001_02101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:15:40,590 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:15:40,718 - stpipe.step - INFO - Step clean_flicker_noise running with args (<RampModel(60, 250, 224, 288) from jw01386030001_02101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:15:40,719 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:15:40,847 - stpipe.step - INFO - Step ramp_fit running with args (<RampModel(60, 250, 224, 288) from jw01386030001_02101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:15:40,852 - jwst.ramp_fitting.ramp_fit_step - INFO - Using READNOISE reference file: /home/runner/crds/references/jwst/miri/jwst_miri_readnoise_0085.fits
# 2026-04-15 18:15:40,853 - jwst.ramp_fitting.ramp_fit_step - INFO - Using GAIN reference file: /home/runner/crds/references/jwst/miri/jwst_miri_gain_0032.fits
# 2026-04-15 18:15:40,885 - jwst.ramp_fitting.ramp_fit_step - INFO - Extracting gain subarray to match science data
# 2026-04-15 18:15:40,898 - jwst.ramp_fitting.ramp_fit_step - INFO - Extracting readnoise subarray to match science data
# 2026-04-15 18:15:40,912 - jwst.ramp_fitting.ramp_fit_step - INFO - Using algorithm = OLS_C
# 2026-04-15 18:15:40,912 - jwst.ramp_fitting.ramp_fit_step - INFO - Using weighting = optimal
# 2026-04-15 18:15:42,661 - stcal.ramp_fitting.ols_fit - INFO - Number of multiprocessing slices: 1
# 2026-04-15 18:15:42,708 - stcal.ramp_fitting.ols_fit - INFO - Number of leading groups that are flagged as DO_NOT_USE: 3
# 2026-04-15 18:15:42,710 - stcal.ramp_fitting.ols_fit - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2026-04-15 18:16:58,173 - stcal.ramp_fitting.ols_fit - INFO - Ramp Fitting C Time: 75.46227169036865
# 2026-04-15 18:16:58,299 - stpipe.step - INFO - Step ramp_fit done
# 2026-04-15 18:16:58,462 - stpipe.step - INFO - Step gain_scale running with args (<ImageModel(224, 288) from jw01386030001_02101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:16:58,465 - jwst.gain_scale.gain_scale_step - INFO - Using GAIN reference file: /home/runner/crds/references/jwst/miri/jwst_miri_gain_0032.fits
# 2026-04-15 18:16:58,483 - jwst.gain_scale.gain_scale_step - INFO - GAINFACT not found in gain reference file
# 2026-04-15 18:16:58,483 - jwst.gain_scale.gain_scale_step - INFO - Step will be skipped
# 2026-04-15 18:16:58,611 - stpipe.step - INFO - Step xply running with args (<ImageModel(224, 288) from jw01386030001_02101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:16:58,629 - py.warnings - WARNING - /tmp/ipykernel_3146/3735983842.py:14: DeprecationWarning: The Step.log attribute is deprecated and will be removed in a future release. Please use a local logger, retrieved via logging.getLogger.
#   self.log.info('Multiplied everything by one in custom step!')
# 2026-04-15 18:16:58,630 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Multiplied everything by one in custom step!
# 2026-04-15 18:16:58,631 - stpipe.step - INFO - Step xply done
# 2026-04-15 18:16:58,634 - stpipe.step - INFO - Step gain_scale done
# 2026-04-15 18:16:58,763 - stpipe.step - INFO - Step gain_scale running with args (<CubeModel(60, 224, 288) from jw01386030001_02101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:16:58,766 - jwst.gain_scale.gain_scale_step - INFO - Using GAIN reference file: /home/runner/crds/references/jwst/miri/jwst_miri_gain_0032.fits
# 2026-04-15 18:16:58,784 - jwst.gain_scale.gain_scale_step - INFO - GAINFACT not found in gain reference file
# 2026-04-15 18:16:58,784 - jwst.gain_scale.gain_scale_step - INFO - Step will be skipped
# 2026-04-15 18:16:58,918 - stpipe.step - INFO - Step xply running with args (<CubeModel(60, 224, 288) from jw01386030001_02101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:16:58,945 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Multiplied everything by one in custom step!
# 2026-04-15 18:16:58,946 - stpipe.step - INFO - Step xply done
# 2026-04-15 18:16:58,949 - stpipe.step - INFO - Step gain_scale done
# 2026-04-15 18:16:59,032 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs030/stage1/jw01386030001_02101_00001_mirimage_rateints.fits
# 2026-04-15 18:16:59,033 - jwst.pipeline.calwebb_detector1 - INFO - ... ending calwebb_detector1
# 2026-04-15 18:16:59,034 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1535.pmap
# 2026-04-15 18:16:59,084 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs030/stage1/jw01386030001_02101_00001_mirimage_rate.fits
# 2026-04-15 18:16:59,085 - stpipe.step - INFO - Step Detector1Pipeline done
# 2026-04-15 18:16:59,085 - jwst.stpipe.core - INFO - Results used jwst version: 2.0.0
# 2026-04-15 18:16:59,109 - stpipe.step - INFO - PARS-EMICORRSTEP parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-emicorrstep_0003.asdf
# 2026-04-15 18:16:59,124 - stpipe.step - INFO - PARS-DARKCURRENTSTEP parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-darkcurrentstep_0001.asdf
# 2026-04-15 18:16:59,134 - stpipe.step - INFO - PARS-JUMPSTEP parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-jumpstep_0004.asdf
# 2026-04-15 18:16:59,147 - stpipe.pipeline - INFO - PARS-DETECTOR1PIPELINE parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-detector1pipeline_0008.asdf
# 2026-04-15 18:16:59,163 - stpipe.step - INFO - Detector1Pipeline instance created.
# 2026-04-15 18:16:59,164 - stpipe.step - INFO - GroupScaleStep instance created.
# 2026-04-15 18:16:59,165 - stpipe.step - INFO - DQInitStep instance created.
# 2026-04-15 18:16:59,166 - stpipe.step - INFO - EmiCorrStep instance created.
# 2026-04-15 18:16:59,167 - stpipe.step - INFO - SaturationStep instance created.
# 2026-04-15 18:16:59,168 - stpipe.step - INFO - IPCStep instance created.
# 2026-04-15 18:16:59,168 - stpipe.step - INFO - SuperBiasStep instance created.
# 2026-04-15 18:16:59,169 - stpipe.step - INFO - RefPixStep instance created.
# 2026-04-15 18:16:59,170 - stpipe.step - INFO - RscdStep instance created.
# 2026-04-15 18:16:59,171 - stpipe.step - INFO - FirstFrameStep instance created.
# 2026-04-15 18:16:59,171 - stpipe.step - INFO - LastFrameStep instance created.
# 2026-04-15 18:16:59,172 - stpipe.step - INFO - LinearityStep instance created.
# 2026-04-15 18:16:59,173 - stpipe.step - INFO - DarkCurrentStep instance created.
# 2026-04-15 18:16:59,173 - stpipe.step - INFO - ResetStep instance created.
# 2026-04-15 18:16:59,174 - stpipe.step - INFO - PersistenceStep instance created.
# 2026-04-15 18:16:59,175 - stpipe.step - INFO - ChargeMigrationStep instance created.
# 2026-04-15 18:16:59,176 - stpipe.step - INFO - JumpStep instance created.
# 2026-04-15 18:16:59,178 - stpipe.step - INFO - PictureFrameStep instance created.
# 2026-04-15 18:16:59,179 - stpipe.step - INFO - CleanFlickerNoiseStep instance created.
# 2026-04-15 18:16:59,179 - stpipe.step - INFO - RampFitStep instance created.
# 2026-04-15 18:16:59,180 - stpipe.step - INFO - GainScaleStep instance created.
# 2026-04-15 18:16:59,181 - stpipe.step - INFO - XplyStep instance created.
# 2026-04-15 18:16:59,321 - stpipe.step - INFO - Step Detector1Pipeline running with args (np.str_('/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs030/uncal/jw01386030001_03101_00001_mirimage_uncal.fits'),).
# 2026-04-15 18:16:59,342 - stpipe.step - INFO - Step Detector1Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./miri_coro_demo_data/Obs030/stage1
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_calibrated_ramp: False
#   steps:
#     group_scale:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dq_init:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       user_supplied_dq: None
#     emicorr:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: joint
#       nints_to_phase: None
#       nbins: None
#       scale_reference: True
#       onthefly_corr_freq: None
#       use_n_cycles: 3
#       fit_ints_separately: False
#       user_supplied_reffile: None
#       save_intermediate_results: False
#     saturation:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       n_pix_grow_sat: 1
#       use_readpatt: True
#     ipc:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     superbias:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     refpix:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       odd_even_columns: True
#       use_side_ref_pixels: True
#       side_smoothing_length: 11
#       side_gain: 1.0
#       odd_even_rows: True
#       ovr_corr_mitigation_ftr: 3.0
#       preserve_irs2_refpix: False
#       irs2_mean_subtraction: False
#       refpix_algorithm: median
#       sigreject: 4.0
#       gaussmooth: 1.0
#       halfwidth: 30
#     rscd:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     firstframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bright_use_group1: True
#     lastframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     linearity:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dark_current:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       dark_output: None
#       average_dark_current: 1.0
#     reset:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     persistence:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       input_trapsfilled: ''
#       flag_pers_cutoff: 40.0
#       save_persistence: False
#       save_trapsfilled: True
#       modify_input: False
#     charge_migration:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       signal_threshold: 25000.0
#     jump:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       rejection_threshold: 4.0
#       three_group_rejection_threshold: 6.0
#       four_group_rejection_threshold: 5.0
#       maximum_cores: half
#       flag_4_neighbors: True
#       max_jump_to_flag_neighbors: 1000
#       min_jump_to_flag_neighbors: 30
#       after_jump_flag_dn1: 500
#       after_jump_flag_time1: 15
#       after_jump_flag_dn2: 1000
#       after_jump_flag_time2: 3000
#       expand_large_events: False
#       min_sat_area: 1
#       min_jump_area: 0
#       expand_factor: 0
#       use_ellipses: False
#       sat_required_snowball: False
#       min_sat_radius_extend: 0.0
#       sat_expand: 0
#       edge_size: 0
#       mask_snowball_core_next_int: True
#       snowball_time_masked_next_int: 4000
#       find_showers: False
#       max_shower_amplitude: 4.0
#       extend_snr_threshold: 3.0
#       extend_min_area: 50
#       extend_inner_radius: 1
#       extend_outer_radius: 2.6
#       extend_ellipse_expand_ratio: 1.1
#       time_masked_after_shower: 30
#       min_diffs_single_pass: 10
#       max_extended_radius: 200
#       minimum_groups: 3
#       minimum_sigclip_groups: 100
#       only_use_ints: True
#     picture_frame:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       mask_science_regions: True
#       n_sigma: 2.0
#       save_mask: False
#       save_correction: False
#     clean_flicker_noise:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       autoparam: False
#       fit_method: median
#       fit_by_channel: False
#       background_method: median
#       background_box_size: None
#       mask_science_regions: False
#       apply_flat_field: False
#       n_sigma: 2.0
#       fit_histogram: False
#       single_mask: True
#       user_mask: None
#       save_mask: False
#       save_background: False
#       save_noise: False
#     ramp_fit:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: OLS_C
#       int_name: ''
#       save_opt: False
#       opt_name: ''
#       suppress_one_group: True
#       firstgroup: None
#       lastgroup: None
#       maximum_cores: '1'
#     gain_scale:
#       pre_hooks: []
#       post_hooks:
#       - !!python/name:__main__.XplyStep ''
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
# 2026-04-15 18:16:59,368 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386030001_03101_00001_mirimage_uncal.fits' reftypes = ['dark', 'emicorr', 'gain', 'linearity', 'mask', 'persat', 'readnoise', 'reset', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# 2026-04-15 18:16:59,371 - stpipe.pipeline - INFO - Prefetch for DARK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_dark_0098.fits'.
# 2026-04-15 18:16:59,372 - stpipe.pipeline - INFO - Prefetch for EMICORR reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_emicorr_0003.asdf'.
# 2026-04-15 18:16:59,372 - stpipe.pipeline - INFO - Prefetch for GAIN reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_gain_0032.fits'.
# 2026-04-15 18:16:59,373 - stpipe.pipeline - INFO - Prefetch for LINEARITY reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_linearity_0032.fits'.
# 2026-04-15 18:16:59,373 - stpipe.pipeline - INFO - Prefetch for MASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_mask_0036.fits'.
# 2026-04-15 18:16:59,374 - stpipe.pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2026-04-15 18:16:59,374 - stpipe.pipeline - INFO - Prefetch for READNOISE reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_readnoise_0085.fits'.
# 2026-04-15 18:16:59,375 - stpipe.pipeline - INFO - Prefetch for RESET reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_reset_0065.fits'.
# 2026-04-15 18:16:59,375 - stpipe.pipeline - INFO - Prefetch for RSCD reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_rscd_0022.fits'.
# 2026-04-15 18:16:59,376 - stpipe.pipeline - INFO - Prefetch for SATURATION reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_saturation_0034.fits'.
# 2026-04-15 18:16:59,376 - stpipe.pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2026-04-15 18:16:59,377 - stpipe.pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2026-04-15 18:16:59,377 - stpipe.pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2026-04-15 18:16:59,378 - jwst.pipeline.calwebb_detector1 - INFO - Starting calwebb_detector1 ...
# 2026-04-15 18:17:03,469 - stpipe.step - INFO - Step group_scale running with args (<RampModel(60, 250, 224, 288) from jw01386030001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:17:03,470 - jwst.group_scale.group_scale_step - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2026-04-15 18:17:03,470 - jwst.group_scale.group_scale_step - INFO - Step will be skipped
# 2026-04-15 18:17:03,472 - stpipe.step - INFO - Step group_scale done
# 2026-04-15 18:17:03,601 - stpipe.step - INFO - Step dq_init running with args (<RampModel(60, 250, 224, 288) from jw01386030001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:17:03,604 - jwst.dq_init.dq_init_step - INFO - Using MASK reference file /home/runner/crds/references/jwst/miri/jwst_miri_mask_0036.fits
# 2026-04-15 18:17:03,636 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:17:03,636 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:17:03,647 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:17:03,654 - jwst.dq_init.dq_initialization - INFO - Extracting mask subarray to match science data
# 2026-04-15 18:17:03,967 - stpipe.step - INFO - Step dq_init done
# 2026-04-15 18:17:04,116 - stpipe.step - INFO - Step emicorr running with args (<RampModel(60, 250, 224, 288) from jw01386030001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:17:04,119 - jwst.emicorr.emicorr_step - INFO - Using EMICORR reference file: /home/runner/crds/references/jwst/miri/jwst_miri_emicorr_0003.asdf
# 2026-04-15 18:17:04,135 - jwst.emicorr.emicorr - INFO - Using reference file to get subarray case.
# 2026-04-15 18:17:04,135 - jwst.emicorr.emicorr - INFO - With configuration: Subarray=MASK1550, Read_pattern=FASTR1, Detector=MIRIMAGE
# 2026-04-15 18:17:04,136 - jwst.emicorr.emicorr - INFO - Will correct data for the following 2 frequencies:
# 2026-04-15 18:17:04,136 - jwst.emicorr.emicorr - INFO -    ['Hz390', 'Hz10']
# 2026-04-15 18:17:04,137 - jwst.emicorr.emicorr - INFO - Running EMI fit with algorithm = 'joint'.
# 2026-04-15 18:18:18,232 - stpipe.step - INFO - Step emicorr done
# 2026-04-15 18:18:18,374 - stpipe.step - INFO - Step saturation running with args (<RampModel(60, 250, 224, 288) from jw01386030001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:18:18,378 - jwst.saturation.saturation_step - INFO - Using SATURATION reference file /home/runner/crds/references/jwst/miri/jwst_miri_saturation_0034.fits
# 2026-04-15 18:18:18,379 - jwst.saturation.saturation_step - INFO - Using SUPERBIAS reference file N/A
# 2026-04-15 18:18:18,412 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:18:18,413 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:18:18,422 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:18:18,429 - jwst.saturation.saturation - INFO - Extracting reference file subarray to match science data
# 2026-04-15 18:18:18,448 - jwst.saturation.saturation - INFO - Using read_pattern with nframes 1
# 2026-04-15 18:18:24,759 - stcal.saturation.saturation - INFO - Detected 672 saturated pixels
# 2026-04-15 18:18:24,923 - stcal.saturation.saturation - INFO - Detected 2 A/D floor pixels
# 2026-04-15 18:18:24,937 - stpipe.step - INFO - Step saturation done
# 2026-04-15 18:18:25,088 - stpipe.step - INFO - Step ipc running with args (<RampModel(60, 250, 224, 288) from jw01386030001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:18:25,089 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:18:25,222 - stpipe.step - INFO - Step firstframe running with args (<RampModel(60, 250, 224, 288) from jw01386030001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:18:25,223 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:18:25,351 - stpipe.step - INFO - Step lastframe running with args (<RampModel(60, 250, 224, 288) from jw01386030001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:18:25,354 - stpipe.step - INFO - Step lastframe done
# 2026-04-15 18:18:25,480 - stpipe.step - INFO - Step reset running with args (<RampModel(60, 250, 224, 288) from jw01386030001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:18:25,483 - jwst.reset.reset_step - INFO - Using RESET reference file /home/runner/crds/references/jwst/miri/jwst_miri_reset_0065.fits
# 2026-04-15 18:18:25,520 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:18:25,521 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:18:25,524 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# ...
# 2026-04-15 18:20:42,999 - stpipe.pipeline - INFO - Prefetch for READNOISE reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_readnoise_0085.fits'.
# 2026-04-15 18:20:42,999 - stpipe.pipeline - INFO - Prefetch for RESET reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_reset_0065.fits'.
# 2026-04-15 18:20:43,000 - stpipe.pipeline - INFO - Prefetch for RSCD reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_rscd_0022.fits'.
# 2026-04-15 18:20:43,000 - stpipe.pipeline - INFO - Prefetch for SATURATION reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_saturation_0034.fits'.
# 2026-04-15 18:20:43,001 - stpipe.pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2026-04-15 18:20:43,001 - stpipe.pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2026-04-15 18:20:43,001 - stpipe.pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2026-04-15 18:20:43,002 - jwst.pipeline.calwebb_detector1 - INFO - Starting calwebb_detector1 ...
# 2026-04-15 18:20:43,509 - stpipe.step - INFO - Step group_scale running with args (<RampModel(19, 100, 224, 288) from jw01386031001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:20:43,510 - jwst.group_scale.group_scale_step - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2026-04-15 18:20:43,511 - jwst.group_scale.group_scale_step - INFO - Step will be skipped
# 2026-04-15 18:20:43,513 - stpipe.step - INFO - Step group_scale done
# 2026-04-15 18:20:43,643 - stpipe.step - INFO - Step dq_init running with args (<RampModel(19, 100, 224, 288) from jw01386031001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:20:43,646 - jwst.dq_init.dq_init_step - INFO - Using MASK reference file /home/runner/crds/references/jwst/miri/jwst_miri_mask_0036.fits
# 2026-04-15 18:20:43,677 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:20:43,678 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:20:43,689 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:20:43,696 - jwst.dq_init.dq_initialization - INFO - Extracting mask subarray to match science data
# 2026-04-15 18:20:43,757 - stpipe.step - INFO - Step dq_init done
# 2026-04-15 18:20:43,897 - stpipe.step - INFO - Step emicorr running with args (<RampModel(19, 100, 224, 288) from jw01386031001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:20:43,900 - jwst.emicorr.emicorr_step - INFO - Using EMICORR reference file: /home/runner/crds/references/jwst/miri/jwst_miri_emicorr_0003.asdf
# 2026-04-15 18:20:43,916 - jwst.emicorr.emicorr - INFO - Using reference file to get subarray case.
# 2026-04-15 18:20:43,916 - jwst.emicorr.emicorr - INFO - With configuration: Subarray=MASK1550, Read_pattern=FASTR1, Detector=MIRIMAGE
# 2026-04-15 18:20:43,917 - jwst.emicorr.emicorr - INFO - Will correct data for the following 2 frequencies:
# 2026-04-15 18:20:43,917 - jwst.emicorr.emicorr - INFO -    ['Hz390', 'Hz10']
# 2026-04-15 18:20:43,918 - jwst.emicorr.emicorr - INFO - Running EMI fit with algorithm = 'joint'.
# 2026-04-15 18:20:56,433 - stpipe.step - INFO - Step emicorr done
# 2026-04-15 18:20:56,574 - stpipe.step - INFO - Step saturation running with args (<RampModel(19, 100, 224, 288) from jw01386031001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:20:56,578 - jwst.saturation.saturation_step - INFO - Using SATURATION reference file /home/runner/crds/references/jwst/miri/jwst_miri_saturation_0034.fits
# 2026-04-15 18:20:56,579 - jwst.saturation.saturation_step - INFO - Using SUPERBIAS reference file N/A
# 2026-04-15 18:20:56,612 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:20:56,613 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:20:56,622 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:20:56,629 - jwst.saturation.saturation - INFO - Extracting reference file subarray to match science data
# 2026-04-15 18:20:56,648 - jwst.saturation.saturation - INFO - Using read_pattern with nframes 1
# 2026-04-15 18:20:57,484 - stcal.saturation.saturation - INFO - Detected 669 saturated pixels
# 2026-04-15 18:20:57,507 - stcal.saturation.saturation - INFO - Detected 2 A/D floor pixels
# 2026-04-15 18:20:57,520 - stpipe.step - INFO - Step saturation done
# 2026-04-15 18:20:57,666 - stpipe.step - INFO - Step ipc running with args (<RampModel(19, 100, 224, 288) from jw01386031001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:20:57,666 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:20:57,798 - stpipe.step - INFO - Step firstframe running with args (<RampModel(19, 100, 224, 288) from jw01386031001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:20:57,799 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:20:57,932 - stpipe.step - INFO - Step lastframe running with args (<RampModel(19, 100, 224, 288) from jw01386031001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:20:57,935 - stpipe.step - INFO - Step lastframe done
# 2026-04-15 18:20:58,064 - stpipe.step - INFO - Step reset running with args (<RampModel(19, 100, 224, 288) from jw01386031001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:20:58,067 - jwst.reset.reset_step - INFO - Using RESET reference file /home/runner/crds/references/jwst/miri/jwst_miri_reset_0065.fits
# 2026-04-15 18:20:58,105 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:20:58,106 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:20:58,108 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:20:58,214 - stpipe.step - INFO - Step reset done
# 2026-04-15 18:20:58,358 - stpipe.step - INFO - Step linearity running with args (<RampModel(19, 100, 224, 288) from jw01386031001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:20:58,361 - jwst.linearity.linearity_step - INFO - Using Linearity reference file /home/runner/crds/references/jwst/miri/jwst_miri_linearity_0032.fits
# 2026-04-15 18:20:58,396 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:20:58,397 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:20:58,406 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:20:58,764 - stpipe.step - INFO - Step linearity done
# 2026-04-15 18:20:58,907 - stpipe.step - INFO - Step rscd running with args (<RampModel(19, 100, 224, 288) from jw01386031001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:20:58,910 - jwst.rscd.rscd_step - INFO - Using RSCD reference file /home/runner/crds/references/jwst/miri/jwst_miri_rscd_0022.fits
# 2026-04-15 18:20:58,926 - jwst.rscd.rscd_sub - INFO - # groups from RSCD reference file for int 1 to flag: 6
# 2026-04-15 18:20:58,927 - jwst.rscd.rscd_sub - INFO - # groups from RSCD reference file for int 2 and higher to flag: 3
# 2026-04-15 18:20:58,928 - jwst.rscd.rscd_sub - INFO -  There are 60 saturated pixels that require the number of rscd groups flagged to be lowered
# 2026-04-15 18:20:58,929 - jwst.rscd.rscd_sub - INFO - Flagged 60 pixels as FLUX_ESTIMATED due to RSCD back-off.
# 2026-04-15 18:20:58,934 - jwst.rscd.rscd_sub - INFO - Number of usable bright pixels with rscd flag groups not set to DO_NOT_USE: 60
# 2026-04-15 18:20:58,936 - jwst.rscd.rscd_sub - INFO -  There are 0 saturated pixels that require the number of rscd groups flagged to be lowered
# 2026-04-15 18:20:59,014 - jwst.rscd.rscd_sub - INFO - Number of usable bright pixels with rscd flag groups not set to DO_NOT_USE: 0
# 2026-04-15 18:20:59,017 - stpipe.step - INFO - Step rscd done
# 2026-04-15 18:20:59,162 - stpipe.step - INFO - Step dark_current running with args (<RampModel(19, 100, 224, 288) from jw01386031001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:20:59,165 - jwst.dark_current.dark_current_step - INFO - Using DARK reference file /home/runner/crds/references/jwst/miri/jwst_miri_dark_0098.fits
# 2026-04-15 18:20:59,292 - stdatamodels.dynamicdq - WARNING - Keyword UNDERSAMP does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:20:59,293 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:20:59,297 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:20:59,308 - jwst.dark_current.dark_current_step - INFO - Using Poisson noise from average dark current 1.0 e-/sec
# 2026-04-15 18:20:59,309 - stcal.dark_current.dark_sub - INFO - Science data nints=19, ngroups=100, nframes=1, groupgap=0
# 2026-04-15 18:20:59,309 - stcal.dark_current.dark_sub - INFO - Dark data nints=3, ngroups=500, nframes=1, groupgap=0
# 2026-04-15 18:20:59,475 - stpipe.step - INFO - Step dark_current done
# 2026-04-15 18:20:59,613 - stpipe.step - INFO - Step refpix running with args (<RampModel(19, 100, 224, 288) from jw01386031001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:20:59,614 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:20:59,743 - stpipe.step - INFO - Step charge_migration running with args (<RampModel(19, 100, 224, 288) from jw01386031001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:20:59,744 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:20:59,873 - stpipe.step - INFO - Step jump running with args (<RampModel(19, 100, 224, 288) from jw01386031001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:20:59,874 - jwst.jump.jump_step - INFO - CR rejection threshold = 4 sigma
# 2026-04-15 18:20:59,875 - jwst.jump.jump_step - INFO - Maximum cores to use = half
# 2026-04-15 18:20:59,878 - jwst.jump.jump_step - INFO - Using GAIN reference file: /home/runner/crds/references/jwst/miri/jwst_miri_gain_0032.fits
# 2026-04-15 18:20:59,880 - jwst.jump.jump_step - INFO - Using READNOISE reference file: /home/runner/crds/references/jwst/miri/jwst_miri_readnoise_0085.fits
# 2026-04-15 18:20:59,911 - jwst.jump.jump_step - INFO - Extracting gain subarray to match science data
# 2026-04-15 18:20:59,925 - jwst.jump.jump_step - INFO - Extracting readnoise subarray to match science data
# 2026-04-15 18:21:00,007 - stcal.jump.jump - INFO - Executing two-point difference method
# 2026-04-15 18:21:00,007 - stcal.jump.jump - INFO - Creating 4 processes for jump detection
# 2026-04-15 18:21:03,324 - stcal.jump.jump - INFO - Total elapsed time = 3.31706 sec
# 2026-04-15 18:21:03,357 - jwst.jump.jump_step - INFO - The execution time in seconds: 3.482258
# 2026-04-15 18:21:03,360 - stpipe.step - INFO - Step jump done
# 2026-04-15 18:21:03,511 - stpipe.step - INFO - Step picture_frame running with args (<RampModel(19, 100, 224, 288) from jw01386031001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:21:03,512 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:21:03,649 - stpipe.step - INFO - Step clean_flicker_noise running with args (<RampModel(19, 100, 224, 288) from jw01386031001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:21:03,650 - stpipe.step - INFO - Step skipped.
# 2026-04-15 18:21:03,786 - stpipe.step - INFO - Step ramp_fit running with args (<RampModel(19, 100, 224, 288) from jw01386031001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:21:03,791 - jwst.ramp_fitting.ramp_fit_step - INFO - Using READNOISE reference file: /home/runner/crds/references/jwst/miri/jwst_miri_readnoise_0085.fits
# 2026-04-15 18:21:03,792 - jwst.ramp_fitting.ramp_fit_step - INFO - Using GAIN reference file: /home/runner/crds/references/jwst/miri/jwst_miri_gain_0032.fits
# 2026-04-15 18:21:03,823 - jwst.ramp_fitting.ramp_fit_step - INFO - Extracting gain subarray to match science data
# 2026-04-15 18:21:03,837 - jwst.ramp_fitting.ramp_fit_step - INFO - Extracting readnoise subarray to match science data
# 2026-04-15 18:21:03,851 - jwst.ramp_fitting.ramp_fit_step - INFO - Using algorithm = OLS_C
# 2026-04-15 18:21:03,851 - jwst.ramp_fitting.ramp_fit_step - INFO - Using weighting = optimal
# 2026-04-15 18:21:04,073 - stcal.ramp_fitting.ols_fit - INFO - Number of multiprocessing slices: 1
# 2026-04-15 18:21:04,089 - stcal.ramp_fitting.ols_fit - INFO - Number of leading groups that are flagged as DO_NOT_USE: 3
# 2026-04-15 18:21:04,090 - stcal.ramp_fitting.ols_fit - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2026-04-15 18:21:11,788 - stcal.ramp_fitting.ols_fit - INFO - Ramp Fitting C Time: 7.696536064147949
# 2026-04-15 18:21:11,907 - stpipe.step - INFO - Step ramp_fit done
# 2026-04-15 18:21:12,050 - stpipe.step - INFO - Step gain_scale running with args (<ImageModel(224, 288) from jw01386031001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:21:12,053 - jwst.gain_scale.gain_scale_step - INFO - Using GAIN reference file: /home/runner/crds/references/jwst/miri/jwst_miri_gain_0032.fits
# 2026-04-15 18:21:12,071 - jwst.gain_scale.gain_scale_step - INFO - GAINFACT not found in gain reference file
# 2026-04-15 18:21:12,071 - jwst.gain_scale.gain_scale_step - INFO - Step will be skipped
# 2026-04-15 18:21:12,206 - stpipe.step - INFO - Step xply running with args (<ImageModel(224, 288) from jw01386031001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:21:12,223 - py.warnings - WARNING - /tmp/ipykernel_3146/3735983842.py:14: DeprecationWarning: The Step.log attribute is deprecated and will be removed in a future release. Please use a local logger, retrieved via logging.getLogger.
#   self.log.info('Multiplied everything by one in custom step!')
# 2026-04-15 18:21:12,224 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Multiplied everything by one in custom step!
# 2026-04-15 18:21:12,226 - stpipe.step - INFO - Step xply done
# 2026-04-15 18:21:12,229 - stpipe.step - INFO - Step gain_scale done
# 2026-04-15 18:21:12,364 - stpipe.step - INFO - Step gain_scale running with args (<CubeModel(19, 224, 288) from jw01386031001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:21:12,367 - jwst.gain_scale.gain_scale_step - INFO - Using GAIN reference file: /home/runner/crds/references/jwst/miri/jwst_miri_gain_0032.fits
# 2026-04-15 18:21:12,385 - jwst.gain_scale.gain_scale_step - INFO - GAINFACT not found in gain reference file
# 2026-04-15 18:21:12,386 - jwst.gain_scale.gain_scale_step - INFO - Step will be skipped
# 2026-04-15 18:21:12,518 - stpipe.step - INFO - Step xply running with args (<CubeModel(19, 224, 288) from jw01386031001_03101_00001_mirimage_uncal.fits>,).
# 2026-04-15 18:21:12,537 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Multiplied everything by one in custom step!
# 2026-04-15 18:21:12,538 - stpipe.step - INFO - Step xply done
# 2026-04-15 18:21:12,541 - stpipe.step - INFO - Step gain_scale done
# 2026-04-15 18:21:12,601 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs031/stage1/jw01386031001_03101_00001_mirimage_rateints.fits
# 2026-04-15 18:21:12,602 - jwst.pipeline.calwebb_detector1 - INFO - ... ending calwebb_detector1
# 2026-04-15 18:21:12,603 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1535.pmap
# 2026-04-15 18:21:12,652 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs031/stage1/jw01386031001_03101_00001_mirimage_rate.fits
# 2026-04-15 18:21:12,652 - stpipe.step - INFO - Step Detector1Pipeline done
# 2026-04-15 18:21:12,653 - jwst.stpipe.core - INFO - Results used jwst version: 2.0.0

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
# Out:
# Runtime so far: 1238.2654 seconds

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ## 6.-Image2 Pipeline
# ------------------
#
# In this section we process our 3D countrate (`rateints`) products from
# Stage 1 (calwebb_detector1) through the Image2 (calwebb_image2) pipeline
# in order to produce Stage 2
# data products (i.e., 3D calibrated `calints` and 3D background-subtracted `bsubints` data). These data products have units of MJy/sr.
#
# In this pipeline processing stage, the [background subtraction](https://jwst-pipeline.readthedocs.io/en/latest/jwst/background_step/index.html#background-step)
# step is performed (if the data has a dedicated background defined), the [world coordinate system (WCS)](https://jwst-pipeline.readthedocs.io/en/latest/jwst/assign_wcs/index.html#assign-wcs-step)
# is assigned, the data is [flat fielded](https://jwst-pipeline.readthedocs.io/en/latest/jwst/flatfield/index.html#flatfield-step),
# and a [photometric calibration](https://jwst-pipeline.readthedocs.io/en/latest/jwst/photom/index.html#photom-step)
# is applied to convert from units of countrate (ADU/s) to surface brightness (MJy/sr).
#
# The [resampling](https://jwst-pipeline.readthedocs.io/en/latest/jwst/resample/index.html#resample-step) step is performed, to create resampled images of each dither position, but this is only a quick-look product. The resampling step occurs during the Coron3 stage by default. While the resampling step is done in the Image2 stage, the data quality from the Coron3 stage will be better since the bad pixels, which adversely affect both the centroids and photometry in individual images, will be mostly removed.
#
# See https://jwst-docs.stsci.edu/jwst-science-calibration-pipeline/stages-of-jwst-data-processing/calwebb_image2

# %%
time_image2 = time.perf_counter()

# %%
# Set up a dictionary to define how the Image2 pipeline should be configured.

# Boilerplate dictionary setup
image2dict = defaultdict(dict)

# Overrides for whether or not certain steps should be skipped (example)
#image2dict['resample']['skip'] = False
#image2dict['bkg_subtract']['skip'] = True

# Overrides for various reference files
# Files should be in the base local directory or provide full path
#image2dict['assign_wcs']['override_distortion'] = 'myfile.asdf'  # Spatial distortion (ASDF file)
#image2dict['assign_wcs']['override_filteroffset'] = 'myfile.asdf'  # Imager filter offsets (ASDF file)
#image2dict['assign_wcs']['override_specwcs'] = 'myfile.asdf'  # Spectral distortion (ASDF file)
#image2dict['assign_wcs']['override_wavelengthrange'] = 'myfile.asdf'  # Wavelength channel mapping (ASDF file)
#image2dict['flat_field']['override_flat'] = 'myfile.fits'  # Pixel flatfield
#image2dict['photom']['override_photom'] = 'myfile.fits'  # Photometric calibration array

# Save the combined background used for subtraction
image2dict['bkg_subtract']['save_combined_background'] = True 

# Relevant step-specific arguments for background subtraction
#image2dict['bkg_subtract']['sigma'] = 3.0  # Number of standard deviations to use for sigma-clipping
#image2dict['bkg_subtract']['maxiters'] = None  # Number of clipping iterations to perform when combining multiple background images. If None, will clip until convergence is achieved

# Relevant step-specific arguments for flat field
#image2dict['flat_field']['user_supplied_flat'] = 'myfile.fits'  # Path to user-supplied Flat-field image 
#image2dict['flat_field']['inverse'] = False  # Whether to inverse the math operations used to apply the Flat-field (i.e. multiply instead of divide)

# Overrides for various reference files
# Files should be in the base local directory or provide full path
#image2dict['assign_wcs']['override_distortion'] = 'myfile.asdf'  # Spatial distortion (ASDF file)
#image2dict['assign_wcs']['override_filteroffset'] = 'myfile.asdf'  # Imager filter offsets (ASDF file)
#image2dict['flat_field']['override_flat'] = 'myfile.fits'  # Pixel flatfield
#image2dict['photom']['override_photom'] = 'myfile.fits'  # Photometric calibration array

# %% [markdown]
# Define a function to create association files for Stage 2. This will enable use of the background subtraction, if chosen above.
#
#
# <div class="alert alert-block alert-warning">
# Note that the background will not be applied properly to all files if more than *one* SCI file is included in the association.
# </div>

# %%
def writel2asn(onescifile, bgfiles, asnfile, prodname):
    # Define the basic association of science files
    asn = afl.asn_from_list([onescifile], rule=DMSLevel2bBase, product_name=prodname)  # Wrap in array since input was single exposure

    #Coron/filter configuration for this sci file
    with fits.open(onescifile) as hdu:
        hdu.verify()
        hdr = hdu[0].header
        this_mask, this_filter = hdr['CORONMSK'], hdr['FILTER']

    # Find which background files are appropriate to this mask/filter and add to association
    for file in bgfiles:
        hdu.verify()
        hdr = hdu[0].header
        if hdr['FILTER'] == this_filter and hdr['CORONMSK'] == this_mask:
            asn['products'][0]['members'].append({'expname': file, 'exptype': 'background'})

    # Write the association to a json file
    _, serialized = asn.dump()
    with open(asnfile, 'w') as outfile:
        outfile.write(serialized)

# %% [markdown]
# Find and sort all of the input files for the selected filter and coronagraphic mask, ensuring use of absolute paths.
#
# The input files should be `rateints.fits` products and for the demo example there should be a total of 2 files corresponding to the science target; 9 files corresponding to the reference target; 2 files corresponding to the science background target and 2 files corresponding to the reference background target.

# %%
# Identify Science Files 
# Roll 1
sstring = os.path.join(det1_sci_r1_dir, 'jw*mirimage*rateints.fits')  # Use files from the detector1 output folder
sci_r1_files = sorted(glob.glob(sstring))

# Check that these are the mask/filter to use
sci_r1_files = select_mask_filter_files(sci_r1_files, use_mask, use_filter)

# Roll 2
sstring = os.path.join(det1_sci_r2_dir, 'jw*mirimage*rateints.fits')  # Use files from the detector1 output folder
sci_r2_files = sorted(glob.glob(sstring))
sci_r2_files = select_mask_filter_files(sci_r2_files, use_mask, use_filter)

# Identify PSF Ref Target Files
sstring = os.path.join(det1_ref_targ_dir, 'jw*mirimage*rateints.fits')
ref_targ_files = sorted(glob.glob(sstring))
ref_targ_files = select_mask_filter_files(ref_targ_files, use_mask, use_filter)

# Background Files
# Sci Bkg
sstring = os.path.join(det1_bg_sci_dir, 'jw*mirimage*rateints.fits')
bg_sci_files = sorted(glob.glob(sstring))
bg_sci_files = select_mask_filter_files(bg_sci_files, use_mask, use_filter)

# Ref target Bkg 
sstring = os.path.join(det1_bg_ref_targ_dir, 'jw*mirimage*rateints.fits')
bg_ref_targ_files = sorted(glob.glob(sstring))
bg_ref_targ_files = select_mask_filter_files(bg_ref_targ_files, use_mask, use_filter)

print('Found ' + str(len(sci_r1_files) + len(sci_r2_files)) + ' science files')
print('Found ' + str(len(ref_targ_files)) + ' reference files')
print('Found ' + str(len(bg_sci_files)) + ' science background files')
print('Found ' + str(len(bg_ref_targ_files)) + ' reference background files')
# Out:
# Found 2 science files
# Found 9 reference files
# Found 2 science background files
# Found 2 reference background files

# %% [markdown]
# Step through each of the science files for both rolls. First creates the association file using relevant associated backgrounds and then runs calwebb_image2 processing.

# %%
if doimage2:
    # Science Roll 1
    # Generate a proper background-subtracting association file
    for file in sci_r1_files:
        asnfile = os.path.join(image2_sci_r1_dir, 'l2asn.json')
        writel2asn(file, bg_sci_files, asnfile, 'Level2')
        Image2Pipeline.call(asnfile, steps=image2dict, save_bsub=True, save_results=True, output_dir=image2_sci_r1_dir)

    # Science Roll 2
    # Generate a proper background-subtracting association file
    for file in sci_r2_files:
        asnfile = os.path.join(image2_sci_r2_dir, 'l2asn.json')
        writel2asn(file, bg_sci_files, asnfile, 'Level2')
        Image2Pipeline.call(asnfile, steps=image2dict, save_bsub=True, save_results=True, output_dir=image2_sci_r2_dir)
else:
    print('Skipping Image2 processing for SCI data')
# Out:
# /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages/jwst/associations/association.py:232: UserWarning: Input association file contains path information; note that this can complicate usage and/or sharing of such files.
#   warnings.warn(err_str, UserWarning, stacklevel=1)
# 2026-04-15 18:21:12,913 - CRDS - INFO -  Fetching  /home/runner/crds/references/jwst/miri/jwst_miri_pars-resamplestep_0001.asdf    1.0 K bytes  (1 / 1 files) (0 / 1.0 K bytes)
# 2026-04-15 18:21:13,094 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-resamplestep_0001.asdf
# 2026-04-15 18:21:13,106 - stpipe.step - INFO - Image2Pipeline instance created.
# 2026-04-15 18:21:13,107 - stpipe.step - INFO - BackgroundStep instance created.
# 2026-04-15 18:21:13,108 - stpipe.step - INFO - AssignWcsStep instance created.
# 2026-04-15 18:21:13,109 - stpipe.step - INFO - FlatFieldStep instance created.
# 2026-04-15 18:21:13,110 - stpipe.step - INFO - PhotomStep instance created.
# 2026-04-15 18:21:13,112 - stpipe.step - INFO - ResampleStep instance created.
# 2026-04-15 18:21:13,253 - stpipe.step - INFO - Step Image2Pipeline running with args ('./miri_coro_demo_data/Obs008/stage2/l2asn.json',).
# 2026-04-15 18:21:13,261 - stpipe.step - INFO - Step Image2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./miri_coro_demo_data/Obs008/stage2
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_bsub: True
#   steps:
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bkg_list: None
#       save_combined_background: True
#       sigma: 3.0
#       maxiters: None
#       soss_source_percentile: 35.0
#       soss_bkg_percentile: None
#       wfss_mmag_extract: None
#       wfss_mask: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#       nrs_ifu_slice_wcs: False
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       apply_time_correction: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
#       propagate_dq: False
#       pixmap_stepsize: 1.0
#       pixmap_order: 1
# 2026-04-15 18:21:13,308 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'l2asn.json' reftypes = ['area', 'bkg', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange']
# 2026-04-15 18:21:13,311 - CRDS - INFO -  Fetching  /home/runner/crds/references/jwst/miri/jwst_miri_distortion_0142.asdf   12.6 K bytes  (1 / 4 files) (0 / 833.7 K bytes)
# 2026-04-15 18:21:13,360 - CRDS - INFO -  Fetching  /home/runner/crds/references/jwst/miri/jwst_miri_filteroffset_0021.asdf    3.2 K bytes  (2 / 4 files) (12.6 K / 833.7 K bytes)
# 2026-04-15 18:21:13,414 - CRDS - INFO -  Fetching  /home/runner/crds/references/jwst/miri/jwst_miri_flat_0768.fits  797.8 K bytes  (3 / 4 files) (15.8 K / 833.7 K bytes)
# 2026-04-15 18:21:13,551 - CRDS - INFO -  Fetching  /home/runner/crds/references/jwst/miri/jwst_miri_photom_0230.fits   20.2 K bytes  (4 / 4 files) (813.6 K / 833.7 K bytes)
# 2026-04-15 18:21:13,611 - stpipe.pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2026-04-15 18:21:13,612 - stpipe.pipeline - INFO - Prefetch for BKG reference file is 'N/A'.
# 2026-04-15 18:21:13,612 - stpipe.pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2026-04-15 18:21:13,613 - stpipe.pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2026-04-15 18:21:13,613 - stpipe.pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2026-04-15 18:21:13,614 - stpipe.pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2026-04-15 18:21:13,614 - stpipe.pipeline - INFO - Prefetch for DISTORTION reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_distortion_0142.asdf'.
# 2026-04-15 18:21:13,615 - stpipe.pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2026-04-15 18:21:13,616 - stpipe.pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_filteroffset_0021.asdf'.
# 2026-04-15 18:21:13,616 - stpipe.pipeline - INFO - Prefetch for FLAT reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_flat_0768.fits'.
# 2026-04-15 18:21:13,617 - stpipe.pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2026-04-15 18:21:13,617 - stpipe.pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2026-04-15 18:21:13,618 - stpipe.pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2026-04-15 18:21:13,618 - stpipe.pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2026-04-15 18:21:13,619 - stpipe.pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2026-04-15 18:21:13,619 - stpipe.pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2026-04-15 18:21:13,619 - stpipe.pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2026-04-15 18:21:13,620 - stpipe.pipeline - INFO - Prefetch for PHOTOM reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_photom_0230.fits'.
# 2026-04-15 18:21:13,620 - stpipe.pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2026-04-15 18:21:13,621 - stpipe.pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2026-04-15 18:21:13,621 - stpipe.pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2026-04-15 18:21:13,621 - stpipe.pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2026-04-15 18:21:13,622 - jwst.pipeline.calwebb_image2 - INFO - Starting calwebb_image2 ...
# 2026-04-15 18:21:13,623 - jwst.pipeline.calwebb_image2 - WARNING - The --save_bsub parameter is deprecated and will be removed in a future release. To toggle saving background-subtracted data, use the background step's --save_results parameter instead.
# 2026-04-15 18:21:13,629 - jwst.pipeline.calwebb_image2 - INFO - Processing product /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs008/stage1/jw01386008001_04101_00001_mirimage
# 2026-04-15 18:21:13,630 - jwst.pipeline.calwebb_image2 - INFO - Working on input /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs008/stage1/jw01386008001_04101_00001_mirimage_rateints.fits ...
# 2026-04-15 18:21:13,859 - stpipe.step - INFO - Step bkg_subtract running with args (<CubeModel(60, 224, 288) from ./miri_coro_demo_data/Obs008/stage2/jw01386008001_04101_00001_mirimage_image2pipeline.fits>, ['/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs030/stage1/jw01386030001_02101_00001_mirimage_rateints.fits', '/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs030/stage1/jw01386030001_03101_00001_mirimage_rateints.fits']).
# 2026-04-15 18:21:13,879 - jwst.background.background_step - INFO - Working on input <CubeModel(60, 224, 288) from ./miri_coro_demo_data/Obs008/stage2/jw01386008001_04101_00001_mirimage_image2pipeline.fits> ...
# 2026-04-15 18:21:13,901 - jwst.background.background_sub - INFO - Accumulate bkg from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs030/stage1/jw01386030001_02101_00001_mirimage_rateints.fits
# 2026-04-15 18:21:14,300 - jwst.background.background_sub - INFO - Accumulate bkg from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs030/stage1/jw01386030001_03101_00001_mirimage_rateints.fits
# 2026-04-15 18:21:14,698 - jwst.background.background_sub - INFO - Subtracting avg bkg from ./miri_coro_demo_data/Obs008/stage2/jw01386008001_04101_00001_mirimage_image2pipeline.fits
# 2026-04-15 18:21:14,732 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs008/stage2/jw01386008001_04101_00001_mirimage_combinedbackground.fits
# 2026-04-15 18:21:14,733 - jwst.background.background_step - INFO - Combined background written to ./miri_coro_demo_data/Obs008/stage2/jw01386008001_04101_00001_mirimage_combinedbackground.fits.
# 2026-04-15 18:21:14,806 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs008/stage2/jw01386008001_04101_00001_mirimage_bsubints.fits
# 2026-04-15 18:21:14,807 - stpipe.step - INFO - Step bkg_subtract done
# 2026-04-15 18:21:14,949 - stpipe.step - INFO - Step assign_wcs running with args (<CubeModel(60, 224, 288) from jw01386008001_04101_00001_mirimage_bsubints.fits>,).
# 2026-04-15 18:21:15,053 - jwst.assign_wcs.miri - INFO - Created a MIRI mir_4qpm pipeline with references {'distortion': '/home/runner/crds/references/jwst/miri/jwst_miri_distortion_0142.asdf', 'filteroffset': '/home/runner/crds/references/jwst/miri/jwst_miri_filteroffset_0021.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2026-04-15 18:21:15,093 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  201.142971984 -51.506928048 201.153510597 -51.509037278 201.157961714 -51.500686153 201.147396425 -51.498552847
# 2026-04-15 18:21:15,094 - jwst.assign_wcs.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  201.142971984 -51.506928048 201.153510597 -51.509037278 201.157961714 -51.500686153 201.147396425 -51.498552847
# 2026-04-15 18:21:15,095 - jwst.assign_wcs.assign_wcs - INFO - COMPLETED assign_wcs
# 2026-04-15 18:21:15,127 - stpipe.step - INFO - Step assign_wcs done
# 2026-04-15 18:21:15,269 - stpipe.step - INFO - Step flat_field running with args (<CubeModel(60, 224, 288) from jw01386008001_04101_00001_mirimage_bsubints.fits>,).
# 2026-04-15 18:21:15,320 - stdatamodels.dynamicdq - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:21:15,321 - stdatamodels.dynamicdq - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:21:15,322 - stdatamodels.dynamicdq - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:21:15,323 - stdatamodels.dynamicdq - WARNING - Keyword DIFF_PATTERN does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:21:15,329 - jwst.flatfield.flat_field_step - INFO - Using FLAT reference file: /home/runner/crds/references/jwst/miri/jwst_miri_flat_0768.fits
# 2026-04-15 18:21:15,329 - jwst.flatfield.flat_field_step - INFO - No reference found for type FFLAT
# 2026-04-15 18:21:15,330 - jwst.flatfield.flat_field_step - INFO - No reference found for type SFLAT
# 2026-04-15 18:21:15,330 - jwst.flatfield.flat_field_step - INFO - No reference found for type DFLAT
# 2026-04-15 18:21:15,406 - stpipe.step - INFO - Step flat_field done
# 2026-04-15 18:21:15,547 - stpipe.step - INFO - Step photom running with args (<CubeModel(60, 224, 288) from jw01386008001_04101_00001_mirimage_bsubints.fits>,).
# 2026-04-15 18:21:15,557 - jwst.photom.photom_step - INFO - Using photom reference file: /home/runner/crds/references/jwst/miri/jwst_miri_photom_0230.fits
# 2026-04-15 18:21:15,558 - jwst.photom.photom_step - INFO - Using area reference file: N/A
# 2026-04-15 18:21:15,559 - jwst.photom.photom - INFO - Using instrument: MIRI
# 2026-04-15 18:21:15,559 - jwst.photom.photom - INFO -  detector: MIRIMAGE
# 2026-04-15 18:21:15,560 - jwst.photom.photom - INFO -  exp_type: MIR_4QPM
# 2026-04-15 18:21:15,560 - jwst.photom.photom - INFO -  filter: F1550C
# 2026-04-15 18:21:15,608 - jwst.photom.photom - INFO - Attempting to obtain PIXAR_SR and PIXAR_A2 values from PHOTOM reference file.
# 2026-04-15 18:21:15,609 - jwst.photom.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from PHOTOM reference file.
# 2026-04-15 18:21:15,610 - jwst.photom.photom - INFO -  subarray: MASK1550
# 2026-04-15 18:21:15,611 - jwst.photom.photom - INFO - Multiplicative time dependence correction is 0.994325
# 2026-04-15 18:21:15,612 - jwst.photom.photom - INFO - PHOTMJSR value: 3.52796
# 2026-04-15 18:21:15,674 - stpipe.step - INFO - Step photom done
# 2026-04-15 18:21:15,675 - jwst.pipeline.calwebb_image2 - INFO - Finished processing product /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs008/stage1/jw01386008001_04101_00001_mirimage
# 2026-04-15 18:21:15,675 - jwst.pipeline.calwebb_image2 - INFO - ... ending calwebb_image2
# 2026-04-15 18:21:15,676 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1535.pmap
# 2026-04-15 18:21:15,798 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs008/stage2/jw01386008001_04101_00001_mirimage_calints.fits
# 2026-04-15 18:21:15,799 - stpipe.step - INFO - Step Image2Pipeline done
# 2026-04-15 18:21:15,800 - jwst.stpipe.core - INFO - Results used jwst version: 2.0.0
# /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages/jwst/associations/association.py:232: UserWarning: Input association file contains path information; note that this can complicate usage and/or sharing of such files.
#   warnings.warn(err_str, UserWarning, stacklevel=1)
# 2026-04-15 18:21:15,871 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-resamplestep_0001.asdf
# 2026-04-15 18:21:15,883 - stpipe.step - INFO - Image2Pipeline instance created.
# 2026-04-15 18:21:15,884 - stpipe.step - INFO - BackgroundStep instance created.
# 2026-04-15 18:21:15,885 - stpipe.step - INFO - AssignWcsStep instance created.
# 2026-04-15 18:21:15,886 - stpipe.step - INFO - FlatFieldStep instance created.
# 2026-04-15 18:21:15,886 - stpipe.step - INFO - PhotomStep instance created.
# 2026-04-15 18:21:15,887 - stpipe.step - INFO - ResampleStep instance created.
# 2026-04-15 18:21:16,033 - stpipe.step - INFO - Step Image2Pipeline running with args ('./miri_coro_demo_data/Obs009/stage2/l2asn.json',).
# 2026-04-15 18:21:16,041 - stpipe.step - INFO - Step Image2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./miri_coro_demo_data/Obs009/stage2
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_bsub: True
#   steps:
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bkg_list: None
#       save_combined_background: True
#       sigma: 3.0
#       maxiters: None
#       soss_source_percentile: 35.0
#       soss_bkg_percentile: None
#       wfss_mmag_extract: None
#       wfss_mask: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#       nrs_ifu_slice_wcs: False
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       apply_time_correction: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
#       propagate_dq: False
#       pixmap_stepsize: 1.0
#       pixmap_order: 1
# 2026-04-15 18:21:16,089 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'l2asn.json' reftypes = ['area', 'bkg', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange']
# 2026-04-15 18:21:16,092 - stpipe.pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2026-04-15 18:21:16,092 - stpipe.pipeline - INFO - Prefetch for BKG reference file is 'N/A'.
# 2026-04-15 18:21:16,093 - stpipe.pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2026-04-15 18:21:16,093 - stpipe.pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2026-04-15 18:21:16,094 - stpipe.pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2026-04-15 18:21:16,094 - stpipe.pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2026-04-15 18:21:16,095 - stpipe.pipeline - INFO - Prefetch for DISTORTION reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_distortion_0142.asdf'.
# 2026-04-15 18:21:16,095 - stpipe.pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2026-04-15 18:21:16,095 - stpipe.pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_filteroffset_0021.asdf'.
# 2026-04-15 18:21:16,096 - stpipe.pipeline - INFO - Prefetch for FLAT reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_flat_0768.fits'.
# 2026-04-15 18:21:16,096 - stpipe.pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2026-04-15 18:21:16,097 - stpipe.pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2026-04-15 18:21:16,098 - stpipe.pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2026-04-15 18:21:16,098 - stpipe.pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2026-04-15 18:21:16,099 - stpipe.pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2026-04-15 18:21:16,099 - stpipe.pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2026-04-15 18:21:16,099 - stpipe.pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2026-04-15 18:21:16,100 - stpipe.pipeline - INFO - Prefetch for PHOTOM reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_photom_0230.fits'.
# 2026-04-15 18:21:16,100 - stpipe.pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2026-04-15 18:21:16,101 - stpipe.pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2026-04-15 18:21:16,101 - stpipe.pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2026-04-15 18:21:16,101 - stpipe.pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2026-04-15 18:21:16,102 - jwst.pipeline.calwebb_image2 - INFO - Starting calwebb_image2 ...
# 2026-04-15 18:21:16,102 - jwst.pipeline.calwebb_image2 - WARNING - The --save_bsub parameter is deprecated and will be removed in a future release. To toggle saving background-subtracted data, use the background step's --save_results parameter instead.
# 2026-04-15 18:21:16,108 - jwst.pipeline.calwebb_image2 - INFO - Processing product /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs009/stage1/jw01386009001_04101_00001_mirimage
# 2026-04-15 18:21:16,109 - jwst.pipeline.calwebb_image2 - INFO - Working on input /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs009/stage1/jw01386009001_04101_00001_mirimage_rateints.fits ...
# 2026-04-15 18:21:16,342 - stpipe.step - INFO - Step bkg_subtract running with args (<CubeModel(60, 224, 288) from ./miri_coro_demo_data/Obs009/stage2/jw01386009001_04101_00001_mirimage_image2pipeline.fits>, ['/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs030/stage1/jw01386030001_02101_00001_mirimage_rateints.fits', '/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs030/stage1/jw01386030001_03101_00001_mirimage_rateints.fits']).
# 2026-04-15 18:21:16,366 - jwst.background.background_step - INFO - Working on input <CubeModel(60, 224, 288) from ./miri_coro_demo_data/Obs009/stage2/jw01386009001_04101_00001_mirimage_image2pipeline.fits> ...
# 2026-04-15 18:21:16,387 - jwst.background.background_sub - INFO - Accumulate bkg from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs030/stage1/jw01386030001_02101_00001_mirimage_rateints.fits
# 2026-04-15 18:21:16,788 - jwst.background.background_sub - INFO - Accumulate bkg from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs030/stage1/jw01386030001_03101_00001_mirimage_rateints.fits
# 2026-04-15 18:21:17,187 - jwst.background.background_sub - INFO - Subtracting avg bkg from ./miri_coro_demo_data/Obs009/stage2/jw01386009001_04101_00001_mirimage_image2pipeline.fits
# 2026-04-15 18:21:17,221 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs009/stage2/jw01386009001_04101_00001_mirimage_combinedbackground.fits
# 2026-04-15 18:21:17,222 - jwst.background.background_step - INFO - Combined background written to ./miri_coro_demo_data/Obs009/stage2/jw01386009001_04101_00001_mirimage_combinedbackground.fits.
# 2026-04-15 18:21:17,295 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs009/stage2/jw01386009001_04101_00001_mirimage_bsubints.fits
# 2026-04-15 18:21:17,296 - stpipe.step - INFO - Step bkg_subtract done
# 2026-04-15 18:21:17,450 - stpipe.step - INFO - Step assign_wcs running with args (<CubeModel(60, 224, 288) from jw01386009001_04101_00001_mirimage_bsubints.fits>,).
# 2026-04-15 18:21:17,520 - jwst.assign_wcs.miri - INFO - Created a MIRI mir_4qpm pipeline with references {'distortion': '/home/runner/crds/references/jwst/miri/jwst_miri_distortion_0142.asdf', 'filteroffset': '/home/runner/crds/references/jwst/miri/jwst_miri_filteroffset_0021.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2026-04-15 18:21:17,554 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  201.142449558 -51.506177928 201.152294942 -51.509327940 201.158873038 -51.501539953 201.149007266 -51.498363462
# 2026-04-15 18:21:17,555 - jwst.assign_wcs.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  201.142449558 -51.506177928 201.152294942 -51.509327940 201.158873038 -51.501539953 201.149007266 -51.498363462
# 2026-04-15 18:21:17,556 - jwst.assign_wcs.assign_wcs - INFO - COMPLETED assign_wcs
# 2026-04-15 18:21:17,586 - stpipe.step - INFO - Step assign_wcs done
# 2026-04-15 18:21:17,729 - stpipe.step - INFO - Step flat_field running with args (<CubeModel(60, 224, 288) from jw01386009001_04101_00001_mirimage_bsubints.fits>,).
# 2026-04-15 18:21:17,775 - stdatamodels.dynamicdq - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:21:17,776 - stdatamodels.dynamicdq - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:21:17,777 - stdatamodels.dynamicdq - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:21:17,778 - stdatamodels.dynamicdq - WARNING - Keyword DIFF_PATTERN does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:21:17,784 - jwst.flatfield.flat_field_step - INFO - Using FLAT reference file: /home/runner/crds/references/jwst/miri/jwst_miri_flat_0768.fits
# 2026-04-15 18:21:17,784 - jwst.flatfield.flat_field_step - INFO - No reference found for type FFLAT
# 2026-04-15 18:21:17,785 - jwst.flatfield.flat_field_step - INFO - No reference found for type SFLAT
# 2026-04-15 18:21:17,786 - jwst.flatfield.flat_field_step - INFO - No reference found for type DFLAT
# 2026-04-15 18:21:17,861 - stpipe.step - INFO - Step flat_field done
# 2026-04-15 18:21:18,004 - stpipe.step - INFO - Step photom running with args (<CubeModel(60, 224, 288) from jw01386009001_04101_00001_mirimage_bsubints.fits>,).
# 2026-04-15 18:21:18,010 - jwst.photom.photom_step - INFO - Using photom reference file: /home/runner/crds/references/jwst/miri/jwst_miri_photom_0230.fits
# 2026-04-15 18:21:18,011 - jwst.photom.photom_step - INFO - Using area reference file: N/A
# 2026-04-15 18:21:18,011 - jwst.photom.photom - INFO - Using instrument: MIRI
# 2026-04-15 18:21:18,012 - jwst.photom.photom - INFO -  detector: MIRIMAGE
# 2026-04-15 18:21:18,013 - jwst.photom.photom - INFO -  exp_type: MIR_4QPM
# 2026-04-15 18:21:18,013 - jwst.photom.photom - INFO -  filter: F1550C
# 2026-04-15 18:21:18,058 - jwst.photom.photom - INFO - Attempting to obtain PIXAR_SR and PIXAR_A2 values from PHOTOM reference file.
# 2026-04-15 18:21:18,059 - jwst.photom.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from PHOTOM reference file.
# 2026-04-15 18:21:18,060 - jwst.photom.photom - INFO -  subarray: MASK1550
# 2026-04-15 18:21:18,061 - jwst.photom.photom - INFO - Multiplicative time dependence correction is 0.99432
# 2026-04-15 18:21:18,062 - jwst.photom.photom - INFO - PHOTMJSR value: 3.52798
# 2026-04-15 18:21:18,122 - stpipe.step - INFO - Step photom done
# 2026-04-15 18:21:18,123 - jwst.pipeline.calwebb_image2 - INFO - Finished processing product /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs009/stage1/jw01386009001_04101_00001_mirimage
# 2026-04-15 18:21:18,124 - jwst.pipeline.calwebb_image2 - INFO - ... ending calwebb_image2
# 2026-04-15 18:21:18,125 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1535.pmap
# 2026-04-15 18:21:18,248 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs009/stage2/jw01386009001_04101_00001_mirimage_calints.fits
# 2026-04-15 18:21:18,249 - stpipe.step - INFO - Step Image2Pipeline done
# 2026-04-15 18:21:18,249 - jwst.stpipe.core - INFO - Results used jwst version: 2.0.0

# %% [markdown]
# Step through each of the reference target files. First creates the association file using relevant associated backgrounds and then runs calwebb_image2 processing.

# %%
if doimage2:
    for file in ref_targ_files:
        # Extract the dither number to use in asn filename
        match = re.compile(r'(\d{5})_mirimage').search(file)

        # Generate a proper background-subtracting association file
        asnfile = os.path.join(image2_ref_targ_dir, match.group(1) + '_l2asn.json')
        writel2asn(file, bg_ref_targ_files, asnfile, 'Level2')
        Image2Pipeline.call(asnfile, steps=image2dict, save_bsub=True, save_results=True, output_dir=image2_ref_targ_dir)  
else:
    print('Skipping Image2 processing for PSF REF target data')
# Out:
# /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages/jwst/associations/association.py:232: UserWarning: Input association file contains path information; note that this can complicate usage and/or sharing of such files.
#   warnings.warn(err_str, UserWarning, stacklevel=1)
# 2026-04-15 18:21:18,326 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-resamplestep_0001.asdf
# 2026-04-15 18:21:18,337 - stpipe.step - INFO - Image2Pipeline instance created.
# 2026-04-15 18:21:18,338 - stpipe.step - INFO - BackgroundStep instance created.
# 2026-04-15 18:21:18,339 - stpipe.step - INFO - AssignWcsStep instance created.
# 2026-04-15 18:21:18,340 - stpipe.step - INFO - FlatFieldStep instance created.
# 2026-04-15 18:21:18,341 - stpipe.step - INFO - PhotomStep instance created.
# 2026-04-15 18:21:18,342 - stpipe.step - INFO - ResampleStep instance created.
# 2026-04-15 18:21:18,493 - stpipe.step - INFO - Step Image2Pipeline running with args ('./miri_coro_demo_data/Obs007/stage2/00001_l2asn.json',).
# 2026-04-15 18:21:18,501 - stpipe.step - INFO - Step Image2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./miri_coro_demo_data/Obs007/stage2
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_bsub: True
#   steps:
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bkg_list: None
#       save_combined_background: True
#       sigma: 3.0
#       maxiters: None
#       soss_source_percentile: 35.0
#       soss_bkg_percentile: None
#       wfss_mmag_extract: None
#       wfss_mask: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#       nrs_ifu_slice_wcs: False
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       apply_time_correction: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
#       propagate_dq: False
#       pixmap_stepsize: 1.0
#       pixmap_order: 1
# 2026-04-15 18:21:18,549 - stpipe.pipeline - INFO - Prefetching reference files for dataset: '00001_l2asn.json' reftypes = ['area', 'bkg', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange']
# 2026-04-15 18:21:18,553 - stpipe.pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2026-04-15 18:21:18,553 - stpipe.pipeline - INFO - Prefetch for BKG reference file is 'N/A'.
# 2026-04-15 18:21:18,553 - stpipe.pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2026-04-15 18:21:18,554 - stpipe.pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2026-04-15 18:21:18,554 - stpipe.pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2026-04-15 18:21:18,555 - stpipe.pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2026-04-15 18:21:18,555 - stpipe.pipeline - INFO - Prefetch for DISTORTION reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_distortion_0142.asdf'.
# 2026-04-15 18:21:18,556 - stpipe.pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2026-04-15 18:21:18,556 - stpipe.pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_filteroffset_0021.asdf'.
# 2026-04-15 18:21:18,557 - stpipe.pipeline - INFO - Prefetch for FLAT reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_flat_0768.fits'.
# 2026-04-15 18:21:18,557 - stpipe.pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2026-04-15 18:21:18,558 - stpipe.pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2026-04-15 18:21:18,558 - stpipe.pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2026-04-15 18:21:18,558 - stpipe.pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2026-04-15 18:21:18,559 - stpipe.pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2026-04-15 18:21:18,560 - stpipe.pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2026-04-15 18:21:18,560 - stpipe.pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2026-04-15 18:21:18,560 - stpipe.pipeline - INFO - Prefetch for PHOTOM reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_photom_0230.fits'.
# 2026-04-15 18:21:18,561 - stpipe.pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2026-04-15 18:21:18,561 - stpipe.pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2026-04-15 18:21:18,562 - stpipe.pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2026-04-15 18:21:18,562 - stpipe.pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2026-04-15 18:21:18,563 - jwst.pipeline.calwebb_image2 - INFO - Starting calwebb_image2 ...
# 2026-04-15 18:21:18,563 - jwst.pipeline.calwebb_image2 - WARNING - The --save_bsub parameter is deprecated and will be removed in a future release. To toggle saving background-subtracted data, use the background step's --save_results parameter instead.
# 2026-04-15 18:21:18,569 - jwst.pipeline.calwebb_image2 - INFO - Processing product /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs007/stage1/jw01386007001_04101_00001_mirimage
# 2026-04-15 18:21:18,570 - jwst.pipeline.calwebb_image2 - INFO - Working on input /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs007/stage1/jw01386007001_04101_00001_mirimage_rateints.fits ...
# 2026-04-15 18:21:18,796 - stpipe.step - INFO - Step bkg_subtract running with args (<CubeModel(19, 224, 288) from ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00001_mirimage_image2pipeline.fits>, ['/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs031/stage1/jw01386031001_02101_00001_mirimage_rateints.fits', '/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs031/stage1/jw01386031001_03101_00001_mirimage_rateints.fits']).
# 2026-04-15 18:21:18,810 - jwst.background.background_step - INFO - Working on input <CubeModel(19, 224, 288) from ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00001_mirimage_image2pipeline.fits> ...
# 2026-04-15 18:21:18,831 - jwst.background.background_sub - INFO - Accumulate bkg from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs031/stage1/jw01386031001_02101_00001_mirimage_rateints.fits
# 2026-04-15 18:21:18,972 - jwst.background.background_sub - INFO - Accumulate bkg from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs031/stage1/jw01386031001_03101_00001_mirimage_rateints.fits
# 2026-04-15 18:21:19,126 - jwst.background.background_sub - INFO - Subtracting avg bkg from ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00001_mirimage_image2pipeline.fits
# 2026-04-15 18:21:19,156 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00001_mirimage_combinedbackground.fits
# 2026-04-15 18:21:19,157 - jwst.background.background_step - INFO - Combined background written to ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00001_mirimage_combinedbackground.fits.
# 2026-04-15 18:21:19,216 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00001_mirimage_bsubints.fits
# 2026-04-15 18:21:19,217 - stpipe.step - INFO - Step bkg_subtract done
# 2026-04-15 18:21:19,364 - stpipe.step - INFO - Step assign_wcs running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00001_mirimage_bsubints.fits>,).
# 2026-04-15 18:21:19,434 - jwst.assign_wcs.miri - INFO - Created a MIRI mir_4qpm pipeline with references {'distortion': '/home/runner/crds/references/jwst/miri/jwst_miri_distortion_0142.asdf', 'filteroffset': '/home/runner/crds/references/jwst/miri/jwst_miri_filteroffset_0021.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2026-04-15 18:21:19,468 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  209.561564092 -42.103152071 209.570351685 -42.105380351 209.574290405 -42.097081211 209.565480600 -42.094828439
# 2026-04-15 18:21:19,469 - jwst.assign_wcs.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  209.561564092 -42.103152071 209.570351685 -42.105380351 209.574290405 -42.097081211 209.565480600 -42.094828439
# 2026-04-15 18:21:19,470 - jwst.assign_wcs.assign_wcs - INFO - COMPLETED assign_wcs
# 2026-04-15 18:21:19,500 - stpipe.step - INFO - Step assign_wcs done
# 2026-04-15 18:21:19,643 - stpipe.step - INFO - Step flat_field running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00001_mirimage_bsubints.fits>,).
# 2026-04-15 18:21:19,689 - stdatamodels.dynamicdq - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:21:19,690 - stdatamodels.dynamicdq - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:21:19,691 - stdatamodels.dynamicdq - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:21:19,692 - stdatamodels.dynamicdq - WARNING - Keyword DIFF_PATTERN does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:21:19,698 - jwst.flatfield.flat_field_step - INFO - Using FLAT reference file: /home/runner/crds/references/jwst/miri/jwst_miri_flat_0768.fits
# 2026-04-15 18:21:19,698 - jwst.flatfield.flat_field_step - INFO - No reference found for type FFLAT
# 2026-04-15 18:21:19,699 - jwst.flatfield.flat_field_step - INFO - No reference found for type SFLAT
# 2026-04-15 18:21:19,700 - jwst.flatfield.flat_field_step - INFO - No reference found for type DFLAT
# 2026-04-15 18:21:19,743 - stpipe.step - INFO - Step flat_field done
# 2026-04-15 18:21:19,888 - stpipe.step - INFO - Step photom running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00001_mirimage_bsubints.fits>,).
# 2026-04-15 18:21:19,894 - jwst.photom.photom_step - INFO - Using photom reference file: /home/runner/crds/references/jwst/miri/jwst_miri_photom_0230.fits
# 2026-04-15 18:21:19,895 - jwst.photom.photom_step - INFO - Using area reference file: N/A
# 2026-04-15 18:21:19,895 - jwst.photom.photom - INFO - Using instrument: MIRI
# 2026-04-15 18:21:19,896 - jwst.photom.photom - INFO -  detector: MIRIMAGE
# 2026-04-15 18:21:19,897 - jwst.photom.photom - INFO -  exp_type: MIR_4QPM
# 2026-04-15 18:21:19,897 - jwst.photom.photom - INFO -  filter: F1550C
# 2026-04-15 18:21:19,942 - jwst.photom.photom - INFO - Attempting to obtain PIXAR_SR and PIXAR_A2 values from PHOTOM reference file.
# 2026-04-15 18:21:19,943 - jwst.photom.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from PHOTOM reference file.
# 2026-04-15 18:21:19,944 - jwst.photom.photom - INFO -  subarray: MASK1550
# 2026-04-15 18:21:19,945 - jwst.photom.photom - INFO - Multiplicative time dependence correction is 0.994333
# 2026-04-15 18:21:19,946 - jwst.photom.photom - INFO - PHOTMJSR value: 3.52793
# 2026-04-15 18:21:19,985 - stpipe.step - INFO - Step photom done
# 2026-04-15 18:21:19,985 - jwst.pipeline.calwebb_image2 - INFO - Finished processing product /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs007/stage1/jw01386007001_04101_00001_mirimage
# 2026-04-15 18:21:19,986 - jwst.pipeline.calwebb_image2 - INFO - ... ending calwebb_image2
# 2026-04-15 18:21:19,987 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1535.pmap
# 2026-04-15 18:21:20,089 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00001_mirimage_calints.fits
# 2026-04-15 18:21:20,090 - stpipe.step - INFO - Step Image2Pipeline done
# 2026-04-15 18:21:20,091 - jwst.stpipe.core - INFO - Results used jwst version: 2.0.0
# /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages/jwst/associations/association.py:232: UserWarning: Input association file contains path information; note that this can complicate usage and/or sharing of such files.
#   warnings.warn(err_str, UserWarning, stacklevel=1)
# 2026-04-15 18:21:20,162 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-resamplestep_0001.asdf
# 2026-04-15 18:21:20,173 - stpipe.step - INFO - Image2Pipeline instance created.
# 2026-04-15 18:21:20,174 - stpipe.step - INFO - BackgroundStep instance created.
# 2026-04-15 18:21:20,175 - stpipe.step - INFO - AssignWcsStep instance created.
# 2026-04-15 18:21:20,176 - stpipe.step - INFO - FlatFieldStep instance created.
# 2026-04-15 18:21:20,177 - stpipe.step - INFO - PhotomStep instance created.
# 2026-04-15 18:21:20,178 - stpipe.step - INFO - ResampleStep instance created.
# 2026-04-15 18:21:20,325 - stpipe.step - INFO - Step Image2Pipeline running with args ('./miri_coro_demo_data/Obs007/stage2/00002_l2asn.json',).
# 2026-04-15 18:21:20,333 - stpipe.step - INFO - Step Image2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./miri_coro_demo_data/Obs007/stage2
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_bsub: True
#   steps:
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bkg_list: None
#       save_combined_background: True
#       sigma: 3.0
#       maxiters: None
#       soss_source_percentile: 35.0
#       soss_bkg_percentile: None
#       wfss_mmag_extract: None
#       wfss_mask: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#       nrs_ifu_slice_wcs: False
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       apply_time_correction: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
#       propagate_dq: False
#       pixmap_stepsize: 1.0
#       pixmap_order: 1
# 2026-04-15 18:21:20,380 - stpipe.pipeline - INFO - Prefetching reference files for dataset: '00002_l2asn.json' reftypes = ['area', 'bkg', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange']
# 2026-04-15 18:21:20,383 - stpipe.pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2026-04-15 18:21:20,384 - stpipe.pipeline - INFO - Prefetch for BKG reference file is 'N/A'.
# 2026-04-15 18:21:20,384 - stpipe.pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2026-04-15 18:21:20,385 - stpipe.pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2026-04-15 18:21:20,385 - stpipe.pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2026-04-15 18:21:20,385 - stpipe.pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2026-04-15 18:21:20,386 - stpipe.pipeline - INFO - Prefetch for DISTORTION reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_distortion_0142.asdf'.
# 2026-04-15 18:21:20,386 - stpipe.pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2026-04-15 18:21:20,386 - stpipe.pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_filteroffset_0021.asdf'.
# 2026-04-15 18:21:20,387 - stpipe.pipeline - INFO - Prefetch for FLAT reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_flat_0768.fits'.
# 2026-04-15 18:21:20,387 - stpipe.pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2026-04-15 18:21:20,388 - stpipe.pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2026-04-15 18:21:20,388 - stpipe.pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2026-04-15 18:21:20,388 - stpipe.pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2026-04-15 18:21:20,389 - stpipe.pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2026-04-15 18:21:20,390 - stpipe.pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2026-04-15 18:21:20,390 - stpipe.pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2026-04-15 18:21:20,391 - stpipe.pipeline - INFO - Prefetch for PHOTOM reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_photom_0230.fits'.
# 2026-04-15 18:21:20,391 - stpipe.pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2026-04-15 18:21:20,391 - stpipe.pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2026-04-15 18:21:20,392 - stpipe.pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2026-04-15 18:21:20,392 - stpipe.pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2026-04-15 18:21:20,393 - jwst.pipeline.calwebb_image2 - INFO - Starting calwebb_image2 ...
# 2026-04-15 18:21:20,393 - jwst.pipeline.calwebb_image2 - WARNING - The --save_bsub parameter is deprecated and will be removed in a future release. To toggle saving background-subtracted data, use the background step's --save_results parameter instead.
# 2026-04-15 18:21:20,399 - jwst.pipeline.calwebb_image2 - INFO - Processing product /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs007/stage1/jw01386007001_04101_00002_mirimage
# 2026-04-15 18:21:20,400 - jwst.pipeline.calwebb_image2 - INFO - Working on input /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs007/stage1/jw01386007001_04101_00002_mirimage_rateints.fits ...
# 2026-04-15 18:21:20,615 - stpipe.step - INFO - Step bkg_subtract running with args (<CubeModel(19, 224, 288) from ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00002_mirimage_image2pipeline.fits>, ['/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs031/stage1/jw01386031001_02101_00001_mirimage_rateints.fits', '/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs031/stage1/jw01386031001_03101_00001_mirimage_rateints.fits']).
# 2026-04-15 18:21:20,629 - jwst.background.background_step - INFO - Working on input <CubeModel(19, 224, 288) from ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00002_mirimage_image2pipeline.fits> ...
# 2026-04-15 18:21:20,649 - jwst.background.background_sub - INFO - Accumulate bkg from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs031/stage1/jw01386031001_02101_00001_mirimage_rateints.fits
# 2026-04-15 18:21:20,784 - jwst.background.background_sub - INFO - Accumulate bkg from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs031/stage1/jw01386031001_03101_00001_mirimage_rateints.fits
# 2026-04-15 18:21:20,934 - jwst.background.background_sub - INFO - Subtracting avg bkg from ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00002_mirimage_image2pipeline.fits
# 2026-04-15 18:21:20,964 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00002_mirimage_combinedbackground.fits
# 2026-04-15 18:21:20,964 - jwst.background.background_step - INFO - Combined background written to ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00002_mirimage_combinedbackground.fits.
# 2026-04-15 18:21:21,024 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00002_mirimage_bsubints.fits
# 2026-04-15 18:21:21,025 - stpipe.step - INFO - Step bkg_subtract done
# 2026-04-15 18:21:21,171 - stpipe.step - INFO - Step assign_wcs running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00002_mirimage_bsubints.fits>,).
# 2026-04-15 18:21:21,241 - jwst.assign_wcs.miri - INFO - Created a MIRI mir_4qpm pipeline with references {'distortion': '/home/runner/crds/references/jwst/miri/jwst_miri_distortion_0142.asdf', 'filteroffset': '/home/runner/crds/references/jwst/miri/jwst_miri_filteroffset_0021.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2026-04-15 18:21:21,275 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  209.561565215 -42.103149458 209.570352808 -42.105377737 209.574291526 -42.097078596 209.565481721 -42.094825825
# 2026-04-15 18:21:21,276 - jwst.assign_wcs.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  209.561565215 -42.103149458 209.570352808 -42.105377737 209.574291526 -42.097078596 209.565481721 -42.094825825
# 2026-04-15 18:21:21,277 - jwst.assign_wcs.assign_wcs - INFO - COMPLETED assign_wcs
# 2026-04-15 18:21:21,308 - stpipe.step - INFO - Step assign_wcs done
# 2026-04-15 18:21:21,451 - stpipe.step - INFO - Step flat_field running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00002_mirimage_bsubints.fits>,).
# 2026-04-15 18:21:21,497 - stdatamodels.dynamicdq - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:21:21,498 - stdatamodels.dynamicdq - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:21:21,499 - stdatamodels.dynamicdq - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:21:21,500 - stdatamodels.dynamicdq - WARNING - Keyword DIFF_PATTERN does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:21:21,505 - jwst.flatfield.flat_field_step - INFO - Using FLAT reference file: /home/runner/crds/references/jwst/miri/jwst_miri_flat_0768.fits
# 2026-04-15 18:21:21,506 - jwst.flatfield.flat_field_step - INFO - No reference found for type FFLAT
# 2026-04-15 18:21:21,507 - jwst.flatfield.flat_field_step - INFO - No reference found for type SFLAT
# 2026-04-15 18:21:21,507 - jwst.flatfield.flat_field_step - INFO - No reference found for type DFLAT
# 2026-04-15 18:21:21,550 - stpipe.step - INFO - Step flat_field done
# 2026-04-15 18:21:21,694 - stpipe.step - INFO - Step photom running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00002_mirimage_bsubints.fits>,).
# 2026-04-15 18:21:21,700 - jwst.photom.photom_step - INFO - Using photom reference file: /home/runner/crds/references/jwst/miri/jwst_miri_photom_0230.fits
# 2026-04-15 18:21:21,701 - jwst.photom.photom_step - INFO - Using area reference file: N/A
# 2026-04-15 18:21:21,702 - jwst.photom.photom - INFO - Using instrument: MIRI
# 2026-04-15 18:21:21,702 - jwst.photom.photom - INFO -  detector: MIRIMAGE
# 2026-04-15 18:21:21,703 - jwst.photom.photom - INFO -  exp_type: MIR_4QPM
# 2026-04-15 18:21:21,703 - jwst.photom.photom - INFO -  filter: F1550C
# 2026-04-15 18:21:21,749 - jwst.photom.photom - INFO - Attempting to obtain PIXAR_SR and PIXAR_A2 values from PHOTOM reference file.
# 2026-04-15 18:21:21,749 - jwst.photom.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from PHOTOM reference file.
# 2026-04-15 18:21:21,750 - jwst.photom.photom - INFO -  subarray: MASK1550
# 2026-04-15 18:21:21,751 - jwst.photom.photom - INFO - Multiplicative time dependence correction is 0.994333
# 2026-04-15 18:21:21,752 - jwst.photom.photom - INFO - PHOTMJSR value: 3.52793
# 2026-04-15 18:21:21,790 - stpipe.step - INFO - Step photom done
# 2026-04-15 18:21:21,791 - jwst.pipeline.calwebb_image2 - INFO - Finished processing product /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs007/stage1/jw01386007001_04101_00002_mirimage
# 2026-04-15 18:21:21,792 - jwst.pipeline.calwebb_image2 - INFO - ... ending calwebb_image2
# 2026-04-15 18:21:21,793 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1535.pmap
# 2026-04-15 18:21:21,895 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00002_mirimage_calints.fits
# 2026-04-15 18:21:21,896 - stpipe.step - INFO - Step Image2Pipeline done
# 2026-04-15 18:21:21,896 - jwst.stpipe.core - INFO - Results used jwst version: 2.0.0
# /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages/jwst/associations/association.py:232: UserWarning: Input association file contains path information; note that this can complicate usage and/or sharing of such files.
#   warnings.warn(err_str, UserWarning, stacklevel=1)
# 2026-04-15 18:21:21,970 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-resamplestep_0001.asdf
# 2026-04-15 18:21:21,981 - stpipe.step - INFO - Image2Pipeline instance created.
# 2026-04-15 18:21:21,982 - stpipe.step - INFO - BackgroundStep instance created.
# 2026-04-15 18:21:21,983 - stpipe.step - INFO - AssignWcsStep instance created.
# 2026-04-15 18:21:21,984 - stpipe.step - INFO - FlatFieldStep instance created.
# 2026-04-15 18:21:21,985 - stpipe.step - INFO - PhotomStep instance created.
# 2026-04-15 18:21:21,986 - stpipe.step - INFO - ResampleStep instance created.
# 2026-04-15 18:21:22,134 - stpipe.step - INFO - Step Image2Pipeline running with args ('./miri_coro_demo_data/Obs007/stage2/00003_l2asn.json',).
# 2026-04-15 18:21:22,142 - stpipe.step - INFO - Step Image2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./miri_coro_demo_data/Obs007/stage2
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_bsub: True
#   steps:
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bkg_list: None
#       save_combined_background: True
#       sigma: 3.0
#       maxiters: None
#       soss_source_percentile: 35.0
#       soss_bkg_percentile: None
#       wfss_mmag_extract: None
#       wfss_mask: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#       nrs_ifu_slice_wcs: False
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       apply_time_correction: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
#       propagate_dq: False
#       pixmap_stepsize: 1.0
#       pixmap_order: 1
# 2026-04-15 18:21:22,190 - stpipe.pipeline - INFO - Prefetching reference files for dataset: '00003_l2asn.json' reftypes = ['area', 'bkg', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange']
# 2026-04-15 18:21:22,193 - stpipe.pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2026-04-15 18:21:22,194 - stpipe.pipeline - INFO - Prefetch for BKG reference file is 'N/A'.
# 2026-04-15 18:21:22,194 - stpipe.pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2026-04-15 18:21:22,195 - stpipe.pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2026-04-15 18:21:22,195 - stpipe.pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2026-04-15 18:21:22,196 - stpipe.pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2026-04-15 18:21:22,196 - stpipe.pipeline - INFO - Prefetch for DISTORTION reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_distortion_0142.asdf'.
# 2026-04-15 18:21:22,196 - stpipe.pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2026-04-15 18:21:22,197 - stpipe.pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_filteroffset_0021.asdf'.
# 2026-04-15 18:21:22,197 - stpipe.pipeline - INFO - Prefetch for FLAT reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_flat_0768.fits'.
# 2026-04-15 18:21:22,198 - stpipe.pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2026-04-15 18:21:22,198 - stpipe.pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2026-04-15 18:21:22,199 - stpipe.pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2026-04-15 18:21:22,199 - stpipe.pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2026-04-15 18:21:22,199 - stpipe.pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2026-04-15 18:21:22,200 - stpipe.pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2026-04-15 18:21:22,200 - stpipe.pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2026-04-15 18:21:22,200 - stpipe.pipeline - INFO - Prefetch for PHOTOM reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_photom_0230.fits'.
# 2026-04-15 18:21:22,201 - stpipe.pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2026-04-15 18:21:22,201 - stpipe.pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2026-04-15 18:21:22,202 - stpipe.pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2026-04-15 18:21:22,203 - stpipe.pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2026-04-15 18:21:22,203 - jwst.pipeline.calwebb_image2 - INFO - Starting calwebb_image2 ...
# 2026-04-15 18:21:22,204 - jwst.pipeline.calwebb_image2 - WARNING - The --save_bsub parameter is deprecated and will be removed in a future release. To toggle saving background-subtracted data, use the background step's --save_results parameter instead.
# 2026-04-15 18:21:22,210 - jwst.pipeline.calwebb_image2 - INFO - Processing product /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs007/stage1/jw01386007001_04101_00003_mirimage
# 2026-04-15 18:21:22,210 - jwst.pipeline.calwebb_image2 - INFO - Working on input /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs007/stage1/jw01386007001_04101_00003_mirimage_rateints.fits ...
# 2026-04-15 18:21:22,429 - stpipe.step - INFO - Step bkg_subtract running with args (<CubeModel(19, 224, 288) from ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00003_mirimage_image2pipeline.fits>, ['/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs031/stage1/jw01386031001_02101_00001_mirimage_rateints.fits', '/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs031/stage1/jw01386031001_03101_00001_mirimage_rateints.fits']).
# 2026-04-15 18:21:22,443 - jwst.background.background_step - INFO - Working on input <CubeModel(19, 224, 288) from ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00003_mirimage_image2pipeline.fits> ...
# 2026-04-15 18:21:22,464 - jwst.background.background_sub - INFO - Accumulate bkg from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs031/stage1/jw01386031001_02101_00001_mirimage_rateints.fits
# 2026-04-15 18:21:22,599 - jwst.background.background_sub - INFO - Accumulate bkg from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs031/stage1/jw01386031001_03101_00001_mirimage_rateints.fits
# 2026-04-15 18:21:22,750 - jwst.background.background_sub - INFO - Subtracting avg bkg from ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00003_mirimage_image2pipeline.fits
# 2026-04-15 18:21:22,780 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00003_mirimage_combinedbackground.fits
# 2026-04-15 18:21:22,781 - jwst.background.background_step - INFO - Combined background written to ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00003_mirimage_combinedbackground.fits.
# 2026-04-15 18:21:22,840 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00003_mirimage_bsubints.fits
# 2026-04-15 18:21:22,841 - stpipe.step - INFO - Step bkg_subtract done
# 2026-04-15 18:21:22,986 - stpipe.step - INFO - Step assign_wcs running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00003_mirimage_bsubints.fits>,).
# 2026-04-15 18:21:23,056 - jwst.assign_wcs.miri - INFO - Created a MIRI mir_4qpm pipeline with references {'distortion': '/home/runner/crds/references/jwst/miri/jwst_miri_distortion_0142.asdf', 'filteroffset': '/home/runner/crds/references/jwst/miri/jwst_miri_filteroffset_0021.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2026-04-15 18:21:23,090 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  209.561561686 -42.103148550 209.570349279 -42.105376830 209.574287998 -42.097077689 209.565478193 -42.094824918
# 2026-04-15 18:21:23,091 - jwst.assign_wcs.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  209.561561686 -42.103148550 209.570349279 -42.105376830 209.574287998 -42.097077689 209.565478193 -42.094824918
# 2026-04-15 18:21:23,092 - jwst.assign_wcs.assign_wcs - INFO - COMPLETED assign_wcs
# 2026-04-15 18:21:23,123 - stpipe.step - INFO - Step assign_wcs done
# 2026-04-15 18:21:23,267 - stpipe.step - INFO - Step flat_field running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00003_mirimage_bsubints.fits>,).
# 2026-04-15 18:21:23,313 - stdatamodels.dynamicdq - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:21:23,314 - stdatamodels.dynamicdq - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:21:23,315 - stdatamodels.dynamicdq - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:21:23,316 - stdatamodels.dynamicdq - WARNING - Keyword DIFF_PATTERN does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:21:23,322 - jwst.flatfield.flat_field_step - INFO - Using FLAT reference file: /home/runner/crds/references/jwst/miri/jwst_miri_flat_0768.fits
# 2026-04-15 18:21:23,323 - jwst.flatfield.flat_field_step - INFO - No reference found for type FFLAT
# 2026-04-15 18:21:23,323 - jwst.flatfield.flat_field_step - INFO - No reference found for type SFLAT
# 2026-04-15 18:21:23,324 - jwst.flatfield.flat_field_step - INFO - No reference found for type DFLAT
# 2026-04-15 18:21:23,367 - stpipe.step - INFO - Step flat_field done
# 2026-04-15 18:21:23,514 - stpipe.step - INFO - Step photom running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00003_mirimage_bsubints.fits>,).
# 2026-04-15 18:21:23,520 - jwst.photom.photom_step - INFO - Using photom reference file: /home/runner/crds/references/jwst/miri/jwst_miri_photom_0230.fits
# 2026-04-15 18:21:23,521 - jwst.photom.photom_step - INFO - Using area reference file: N/A
# 2026-04-15 18:21:23,521 - jwst.photom.photom - INFO - Using instrument: MIRI
# 2026-04-15 18:21:23,522 - jwst.photom.photom - INFO -  detector: MIRIMAGE
# 2026-04-15 18:21:23,522 - jwst.photom.photom - INFO -  exp_type: MIR_4QPM
# 2026-04-15 18:21:23,523 - jwst.photom.photom - INFO -  filter: F1550C
# 2026-04-15 18:21:23,568 - jwst.photom.photom - INFO - Attempting to obtain PIXAR_SR and PIXAR_A2 values from PHOTOM reference file.
# 2026-04-15 18:21:23,569 - jwst.photom.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from PHOTOM reference file.
# 2026-04-15 18:21:23,570 - jwst.photom.photom - INFO -  subarray: MASK1550
# 2026-04-15 18:21:23,571 - jwst.photom.photom - INFO - Multiplicative time dependence correction is 0.994332
# 2026-04-15 18:21:23,571 - jwst.photom.photom - INFO - PHOTMJSR value: 3.52793
# 2026-04-15 18:21:23,609 - stpipe.step - INFO - Step photom done
# 2026-04-15 18:21:23,610 - jwst.pipeline.calwebb_image2 - INFO - Finished processing product /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs007/stage1/jw01386007001_04101_00003_mirimage
# 2026-04-15 18:21:23,611 - jwst.pipeline.calwebb_image2 - INFO - ... ending calwebb_image2
# 2026-04-15 18:21:23,612 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1535.pmap
# 2026-04-15 18:21:23,717 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00003_mirimage_calints.fits
# 2026-04-15 18:21:23,718 - stpipe.step - INFO - Step Image2Pipeline done
# 2026-04-15 18:21:23,718 - jwst.stpipe.core - INFO - Results used jwst version: 2.0.0
# /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages/jwst/associations/association.py:232: UserWarning: Input association file contains path information; note that this can complicate usage and/or sharing of such files.
#   warnings.warn(err_str, UserWarning, stacklevel=1)
# 2026-04-15 18:21:23,791 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-resamplestep_0001.asdf
# 2026-04-15 18:21:23,802 - stpipe.step - INFO - Image2Pipeline instance created.
# 2026-04-15 18:21:23,803 - stpipe.step - INFO - BackgroundStep instance created.
# 2026-04-15 18:21:23,804 - stpipe.step - INFO - AssignWcsStep instance created.
# 2026-04-15 18:21:23,805 - stpipe.step - INFO - FlatFieldStep instance created.
# 2026-04-15 18:21:23,806 - stpipe.step - INFO - PhotomStep instance created.
# 2026-04-15 18:21:23,807 - stpipe.step - INFO - ResampleStep instance created.
# 2026-04-15 18:21:23,951 - stpipe.step - INFO - Step Image2Pipeline running with args ('./miri_coro_demo_data/Obs007/stage2/00004_l2asn.json',).
# 2026-04-15 18:21:23,959 - stpipe.step - INFO - Step Image2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./miri_coro_demo_data/Obs007/stage2
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_bsub: True
#   steps:
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bkg_list: None
#       save_combined_background: True
#       sigma: 3.0
#       maxiters: None
#       soss_source_percentile: 35.0
#       soss_bkg_percentile: None
#       wfss_mmag_extract: None
#       wfss_mask: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#       nrs_ifu_slice_wcs: False
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       apply_time_correction: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
#       propagate_dq: False
#       pixmap_stepsize: 1.0
#       pixmap_order: 1
# 2026-04-15 18:21:24,007 - stpipe.pipeline - INFO - Prefetching reference files for dataset: '00004_l2asn.json' reftypes = ['area', 'bkg', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange']
# 2026-04-15 18:21:24,010 - stpipe.pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2026-04-15 18:21:24,011 - stpipe.pipeline - INFO - Prefetch for BKG reference file is 'N/A'.
# 2026-04-15 18:21:24,011 - stpipe.pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2026-04-15 18:21:24,012 - stpipe.pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2026-04-15 18:21:24,012 - stpipe.pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2026-04-15 18:21:24,013 - stpipe.pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# ...
# 2026-04-15 18:21:32,596 - jwst.photom.photom_step - INFO - Using area reference file: N/A
# 2026-04-15 18:21:32,597 - jwst.photom.photom - INFO - Using instrument: MIRI
# 2026-04-15 18:21:32,598 - jwst.photom.photom - INFO -  detector: MIRIMAGE
# 2026-04-15 18:21:32,598 - jwst.photom.photom - INFO -  exp_type: MIR_4QPM
# 2026-04-15 18:21:32,599 - jwst.photom.photom - INFO -  filter: F1550C
# 2026-04-15 18:21:32,644 - jwst.photom.photom - INFO - Attempting to obtain PIXAR_SR and PIXAR_A2 values from PHOTOM reference file.
# 2026-04-15 18:21:32,644 - jwst.photom.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from PHOTOM reference file.
# 2026-04-15 18:21:32,646 - jwst.photom.photom - INFO -  subarray: MASK1550
# 2026-04-15 18:21:32,647 - jwst.photom.photom - INFO - Multiplicative time dependence correction is 0.99433
# 2026-04-15 18:21:32,647 - jwst.photom.photom - INFO - PHOTMJSR value: 3.52794
# 2026-04-15 18:21:32,685 - stpipe.step - INFO - Step photom done
# 2026-04-15 18:21:32,686 - jwst.pipeline.calwebb_image2 - INFO - Finished processing product /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs007/stage1/jw01386007001_04101_00008_mirimage
# 2026-04-15 18:21:32,687 - jwst.pipeline.calwebb_image2 - INFO - ... ending calwebb_image2
# 2026-04-15 18:21:32,688 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1535.pmap
# 2026-04-15 18:21:32,789 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00008_mirimage_calints.fits
# 2026-04-15 18:21:32,790 - stpipe.step - INFO - Step Image2Pipeline done
# 2026-04-15 18:21:32,791 - jwst.stpipe.core - INFO - Results used jwst version: 2.0.0
# /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages/jwst/associations/association.py:232: UserWarning: Input association file contains path information; note that this can complicate usage and/or sharing of such files.
#   warnings.warn(err_str, UserWarning, stacklevel=1)
# 2026-04-15 18:21:32,861 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-resamplestep_0001.asdf
# 2026-04-15 18:21:32,872 - stpipe.step - INFO - Image2Pipeline instance created.
# 2026-04-15 18:21:32,874 - stpipe.step - INFO - BackgroundStep instance created.
# 2026-04-15 18:21:32,875 - stpipe.step - INFO - AssignWcsStep instance created.
# 2026-04-15 18:21:32,875 - stpipe.step - INFO - FlatFieldStep instance created.
# 2026-04-15 18:21:32,876 - stpipe.step - INFO - PhotomStep instance created.
# 2026-04-15 18:21:32,877 - stpipe.step - INFO - ResampleStep instance created.
# 2026-04-15 18:21:33,023 - stpipe.step - INFO - Step Image2Pipeline running with args ('./miri_coro_demo_data/Obs007/stage2/00009_l2asn.json',).
# 2026-04-15 18:21:33,031 - stpipe.step - INFO - Step Image2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./miri_coro_demo_data/Obs007/stage2
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_bsub: True
#   steps:
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bkg_list: None
#       save_combined_background: True
#       sigma: 3.0
#       maxiters: None
#       soss_source_percentile: 35.0
#       soss_bkg_percentile: None
#       wfss_mmag_extract: None
#       wfss_mask: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#       nrs_ifu_slice_wcs: False
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       apply_time_correction: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
#       propagate_dq: False
#       pixmap_stepsize: 1.0
#       pixmap_order: 1
# 2026-04-15 18:21:33,079 - stpipe.pipeline - INFO - Prefetching reference files for dataset: '00009_l2asn.json' reftypes = ['area', 'bkg', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange']
# 2026-04-15 18:21:33,082 - stpipe.pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2026-04-15 18:21:33,083 - stpipe.pipeline - INFO - Prefetch for BKG reference file is 'N/A'.
# 2026-04-15 18:21:33,083 - stpipe.pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2026-04-15 18:21:33,084 - stpipe.pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2026-04-15 18:21:33,084 - stpipe.pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2026-04-15 18:21:33,085 - stpipe.pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2026-04-15 18:21:33,085 - stpipe.pipeline - INFO - Prefetch for DISTORTION reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_distortion_0142.asdf'.
# 2026-04-15 18:21:33,086 - stpipe.pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2026-04-15 18:21:33,086 - stpipe.pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_filteroffset_0021.asdf'.
# 2026-04-15 18:21:33,086 - stpipe.pipeline - INFO - Prefetch for FLAT reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_flat_0768.fits'.
# 2026-04-15 18:21:33,087 - stpipe.pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2026-04-15 18:21:33,088 - stpipe.pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2026-04-15 18:21:33,088 - stpipe.pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2026-04-15 18:21:33,088 - stpipe.pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2026-04-15 18:21:33,089 - stpipe.pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2026-04-15 18:21:33,089 - stpipe.pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2026-04-15 18:21:33,090 - stpipe.pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2026-04-15 18:21:33,090 - stpipe.pipeline - INFO - Prefetch for PHOTOM reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_photom_0230.fits'.
# 2026-04-15 18:21:33,091 - stpipe.pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2026-04-15 18:21:33,091 - stpipe.pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2026-04-15 18:21:33,092 - stpipe.pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2026-04-15 18:21:33,092 - stpipe.pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2026-04-15 18:21:33,093 - jwst.pipeline.calwebb_image2 - INFO - Starting calwebb_image2 ...
# 2026-04-15 18:21:33,093 - jwst.pipeline.calwebb_image2 - WARNING - The --save_bsub parameter is deprecated and will be removed in a future release. To toggle saving background-subtracted data, use the background step's --save_results parameter instead.
# 2026-04-15 18:21:33,099 - jwst.pipeline.calwebb_image2 - INFO - Processing product /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs007/stage1/jw01386007001_04101_00009_mirimage
# 2026-04-15 18:21:33,100 - jwst.pipeline.calwebb_image2 - INFO - Working on input /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs007/stage1/jw01386007001_04101_00009_mirimage_rateints.fits ...
# 2026-04-15 18:21:33,311 - stpipe.step - INFO - Step bkg_subtract running with args (<CubeModel(19, 224, 288) from ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00009_mirimage_image2pipeline.fits>, ['/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs031/stage1/jw01386031001_02101_00001_mirimage_rateints.fits', '/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs031/stage1/jw01386031001_03101_00001_mirimage_rateints.fits']).
# 2026-04-15 18:21:33,325 - jwst.background.background_step - INFO - Working on input <CubeModel(19, 224, 288) from ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00009_mirimage_image2pipeline.fits> ...
# 2026-04-15 18:21:33,346 - jwst.background.background_sub - INFO - Accumulate bkg from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs031/stage1/jw01386031001_02101_00001_mirimage_rateints.fits
# 2026-04-15 18:21:33,480 - jwst.background.background_sub - INFO - Accumulate bkg from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs031/stage1/jw01386031001_03101_00001_mirimage_rateints.fits
# 2026-04-15 18:21:33,631 - jwst.background.background_sub - INFO - Subtracting avg bkg from ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00009_mirimage_image2pipeline.fits
# 2026-04-15 18:21:33,661 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00009_mirimage_combinedbackground.fits
# 2026-04-15 18:21:33,661 - jwst.background.background_step - INFO - Combined background written to ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00009_mirimage_combinedbackground.fits.
# 2026-04-15 18:21:33,721 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00009_mirimage_bsubints.fits
# 2026-04-15 18:21:33,722 - stpipe.step - INFO - Step bkg_subtract done
# 2026-04-15 18:21:33,867 - stpipe.step - INFO - Step assign_wcs running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00009_mirimage_bsubints.fits>,).
# 2026-04-15 18:21:33,938 - jwst.assign_wcs.miri - INFO - Created a MIRI mir_4qpm pipeline with references {'distortion': '/home/runner/crds/references/jwst/miri/jwst_miri_distortion_0142.asdf', 'filteroffset': '/home/runner/crds/references/jwst/miri/jwst_miri_filteroffset_0021.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2026-04-15 18:21:33,971 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  209.561568759 -42.103150377 209.570356352 -42.105378655 209.574295070 -42.097079514 209.565485265 -42.094826744
# 2026-04-15 18:21:33,972 - jwst.assign_wcs.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  209.561568759 -42.103150377 209.570356352 -42.105378655 209.574295070 -42.097079514 209.565485265 -42.094826744
# 2026-04-15 18:21:33,973 - jwst.assign_wcs.assign_wcs - INFO - COMPLETED assign_wcs
# 2026-04-15 18:21:34,004 - stpipe.step - INFO - Step assign_wcs done
# 2026-04-15 18:21:34,158 - stpipe.step - INFO - Step flat_field running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00009_mirimage_bsubints.fits>,).
# 2026-04-15 18:21:34,204 - stdatamodels.dynamicdq - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:21:34,205 - stdatamodels.dynamicdq - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:21:34,206 - stdatamodels.dynamicdq - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:21:34,207 - stdatamodels.dynamicdq - WARNING - Keyword DIFF_PATTERN does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-04-15 18:21:34,213 - jwst.flatfield.flat_field_step - INFO - Using FLAT reference file: /home/runner/crds/references/jwst/miri/jwst_miri_flat_0768.fits
# 2026-04-15 18:21:34,213 - jwst.flatfield.flat_field_step - INFO - No reference found for type FFLAT
# 2026-04-15 18:21:34,214 - jwst.flatfield.flat_field_step - INFO - No reference found for type SFLAT
# 2026-04-15 18:21:34,215 - jwst.flatfield.flat_field_step - INFO - No reference found for type DFLAT
# 2026-04-15 18:21:34,258 - stpipe.step - INFO - Step flat_field done
# 2026-04-15 18:21:34,401 - stpipe.step - INFO - Step photom running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00009_mirimage_bsubints.fits>,).
# 2026-04-15 18:21:34,407 - jwst.photom.photom_step - INFO - Using photom reference file: /home/runner/crds/references/jwst/miri/jwst_miri_photom_0230.fits
# 2026-04-15 18:21:34,408 - jwst.photom.photom_step - INFO - Using area reference file: N/A
# 2026-04-15 18:21:34,408 - jwst.photom.photom - INFO - Using instrument: MIRI
# 2026-04-15 18:21:34,409 - jwst.photom.photom - INFO -  detector: MIRIMAGE
# 2026-04-15 18:21:34,410 - jwst.photom.photom - INFO -  exp_type: MIR_4QPM
# 2026-04-15 18:21:34,410 - jwst.photom.photom - INFO -  filter: F1550C
# 2026-04-15 18:21:34,455 - jwst.photom.photom - INFO - Attempting to obtain PIXAR_SR and PIXAR_A2 values from PHOTOM reference file.
# 2026-04-15 18:21:34,456 - jwst.photom.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from PHOTOM reference file.
# 2026-04-15 18:21:34,457 - jwst.photom.photom - INFO -  subarray: MASK1550
# 2026-04-15 18:21:34,458 - jwst.photom.photom - INFO - Multiplicative time dependence correction is 0.99433
# 2026-04-15 18:21:34,459 - jwst.photom.photom - INFO - PHOTMJSR value: 3.52794
# 2026-04-15 18:21:34,497 - stpipe.step - INFO - Step photom done
# 2026-04-15 18:21:34,498 - jwst.pipeline.calwebb_image2 - INFO - Finished processing product /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/MIRI/Coronagraphy/miri_coro_demo_data/Obs007/stage1/jw01386007001_04101_00009_mirimage
# 2026-04-15 18:21:34,499 - jwst.pipeline.calwebb_image2 - INFO - ... ending calwebb_image2
# 2026-04-15 18:21:34,499 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1535.pmap
# 2026-04-15 18:21:34,600 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/Obs007/stage2/jw01386007001_04101_00009_mirimage_calints.fits
# 2026-04-15 18:21:34,601 - stpipe.step - INFO - Step Image2Pipeline done
# 2026-04-15 18:21:34,602 - jwst.stpipe.core - INFO - Results used jwst version: 2.0.0

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
print(f"Runtime for Image2: {time1 - time_image2} seconds")
# Out:
# Runtime so far: 1260.2141 seconds
# Runtime for Image2: 21.94500343200002 seconds

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ## 7.-Coron3 Pipeline
# ------------------
# In this section, we'll run the Coron3 (calwebb_coron3) pipeline on the calibrated MIRI coronagraphic exposures to produce PSF-subtracted, resampled, combined images of the source object. The input to calwebb_coron3 must be in the form of an association file that lists one or more exposures of a science target and one or more reference PSF targets. The individual target and reference PSF exposures should be in the form of 3D photometrically calibrated (`_calints`) products from calwebb_image2 processing. Each pipeline step will loop over the 3D stack of per-integration images contained in each exposure. The relevant steps are:
#
# - [outlier_detection](https://jwst-pipeline.readthedocs.io/en/latest/jwst/outlier_detection/index.html#outlier-detection-step): CR-flag all PSF and science target exposures
# - [stack_refs](https://jwst-pipeline.readthedocs.io/en/latest/jwst/stack_refs/index.html#stack-refs-step): Reference PSF stacking
# - [align_refs](https://jwst-pipeline.readthedocs.io/en/latest/jwst/align_refs/index.html#align-refs-step): Reference PSF alignment
# - [klip](https://jwst-pipeline.readthedocs.io/en/latest/jwst/klip/index.html#klip-step): PSF subtraction with the KLIP algorithm
# - [resample](https://jwst-pipeline.readthedocs.io/en/latest/jwst/resample/index.html#resample-step): Image resampling and World Coordinate System registration
#
# See https://jwst-docs.stsci.edu/jwst-science-calibration-pipeline/stages-of-jwst-data-processing/calwebb_coron3

# %%
time_coron3 = time.perf_counter()

# %%
# Set up a dictionary to define how the Coron3 pipeline should be configured

# Boilerplate dictionary setup
coron3dict = defaultdict(dict)

# Set the maximum number of KL transform rows to keep when computing the PSF fit to the target.
coron3dict['klip']['truncate'] = 25   # The maximum number of KL modes to use.

# Overrides for various reference files
# Files should be in the base local directory or provide full path
#coron3dict['align_refs']['override_psfmask'] = 'myfile.fits'  # The PSFMASK reference file

# Options for adjusting performance for the outlier detection step
#coron3dict['outlier_detection']['kernel_size'] = '7 7'  # Dial this to adjust the detector kernel size
#coron3dict['outlier_detection']['threshold_percent'] = 99.8  # Dial this to be more/less aggressive in outlier flagging (values closer to 100% are less aggressive)

# Options for adjusting the resample step
#coron3dict['resample']['pixfrac'] = 1.0  # Fraction by which input pixels are “shrunk” before being drizzled onto the output image grid
#coron3dict['resample']['kernel'] = 'square'  # Kernel form used to distribute flux onto the output image
#coron3dict['resample']['fillval'] = 'INDEF'  # Value to assign to output pixels that have zero weight or do not receive any flux from any input pixels during drizzling
#coron3dict['resample']['weight_type'] = 'ivm'  # Weighting type for each input image.
#coron3dict['resample']['output_shape'] = None  
#coron3dict['resample']['crpix'] = None
#coron3dict['resample']['crval'] = None
#coron3dict['resample']['rotation'] = None
#coron3dict['resample']['pixel_scale_ratio'] = 1.0
#coron3dict['resample']['pixel_scale'] = None
#coron3dict['resample']['output_wcs'] = ''
#coron3dict['resample']['single'] = False
#coron3dict['resample']['blendheaders'] = True

# %% [markdown]
# Define a function to create association files for Stage 3. It creates an association from a list of science exposures and a list of PSF reference exposures.

# %%
def writel3asn(scifiles, ref_targ_files, asnfile, prodname):
    """Create an association from a list of science exposures and a list of PSF reference exposures, 
    intended for calwebb_coron3 processing.

    Parameters
    ----------
    scifiles : list
        List of science files
    ref_targ_files : list
        List of reference files
    asnfile : str
        The path to the association file.
    """
    # Define the basic association of science files
    asn = afl.asn_from_list(scifiles, rule=DMS_Level3_Base, product_name=prodname)

    # Add reference target files to the association
    nref = len(ref_targ_files)
    for ii in range(0, nref):
        asn['products'][0]['members'].append({'expname': ref_targ_files[ii], 'exptype': 'psf'})

    # Write the association to a json file
    _, serialized = asn.dump()
    with open(asnfile, 'w') as outfile:
        outfile.write(serialized)

# %%
# Science Files need the calints.fits files
sstring = os.path.join(image2_sci_r1_dir, 'jw*mirimage*calints.fits')
sstring2 = os.path.join(image2_sci_r2_dir, 'jw*mirimage*calints.fits')
r1_calfiles = sorted(glob.glob(sstring))
r2_calfiles = sorted(glob.glob(sstring2))
calfiles = r1_calfiles + r2_calfiles

# Check that these are the mask/filter to use
calfiles = select_mask_filter_files(calfiles, use_mask, use_filter)

# Reference target Files need the calints.fits files
sstring = os.path.join(image2_ref_targ_dir, 'jw*mirimage*calints.fits')
ref_targ_files = sorted(glob.glob(sstring))

# Check that these are the mask/filter to use
ref_targ_files = select_mask_filter_files(ref_targ_files, use_mask, use_filter)

print('Found ' + str(len(calfiles)) + ' science files to process')
print('Found ' + str(len(ref_targ_files)) + ' reference PSF files to process')
# Out:
# Found 2 science files to process
# Found 9 reference PSF files to process

# %% [markdown]
# Make an association file that includes all of the Science and Reference files and run Coron3

# %%
if docoron3:
    asnfile = os.path.join(coron3_dir, 'l3asn.json')
    writel3asn(calfiles, ref_targ_files, asnfile, 'Level 3')
    Coron3Pipeline.call(asnfile, steps=coron3dict, save_results=True, output_dir=coron3_dir)
else:
    print('Skipping coron3 processing')
# Out:
# /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages/jwst/associations/association.py:232: UserWarning: Input association file contains path information; note that this can complicate usage and/or sharing of such files.
#   warnings.warn(err_str, UserWarning, stacklevel=1)
# 2026-04-15 18:21:34,818 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-resamplestep_0001.asdf
# 2026-04-15 18:21:34,829 - stpipe.step - INFO - Coron3Pipeline instance created.
# 2026-04-15 18:21:34,830 - stpipe.step - INFO - StackRefsStep instance created.
# 2026-04-15 18:21:34,831 - stpipe.step - INFO - AlignRefsStep instance created.
# 2026-04-15 18:21:34,831 - stpipe.step - INFO - KlipStep instance created.
# 2026-04-15 18:21:34,833 - stpipe.step - INFO - OutlierDetectionStep instance created.
# 2026-04-15 18:21:34,834 - stpipe.step - INFO - ResampleStep instance created.
# 2026-04-15 18:21:34,981 - stpipe.step - INFO - Step Coron3Pipeline running with args ('./miri_coro_demo_data/stage3/l3asn.json',).
# 2026-04-15 18:21:34,989 - stpipe.step - INFO - Step Coron3Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./miri_coro_demo_data/stage3
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: i2d
#   search_output_file: True
#   input_dir: ''
#   steps:
#     stack_refs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     align_refs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       median_box_length: 3
#       bad_bits: DO_NOT_USE
#     klip:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       truncate: 25
#     outlier_detection:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: False
#       input_dir: ''
#       weight_type: ivm
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       maskpt: 0.7
#       snr: 5.0 4.0
#       scale: 1.2 0.7
#       backg: 0.0
#       kernel_size: 7 7
#       threshold_percent: 99.8
#       rolling_window_width: 25
#       ifu_second_check: False
#       save_intermediate_results: False
#       resample_data: True
#       good_bits: ~DO_NOT_USE
#       in_memory: True
#       pixmap_stepsize: 1.0
#       pixmap_order: 1
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
#       propagate_dq: False
#       pixmap_stepsize: 1.0
#       pixmap_order: 1
# 2026-04-15 18:21:34,991 - jwst.pipeline.calwebb_coron3 - INFO - Starting calwebb_coron3 ...
# 2026-04-15 18:21:36,352 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386007001_04101_00001_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:21:36,362 - CRDS - INFO -  Fetching  /home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits  267.8 K bytes  (1 / 1 files) (0 / 267.8 K bytes)
# 2026-04-15 18:21:36,459 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:21:36,461 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386007001_04101_00002_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:21:36,463 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:21:36,465 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386007001_04101_00003_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:21:36,467 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:21:36,468 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386007001_04101_00004_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:21:36,471 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:21:36,472 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386007001_04101_00005_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:21:36,475 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:21:36,476 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386007001_04101_00006_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:21:36,479 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:21:36,480 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386007001_04101_00007_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:21:36,482 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:21:36,484 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386007001_04101_00008_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:21:36,486 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:21:36,488 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386007001_04101_00009_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:21:36,490 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:21:36,491 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386008001_04101_00001_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:21:36,493 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:21:36,495 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386009001_04101_00001_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:21:36,497 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:21:36,705 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00001_mirimage_calints.fits>,).
# 2026-04-15 18:21:36,706 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:21:36,707 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:21:36,714 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:21:36,843 - jwst.outlier_detection.utils - INFO - 64 pixels marked as outliers
# 2026-04-15 18:21:36,958 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3/jw01386007001_04101_00001_mirimage_a3001_crfints.fits
# 2026-04-15 18:21:36,959 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:21:37,120 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00002_mirimage_calints.fits>,).
# 2026-04-15 18:21:37,121 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:21:37,122 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:21:37,128 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:21:37,252 - jwst.outlier_detection.utils - INFO - 62 pixels marked as outliers
# 2026-04-15 18:21:37,366 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3/jw01386007001_04101_00002_mirimage_a3001_crfints.fits
# 2026-04-15 18:21:37,367 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:21:37,535 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00003_mirimage_calints.fits>,).
# 2026-04-15 18:21:37,536 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:21:37,537 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:21:37,544 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:21:37,667 - jwst.outlier_detection.utils - INFO - 128 pixels marked as outliers
# 2026-04-15 18:21:37,781 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3/jw01386007001_04101_00003_mirimage_a3001_crfints.fits
# 2026-04-15 18:21:37,782 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:21:37,944 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00004_mirimage_calints.fits>,).
# 2026-04-15 18:21:37,945 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:21:37,946 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:21:37,952 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:21:38,075 - jwst.outlier_detection.utils - INFO - 128 pixels marked as outliers
# 2026-04-15 18:21:38,190 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3/jw01386007001_04101_00004_mirimage_a3001_crfints.fits
# 2026-04-15 18:21:38,191 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:21:38,353 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00005_mirimage_calints.fits>,).
# 2026-04-15 18:21:38,354 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:21:38,355 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:21:38,362 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:21:38,484 - jwst.outlier_detection.utils - INFO - 115 pixels marked as outliers
# 2026-04-15 18:21:38,599 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3/jw01386007001_04101_00005_mirimage_a3001_crfints.fits
# 2026-04-15 18:21:38,600 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:21:38,761 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00006_mirimage_calints.fits>,).
# 2026-04-15 18:21:38,762 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:21:38,763 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:21:38,770 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:21:38,894 - jwst.outlier_detection.utils - INFO - 155 pixels marked as outliers
# 2026-04-15 18:21:39,009 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3/jw01386007001_04101_00006_mirimage_a3001_crfints.fits
# 2026-04-15 18:21:39,010 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:21:39,177 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00007_mirimage_calints.fits>,).
# 2026-04-15 18:21:39,177 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:21:39,178 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:21:39,185 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:21:39,310 - jwst.outlier_detection.utils - INFO - 213 pixels marked as outliers
# 2026-04-15 18:21:39,426 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3/jw01386007001_04101_00007_mirimage_a3001_crfints.fits
# 2026-04-15 18:21:39,427 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:21:39,594 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00008_mirimage_calints.fits>,).
# 2026-04-15 18:21:39,595 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:21:39,595 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:21:39,602 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:21:39,727 - jwst.outlier_detection.utils - INFO - 250 pixels marked as outliers
# 2026-04-15 18:21:39,843 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3/jw01386007001_04101_00008_mirimage_a3001_crfints.fits
# 2026-04-15 18:21:39,844 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:21:40,005 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00009_mirimage_calints.fits>,).
# 2026-04-15 18:21:40,006 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:21:40,007 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:21:40,014 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:21:40,136 - jwst.outlier_detection.utils - INFO - 216 pixels marked as outliers
# 2026-04-15 18:21:40,252 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3/jw01386007001_04101_00009_mirimage_a3001_crfints.fits
# 2026-04-15 18:21:40,253 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:21:40,413 - stpipe.step - INFO - Step stack_refs running with args (<jwst.datamodels.container.ModelContainer object at 0x7f0ac80d1f90>,).
# 2026-04-15 18:21:40,423 - jwst.coron.stack_refs - INFO -  Adding psf member 1 to output stack
# 2026-04-15 18:21:40,426 - jwst.coron.stack_refs - INFO -  Adding psf member 2 to output stack
# 2026-04-15 18:21:40,428 - jwst.coron.stack_refs - INFO -  Adding psf member 3 to output stack
# 2026-04-15 18:21:40,431 - jwst.coron.stack_refs - INFO -  Adding psf member 4 to output stack
# 2026-04-15 18:21:40,434 - jwst.coron.stack_refs - INFO -  Adding psf member 5 to output stack
# 2026-04-15 18:21:40,437 - jwst.coron.stack_refs - INFO -  Adding psf member 6 to output stack
# 2026-04-15 18:21:40,440 - jwst.coron.stack_refs - INFO -  Adding psf member 7 to output stack
# 2026-04-15 18:21:40,442 - jwst.coron.stack_refs - INFO -  Adding psf member 8 to output stack
# 2026-04-15 18:21:40,445 - jwst.coron.stack_refs - INFO -  Adding psf member 9 to output stack
# 2026-04-15 18:21:40,505 - stpipe.step - INFO - Step stack_refs done
# 2026-04-15 18:21:40,607 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3/Level 3_psfstack.fits
# 2026-04-15 18:21:40,772 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(60, 224, 288) from jw01386008001_04101_00001_mirimage_calints.fits>,).
# 2026-04-15 18:21:40,773 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:21:40,774 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:21:40,783 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:21:41,000 - jwst.outlier_detection.utils - INFO - 34 pixels marked as outliers
# 2026-04-15 18:21:41,154 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3/jw01386008001_04101_00001_mirimage_a3001_crfints.fits
# 2026-04-15 18:21:41,155 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:21:41,316 - stpipe.step - INFO - Step align_refs running with args (<CubeModel(60, 224, 288) from jw01386008001_04101_00001_mirimage_a3001_crfints.fits>, <CubeModel(171, 224, 288) from Level 3_psfstack.fits>).
# 2026-04-15 18:21:41,364 - jwst.coron.align_refs_step - INFO - Using PSFMASK reference file /home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits
# 2026-04-15 18:22:26,033 - stpipe.step - INFO - Step align_refs done
# 2026-04-15 18:22:26,135 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3/jw01386008001_04101_00001_mirimage_a3001_psfalign.fits
# 2026-04-15 18:22:26,304 - stpipe.step - INFO - Step klip running with args (<CubeModel(60, 224, 288) from jw01386008001_04101_00001_mirimage_a3001_crfints.fits>, <CubeModel
- jwst.stpipe.core - INFO - Results used jwst version: 2.0.0

# %% [markdown]
# Run calwebb_image3 using the call method.

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
print(f"Runtime for coron3: {time1 - time_coron3} seconds")
# Out:
# Runtime so far: 1399.9213 seconds
# Runtime for coron3: 139.70322438599987 seconds

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ## 8.-Examine the output
# ------------------
# Here we'll plot the data to see what our source looks like.

# %%
# Stage 3 output files

# Individual exposures
sstring = os.path.join(coron3_dir, 'jw*psfsub.fits')
psfsubfiles = sorted(glob.glob(sstring))
npsfsub = len(psfsubfiles)

# Combined exposure
sstring = os.path.join(coron3_dir, '*i2d.fits')
i2dfiles = sorted(glob.glob(sstring))

# %%
if npsfsub == 1:
    imgs = {'roll1': datamodels.open(psfsubfiles[0]).data.copy(),
            'combo': datamodels.open(i2dfiles[0]).data.copy()}
else:
    imgs = {'roll1': datamodels.open(psfsubfiles[0]).data.copy(),
            'roll2': datamodels.open(psfsubfiles[1]).data.copy(),
            'combo': datamodels.open(i2dfiles[0]).data.copy()}

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(16, 8))
vmin, vmax = np.nanquantile(np.concatenate(list([i.ravel() for i in imgs.values()])), [0.05, 0.95])
for i, roll in enumerate(imgs.keys()):
    img = imgs[roll]
    while img.ndim > 2:
        img = np.nanmedian(img[0:60], axis=0)
    ax = axes[i]
    ax.set_title(roll)
    ax.imshow(img, vmin=-0.5, vmax=1)

# %% [markdown]
# ### Overlay sky coordinates
#
# Overlay the RA and Dec grid over the combined rolls

# %%
with fits.open(i2dfiles[0]) as f:
    wcs = WCS(f[1].header)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2022-07-17T22:58:10.204' from MJD-BEG.
# Set DATE-AVG to '2022-07-18T00:15:08.760' from MJD-AVG.
# Set DATE-END to '2022-07-18T01:32:07.316' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -69.981478 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -37.692706 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1737840324.368 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]

# %%
# The star coordinates at the time of observation are in the header
exp_file = uncal_sci_r1_files[0]
targ_ra = fits.getval(exp_file, 'TARG_RA', 0)
targ_dec = fits.getval(exp_file, 'TARG_DEC', 0)
starcoord = SkyCoord(targ_ra, targ_dec, unit='deg', frame='icrs')

# %%
fig, ax = plt.subplots(1, 1, subplot_kw={'projection': wcs})
vmin, vmax = np.nanquantile(imgs['combo'], [0.01, 0.99])
ax.imshow(imgs['combo'], vmin=vmin, vmax=vmax)
ax.scatter(*wcs.world_to_pixel(starcoord),
           marker='x', s=100, c='w')
ax.grid(True)

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ## 9.-Advanced Usage- PSF Reference Library
# ------------------
# In the above sections, we processed a single observation of a science target and its associated PSF reference target. However, the JWST archive contains many observations of MIRI coronagraphic PSF reference targets that could be used to construct a larger library of reference PSFs for improved PSF subtraction. In this section, we'll show how to use multiple observations of different PSF reference targets through the pipeline and assemble them into a single association that can be used for PSF subtraction.
#
# First we need to query the MAST database for potential references, and to do so we will make use of functions held within the local *coron_psflib_functions.py* file.

# %%
download_coron_references=None

# Check PSF library functions code is available to import
if importlib.util.find_spec("coron_psflib_functions") is None:
    print("Could not find `coron_psflib_functions.py` on the Python path or in the current project. Please ensure you have the latest pipeline notebook installation, or download `coron_psflib_functions.py` from the notebook repository directly.")
else:
    from coron_psflib_functions import download_coron_references
    print("Imported `coron_psflib_functions.py` successfully")
# Out:
# Imported `coron_psflib_functions.py` successfully

# %%
# If the relevant psflib functions were found and docoron3_psflib is True, proceed with PSF reference library
if download_coron_references and docoron3_psflib:
    # In this case we'll skip to the stage 2 products to avoid manual reprocessing.
    additional_ref_dir = os.path.join(basedir, 'ObsRef/stage2/')

    # We also need to provide the current calibrated science and reference files we're using so that we can match an appropriate reference and avoid duplicates.
    current_files = np.concatenate([calfiles, ref_targ_files])

    # Run function to download the files
    download_coron_references(current_files, download_dir=additional_ref_dir, num_refs=2)

# %% [markdown]
# Now that we have some files downloaded, we can simply add them to the reference target files list.

# %%
# Gather the filenames of the downloaded additional reference files.
if download_coron_references and docoron3_psflib:
    # Get the files
    sstring = os.path.join(additional_ref_dir, 'jw*mirimage*calints.fits')
    additional_ref_targ_files = sorted(glob.glob(sstring))

    # Add them to the current list
    psflib_ref_targ_files = np.concatenate([ref_targ_files, additional_ref_targ_files])

    # Check that these are the mask/filter to use
    psflib_ref_targ_files = select_mask_filter_files(psflib_ref_targ_files, use_mask, use_filter)

# %% [markdown]
# And run the Coron3 pipeline using the same settings as before using the call method.

# %%
if download_coron_references and docoron3_psflib:
    asnfile = os.path.join(coron3_psflib_dir, 'l3asn.json')
    writel3asn(calfiles, psflib_ref_targ_files, asnfile, 'Level 3')
    Coron3Pipeline.call(asnfile, steps=coron3dict, save_results=True, output_dir=coron3_psflib_dir)
else:
    print('Skipping coron3 processing')
# Out:
# /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages/jwst/associations/association.py:232: UserWarning: Input association file contains path information; note that this can complicate usage and/or sharing of such files.
#   warnings.warn(err_str, UserWarning, stacklevel=1)
# 2026-04-15 18:24:00,820 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /home/runner/crds/references/jwst/miri/jwst_miri_pars-resamplestep_0001.asdf
# 2026-04-15 18:24:00,831 - stpipe.step - INFO - Coron3Pipeline instance created.
# 2026-04-15 18:24:00,832 - stpipe.step - INFO - StackRefsStep instance created.
# 2026-04-15 18:24:00,833 - stpipe.step - INFO - AlignRefsStep instance created.
# 2026-04-15 18:24:00,834 - stpipe.step - INFO - KlipStep instance created.
# 2026-04-15 18:24:00,835 - stpipe.step - INFO - OutlierDetectionStep instance created.
# 2026-04-15 18:24:00,836 - stpipe.step - INFO - ResampleStep instance created.
# 2026-04-15 18:24:01,021 - stpipe.step - INFO - Step Coron3Pipeline running with args ('./miri_coro_demo_data/stage3_psflib/l3asn.json',).
# 2026-04-15 18:24:01,029 - stpipe.step - INFO - Step Coron3Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./miri_coro_demo_data/stage3_psflib/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: i2d
#   search_output_file: True
#   input_dir: ''
#   steps:
#     stack_refs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     align_refs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       median_box_length: 3
#       bad_bits: DO_NOT_USE
#     klip:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       truncate: 25
#     outlier_detection:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: False
#       input_dir: ''
#       weight_type: ivm
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       maskpt: 0.7
#       snr: 5.0 4.0
#       scale: 1.2 0.7
#       backg: 0.0
#       kernel_size: 7 7
#       threshold_percent: 99.8
#       rolling_window_width: 25
#       ifu_second_check: False
#       save_intermediate_results: False
#       resample_data: True
#       good_bits: ~DO_NOT_USE
#       in_memory: True
#       pixmap_stepsize: 1.0
#       pixmap_order: 1
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
#       propagate_dq: False
#       pixmap_stepsize: 1.0
#       pixmap_order: 1
# 2026-04-15 18:24:01,032 - jwst.pipeline.calwebb_coron3 - INFO - Starting calwebb_coron3 ...
# 2026-04-15 18:24:04,236 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386007001_04101_00001_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:24:04,239 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:24:04,240 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386007001_04101_00002_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:24:04,243 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:24:04,244 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386007001_04101_00003_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:24:04,246 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:24:04,248 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386007001_04101_00004_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:24:04,250 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:24:04,252 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386007001_04101_00005_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:24:04,254 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:24:04,256 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386007001_04101_00006_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:24:04,258 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:24:04,259 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386007001_04101_00007_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:24:04,261 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:24:04,263 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386007001_04101_00008_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:24:04,265 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:24:04,267 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386007001_04101_00009_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:24:04,269 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:24:04,271 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01194016001_04101_00001_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:24:04,313 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:24:04,314 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01194016001_04101_00002_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:24:04,316 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:24:04,318 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01194016001_04101_00003_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:24:04,320 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:24:04,322 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01194016001_04101_00004_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:24:04,324 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:24:04,325 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01194016001_04101_00005_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:24:04,327 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:24:04,328 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01194016001_04101_00006_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:24:04,331 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:24:04,332 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01194016001_04101_00007_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:24:04,334 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:24:04,336 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01194016001_04101_00008_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:24:04,337 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:24:04,339 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01194016001_04101_00009_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:24:04,341 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:24:04,343 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01411008001_04101_00001_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:24:04,345 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:24:04,346 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01411008001_04101_00002_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:24:04,348 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:24:04,350 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01411008001_04101_00003_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:24:04,352 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:24:04,353 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01411008001_04101_00004_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:24:04,355 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:24:04,357 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01411008001_04101_00005_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:24:04,359 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:24:04,360 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386008001_04101_00001_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:24:04,363 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:24:04,364 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386009001_04101_00001_mirimage_calints.fits' reftypes = ['psfmask']
# 2026-04-15 18:24:04,366 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits'.
# 2026-04-15 18:24:04,691 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00001_mirimage_calints.fits>,).
# 2026-04-15 18:24:04,692 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:24:04,693 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:24:04,701 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:24:04,830 - jwst.outlier_detection.utils - INFO - 64 pixels marked as outliers
# 2026-04-15 18:24:04,947 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/jw01386007001_04101_00001_mirimage_a3001_crfints.fits
# 2026-04-15 18:24:04,948 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:24:05,168 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00002_mirimage_calints.fits>,).
# 2026-04-15 18:24:05,169 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:24:05,170 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:24:05,177 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:24:05,300 - jwst.outlier_detection.utils - INFO - 62 pixels marked as outliers
# 2026-04-15 18:24:05,417 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/jw01386007001_04101_00002_mirimage_a3001_crfints.fits
# 2026-04-15 18:24:05,417 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:24:05,629 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00003_mirimage_calints.fits>,).
# 2026-04-15 18:24:05,630 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:24:05,631 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:24:05,638 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:24:05,763 - jwst.outlier_detection.utils - INFO - 128 pixels marked as outliers
# 2026-04-15 18:24:05,879 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/jw01386007001_04101_00003_mirimage_a3001_crfints.fits
# 2026-04-15 18:24:05,880 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:24:06,091 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00004_mirimage_calints.fits>,).
# 2026-04-15 18:24:06,092 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:24:06,093 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:24:06,100 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:24:06,225 - jwst.outlier_detection.utils - INFO - 128 pixels marked as outliers
# 2026-04-15 18:24:06,342 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/jw01386007001_04101_00004_mirimage_a3001_crfints.fits
# 2026-04-15 18:24:06,343 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:24:06,552 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00005_mirimage_calints.fits>,).
# 2026-04-15 18:24:06,554 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:24:06,554 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:24:06,561 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:24:06,689 - jwst.outlier_detection.utils - INFO - 115 pixels marked as outliers
# 2026-04-15 18:24:06,807 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/jw01386007001_04101_00005_mirimage_a3001_crfints.fits
# 2026-04-15 18:24:06,808 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:24:07,024 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00006_mirimage_calints.fits>,).
# 2026-04-15 18:24:07,025 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:24:07,026 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:24:07,033 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:24:07,158 - jwst.outlier_detection.utils - INFO - 155 pixels marked as outliers
# 2026-04-15 18:24:07,276 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/jw01386007001_04101_00006_mirimage_a3001_crfints.fits
# 2026-04-15 18:24:07,277 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:24:07,487 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00007_mirimage_calints.fits>,).
# 2026-04-15 18:24:07,488 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:24:07,488 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:24:07,495 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:24:07,621 - jwst.outlier_detection.utils - INFO - 213 pixels marked as outliers
# 2026-04-15 18:24:07,739 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/jw01386007001_04101_00007_mirimage_a3001_crfints.fits
# 2026-04-15 18:24:07,740 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:24:07,950 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00008_mirimage_calints.fits>,).
# 2026-04-15 18:24:07,951 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:24:07,951 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:24:07,958 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:24:08,084 - jwst.outlier_detection.utils - INFO - 250 pixels marked as outliers
# 2026-04-15 18:24:08,202 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/jw01386007001_04101_00008_mirimage_a3001_crfints.fits
# 2026-04-15 18:24:08,203 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:24:08,422 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(19, 224, 288) from jw01386007001_04101_00009_mirimage_calints.fits>,).
# 2026-04-15 18:24:08,423 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:24:08,423 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:24:08,430 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:24:08,556 - jwst.outlier_detection.utils - INFO - 216 pixels marked as outliers
# 2026-04-15 18:24:08,679 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/jw01386007001_04101_00009_mirimage_a3001_crfints.fits
# 2026-04-15 18:24:08,680 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:24:08,895 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(2, 224, 288) from jw01194016001_04101_00001_mirimage_calints.fits>,).
# 2026-04-15 18:24:08,896 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:24:08,897 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:24:08,903 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:24:08,989 - jwst.outlier_detection.utils - INFO - 42 pixels marked as outliers
# 2026-04-15 18:24:09,090 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/jw01194016001_04101_00001_mirimage_a3001_crfints.fits
# 2026-04-15 18:24:09,090 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:24:09,304 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(2, 224, 288) from jw01194016001_04101_00002_mirimage_calints.fits>,).
# 2026-04-15 18:24:09,305 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:24:09,305 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:24:09,312 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:24:09,398 - jwst.outlier_detection.utils - INFO - 43 pixels marked as outliers
# 2026-04-15 18:24:09,498 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/jw01194016001_04101_00002_mirimage_a3001_crfints.fits
# 2026-04-15 18:24:09,499 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:24:09,710 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(2, 224, 288) from jw01194016001_04101_00003_mirimage_calints.fits>,).
# 2026-04-15 18:24:09,711 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:24:09,712 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:24:09,718 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:24:09,804 - jwst.outlier_detection.utils - INFO - 42 pixels marked as outliers
# 2026-04-15 18:24:09,905 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/jw01194016001_04101_00003_mirimage_a3001_crfints.fits
# 2026-04-15 18:24:09,905 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:24:10,121 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(2, 224, 288) from jw01194016001_04101_00004_mirimage_calints.fits>,).
# 2026-04-15 18:24:10,122 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:24:10,122 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:24:10,129 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:24:10,215 - jwst.outlier_detection.utils - INFO - 37 pixels marked as outliers
# 2026-04-15 18:24:10,316 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/jw01194016001_04101_00004_mirimage_a3001_crfints.fits
# 2026-04-15 18:24:10,317 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:24:10,527 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(2, 224, 288) from jw01194016001_04101_00005_mirimage_calints.fits>,).
# 2026-04-15 18:24:10,528 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:24:10,528 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:24:10,535 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:24:10,622 - jwst.outlier_detection.utils - INFO - 62 pixels marked as outliers
# 2026-04-15 18:24:10,722 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/jw01194016001_04101_00005_mirimage_a3001_crfints.fits
# 2026-04-15 18:24:10,723 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:24:10,930 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(2, 224, 288) from jw01194016001_04101_00006_mirimage_calints.fits>,).
# 2026-04-15 18:24:10,931 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:24:10,932 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:24:10,939 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:24:11,025 - jwst.outlier_detection.utils - INFO - 27 pixels marked as outliers
# 2026-04-15 18:24:11,126 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/jw01194016001_04101_00006_mirimage_a3001_crfints.fits
# 2026-04-15 18:24:11,127 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:24:11,344 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(2, 224, 288) from jw01194016001_04101_00007_mirimage_calints.fits>,).
# 2026-04-15 18:24:11,345 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:24:11,345 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:24:11,352 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:24:11,439 - jwst.outlier_detection.utils - INFO - 27 pixels marked as outliers
# 2026-04-15 18:24:11,540 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/jw01194016001_04101_00007_mirimage_a3001_crfints.fits
# 2026-04-15 18:24:11,541 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:24:11,757 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(2, 224, 288) from jw01194016001_04101_00008_mirimage_calints.fits>,).
# 2026-04-15 18:24:11,758 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:24:11,758 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:24:11,765 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:24:11,854 - jwst.outlier_detection.utils - INFO - 51 pixels marked as outliers
# 2026-04-15 18:24:11,957 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/jw01194016001_04101_00008_mirimage_a3001_crfints.fits
# 2026-04-15 18:24:11,958 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:24:12,182 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(2, 224, 288) from jw01194016001_04101_00009_mirimage_calints.fits>,).
# 2026-04-15 18:24:12,183 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:24:12,183 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:24:12,190 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:24:12,275 - jwst.outlier_detection.utils - INFO - 42 pixels marked as outliers
# 2026-04-15 18:24:12,378 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/jw01194016001_04101_00009_mirimage_a3001_crfints.fits
# 2026-04-15 18:24:12,378 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:24:12,590 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(30, 224, 288) from jw01411008001_04101_00001_mirimage_calints.fits>,).
# 2026-04-15 18:24:12,591 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:24:12,592 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:24:12,599 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:24:12,747 - jwst.outlier_detection.utils - INFO - 45 pixels marked as outliers
# 2026-04-15 18:24:12,876 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/jw01411008001_04101_00001_mirimage_a3001_crfints.fits
# 2026-04-15 18:24:12,877 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:24:13,104 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(30, 224, 288) from jw01411008001_04101_00002_mirimage_calints.fits>,).
# 2026-04-15 18:24:13,105 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:24:13,105 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:24:13,113 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:24:13,259 - jwst.outlier_detection.utils - INFO - 116 pixels marked as outliers
# 2026-04-15 18:24:13,389 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/jw01411008001_04101_00002_mirimage_a3001_crfints.fits
# 2026-04-15 18:24:13,390 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:24:13,607 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(30, 224, 288) from jw01411008001_04101_00003_mirimage_calints.fits>,).
# 2026-04-15 18:24:13,608 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:24:13,609 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:24:13,616 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:24:13,762 - jwst.outlier_detection.utils - INFO - 133 pixels marked as outliers
# 2026-04-15 18:24:13,891 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/jw01411008001_04101_00003_mirimage_a3001_crfints.fits
# 2026-04-15 18:24:13,892 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:24:14,114 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(30, 224, 288) from jw01411008001_04101_00004_mirimage_calints.fits>,).
# 2026-04-15 18:24:14,115 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:24:14,115 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:24:14,123 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:24:14,266 - jwst.outlier_detection.utils - INFO - 161 pixels marked as outliers
# 2026-04-15 18:24:14,397 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/jw01411008001_04101_00004_mirimage_a3001_crfints.fits
# 2026-04-15 18:24:14,398 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:24:14,618 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(30, 224, 288) from jw01411008001_04101_00005_mirimage_calints.fits>,).
# 2026-04-15 18:24:14,619 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:24:14,620 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:24:14,627 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:24:14,773 - jwst.outlier_detection.utils - INFO - 163 pixels marked as outliers
# 2026-04-15 18:24:14,903 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/jw01411008001_04101_00005_mirimage_a3001_crfints.fits
# 2026-04-15 18:24:14,904 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:24:15,119 - stpipe.step - INFO - Step stack_refs running with args (<jwst.datamodels.container.ModelContainer object at 0x7f0ac84baf10>,).
# 2026-04-15 18:24:15,137 - jwst.coron.stack_refs - INFO -  Adding psf member 1 to output stack
# 2026-04-15 18:24:15,141 - jwst.coron.stack_refs - INFO -  Adding psf member 2 to output stack
# 2026-04-15 18:24:15,144 - jwst.coron.stack_refs - INFO -  Adding psf member 3 to output stack
# 2026-04-15 18:24:15,146 - jwst.coron.stack_refs - INFO -  Adding psf member 4 to output stack
# 2026-04-15 18:24:15,149 - jwst.coron.stack_refs - INFO -  Adding psf member 5 to output stack
# 2026-04-15 18:24:15,152 - jwst.coron.stack_refs - INFO -  Adding psf member 6 to output stack
# 2026-04-15 18:24:15,155 - jwst.coron.stack_refs - INFO -  Adding psf member 7 to output stack
# 2026-04-15 18:24:15,158 - jwst.coron.stack_refs - INFO -  Adding psf member 8 to output stack
# 2026-04-15 18:24:15,161 - jwst.coron.stack_refs - INFO -  Adding psf member 9 to output stack
# 2026-04-15 18:24:15,164 - jwst.coron.stack_refs - INFO -  Adding psf member 10 to output stack
# 2026-04-15 18:24:15,165 - jwst.coron.stack_refs - INFO -  Adding psf member 11 to output stack
# 2026-04-15 18:24:15,165 - jwst.coron.stack_refs - INFO -  Adding psf member 12 to output stack
# 2026-04-15 18:24:15,166 - jwst.coron.stack_refs - INFO -  Adding psf member 13 to output stack
# 2026-04-15 18:24:15,167 - jwst.coron.stack_refs - INFO -  Adding psf member 14 to output stack
# 2026-04-15 18:24:15,168 - jwst.coron.stack_refs - INFO -  Adding psf member 15 to output stack
# 2026-04-15 18:24:15,169 - jwst.coron.stack_refs - INFO -  Adding psf member 16 to output stack
# 2026-04-15 18:24:15,170 - jwst.coron.stack_refs - INFO -  Adding psf member 17 to output stack
# 2026-04-15 18:24:15,171 - jwst.coron.stack_refs - INFO -  Adding psf member 18 to output stack
# 2026-04-15 18:24:15,172 - jwst.coron.stack_refs - INFO -  Adding psf member 19 to output stack
# 2026-04-15 18:24:15,176 - jwst.coron.stack_refs - INFO -  Adding psf member 20 to output stack
# 2026-04-15 18:24:15,180 - jwst.coron.stack_refs - INFO -  Adding psf member 21 to output stack
# 2026-04-15 18:24:15,184 - jwst.coron.stack_refs - INFO -  Adding psf member 22 to output stack
# 2026-04-15 18:24:15,189 - jwst.coron.stack_refs - INFO -  Adding psf member 23 to output stack
# 2026-04-15 18:24:15,265 - stpipe.step - INFO - Step stack_refs done
# 2026-04-15 18:24:15,415 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/Level 3_psfstack.fits
# 2026-04-15 18:24:15,630 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(60, 224, 288) from jw01386008001_04101_00001_mirimage_calints.fits>,).
# 2026-04-15 18:24:15,631 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-04-15 18:24:15,631 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-04-15 18:24:15,640 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-04-15 18:24:15,859 - jwst.outlier_detection.utils - INFO - 34 pixels marked as outliers
# 2026-04-15 18:24:16,019 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/jw01386008001_04101_00001_mirimage_a3001_crfints.fits
# 2026-04-15 18:24:16,020 - stpipe.step - INFO - Step outlier_detection done
# 2026-04-15 18:24:16,237 - stpipe.step - INFO - Step align_refs running with args (<CubeModel(60, 224, 288) from jw01386008001_04101_00001_mirimage_a3001_crfints.fits>, <CubeModel(339, 224, 288) from Level 3_psfstack.fits>).
# 2026-04-15 18:24:16,293 - jwst.coron.align_refs_step - INFO - Using PSFMASK reference file /home/runner/crds/references/jwst/miri/jwst_miri_psfmask_0012.fits
# 2026-04-15 18:25:40,319 - stpipe.step - INFO - Step align_refs done
# 2026-04-15 18:25:40,469 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/jw01386008001_04101_00001_mirimage_a3001_psfalign.fits
# 2026-04-15 18:25:40,687 - stpipe.step - INFO - Step klip running with args (<CubeModel(60, 224, 288) from jw01386008001_04101_00001_mirimage_a3001_crfints.fits>, <CubeModel(339, 224, 288) from jw01386008001_04101_00001_mirimage_a3001_psfalign.fits>).
# 2026-04-15 18:25:40,689 - jwst.coron.klip_step - INFO - KL transform truncation = 25
# 2026-04-15 18:26:04,321 - stpipe.step - INFO - Step klip done
# 2026-04-15 18:26:04,492 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/jw01
- stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,180 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,190 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,226 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-04-15 18:28:13,236 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,246 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,256 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,292 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-04-15 18:28:13,302 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,312 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,322 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,359 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-04-15 18:28:13,369 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,379 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,389 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,426 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-04-15 18:28:13,436 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,446 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,455 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,492 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-04-15 18:28:13,502 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,512 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,521 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,558 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-04-15 18:28:13,569 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,579 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,588 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,625 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-04-15 18:28:13,635 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,645 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,655 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,691 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-04-15 18:28:13,701 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,711 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,721 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,760 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-04-15 18:28:13,771 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,782 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,791 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,830 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-04-15 18:28:13,841 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,851 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,861 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,898 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-04-15 18:28:13,909 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,919 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,929 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,967 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-04-15 18:28:13,978 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,988 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:13,997 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,034 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-04-15 18:28:14,044 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,054 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,064 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,100 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-04-15 18:28:14,111 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,121 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,130 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,167 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-04-15 18:28:14,178 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,188 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,197 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,234 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-04-15 18:28:14,244 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,254 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,264 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,302 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-04-15 18:28:14,314 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,324 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,334 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,371 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-04-15 18:28:14,382 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,392 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,402 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,442 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-04-15 18:28:14,453 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,463 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,473 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,509 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-04-15 18:28:14,522 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,534 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,545 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,583 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-04-15 18:28:14,594 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,603 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,613 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,650 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-04-15 18:28:14,660 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,670 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,679 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,716 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-04-15 18:28:14,726 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,736 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,745 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,782 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-04-15 18:28:14,793 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,803 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,813 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,849 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-04-15 18:28:14,859 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,869 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,879 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,915 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-04-15 18:28:14,926 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,936 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:14,946 - stcal.resample.resample - INFO - Drizzling (224, 288) --> (269, 319)
# 2026-04-15 18:28:15,155 - jwst.resample.resample - INFO - Assigning output S_REGION: POLYGON ICRS  201.153510597 -51.509037278 201.155169788 -51.505924705 201.158766766 -51.501665796 201.158838888 -51.501528960 201.157706792 -51.501164522 201.157961714 -51.500686153 201.153293873 -51.499743781 201.149018630 -51.498367122 201.149006308 -51.498364604 201.148637983 -51.498803598 201.147396425 -51.498552847 201.144929378 -51.503223218 201.142449558 -51.506177928 201.143235448 -51.506429418 201.142971984 -51.506928048 201.147837858 -51.507902060 201.152294942 -51.509327940 201.152680767 -51.508871235
# 2026-04-15 18:28:15,170 - stpipe.step - INFO - Step resample done
# 2026-04-15 18:28:15,561 - stpipe.step - INFO - Saved model in ./miri_coro_demo_data/stage3_psflib/Level 3_i2d.fits
# 2026-04-15 18:28:15,562 - jwst.pipeline.calwebb_coron3 - INFO - ...ending calwebb_coron3
# 2026-04-15 18:28:15,597 - stpipe.step - INFO - Step Coron3Pipeline done
# 2026-04-15 18:28:15,598 - jwst.stpipe.core - INFO - Results used jwst version: 2.0.0

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ## 10.-Advanced Usage- Examine the output
# ------------------
# Here we'll plot the data from the larger library to see what our source looks like and whether the subtraction improved.

# %%
# Inspect the psf-subtracted images generated in the coron3 pipeline run
if download_coron_references and docoron3_psflib:
    # Gather Stage 3 PSF Library output files

    # Individual exposures
    sstring = os.path.join(coron3_psflib_dir, 'jw*psfsub.fits')
    psfsubfiles = sorted(glob.glob(sstring))
    npsfsub = len(psfsubfiles)

    # Combined exposure
    sstring = os.path.join(coron3_psflib_dir, '*i2d.fits')
    i2dfiles = sorted(glob.glob(sstring))
    
    if npsfsub == 1:
        imgs = {'roll1': datamodels.open(psfsubfiles[0]).data.copy(),
                'combo': datamodels.open(i2dfiles[0]).data.copy()}
    else:
        imgs = {'roll1': datamodels.open(psfsubfiles[0]).data.copy(),
                'roll2': datamodels.open(psfsubfiles[1]).data.copy(),
                'combo': datamodels.open(i2dfiles[0]).data.copy()}
        
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(16, 8))
    vmin, vmax = np.nanquantile(np.concatenate(list([i.ravel() for i in imgs.values()])), [0.05, 0.95])
    for i, roll in enumerate(imgs.keys()):
        img = imgs[roll]
        while img.ndim > 2:
            img = np.nanmedian(img[0:60], axis=0)
        ax = axes[i]
        ax.set_title(roll)
        ax.imshow(img, vmin=-0.5, vmax=1)

# %% [markdown]
# ### Overlay sky coordinates
#
# Overlay the RA and Dec grid over the combined rolls

# %%
if download_coron_references and docoron3_psflib:
    with fits.open(i2dfiles[0]) as f:
        wcs = WCS(f[1].header)
        
    # The star coordinates at the time of observation are in the header
    exp_file = uncal_sci_r1_files[0]
    targ_ra = fits.getval(exp_file, 'TARG_RA', 0)
    targ_dec = fits.getval(exp_file, 'TARG_DEC', 0)
    starcoord = SkyCoord(targ_ra, targ_dec, unit='deg', frame='icrs')
    
    fig, ax = plt.subplots(1, 1, subplot_kw={'projection': wcs})
    vmin, vmax = np.nanquantile(imgs['combo'], [0.01, 0.99])
    ax.imshow(imgs['combo'], vmin=vmin, vmax=vmax)
    ax.scatter(*wcs.world_to_pixel(starcoord),
               marker='x', s=100, c='w')
    ax.grid(True)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2022-07-17T22:58:10.204' from MJD-BEG.
# Set DATE-AVG to '2022-07-18T00:15:08.760' from MJD-AVG.
# Set DATE-END to '2022-07-18T01:32:07.316' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -69.981478 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -37.692706 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1737840324.368 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]

# %% [markdown]
# The subtraction is clearly dramatically improved, but we can get a quick quantitative estimate of the comparison between the dedicated reference versus the library by plotting the profiles of the annular standard deviation as a function of separation from the coronagraph center. This is analogous to a contrast curve, but without the normalization for the stellar peak flux. As our science target hasn't changed, this is a suitable proxy for the improvement in contrast.

# %%
def compute_stdev_curves(i2d_file_orig, i2d_file_psflib, mask_circle=None):
    """
    Compute 5-sigma standard deviation curves for two i2d FITS files using CRPIX as center.

    Parameters
    ----------
    i2d_file_orig : str
        Path to the original i2d FITS file.
    i2d_file_psflib : str
        Path to the large-library i2d FITS file.
    mask_circle : tuple, optional
        A tuple of (x, y, radius) in pixels defining a circular region to set
        to NaN before computing the stdev curves. x and y are the center
        of the circle in pixel coordinates (0-indexed).

    Returns
    -------
    radii_arcsec : np.ndarray
        Radii in arcseconds for the stdev curve.
    stdev_orig : np.ndarray
        5-sigma stdev curve for the original library.
    stdev_psflib : np.ndarray
        5-sigma stdev curve for the larger library.
    """

    def load_i2d(filepath):
        with fits.open(filepath) as hdul:
            data = hdul['SCI'].data.astype(float)
            hdr = hdul['SCI'].header
            # CRPIX is 1-indexed, convert to 0-indexed
            cx = hdr.get('CRPIX1', data.shape[1] / 2) - 1
            cy = hdr.get('CRPIX2', data.shape[0] / 2) - 1
            pixelscale = np.sqrt(hdr.get('PIXAR_A2'))
        return data, cx, cy, pixelscale

    def apply_circle_mask(data, mask_circle):
        if mask_circle is not None:
            mx, my, mr = mask_circle
            y, x = np.indices(data.shape)
            dist = np.sqrt((x - mx)**2 + (y - my)**2)
            data = data.copy()
            data[dist <= mr] = np.nan
        return data

    def radial_5sigma_stdev(data, cx, cy):
        y, x = np.indices(data.shape)
        r = np.sqrt((x - cx)**2 + (y - cy)**2).astype(int)

        max_r = int(np.min([cx, cy, data.shape[1] - cx, data.shape[0] - cy]))
        radii = np.arange(1, max_r)
        stdev = np.full(len(radii), np.nan)

        for i, radius in enumerate(radii):
            annulus_mask = r == radius
            annulus_values = data[annulus_mask]
            # Remove NaNs
            annulus_values = annulus_values[np.isfinite(annulus_values)]
            if len(annulus_values) > 2:
                stdev[i] = 5.0 * np.nanstd(annulus_values)

        return radii, stdev

    # Load data
    data_orig, cx_orig, cy_orig, pixelscale_orig = load_i2d(i2d_file_orig)
    data_psflib, cx_psflib, cy_psflib, pixelscale_psflib = load_i2d(i2d_file_psflib)
    if pixelscale_orig != pixelscale_psflib:
        raise ValueError("Pixel scales of the two i2d files do not match.")
    else:
        pixelscale = pixelscale_orig

    # Apply circular mask if provided
    data_orig = apply_circle_mask(data_orig, mask_circle)
    data_psflib = apply_circle_mask(data_psflib, mask_circle)

    # Compute stdev curves
    radii_orig, stdev_orig = radial_5sigma_stdev(data_orig, cx_orig, cy_orig)
    radii_psflib, stdev_psflib = radial_5sigma_stdev(data_psflib, cx_psflib, cy_psflib)

    # Use the shorter of the two radius arrays for comparison
    min_len = min(len(radii_orig), len(radii_psflib))
    radii_arcsec = radii_orig[:min_len] * pixelscale

    return radii_arcsec, stdev_orig[:min_len], stdev_psflib[:min_len]

# %%
if download_coron_references and docoron3_psflib:
    # Look for *i2d file in the original coron3 output directory
    i2d_file_orig = sorted(glob.glob(os.path.join(coron3_dir, '*_i2d.fits')))[0]
    i2d_file_psflib = sorted(glob.glob(os.path.join(coron3_psflib_dir, '*_i2d.fits')))[0]

    # Run the stdev calculation, applying a circular mask to reduce the impact of the bright inner planet, HIP 65426 b
    radii_arcsec, stdev_orig, stdev_psflib = compute_stdev_curves(i2d_file_orig, i2d_file_psflib, mask_circle=(131, 138, 6))

    # Make plot of the stdev curves and relative residuals in second panel
    fig, ax = plt.subplots(2, 1, figsize=(8, 6), sharex=True, gridspec_kw={'height_ratios': [3,1]})
    ax[0].plot(radii_arcsec, stdev_orig, label='Dedicated Reference')
    ax[0].plot(radii_arcsec, stdev_psflib, label='PSF Library')
    ax[0].set_yscale('log')
    ax[0].set_ylabel('5$\\sigma$ Annular Standard Deviation')
    ax[0].set_xlim(0, 5)
    ax[0].legend()
    ax[1].plot(radii_arcsec, stdev_orig/stdev_psflib, label='Dedicated / Library')
    ax[1].axhline(1, color='gray', linestyle='--')
    ax[1].set_xlabel('Separation (arcsec)')
    ax[1].set_ylabel('Noise Reduction Factor')
    ax[1].set_xlim(0, 5)
    ax[1].legend()
    plt.tight_layout()

# %% [markdown]
# The output images above show that adopting a larger reference library has significantly improved the quality of the PSF subtraction, and the companion exoplanet HIP 65426 b is clearly resolved close to the center of the coronagraph. However, caution should still be taken when adopting such strategies. Even larger PSF libraries may improve the PSF subtraction quality further, but are more computationally demanding, and in some cases the subtraction quality may degrade if the additional PSFs are not suitably matched to the science data. Custom PSF libraries can also be useful when a formal reference target has not been defined for a given science observation.

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# <img style="float: center;" src="https://github.com/spacetelescope/jwst-pipeline-notebooks/raw/main/_static/stsci_footer.png" alt="stsci_logo" width="200px"/>
