# %% [markdown]
# <img style="float: center;" src='https://github.com/spacetelescope/jwst-pipeline-notebooks/raw/main/_static/stsci_header.png' alt="stsci_logo" width="900px"/>

# %% [markdown]
# #  NIRCam Coronagraphy Pipeline Notebook
#
# **Authors**: B. Sunnquist, A.L. Carter, based on the NIRISS/NIRCam imaging notebooks by R. Diaz and B. Hilbert<br>
# **Last Updated**: July 27, 2026<br>
# **Pipeline Version**: 3.0.0 (Build 13.0)

# %% [markdown]
# **Purpose**:<BR>
# This notebook provides a framework for processing generic Near-Infrared
# Camera (NIRCam) Coronagraphy data through all three James Webb Space Telescope
# (JWST) pipeline stages.  Data is assumed to be located in a folder structure
# following the paths set up below. It should not be necessary to edit
# any cells other than in the [Configuration](#1.-Configuration) section unless
# modifying the standard pipeline processing options.
#
# **Data**:<BR>
# This example is set up to use an example dataset from
# [Program ID](https://www.stsci.edu/jwst/science-execution/program-information)
# 1386 (PI: Sasha Hinkley).
# The science PSF is HIP-65426 which is taken using 2 different roll angles in observations 2 and 3. These observations use the DEEP8 readout pattern with 2 integrations per exposure and 15 groups per intergration. The PSF reference star is HIP-68245 taken in observation 1 using a 9-POINT-CIRCLE dither pattern. This observation uses the MEDIUM8 readout pattern with 2 integrations per exposure and 4 groups per integration. All data is observed on the NRCALONG detector with the SUB320A335R subarray and uses the F444W filter and MASK335R round coronagraphic mask.
# Example input data to use will be downloaded automatically unless
# disabled (i.e., to use local files instead).
#
# **[JWST pipeline version and CRDS context](#Set-CRDS-Context-and-Server)**:<br>
# This notebook was written for the above-specified pipeline version and associated build context for this version of the JWST Calibration Pipeline. Information about this and other contexts can be found in the JWST Calibration Reference Data System (CRDS [server](https://jwst-crds.stsci.edu/)). If you use different pipeline versions, please refer to the table [here](https://jwst-crds.stsci.edu/display_build_contexts/) to determine what context to use. To learn more about the differences for the pipeline, read the relevant [documentation](https://jwst-docs.stsci.edu/jwst-science-calibration-pipeline/jwst-operations-pipeline-build-information#references).<br>
#
# Please note that pipeline software development is a continuous process, so results in some cases may be slightly different if a subsequent version is used. **For optimal results, users are strongly encouraged to reprocess their data using the most recent pipeline version and [associated CRDS context](https://jwst-crds.stsci.edu/display_build_contexts/), taking advantage of bug fixes and algorithm improvements.**
# Any [known issues](https://jwst-docs.stsci.edu/known-issues-with-jwst-data/nircam-known-issues) for this build are provided in the JWST User Documentaion.<BR>
#
# **Updates**:<BR>
# This notebook is regularly updated as improvements are made to the
# pipeline. Find the most up to date version of this notebook at:
# https://github.com/spacetelescope/jwst-pipeline-notebooks/
#
# **Recent Changes**:<br>
# Feb 26, 2025: original notebook created<br>
# May 5, 2025: Updated to jwst 1.18.0 (no significant changes)<br>
# July 16, 2025: Updated to jwst 1.19.1 (no significant changes)<br>
# December 10, 2025: Updated to jwst 1.20.2 (no significant changes)<br>
# March 27, 2026: Updated to demonstrate PSF library subtraction<br>
# April 17, 2026: Updated to jwst 2.0.0 (no significant changes)<br>
# July 27, 2026: Updated to jwst 3.0.0 (no significant changes)

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ## Table of Contents
# 1. [Configuration](#1.-Configuration)
# 2. [Package Imports](#2.-Package-Imports)
# 3. [Demo Mode Setup (ignore if not using demo data)](#3.-Demo-Mode-Setup-(ignore-if-not-using-demo-data))
# 4. [Directory Setup](#4.-Directory-Setup)
# 5. [Detector1 Pipeline](#5.-Detector1-Pipeline)
# 6. [Image2 Pipeline](#6.-Image2-Pipeline)
# 7. [Coron3 Pipeline](#7.-Coron3-Pipeline)
# 8. [Visualize the final PSF-subtracted images](#8.-Visualize-the-final-PSF-subtracted-images)
# 9. [Advanced Usage- PSF Reference Library](#9.-Advanced-Usage--PSF-Reference-Library)
# 10. [Advanced Usage - Examine the output](#10.-Advanced-Usage--Examine-the-output)

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ## 1. Configuration

# %% [markdown]
# ------------------

# %% [markdown]
# #### Install dependencies and parameters
#
# To make sure that the pipeline version is compatabile with the steps
# discussed below and the required dependencies and packages are installed,
#  you can create a fresh conda environment and install the provided
# `requirements.txt` file:
# ```
# conda create -n nircam_coronagraphy_pipeline python=3.13
# conda activate nircam_coronagraphy_pipeline
# pip install -r requirements.txt
# ```
#
# #### Set the basic parameters to use with this notebook.
#
# These parameters will affect
# what data is used, where data is located (if already in disk), and
# pipeline modules run in this data. The list of parameters are:
#
# * demo_mode
# * directories with data
# * pipeline modules

# %%
# Basic import necessary for configuration
import os

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Note that <code>demo_mode</code> must be set appropriately below.
# </div>
#
# Set <code>demo_mode = True </code> to run in demonstration mode. In this
# mode this notebook will download example data from the Barbara A.
# Mikulski Archive for Space Telescopes
# ([MAST](https://mast.stsci.edu/search/ui/#/jwst)) and process it through
# the pipeline. This will all happen in a local directory unless modified in
# [Section 3](#3.-Demo-Mode-Setup-(ignore-if-not-using-demo-data)) below.
#
# Set <code>demo_mode = False</code> if you want to process your own data
# that has already been downloaded and provide the location of the data.<br>

# %%
# Set parameters for demo_mode, channel, band, data mode directories, and 
# processing steps.

# -----------------------------Demo Mode---------------------------------
demo_mode = True

if demo_mode:
    print('Running in demonstration mode using online example data!')

# --------------------------User Mode Directories------------------------
# If demo_mode = False, look for user data in these paths
if not demo_mode:
    # Set directory paths for processing specific data; these will need
    # to be changed to your local directory setup (below are given as
    # examples)
    basedir = os.path.join(os.getcwd(), '')

    # Point to where science observation data are
    # Assumes uncalibrated data in <sci_dir>/uncal/ and results in stage1,
    # stage2, stage3 directories
    sci_dir = os.path.join(basedir, 'PID1386/')

    # Create directory if it does not exist
    if not os.path.isdir(sci_dir):
        os.mkdir(sci_dir)

    print('Using user provided files')

# --------------------------Set Processing Steps--------------------------
# Individual pipeline stages can be turned on/off here.  Note that a later
# stage won't be able to run unless data products have already been
# produced from the prior stage.

# Science processing
dodet1 = True  # calwebb_detector1
doimage2 = True  # calwebb_image2
docoron3 = True  # calwebb_coron3
docoron3_psflib = True # Custom extension to calwebb_coron3
# Out:
# Running in demonstration mode using online example data!

# %% [markdown]
# ### Set CRDS context and server
# Before importing <code>CRDS</code> and <code>JWST</code> modules, we need
# to configure our environment. This includes defining a CRDS cache
# directory in which to keep the reference files that will be used by the
# calibration pipeline.
#
# If the root directory for the local CRDS cache directory has not been set
# already, it will be set to create one in the home directory.<br><br>
# [Build Context Table](https://jwst-crds.stsci.edu/display_build_contexts/)

# %%
# ------------------------Set CRDS context and paths----------------------

# Each version of the calibration pipeline is associated with a specific CRDS
# context file. The pipeline will select the appropriate context file behind
# the scenes while running. However, if you wish to override the default context
# file and run the pipeline with a different context, you can set that using
# the CRDS_CONTEXT environment variable. Here we show how this is done,
# although we leave the line commented out in order to use the default context.
# If you wish to specify a different context, uncomment the line below.
#os.environ['CRDS_CONTEXT'] = 'jwst_1322.pmap'  # CRDS context for 1.17.1

# Check whether the local CRDS cache directory has been set.
# If not, set it to the user home directory
if (os.getenv('CRDS_PATH') is None):
    os.environ['CRDS_PATH'] = os.path.join(os.path.expanduser('~'), 'crds')
# Check whether the CRDS server URL has been set.  If not, set it.
if (os.getenv('CRDS_SERVER_URL') is None):
    os.environ['CRDS_SERVER_URL'] = 'https://jwst-crds.stsci.edu'

# Echo CRDS path in use
print(f"CRDS local filepath: {os.environ['CRDS_PATH']}")
print(f"CRDS file server: {os.environ['CRDS_SERVER_URL']}")
if os.getenv('CRDS_CONTEXT'):
    print(f"CRDS CONTEXT: {os.environ['CRDS_CONTEXT']}")
# Out:
# CRDS local filepath: /home/runner/crds
# CRDS file server: https://jwst-crds.stsci.edu

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ## 2. Package Imports

# %%
# Use the entire available screen width for this notebook
from IPython.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
# Basic system utilities for interacting with files
# ----------------------General Imports------------------------------------
import glob, os, importlib
import time

# Numpy
import numpy as np

# To display full ouptut of cell, not just the last result
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# -----------------------Astropy/Astroquery Imports--------------------------------
# for viewing astropy images and tables
from astropy.io import fits
from astropy.table import Table

# for downloading demo files
from astroquery.mast import Observations

# ------------ Pipeline and  Visualization Imports -----------------------
# for visualizing images
import matplotlib.pyplot as plt

# for JWST calibration pipeline
import jwst
import crds

from jwst.pipeline import Detector1Pipeline
from jwst.pipeline import Image2Pipeline
from jwst.pipeline import Coron3Pipeline

# JWST pipeline utilities
from jwst import datamodels
from jwst.associations import asn_from_list  # Tools for creating association files
from jwst.associations.lib.rules_level3 import Asn_Lv3NRCCoron  # Definition of a Lvl3 association file

# Echo pipeline version and CRDS context in use
print(f"JWST Calibration Pipeline Version: {jwst.__version__}")
print(f"Using CRDS Context: {crds.get_context_name('jwst')}")
# Out:
# JWST Calibration Pipeline Version: 3.0.0
# CRDS - INFO -  Calibration SW Found: jwst 3.0.0 (/home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages/jwst-3.0.0.dist-info)
# Using CRDS Context: jwst_1584.pmap

# %%
# Start a timer to keep track of runtime
time0 = time.perf_counter()

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ## 3. Demo Mode Setup (ignore if not using demo data)

# %% [markdown]
# ------------------
# If running in demonstration mode, set up the program information to
# retrieve the uncalibrated data automatically from MAST using
# [astroquery](https://astroquery.readthedocs.io/en/latest/mast/mast.html).
# MAST allows for flexibility of searching by the proposal ID and the
# observation ID instead of just filenames.<br>
#
# We will download data from
# [Program ID](https://www.stsci.edu/jwst/science-execution/program-information)
# 1386 (PI: Sasha Hinkley).
# The science target is HIP-65426 which is taken using 2 different roll angles in observations 2 and 3 (2 total uncal files). The reference PSF is HIP-68245 taken in observation 1 using a 9-POINT-CIRCLE dither pattern (9 total uncal files). All data is observed on the NRCALONG detector with the SUB320A335R subarray and uses the F444W filter and MASK335R round coronagraphic mask.
#
# More information about the JWST file naming conventions can be found at:
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/data_products/file_naming.html

# %%
# Set up the program information and paths for demo program
if demo_mode:
    print('Running in demonstration mode and will download example data from MAST!')

    program = "01386"
    data_dir = os.path.abspath(os.path.join('.', 'nrc_coron_demo_data'))
    download_dir = data_dir
    sci_dir = data_dir
    uncal_dir = os.path.join(sci_dir, 'uncal')

    # Ensure filepaths for input data exist
    if not os.path.exists(uncal_dir):
        os.makedirs(uncal_dir)

    # Create directory if it does not exist
    if not os.path.isdir(data_dir):
        os.mkdir(data_dir)
# Out:
# Running in demonstration mode and will download example data from MAST!

# %% [markdown]
# Identify list of science (SCI) uncalibrated files associated with visits.

# %%
# Obtain a list of observation IDs for the specified demo program
if demo_mode:
    sci_obs_id_table = Observations.query_criteria(instrument_name=["NIRCAM/CORON"],
                                                   proposal_id=program,
                                                   filters=['F444W']
                                                   )

# %%
if demo_mode:
    sci_obs_id_table
# Out:
# <Table masked=True length=1>
# intentType obs_collection provenance_name ...   objID    wave_min wave_max
#    str7         str4            str7      ...   str10    float64  float64
# ---------- -------------- --------------- ... ---------- -------- --------
#    science           JWST         CALJWST ... 1059938148   3880.0   4986.0

# %%
# Turn the list of visits into a list of uncalibrated data files
if demo_mode:
    # Define types of files to select
    file_dict = {'uncal': {'product_type': 'SCIENCE',
                           'productSubGroupDescription': 'UNCAL',
                           'filters': 'F444W;MASKRND',
                           'calib_level': [1]}}

    # Science files
    sci_files_to_download = []

    # Loop over visits identifying uncalibrated files that are associated with them
    for exposure in (sci_obs_id_table):
        products = Observations.get_product_list(exposure)
        for filetype, query_dict in file_dict.items():
            filtered_products = Observations.filter_products(products, productType=query_dict['product_type'],
                                                             productSubGroupDescription=query_dict['productSubGroupDescription'],
                                                             filters=query_dict['filters'],
                                                             calib_level=query_dict['calib_level'])
            sci_files_to_download.extend(filtered_products['dataURI'])
    sci_files_to_download = sorted(sci_files_to_download)
    print(f"Science files selected for downloading: {len(sci_files_to_download)}")
# Out:
# Science files selected for downloading: 11

# %%
# List the files to download
if demo_mode:
    sci_files_to_download
# Out:
# [np.str_('mast:JWST/product/jw01386001001_0310e_00001_nrcalong_uncal.fits'),
#  np.str_('mast:JWST/product/jw01386001001_0310e_00002_nrcalong_uncal.fits'),
#  np.str_('mast:JWST/product/jw01386001001_0310e_00003_nrcalong_uncal.fits'),
#  np.str_('mast:JWST/product/jw01386001001_0310e_00004_nrcalong_uncal.fits'),
#  np.str_('mast:JWST/product/jw01386001001_0310e_00005_nrcalong_uncal.fits'),
#  np.str_('mast:JWST/product/jw01386001001_0310e_00006_nrcalong_uncal.fits'),
#  np.str_('mast:JWST/product/jw01386001001_0310e_00007_nrcalong_uncal.fits'),
#  np.str_('mast:JWST/product/jw01386001001_0310e_00008_nrcalong_uncal.fits'),
#  np.str_('mast:JWST/product/jw01386001001_0310e_00009_nrcalong_uncal.fits'),
#  np.str_('mast:JWST/product/jw01386002001_0310a_00001_nrcalong_uncal.fits'),
#  np.str_('mast:JWST/product/jw01386003001_0310a_00001_nrcalong_uncal.fits')]

# %% [markdown]
# Download all the uncal files and place them into the appropriate
# directories.
#
# <div class="alert alert-block alert-warning">
# Warning: If this notebook is halted during this step the downloaded file
# may be incomplete, and cause crashes later on!
# </div>

# %%
# Download the demo data if it does not already exist
if demo_mode:
    for filename in sci_files_to_download:
        sci_manifest = Observations.download_file(filename,
                                                  local_path=uncal_dir)
# Out:
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386001001_0310e_00001_nrcalong_uncal.fits to /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/uncal/jw01386001001_0310e_00001_nrcalong_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386001001_0310e_00002_nrcalong_uncal.fits to /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/uncal/jw01386001001_0310e_00002_nrcalong_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386001001_0310e_00003_nrcalong_uncal.fits to /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/uncal/jw01386001001_0310e_00003_nrcalong_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386001001_0310e_00004_nrcalong_uncal.fits to /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/uncal/jw01386001001_0310e_00004_nrcalong_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386001001_0310e_00005_nrcalong_uncal.fits to /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/uncal/jw01386001001_0310e_00005_nrcalong_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386001001_0310e_00006_nrcalong_uncal.fits to /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/uncal/jw01386001001_0310e_00006_nrcalong_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386001001_0310e_00007_nrcalong_uncal.fits to /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/uncal/jw01386001001_0310e_00007_nrcalong_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386001001_0310e_00008_nrcalong_uncal.fits to /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/uncal/jw01386001001_0310e_00008_nrcalong_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386001001_0310e_00009_nrcalong_uncal.fits to /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/uncal/jw01386001001_0310e_00009_nrcalong_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386002001_0310a_00001_nrcalong_uncal.fits to /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/uncal/jw01386002001_0310a_00001_nrcalong_uncal.fits ...
#  [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw01386003001_0310a_00001_nrcalong_uncal.fits to /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/uncal/jw01386003001_0310a_00001_nrcalong_uncal.fits ...
#  [Done]

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ## 4. Directory Setup

# %% [markdown]
# ------------------
# Set up detailed paths to input/output stages here.

# %%
# Define output subdirectories to keep science data products organized

uncal_dir = os.path.join(sci_dir, 'uncal')  # Uncalibrated pipeline inputs should be here
det1_dir = os.path.join(sci_dir, 'stage1')  # calwebb_detector1 pipeline outputs will go here
image2_dir = os.path.join(sci_dir, 'stage2')  # calwebb_image2 pipeline outputs will go here
coron3_dir = os.path.join(sci_dir, 'stage3')  # calwebb_coron3 pipeline outputs will go here
coron3_psflib_dir = os.path.join(data_dir, 'stage3_psflib/') # calwebb_coron3 pipeline outputs using the PSF library will go here

# We need to check that the desired output directories exist, and if not create them
if not os.path.exists(det1_dir):
    os.makedirs(det1_dir)
if not os.path.exists(image2_dir):
    os.makedirs(image2_dir)
if not os.path.exists(coron3_dir):
    os.makedirs(coron3_dir)
if not os.path.exists(coron3_psflib_dir):
    os.makedirs(coron3_psflib_dir)

# %% [markdown]
# Look at the first file to determine exposure parameters and practice using
# JWST datamodels to show basic exposure information.

# %%
# List uncal files
uncal_files = sorted(glob.glob(os.path.join(uncal_dir, '*_uncal.fits')))

colnames = ('Instrument', 'Filter', 'Pupil', 'Number of Integrations', 'Number of Groups',
            'Readout pattern', 'Dither position number')
dtypes = ('S7', 'S10', 'S10', 'i4', 'i4', 'S15', 'i4')
meta_check = Table(names=(colnames), dtype=dtypes)

# Open example files and get metadata for display
if len(uncal_files) > 0:
    lw_examine = datamodels.open(uncal_files[0])
    lw_row = [lw_examine.meta.instrument.name, lw_examine.meta.instrument.filter,
              lw_examine.meta.instrument.pupil, lw_examine.meta.exposure.nints,
              lw_examine.meta.exposure.ngroups, lw_examine.meta.exposure.readpatt,
              lw_examine.meta.dither.position_number]
    meta_check.add_row(lw_row)

# Print out exposure info
meta_check
# Out:
# <Table length=1>
# Instrument  Filter  Pupil  ... Readout pattern Dither position number
#   bytes7   bytes10 bytes10 ...     bytes15             int32
# ---------- ------- ------- ... --------------- ----------------------
#     NIRCAM   F444W MASKRND ...         MEDIUM8                      1

# %%
# Print out the time benchmark
time_det1 = time.perf_counter()
print(f"Runtime so far: {time_det1 - time0:0.0f} seconds")
# Out:
# Runtime so far: 5 seconds

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ## 5. Detector1 Pipeline
# Run the datasets through the
# [Detector1](https://jwst-docs.stsci.edu/jwst-science-calibration-pipeline-overview/stages-of-jwst-data-processing/calwebb_detector1)
# stage of the pipeline to apply detector level calibrations and create a
# countrate data product where slopes are fitted to the integration ramps.
# These `*_rate.fits` products are 2D (nrows x ncols), averaged over all
# integrations. 3D countrate data products (`*_rateints.fits`) are also
# created (nintegrations x nrows x ncols) which have the fitted ramp slopes
# for each integration.
#
# By default, all steps in the `Detector1` stage of the pipeline are run for
# NIRCam except the `ipc` correction step and the `gain_scale` step. Note
# that the [`persistence` step](https://jwst-pipeline.readthedocs.io/en/latest/jwst/persistence/description.html)
# has been turned off by default starting with CRDS context `jwst_1264.pmap`.
# This step does not automatically correct the science data for persistence.
# The `persistence` step creates a `*_trapsfilled.fits` file which is a model
# that records the number of traps filled at each pixel at the end of an exposure.
# This file would be used as an input to the `persistence` step, via the `input_trapsfilled`
# argument, to correct the subsequent science exposure for persistence. Since persistence
# is not well calibrated for NIRCam, the step has been turned off in order to speed up
# calibration and to not create empty `*_trapsfilled.fits` files. This step
# can be turned on when running the pipeline by setting `skip = False` in the cell below using a dictionary.
#
# An additional 1/f noise-cleaning algorithm, `clean_flicker_noise`, has been implemented at the group stage in the `Detector1Pipeline`. This step is also off by default. The cell bellow provides an example on how to turn it on and change parameters.
#
# <div class="alert alert-info">
#
# As of CRDS context `jwst_1155.pmap` and later, the
# [`jump` step](https://jwst-pipeline.readthedocs.io/en/latest/api/jwst.jump.JumpStep.html)
# of the `Detector1` stage of the pipeline will remove signal associated
# with [snowballs](https://jwst-docs.stsci.edu/known-issues-with-jwst-data/shower-and-snowball-artifacts)
# in the NIRCam imaging and coronagraphy modes. This correction is turned on using the parameter
# `expand_large_events=True`. This and other parameters related to the snowball correction
# are specified in the `pars-jumpstep` parameter reference file. Users may wish to alter
# parameters to optimize removal of snowball residuals. Available parameters are discussed
# in the [Detection and Flagging of Showers and Snowballs in JWST Technical Report (Regan 2023)](https://www.stsci.edu/files/live/sites/www/files/home/jwst/documentation/technical-documents/_documents/JWST-STScI-008545.pdf).
#
# </div>

# %%
# Set up a dictionary to define how the Detector1 pipeline should be configured

# Boilerplate dictionary setup
det1dict = {}
det1dict['group_scale'], det1dict['dq_init'], det1dict['saturation'] = {}, {}, {}
det1dict['ipc'], det1dict['superbias'], det1dict['refpix'] = {}, {}, {}
det1dict['linearity'], det1dict['persistence'], det1dict['dark_current'], = {}, {}, {}
det1dict['charge_migration'], det1dict['jump'], det1dict['clean_flicker_noise'] = {}, {}, {}
det1dict['ramp_fit'], det1dict['gain_scale'] = {}, {}

# Overrides for whether or not certain steps should be skipped
# skipping the persistence step
det1dict['persistence']['skip'] = True

# Overrides for various reference files
# Files should be in the base local directory or provide full path
#det1dict['dq_init']['override_mask'] = 'myfile.fits'  # Bad pixel mask
#det1dict['saturation']['override_saturation'] = 'myfile.fits'  # Saturation
#det1dict['reset']['override_reset'] = 'myfile.fits'  # Reset
#det1dict['linearity']['override_linearity'] = 'myfile.fits'  # Linearity
#det1dict['rscd']['override_rscd'] = 'myfile.fits'  # RSCD
#det1dict['dark_current']['override_dark'] = 'myfile.fits'  # Dark current subtraction
#det1dict['jump']['override_gain'] = 'myfile.fits'  # Gain used by jump step
#det1dict['ramp_fit']['override_gain'] = 'myfile.fits'  # Gain used by ramp fitting step
#det1dict['jump']['override_readnoise'] = 'myfile.fits'  # Read noise used by jump step
#det1dict['ramp_fit']['override_readnoise'] = 'myfile.fits'  # Read noise used by ramp fitting step

# Turn on multi-core processing (This is off by default). Choose what fraction
# of cores to use (quarter, half, all, or an integer number)
det1dict['jump']['maximum_cores'] = 'half'

# Explicitly turn on snowball correction. (Even though it is on by default)
det1dict['jump']['expand_large_events'] = True

# Turn on 1/f correction if desired
# For guidance see https://jwst-docs.stsci.edu/known-issues-with-jwst-data/1-f-noise
#det1dict['clean_flicker_noise']['skip'] = False
#det1dict['clean_flicker_noise']['fit_method'] = 'median' # 'median' or 'fft'
#det1dict['clean_flicker_noise']['background_method'] = 'median' # 'median' or 'model'
#det1dict['clean_flicker_noise']['fit_by_channel'] = False

# %% [markdown]
# Run the `Detector1` pipeline on all input data, regardless of filter.

# %%
# Run Detector1 stage of pipeline, specifying:
# output directory to save *_rate.fits files
# save_results flag set to True so the rate files are saved
if dodet1:
    for uncal in uncal_files:
        rate_result = Detector1Pipeline.call(uncal, output_dir=det1_dir, steps=det1dict, save_results=True)
else:
    print('Skipping Detector1 processing')
# Out:
# 2026-07-28 16:34:10,714 - CRDS - INFO -  Syncing 225 files
# 2026-07-28 16:34:10,734 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_system_datalvl_0002.rmap      694 bytes  (1 / 225 files) (0 / 804.1 K bytes)
# 2026-07-28 16:34:10,807 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_system_calver_0075.rmap    6.0 K bytes  (2 / 225 files) (694 / 804.1 K bytes)
# 2026-07-28 16:34:10,857 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_system_0068.imap        385 bytes  (3 / 225 files) (6.7 K / 804.1 K bytes)
# 2026-07-28 16:34:10,966 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_wavelengthrange_0024.rmap    1.4 K bytes  (4 / 225 files) (7.1 K / 804.1 K bytes)
# 2026-07-28 16:34:11,014 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_wavecorr_0005.rmap      884 bytes  (5 / 225 files) (8.5 K / 804.1 K bytes)
# 2026-07-28 16:34:11,061 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_superbias_0090.rmap   39.5 K bytes  (6 / 225 files) (9.3 K / 804.1 K bytes)
# 2026-07-28 16:34:11,114 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_sirskernel_0002.rmap      704 bytes  (7 / 225 files) (48.9 K / 804.1 K bytes)
# 2026-07-28 16:34:11,173 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_sflat_0027.rmap   20.6 K bytes  (8 / 225 files) (49.6 K / 804.1 K bytes)
# 2026-07-28 16:34:11,227 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_saturation_0018.rmap    2.0 K bytes  (9 / 225 files) (70.2 K / 804.1 K bytes)
# 2026-07-28 16:34:11,366 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_refpix_0015.rmap    1.6 K bytes  (10 / 225 files) (72.2 K / 804.1 K bytes)
# 2026-07-28 16:34:11,444 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_readnoise_0025.rmap    2.6 K bytes  (11 / 225 files) (73.8 K / 804.1 K bytes)
# 2026-07-28 16:34:11,527 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_psf_0002.rmap      687 bytes  (12 / 225 files) (76.3 K / 804.1 K bytes)
# 2026-07-28 16:34:11,573 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_pictureframe_0002.rmap      886 bytes  (13 / 225 files) (77.0 K / 804.1 K bytes)
# 2026-07-28 16:34:11,654 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_photom_0013.rmap      958 bytes  (14 / 225 files) (77.9 K / 804.1 K bytes)
# 2026-07-28 16:34:11,712 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_pathloss_0011.rmap    1.2 K bytes  (15 / 225 files) (78.9 K / 804.1 K bytes)
# 2026-07-28 16:34:11,789 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_pars-whitelightstep_0001.rmap      777 bytes  (16 / 225 files) (80.0 K / 804.1 K bytes)
# 2026-07-28 16:34:11,834 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_pars-tso3pipeline_0001.rmap      786 bytes  (17 / 225 files) (80.8 K / 804.1 K bytes)
# 2026-07-28 16:34:11,878 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_pars-spec2pipeline_0016.rmap    2.4 K bytes  (18 / 225 files) (81.6 K / 804.1 K bytes)
# 2026-07-28 16:34:11,924 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_pars-resamplespecstep_0002.rmap      709 bytes  (19 / 225 files) (84.0 K / 804.1 K bytes)
# 2026-07-28 16:34:12,098 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_pars-refpixstep_0003.rmap      910 bytes  (20 / 225 files) (84.7 K / 804.1 K bytes)
# 2026-07-28 16:34:12,181 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_pars-pixelreplacestep_0001.rmap      818 bytes  (21 / 225 files) (85.6 K / 804.1 K bytes)
# 2026-07-28 16:34:12,225 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_pars-pictureframestep_0001.rmap      818 bytes  (22 / 225 files) (86.4 K / 804.1 K bytes)
# 2026-07-28 16:34:12,269 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_pars-outlierdetectionstep_0005.rmap    1.1 K bytes  (23 / 225 files) (87.3 K / 804.1 K bytes)
# 2026-07-28 16:34:12,316 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_pars-jumpstep_0006.rmap      810 bytes  (24 / 225 files) (88.4 K / 804.1 K bytes)
# 2026-07-28 16:34:12,430 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_pars-image2pipeline_0008.rmap    1.0 K bytes  (25 / 225 files) (89.2 K / 804.1 K bytes)
# 2026-07-28 16:34:12,474 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_pars-extract1dstep_0002.rmap      916 bytes  (26 / 225 files) (90.2 K / 804.1 K bytes)
# 2026-07-28 16:34:12,592 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_pars-detector1pipeline_0008.rmap    1.7 K bytes  (27 / 225 files) (91.1 K / 804.1 K bytes)
# 2026-07-28 16:34:12,633 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_pars-darkpipeline_0003.rmap      872 bytes  (28 / 225 files) (92.8 K / 804.1 K bytes)
# 2026-07-28 16:34:12,682 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_pars-darkcurrentstep_0003.rmap    1.8 K bytes  (29 / 225 files) (93.7 K / 804.1 K bytes)
# 2026-07-28 16:34:12,795 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_pars-cubebuildstep_0001.rmap      862 bytes  (30 / 225 files) (95.5 K / 804.1 K bytes)
# 2026-07-28 16:34:12,838 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_pars-cleanflickernoisestep_0003.rmap    1.1 K bytes  (31 / 225 files) (96.4 K / 804.1 K bytes)
# 2026-07-28 16:34:12,918 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_pars-adaptivetracemodelstep_0002.rmap      997 bytes  (32 / 225 files) (97.5 K / 804.1 K bytes)
# 2026-07-28 16:34:12,965 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_ote_0030.rmap    1.3 K bytes  (33 / 225 files) (98.5 K / 804.1 K bytes)
# 2026-07-28 16:34:13,033 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_msaoper_0019.rmap    1.7 K bytes  (34 / 225 files) (99.8 K / 804.1 K bytes)
# 2026-07-28 16:34:13,076 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_msa_0027.rmap    1.3 K bytes  (35 / 225 files) (101.4 K / 804.1 K bytes)
# 2026-07-28 16:34:13,120 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_mask_0045.rmap    4.9 K bytes  (36 / 225 files) (102.7 K / 804.1 K bytes)
# 2026-07-28 16:34:13,167 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_linearity_0017.rmap    1.6 K bytes  (37 / 225 files) (107.6 K / 804.1 K bytes)
# 2026-07-28 16:34:13,224 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_ipc_0006.rmap      876 bytes  (38 / 225 files) (109.2 K / 804.1 K bytes)
# 2026-07-28 16:34:13,270 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_ifuslicer_0018.rmap    1.5 K bytes  (39 / 225 files) (110.1 K / 804.1 K bytes)
# 2026-07-28 16:34:13,313 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_ifupost_0020.rmap    1.5 K bytes  (40 / 225 files) (111.6 K / 804.1 K bytes)
# 2026-07-28 16:34:13,358 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_ifufore_0017.rmap    1.5 K bytes  (41 / 225 files) (113.1 K / 804.1 K bytes)
# 2026-07-28 16:34:13,532 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_gain_0023.rmap    1.8 K bytes  (42 / 225 files) (114.6 K / 804.1 K bytes)
# 2026-07-28 16:34:13,584 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_fpa_0028.rmap    1.3 K bytes  (43 / 225 files) (116.4 K / 804.1 K bytes)
# 2026-07-28 16:34:13,634 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_fore_0026.rmap    5.0 K bytes  (44 / 225 files) (117.6 K / 804.1 K bytes)
# 2026-07-28 16:34:13,679 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_flat_0015.rmap    3.8 K bytes  (45 / 225 files) (122.6 K / 804.1 K bytes)
# 2026-07-28 16:34:13,724 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_fflat_0030.rmap    7.2 K bytes  (46 / 225 files) (126.4 K / 804.1 K bytes)
# 2026-07-28 16:34:13,767 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_extract1d_0018.rmap    2.3 K bytes  (47 / 225 files) (133.6 K / 804.1 K bytes)
# 2026-07-28 16:34:13,884 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_disperser_0028.rmap    5.7 K bytes  (48 / 225 files) (135.9 K / 804.1 K bytes)
# 2026-07-28 16:34:13,931 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_dflat_0007.rmap    1.1 K bytes  (49 / 225 files) (141.6 K / 804.1 K bytes)
# 2026-07-28 16:34:13,975 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_dark_0086.rmap   37.5 K bytes  (50 / 225 files) (142.8 K / 804.1 K bytes)
# 2026-07-28 16:34:14,030 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_cubepar_0015.rmap      966 bytes  (51 / 225 files) (180.3 K / 804.1 K bytes)
# 2026-07-28 16:34:14,073 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_collimator_0026.rmap    1.3 K bytes  (52 / 225 files) (181.2 K / 804.1 K bytes)
# 2026-07-28 16:34:14,136 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_chromcorr_0002.rmap    1.4 K bytes  (53 / 225 files) (182.6 K / 804.1 K bytes)
# 2026-07-28 16:34:14,181 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_camera_0026.rmap    1.3 K bytes  (54 / 225 files) (183.9 K / 804.1 K bytes)
# 2026-07-28 16:34:14,227 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_barshadow_0007.rmap    1.8 K bytes  (55 / 225 files) (185.2 K / 804.1 K bytes)
# 2026-07-28 16:34:14,281 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_area_0019.rmap    6.8 K bytes  (56 / 225 files) (187.0 K / 804.1 K bytes)
# 2026-07-28 16:34:14,327 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_apcorr_0009.rmap    5.6 K bytes  (57 / 225 files) (193.8 K / 804.1 K bytes)
# 2026-07-28 16:34:14,371 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nirspec_0441.imap     6.2 K bytes  (58 / 225 files) (199.4 K / 804.1 K bytes)
# 2026-07-28 16:34:14,421 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_wavelengthrange_0008.rmap      897 bytes  (59 / 225 files) (205.7 K / 804.1 K bytes)
# 2026-07-28 16:34:14,467 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_trappars_0004.rmap      753 bytes  (60 / 225 files) (206.6 K / 804.1 K bytes)
# 2026-07-28 16:34:14,512 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_trapdensity_0005.rmap      705 bytes  (61 / 225 files) (207.3 K / 804.1 K bytes)
# 2026-07-28 16:34:14,556 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_throughput_0005.rmap    1.3 K bytes  (62 / 225 files) (208.0 K / 804.1 K bytes)
# 2026-07-28 16:34:14,601 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_superbias_0037.rmap    8.6 K bytes  (63 / 225 files) (209.3 K / 804.1 K bytes)
# 2026-07-28 16:34:14,643 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_specwcs_0017.rmap    3.1 K bytes  (64 / 225 files) (217.9 K / 804.1 K bytes)
# 2026-07-28 16:34:14,689 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_specprofile_0010.rmap    2.5 K bytes  (65 / 225 files) (221.0 K / 804.1 K bytes)
# 2026-07-28 16:34:14,731 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_speckernel_0006.rmap    1.0 K bytes  (66 / 225 files) (223.5 K / 804.1 K bytes)
# 2026-07-28 16:34:14,774 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_sirskernel_0002.rmap      700 bytes  (67 / 225 files) (224.5 K / 804.1 K bytes)
# 2026-07-28 16:34:14,817 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_saturation_0015.rmap      829 bytes  (68 / 225 files) (225.2 K / 804.1 K bytes)
# 2026-07-28 16:34:14,865 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_readnoise_0011.rmap      987 bytes  (69 / 225 files) (226.1 K / 804.1 K bytes)
# 2026-07-28 16:34:14,909 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_photom_0042.rmap    1.3 K bytes  (70 / 225 files) (227.1 K / 804.1 K bytes)
# 2026-07-28 16:34:14,953 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_persat_0007.rmap      674 bytes  (71 / 225 files) (228.3 K / 804.1 K bytes)
# 2026-07-28 16:34:14,997 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_pathloss_0003.rmap      758 bytes  (72 / 225 files) (229.0 K / 804.1 K bytes)
# 2026-07-28 16:34:15,042 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_pastasoss_0006.rmap      818 bytes  (73 / 225 files) (229.7 K / 804.1 K bytes)
# 2026-07-28 16:34:15,086 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_pars-wfsscontamstep_0001.rmap      797 bytes  (74 / 225 files) (230.6 K / 804.1 K bytes)
# 2026-07-28 16:34:15,131 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_pars-undersamplecorrectionstep_0001.rmap      904 bytes  (75 / 225 files) (231.4 K / 804.1 K bytes)
# 2026-07-28 16:34:15,277 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_pars-tweakregstep_0012.rmap    3.1 K bytes  (76 / 225 files) (232.3 K / 804.1 K bytes)
# 2026-07-28 16:34:15,325 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_pars-spec2pipeline_0009.rmap    1.2 K bytes  (77 / 225 files) (235.4 K / 804.1 K bytes)
# 2026-07-28 16:34:15,368 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_pars-sourcecatalogstep_0004.rmap    2.3 K bytes  (78 / 225 files) (236.6 K / 804.1 K bytes)
# 2026-07-28 16:34:15,412 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_pars-resamplestep_0002.rmap      687 bytes  (79 / 225 files) (239.0 K / 804.1 K bytes)
# 2026-07-28 16:34:15,457 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_pars-outlierdetectionstep_0004.rmap    2.7 K bytes  (80 / 225 files) (239.6 K / 804.1 K bytes)
# 2026-07-28 16:34:15,499 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_pars-jumpstep_0007.rmap    6.4 K bytes  (81 / 225 files) (242.3 K / 804.1 K bytes)
# 2026-07-28 16:34:15,547 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_pars-image2pipeline_0005.rmap    1.0 K bytes  (82 / 225 files) (248.7 K / 804.1 K bytes)
# 2026-07-28 16:34:15,594 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_pars-detector1pipeline_0005.rmap    1.5 K bytes  (83 / 225 files) (249.7 K / 804.1 K bytes)
# 2026-07-28 16:34:15,772 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_pars-darkpipeline_0002.rmap      868 bytes  (84 / 225 files) (251.2 K / 804.1 K bytes)
# 2026-07-28 16:34:15,817 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_pars-darkcurrentstep_0001.rmap      591 bytes  (85 / 225 files) (252.1 K / 804.1 K bytes)
# 2026-07-28 16:34:15,862 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_pars-cleanflickernoisestep_0003.rmap    1.2 K bytes  (86 / 225 files) (252.7 K / 804.1 K bytes)
# 2026-07-28 16:34:15,906 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_pars-chargemigrationstep_0005.rmap    5.7 K bytes  (87 / 225 files) (253.9 K / 804.1 K bytes)
# 2026-07-28 16:34:15,952 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_pars-backgroundstep_0003.rmap      822 bytes  (88 / 225 files) (259.6 K / 804.1 K bytes)
# 2026-07-28 16:34:16,001 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_nrm_0005.rmap      663 bytes  (89 / 225 files) (260.4 K / 804.1 K bytes)
# 2026-07-28 16:34:16,053 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_mask_0025.rmap    1.6 K bytes  (90 / 225 files) (261.1 K / 804.1 K bytes)
# 2026-07-28 16:34:16,104 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_linearity_0022.rmap      961 bytes  (91 / 225 files) (262.7 K / 804.1 K bytes)
# 2026-07-28 16:34:16,150 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_ipc_0007.rmap      651 bytes  (92 / 225 files) (263.6 K / 804.1 K bytes)
# 2026-07-28 16:34:16,194 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_gain_0011.rmap      797 bytes  (93 / 225 files) (264.3 K / 804.1 K bytes)
# 2026-07-28 16:34:16,237 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_flat_0023.rmap    5.9 K bytes  (94 / 225 files) (265.1 K / 804.1 K bytes)
# 2026-07-28 16:34:16,285 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_filteroffset_0010.rmap      853 bytes  (95 / 225 files) (270.9 K / 804.1 K bytes)
# 2026-07-28 16:34:16,332 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_extract1d_0007.rmap      905 bytes  (96 / 225 files) (271.8 K / 804.1 K bytes)
# 2026-07-28 16:34:16,376 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_drizpars_0004.rmap      519 bytes  (97 / 225 files) (272.7 K / 804.1 K bytes)
# 2026-07-28 16:34:16,421 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_distortion_0025.rmap    3.4 K bytes  (98 / 225 files) (273.2 K / 804.1 K bytes)
# 2026-07-28 16:34:16,467 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_dark_0041.rmap    8.7 K bytes  (99 / 225 files) (276.6 K / 804.1 K bytes)
# 2026-07-28 16:34:16,512 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_bkg_0005.rmap    3.1 K bytes  (100 / 225 files) (285.3 K / 804.1 K bytes)
# 2026-07-28 16:34:16,559 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_area_0014.rmap    2.7 K bytes  (101 / 225 files) (288.4 K / 804.1 K bytes)
# 2026-07-28 16:34:16,604 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_apcorr_0010.rmap    4.3 K bytes  (102 / 225 files) (291.1 K / 804.1 K bytes)
# 2026-07-28 16:34:16,650 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_abvegaoffset_0004.rmap    1.4 K bytes  (103 / 225 files) (295.4 K / 804.1 K bytes)
# 2026-07-28 16:34:16,698 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_niriss_0313.imap      6.0 K bytes  (104 / 225 files) (296.7 K / 804.1 K bytes)
# 2026-07-28 16:34:16,747 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_wavelengthrange_0014.rmap      996 bytes  (105 / 225 files) (302.7 K / 804.1 K bytes)
# 2026-07-28 16:34:16,790 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_tsophot_0003.rmap      896 bytes  (106 / 225 files) (303.7 K / 804.1 K bytes)
# 2026-07-28 16:34:16,836 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_trappars_0003.rmap    1.6 K bytes  (107 / 225 files) (304.6 K / 804.1 K bytes)
# 2026-07-28 16:34:16,879 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_trapdensity_0003.rmap    1.6 K bytes  (108 / 225 files) (306.2 K / 804.1 K bytes)
# 2026-07-28 16:34:16,924 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_superbias_0022.rmap   25.5 K bytes  (109 / 225 files) (307.8 K / 804.1 K bytes)
# 2026-07-28 16:34:16,978 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_specwcs_0027.rmap    8.0 K bytes  (110 / 225 files) (333.3 K / 804.1 K bytes)
# 2026-07-28 16:34:17,024 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_sirskernel_0003.rmap      671 bytes  (111 / 225 files) (341.3 K / 804.1 K bytes)
# 2026-07-28 16:34:17,068 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_saturation_0011.rmap    2.8 K bytes  (112 / 225 files) (342.0 K / 804.1 K bytes)
# 2026-07-28 16:34:17,115 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_regions_0003.rmap    3.4 K bytes  (113 / 225 files) (344.8 K / 804.1 K bytes)
# 2026-07-28 16:34:17,164 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_readnoise_0028.rmap   27.1 K bytes  (114 / 225 files) (348.2 K / 804.1 K bytes)
# 2026-07-28 16:34:17,223 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_psfmask_0008.rmap   28.4 K bytes  (115 / 225 files) (375.4 K / 804.1 K bytes)
# 2026-07-28 16:34:17,276 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_photom_0031.rmap    3.4 K bytes  (116 / 225 files) (403.7 K / 804.1 K bytes)
# 2026-07-28 16:34:17,328 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_persat_0005.rmap    1.6 K bytes  (117 / 225 files) (407.2 K / 804.1 K bytes)
# 2026-07-28 16:34:17,372 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_pars-whitelightstep_0004.rmap    2.0 K bytes  (118 / 225 files) (408.7 K / 804.1 K bytes)
# 2026-07-28 16:34:17,415 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_pars-wfsscontamstep_0001.rmap      797 bytes  (119 / 225 files) (410.7 K / 804.1 K bytes)
# 2026-07-28 16:34:17,459 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_pars-tweakregstep_0003.rmap    4.5 K bytes  (120 / 225 files) (411.5 K / 804.1 K bytes)
# 2026-07-28 16:34:17,503 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_pars-tsophotometrystep_0003.rmap    1.1 K bytes  (121 / 225 files) (416.0 K / 804.1 K bytes)
# 2026-07-28 16:34:17,549 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_pars-spec2pipeline_0009.rmap      984 bytes  (122 / 225 files) (417.1 K / 804.1 K bytes)
# 2026-07-28 16:34:17,591 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_pars-sourcecatalogstep_0002.rmap    4.6 K bytes  (123 / 225 files) (418.1 K / 804.1 K bytes)
# 2026-07-28 16:34:17,637 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_pars-resamplestep_0002.rmap      687 bytes  (124 / 225 files) (422.7 K / 804.1 K bytes)
# 2026-07-28 16:34:17,684 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_pars-outlierdetectionstep_0003.rmap      940 bytes  (125 / 225 files) (423.4 K / 804.1 K bytes)
# 2026-07-28 16:34:17,728 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_pars-jumpstep_0005.rmap      806 bytes  (126 / 225 files) (424.3 K / 804.1 K bytes)
# 2026-07-28 16:34:17,770 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_pars-image2pipeline_0004.rmap    1.1 K bytes  (127 / 225 files) (425.1 K / 804.1 K bytes)
# 2026-07-28 16:34:17,816 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_pars-detector1pipeline_0008.rmap    1.9 K bytes  (128 / 225 files) (426.3 K / 804.1 K bytes)
# 2026-07-28 16:34:17,863 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_pars-darkpipeline_0002.rmap      868 bytes  (129 / 225 files) (428.1 K / 804.1 K bytes)
# 2026-07-28 16:34:17,904 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_pars-darkcurrentstep_0001.rmap      618 bytes  (130 / 225 files) (429.0 K / 804.1 K bytes)
# 2026-07-28 16:34:17,948 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_pars-backgroundstep_0003.rmap      822 bytes  (131 / 225 files) (429.6 K / 804.1 K bytes)
# 2026-07-28 16:34:17,995 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_mask_0015.rmap    6.0 K bytes  (132 / 225 files) (430.4 K / 804.1 K bytes)
# 2026-07-28 16:34:18,037 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_linearity_0011.rmap    2.4 K bytes  (133 / 225 files) (436.4 K / 804.1 K bytes)
# 2026-07-28 16:34:18,082 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_ipc_0003.rmap    2.0 K bytes  (134 / 225 files) (438.8 K / 804.1 K bytes)
# 2026-07-28 16:34:18,132 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_gain_0016.rmap    2.1 K bytes  (135 / 225 files) (440.8 K / 804.1 K bytes)
# 2026-07-28 16:34:18,176 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_flat_0028.rmap   51.7 K bytes  (136 / 225 files) (442.9 K / 804.1 K bytes)
# 2026-07-28 16:34:18,236 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_filteroffset_0004.rmap    1.4 K bytes  (137 / 225 files) (494.6 K / 804.1 K bytes)
# 2026-07-28 16:34:18,284 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_extract1d_0007.rmap    2.2 K bytes  (138 / 225 files) (496.0 K / 804.1 K bytes)
# 2026-07-28 16:34:18,327 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_drizpars_0001.rmap      519 bytes  (139 / 225 files) (498.2 K / 804.1 K bytes)
# 2026-07-28 16:34:18,373 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_distortion_0034.rmap   53.4 K bytes  (140 / 225 files) (498.7 K / 804.1 K bytes)
# 2026-07-28 16:34:18,441 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_dark_0054.rmap   33.9 K bytes  (141 / 225 files) (552.1 K / 804.1 K bytes)
# 2026-07-28 16:34:18,496 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_bkg_0002.rmap    7.0 K bytes  (142 / 225 files) (585.9 K / 804.1 K bytes)
# 2026-07-28 16:34:18,541 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_area_0012.rmap   33.5 K bytes  (143 / 225 files) (592.9 K / 804.1 K bytes)
# 2026-07-28 16:34:18,596 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_apcorr_0009.rmap    4.3 K bytes  (144 / 225 files) (626.4 K / 804.1 K bytes)
# 2026-07-28 16:34:18,645 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_abvegaoffset_0004.rmap    1.3 K bytes  (145 / 225 files) (630.7 K / 804.1 K bytes)
# 2026-07-28 16:34:18,695 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_nircam_0358.imap      5.8 K bytes  (146 / 225 files) (632.0 K / 804.1 K bytes)
# 2026-07-28 16:34:18,737 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_wavelengthrange_0031.rmap    1.0 K bytes  (147 / 225 files) (637.8 K / 804.1 K bytes)
# 2026-07-28 16:34:18,782 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_tsophot_0004.rmap      882 bytes  (148 / 225 files) (638.8 K / 804.1 K bytes)
# 2026-07-28 16:34:18,823 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_straymask_0009.rmap      987 bytes  (149 / 225 files) (639.7 K / 804.1 K bytes)
# 2026-07-28 16:34:18,867 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_specwcs_0051.rmap    6.4 K bytes  (150 / 225 files) (640.7 K / 804.1 K bytes)
# 2026-07-28 16:34:18,913 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_saturation_0015.rmap    1.2 K bytes  (151 / 225 files) (647.1 K / 804.1 K bytes)
# 2026-07-28 16:34:18,956 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_rscd_0012.rmap    1.0 K bytes  (152 / 225 files) (648.2 K / 804.1 K bytes)
# 2026-07-28 16:34:18,999 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_resol_0006.rmap      790 bytes  (153 / 225 files) (649.2 K / 804.1 K bytes)
# 2026-07-28 16:34:19,042 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_reset_0027.rmap    3.8 K bytes  (154 / 225 files) (650.0 K / 804.1 K bytes)
# 2026-07-28 16:34:19,097 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_regions_0036.rmap    4.4 K bytes  (155 / 225 files) (653.8 K / 804.1 K bytes)
# 2026-07-28 16:34:19,141 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_readnoise_0026.rmap    1.9 K bytes  (156 / 225 files) (658.2 K / 804.1 K bytes)
# 2026-07-28 16:34:19,183 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_psfmask_0009.rmap    2.1 K bytes  (157 / 225 files) (660.1 K / 804.1 K bytes)
# 2026-07-28 16:34:19,226 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_psf_0008.rmap    2.6 K bytes  (158 / 225 files) (662.2 K / 804.1 K bytes)
# 2026-07-28 16:34:19,271 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_photom_0068.rmap    4.0 K bytes  (159 / 225 files) (664.9 K / 804.1 K bytes)
# 2026-07-28 16:34:19,317 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_pathloss_0006.rmap      866 bytes  (160 / 225 files) (668.8 K / 804.1 K bytes)
# 2026-07-28 16:34:19,359 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_pars-whitelightstep_0003.rmap      912 bytes  (161 / 225 files) (669.7 K / 804.1 K bytes)
# 2026-07-28 16:34:19,406 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_pars-wfsscontamstep_0001.rmap      787 bytes  (162 / 225 files) (670.6 K / 804.1 K bytes)
# 2026-07-28 16:34:19,449 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_pars-tweakregstep_0003.rmap    1.8 K bytes  (163 / 225 files) (671.4 K / 804.1 K bytes)
# 2026-07-28 16:34:19,496 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_pars-tsophotometrystep_0003.rmap    2.7 K bytes  (164 / 225 files) (673.2 K / 804.1 K bytes)
# 2026-07-28 16:34:19,547 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_pars-spec3pipeline_0011.rmap      886 bytes  (165 / 225 files) (675.9 K / 804.1 K bytes)
# 2026-07-28 16:34:19,591 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_pars-spec2pipeline_0015.rmap    1.5 K bytes  (166 / 225 files) (676.8 K / 804.1 K bytes)
# 2026-07-28 16:34:19,637 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_pars-sourcecatalogstep_0004.rmap    1.9 K bytes  (167 / 225 files) (678.3 K / 804.1 K bytes)
# 2026-07-28 16:34:19,682 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_pars-resamplestep_0002.rmap      677 bytes  (168 / 225 files) (680.2 K / 804.1 K bytes)
# 2026-07-28 16:34:19,724 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_pars-resamplespecstep_0002.rmap      706 bytes  (169 / 225 files) (680.9 K / 804.1 K bytes)
# 2026-07-28 16:34:19,766 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_pars-outlierdetectionstep_0020.rmap    3.4 K bytes  (170 / 225 files) (681.6 K / 804.1 K bytes)
# 2026-07-28 16:34:19,811 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_pars-jumpstep_0011.rmap    1.6 K bytes  (171 / 225 files) (685.0 K / 804.1 K bytes)
# 2026-07-28 16:34:19,854 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_pars-image2pipeline_0010.rmap    1.1 K bytes  (172 / 225 files) (686.5 K / 804.1 K bytes)
# 2026-07-28 16:34:19,901 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_pars-extract1dstep_0003.rmap      807 bytes  (173 / 225 files) (687.6 K / 804.1 K bytes)
# 2026-07-28 16:34:19,944 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_pars-emicorrstep_0003.rmap      796 bytes  (174 / 225 files) (688.4 K / 804.1 K bytes)
# 2026-07-28 16:34:19,992 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_pars-detector1pipeline_0012.rmap    1.6 K bytes  (175 / 225 files) (689.2 K / 804.1 K bytes)
# 2026-07-28 16:34:20,040 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_pars-darkpipeline_0002.rmap      860 bytes  (176 / 225 files) (690.8 K / 804.1 K bytes)
# 2026-07-28 16:34:20,083 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_pars-darkcurrentstep_0002.rmap      683 bytes  (177 / 225 files) (691.7 K / 804.1 K bytes)
# 2026-07-28 16:34:20,128 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_pars-backgroundstep_0003.rmap      814 bytes  (178 / 225 files) (692.3 K / 804.1 K bytes)
# 2026-07-28 16:34:20,172 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_pars-adaptivetracemodelstep_0002.rmap      979 bytes  (179 / 225 files) (693.2 K / 804.1 K bytes)
# 2026-07-28 16:34:20,214 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_mrsxartcorr_0002.rmap    2.2 K bytes  (180 / 225 files) (694.1 K / 804.1 K bytes)
# 2026-07-28 16:34:20,262 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_mrsptcorr_0005.rmap    2.0 K bytes  (181 / 225 files) (696.3 K / 804.1 K bytes)
# 2026-07-28 16:34:20,304 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_mask_0037.rmap    9.3 K bytes  (182 / 225 files) (698.3 K / 804.1 K bytes)
# 2026-07-28 16:34:20,348 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_linearity_0018.rmap    2.8 K bytes  (183 / 225 files) (707.6 K / 804.1 K bytes)
# 2026-07-28 16:34:20,390 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_ipc_0008.rmap      700 bytes  (184 / 225 files) (710.4 K / 804.1 K bytes)
# 2026-07-28 16:34:20,437 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_gain_0013.rmap    3.9 K bytes  (185 / 225 files) (711.1 K / 804.1 K bytes)
# 2026-07-28 16:34:20,479 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_fringefreq_0003.rmap    1.4 K bytes  (186 / 225 files) (715.0 K / 804.1 K bytes)
# 2026-07-28 16:34:20,523 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_fringe_0019.rmap    3.9 K bytes  (187 / 225 files) (716.5 K / 804.1 K bytes)
# 2026-07-28 16:34:20,566 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_flat_0079.rmap   17.1 K bytes  (188 / 225 files) (720.4 K / 804.1 K bytes)
# 2026-07-28 16:34:20,614 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_filteroffset_0029.rmap    2.4 K bytes  (189 / 225 files) (737.5 K / 804.1 K bytes)
# 2026-07-28 16:34:20,663 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_extract1d_0022.rmap    1.0 K bytes  (190 / 225 files) (739.9 K / 804.1 K bytes)
# 2026-07-28 16:34:20,706 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_emicorr_0007.rmap      663 bytes  (191 / 225 files) (740.9 K / 804.1 K bytes)
# 2026-07-28 16:34:20,750 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_drizpars_0002.rmap      511 bytes  (192 / 225 files) (741.6 K / 804.1 K bytes)
# 2026-07-28 16:34:20,793 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_distortion_0043.rmap    4.8 K bytes  (193 / 225 files) (742.1 K / 804.1 K bytes)
# 2026-07-28 16:34:20,836 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_dark_0043.rmap    5.6 K bytes  (194 / 225 files) (746.9 K / 804.1 K bytes)
# 2026-07-28 16:34:20,878 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_cubepar_0017.rmap      800 bytes  (195 / 225 files) (752.4 K / 804.1 K bytes)
# 2026-07-28 16:34:20,921 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_bkg_0006.rmap      712 bytes  (196 / 225 files) (753.2 K / 804.1 K bytes)
# 2026-07-28 16:34:20,965 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_area_0015.rmap      866 bytes  (197 / 225 files) (753.9 K / 804.1 K bytes)
# 2026-07-28 16:34:21,007 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_apcorr_0024.rmap    5.0 K bytes  (198 / 225 files) (754.8 K / 804.1 K bytes)
# 2026-07-28 16:34:21,049 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_abvegaoffset_0003.rmap    1.3 K bytes  (199 / 225 files) (759.8 K / 804.1 K bytes)
# 2026-07-28 16:34:21,097 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_miri_0517.imap        6.1 K bytes  (200 / 225 files) (761.1 K / 804.1 K bytes)
# 2026-07-28 16:34:21,141 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_trappars_0004.rmap      903 bytes  (201 / 225 files) (767.2 K / 804.1 K bytes)
# 2026-07-28 16:34:21,184 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_trapdensity_0006.rmap      930 bytes  (202 / 225 files) (768.1 K / 804.1 K bytes)
# 2026-07-28 16:34:21,231 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_superbias_0017.rmap    3.8 K bytes  (203 / 225 files) (769.0 K / 804.1 K bytes)
# 2026-07-28 16:34:21,272 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_saturation_0009.rmap      779 bytes  (204 / 225 files) (772.8 K / 804.1 K bytes)
# 2026-07-28 16:34:21,318 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_readnoise_0014.rmap    1.3 K bytes  (205 / 225 files) (773.6 K / 804.1 K bytes)
# 2026-07-28 16:34:21,361 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_photom_0014.rmap    1.1 K bytes  (206 / 225 files) (774.8 K / 804.1 K bytes)
# 2026-07-28 16:34:21,403 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_persat_0006.rmap      884 bytes  (207 / 225 files) (776.0 K / 804.1 K bytes)
# 2026-07-28 16:34:21,450 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_pars-tweakregstep_0002.rmap      850 bytes  (208 / 225 files) (776.8 K / 804.1 K bytes)
# 2026-07-28 16:34:21,492 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_pars-sourcecatalogstep_0001.rmap      636 bytes  (209 / 225 files) (777.7 K / 804.1 K bytes)
# 2026-07-28 16:34:21,535 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_pars-outlierdetectionstep_0001.rmap      654 bytes  (210 / 225 files) (778.3 K / 804.1 K bytes)
# 2026-07-28 16:34:21,577 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_pars-image2pipeline_0005.rmap      974 bytes  (211 / 225 files) (779.0 K / 804.1 K bytes)
# 2026-07-28 16:34:21,622 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_pars-detector1pipeline_0002.rmap    1.0 K bytes  (212 / 225 files) (779.9 K / 804.1 K bytes)
# 2026-07-28 16:34:21,674 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_pars-darkpipeline_0002.rmap      856 bytes  (213 / 225 files) (781.0 K / 804.1 K bytes)
# 2026-07-28 16:34:21,723 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_mask_0023.rmap    1.1 K bytes  (214 / 225 files) (781.8 K / 804.1 K bytes)
# 2026-07-28 16:34:21,770 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_linearity_0015.rmap      925 bytes  (215 / 225 files) (782.9 K / 804.1 K bytes)
# 2026-07-28 16:34:21,816 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_ipc_0003.rmap       614 bytes  (216 / 225 files) (783.8 K / 804.1 K bytes)
# 2026-07-28 16:34:21,862 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_gain_0010.rmap      890 bytes  (217 / 225 files) (784.4 K / 804.1 K bytes)
# 2026-07-28 16:34:21,906 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_flat_0009.rmap    1.1 K bytes  (218 / 225 files) (785.3 K / 804.1 K bytes)
# 2026-07-28 16:34:21,947 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_distortion_0011.rmap    1.2 K bytes  (219 / 225 files) (786.4 K / 804.1 K bytes)
# 2026-07-28 16:34:21,990 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_dark_0017.rmap    4.3 K bytes  (220 / 225 files) (787.7 K / 804.1 K bytes)
# 2026-07-28 16:34:22,038 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_area_0010.rmap    1.2 K bytes  (221 / 225 files) (792.0 K / 804.1 K bytes)
# 2026-07-28 16:34:22,081 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_apcorr_0004.rmap    4.0 K bytes  (222 / 225 files) (793.1 K / 804.1 K bytes)
# 2026-07-28 16:34:22,126 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_abvegaoffset_0002.rmap    1.3 K bytes  (223 / 225 files) (797.1 K / 804.1 K bytes)
# 2026-07-28 16:34:22,168 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_fgs_0126.imap         5.2 K bytes  (224 / 225 files) (798.4 K / 804.1 K bytes)
# 2026-07-28 16:34:22,220 - CRDS - INFO -  Fetching  /home/runner/crds/mappings/jwst/jwst_1584.pmap               580 bytes  (225 / 225 files) (803.5 K / 804.1 K bytes)
# 2026-07-28 16:34:22,564 - CRDS - ERROR -  Error determining best reference for 'pars-darkcurrentstep'  =   No match found.
# 2026-07-28 16:34:22,571 - CRDS - INFO -  Syncing 1 files
# 2026-07-28 16:34:22,571 - CRDS - INFO -  Fetching  /home/runner/crds/references/jwst/nircam/jwst_nircam_pars-jumpstep_0003.asdf    1.8 K bytes  (1 / 1 files) (0 / 1.8 K bytes)
# 2026-07-28 16:34:22,619 - stpipe.step - INFO - PARS-JUMPSTEP parameters found: /home/runner/crds/references/jwst/nircam/jwst_nircam_pars-jumpstep_0003.asdf
# 2026-07-28 16:34:22,637 - CRDS - INFO -  Syncing 1 files
# 2026-07-28 16:34:22,638 - CRDS - INFO -  Fetching  /home/runner/crds/references/jwst/nircam/jwst_nircam_pars-detector1pipeline_0007.asdf    3.0 K bytes  (1 / 1 files) (0 / 3.0 K bytes)
# 2026-07-28 16:34:22,682 - stpipe.pipeline - INFO - PARS-DETECTOR1PIPELINE parameters found: /home/runner/crds/references/jwst/nircam/jwst_nircam_pars-detector1pipeline_0007.asdf
# 2026-07-28 16:34:22,700 - stpipe.step - INFO - Detector1Pipeline instance created.
# 2026-07-28 16:34:22,701 - stpipe.step - INFO - GroupScaleStep instance created.
# 2026-07-28 16:34:22,701 - stpipe.step - INFO - DQInitStep instance created.
# 2026-07-28 16:34:22,702 - stpipe.step - INFO - EmiCorrStep instance created.
# 2026-07-28 16:34:22,703 - stpipe.step - INFO - SaturationStep instance created.
# 2026-07-28 16:34:22,704 - stpipe.step - INFO - IPCStep instance created.
# 2026-07-28 16:34:22,705 - stpipe.step - INFO - SuperBiasStep instance created.
# 2026-07-28 16:34:22,707 - stpipe.step - INFO - RefPixStep instance created.
# 2026-07-28 16:34:22,708 - stpipe.step - INFO - RscdStep instance created.
# 2026-07-28 16:34:22,708 - stpipe.step - INFO - FirstFrameStep instance created.
# 2026-07-28 16:34:22,709 - stpipe.step - INFO - LastFrameStep instance created.
# 2026-07-28 16:34:22,710 - stpipe.step - INFO - LinearityStep instance created.
# 2026-07-28 16:34:22,711 - stpipe.step - INFO - DarkCurrentStep instance created.
# 2026-07-28 16:34:22,712 - stpipe.step - INFO - ResetStep instance created.
# 2026-07-28 16:34:22,713 - stpipe.step - INFO - PersistenceStep instance created.
# 2026-07-28 16:34:22,714 - stpipe.step - INFO - ChargeMigrationStep instance created.
# 2026-07-28 16:34:22,715 - stpipe.step - INFO - JumpStep instance created.
# 2026-07-28 16:34:22,716 - stpipe.step - INFO - PictureFrameStep instance created.
# 2026-07-28 16:34:22,717 - stpipe.step - INFO - CleanFlickerNoiseStep instance created.
# 2026-07-28 16:34:22,718 - stpipe.step - INFO - RampFitStep instance created.
# 2026-07-28 16:34:22,721 - stpipe.step - INFO - GainScaleStep instance created.
# 2026-07-28 16:34:22,903 - stpipe.step - INFO - Step Detector1Pipeline running with args ('/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/uncal/jw01386001001_0310e_00001_nrcalong_uncal.fits',).
# 2026-07-28 16:34:22,922 - stpipe.step - INFO - Step Detector1Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_calibrated_ramp: False
#   steps:
#     group_scale:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dq_init:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       user_supplied_dq: None
#     emicorr:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: joint
#       nints_to_phase: None
#       nbins: None
#       scale_reference: True
#       onthefly_corr_freq: None
#       use_n_cycles: 3
#       fit_ints_separately: False
#       user_supplied_reffile: None
#       save_intermediate_results: False
#     saturation:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       n_pix_grow_sat: 1
#       use_readpatt: True
#     ipc:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     superbias:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     refpix:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       odd_even_columns: True
#       use_side_ref_pixels: True
#       side_smoothing_length: 11
#       side_gain: 1.0
#       odd_even_rows: True
#       ovr_corr_mitigation_ftr: 3.0
#       preserve_irs2_refpix: False
#       irs2_mean_subtraction: False
#       refpix_algorithm: median
#       sigreject: 4.0
#       gaussmooth: 1.0
#       halfwidth: 30
#       siglimit: 3.0
#     rscd:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     firstframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bright_use_group1: True
#     lastframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     linearity:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dark_current:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       dark_output: None
#       average_dark_current: None
#     reset:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     persistence:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_persistence: None
#       persistence_time: None
#       dn_threshold: None
# ...
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       rejection_threshold: 4.0
#       three_group_rejection_threshold: 6.0
#       four_group_rejection_threshold: 5.0
#       maximum_cores: half
#       flag_4_neighbors: True
#       max_jump_to_flag_neighbors: 1000
#       min_jump_to_flag_neighbors: 30
#       after_jump_flag_dn1: 0
#       after_jump_flag_time1: 0
#       after_jump_flag_dn2: 0
#       after_jump_flag_time2: 0
#       expand_large_events: True
#       min_sat_area: 1
#       min_jump_area: 5
#       expand_factor: 2
#       use_ellipses: False
#       sat_required_snowball: True
#       min_sat_radius_extend: 2.5
#       sat_expand: 2
#       edge_size: 25
#       mask_snowball_core_next_int: True
#       snowball_time_masked_next_int: 4000
#       find_showers: False
#       max_shower_amplitude: 4.0
#       extend_snr_threshold: 0.0
#       extend_min_area: 0
#       extend_inner_radius: 0
#       extend_outer_radius: 0.0
#       extend_ellipse_expand_ratio: 0.0
#       time_masked_after_shower: 0
#       min_diffs_single_pass: 10
#       max_extended_radius: 200
#       minimum_groups: 3
#       minimum_sigclip_groups: 100
#       only_use_ints: True
#     picture_frame:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       mask_science_regions: True
#       n_sigma: 2.0
#       save_mask: False
#       save_correction: False
#     clean_flicker_noise:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       autoparam: False
#       fit_method: median
#       fit_by_channel: False
#       background_method: median
#       background_box_size: None
#       mask_science_regions: False
#       apply_flat_field: False
#       n_sigma: 2.0
#       fit_histogram: False
#       single_mask: True
#       user_mask: None
#       save_mask: False
#       save_background: False
#       save_noise: False
#     ramp_fit:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: OLS_C
#       int_name: ''
#       save_opt: False
#       opt_name: ''
#       suppress_one_group: False
#       firstgroup: None
#       lastgroup: None
#       maximum_cores: '1'
#     gain_scale:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
# 2026-07-28 16:35:17,175 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386003001_0310a_00001_nrcalong_uncal.fits' reftypes = ['gain', 'linearity', 'mask', 'readnoise', 'refpix', 'reset', 'rscd', 'saturation', 'sirskernel', 'superbias']
# 2026-07-28 16:35:17,179 - stpipe.pipeline - INFO - Prefetch for GAIN reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_gain_0097.fits'.
# 2026-07-28 16:35:17,179 - stpipe.pipeline - INFO - Prefetch for LINEARITY reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_linearity_0052.fits'.
# 2026-07-28 16:35:17,180 - stpipe.pipeline - INFO - Prefetch for MASK reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_mask_0076.fits'.
# 2026-07-28 16:35:17,181 - stpipe.pipeline - INFO - Prefetch for READNOISE reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_readnoise_0284.fits'.
# 2026-07-28 16:35:17,181 - stpipe.pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2026-07-28 16:35:17,182 - stpipe.pipeline - INFO - Prefetch for RESET reference file is 'N/A'.
# 2026-07-28 16:35:17,182 - stpipe.pipeline - INFO - Prefetch for RSCD reference file is 'N/A'.
# 2026-07-28 16:35:17,183 - stpipe.pipeline - INFO - Prefetch for SATURATION reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_saturation_0097.fits'.
# 2026-07-28 16:35:17,183 - stpipe.pipeline - INFO - Prefetch for SIRSKERNEL reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_sirskernel_0002.asdf'.
# 2026-07-28 16:35:17,184 - stpipe.pipeline - INFO - Prefetch for SUPERBIAS reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_superbias_0229.fits'.
# 2026-07-28 16:35:17,184 - jwst.pipeline.calwebb_detector1 - INFO - Starting calwebb_detector1 ...
# 2026-07-28 16:35:17,501 - stpipe.step - INFO - Step group_scale running with args (<RampModel(2, 15, 320, 320) from jw01386003001_0310a_00001_nrcalong_uncal.fits>,).
# 2026-07-28 16:35:17,501 - jwst.group_scale.group_scale_step - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2026-07-28 16:35:17,502 - jwst.group_scale.group_scale_step - INFO - Step will be skipped
# 2026-07-28 16:35:17,504 - stpipe.step - INFO - Step group_scale done
# 2026-07-28 16:35:17,697 - stpipe.step - INFO - Step dq_init running with args (<RampModel(2, 15, 320, 320) from jw01386003001_0310a_00001_nrcalong_uncal.fits>,).
# 2026-07-28 16:35:17,700 - jwst.dq_init.dq_init_step - INFO - Using MASK reference file /home/runner/crds/references/jwst/nircam/jwst_nircam_mask_0076.fits
# 2026-07-28 16:35:17,758 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-07-28 16:35:17,824 - jwst.dq_init.dq_initialization - INFO - Extracting mask subarray to match science data
# 2026-07-28 16:35:17,848 - stpipe.step - INFO - Step dq_init done
# 2026-07-28 16:35:18,042 - stpipe.step - INFO - Step saturation running with args (<RampModel(2, 15, 320, 320) from jw01386003001_0310a_00001_nrcalong_uncal.fits>,).
# 2026-07-28 16:35:18,047 - jwst.saturation.saturation_step - INFO - Using SATURATION reference file /home/runner/crds/references/jwst/nircam/jwst_nircam_saturation_0097.fits
# 2026-07-28 16:35:18,047 - jwst.saturation.saturation_step - INFO - Using SUPERBIAS reference file /home/runner/crds/references/jwst/nircam/jwst_nircam_superbias_0229.fits
# 2026-07-28 16:35:18,104 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-07-28 16:35:18,105 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-07-28 16:35:18,146 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-07-28 16:35:18,195 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-07-28 16:35:18,203 - jwst.saturation.saturation - INFO - Extracting reference file subarray to match science data
# 2026-07-28 16:35:18,218 - jwst.saturation.saturation - INFO - Using read_pattern with nframes 8
# 2026-07-28 16:35:18,258 - stcal.saturation.saturation - INFO - Detected 48 saturated pixels
# 2026-07-28 16:35:18,259 - stcal.saturation.saturation - INFO - Detected 0 A/D floor pixels
# 2026-07-28 16:35:18,278 - stpipe.step - INFO - Step saturation done
# 2026-07-28 16:35:18,475 - stpipe.step - INFO - Step ipc running with args (<RampModel(2, 15, 320, 320) from jw01386003001_0310a_00001_nrcalong_uncal.fits>,).
# 2026-07-28 16:35:18,476 - stpipe.step - INFO - Step skipped.
# 2026-07-28 16:35:18,668 - stpipe.step - INFO - Step superbias running with args (<RampModel(2, 15, 320, 320) from jw01386003001_0310a_00001_nrcalong_uncal.fits>,).
# 2026-07-28 16:35:18,672 - jwst.superbias.superbias_step - INFO - Using SUPERBIAS reference file /home/runner/crds/references/jwst/nircam/jwst_nircam_superbias_0229.fits
# 2026-07-28 16:35:18,707 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-07-28 16:35:18,734 - stpipe.step - INFO - Step superbias done
# 2026-07-28 16:35:18,926 - stpipe.step - INFO - Step refpix running with args (<RampModel(2, 15, 320, 320) from jw01386003001_0310a_00001_nrcalong_uncal.fits>,).
# 2026-07-28 16:35:18,928 - jwst.refpix.reference_pixels - INFO - NIR subarray data
# 2026-07-28 16:35:18,930 - jwst.refpix.reference_pixels - INFO - Single readout amplifier used
# 2026-07-28 16:35:18,931 - jwst.refpix.reference_pixels - INFO - No valid reference pixels.  This step will have no effect.
# 2026-07-28 16:35:18,949 - jwst.refpix.reference_pixels - INFO - Processing the zero frame
# 2026-07-28 16:35:19,002 - stpipe.step - INFO - Step refpix done
# 2026-07-28 16:35:19,194 - stpipe.step - INFO - Step linearity running with args (<RampModel(2, 15, 320, 320) from jw01386003001_0310a_00001_nrcalong_uncal.fits>,).
# 2026-07-28 16:35:19,198 - jwst.linearity.linearity_step - INFO - Using Linearity reference file /home/runner/crds/references/jwst/nircam/jwst_nircam_linearity_0052.fits
# 2026-07-28 16:35:19,262 - stdatamodels.dynamicdq - WARNING - Keyword UAZ_DO_NOT_USE does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-07-28 16:35:19,263 - stdatamodels.dynamicdq - WARNING - Keyword UAZ_NO_LIN_SAMP does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-07-28 16:35:19,264 - stdatamodels.dynamicdq - WARNING - Keyword UAZ_BAD_LIN_FIT does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-07-28 16:35:19,264 - stdatamodels.dynamicdq - WARNING - Keyword UAZ_NO_WELL_SAMP does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-07-28 16:35:19,265 - stdatamodels.dynamicdq - WARNING - Keyword UAZ_MODEL_FIT_FAIL does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-07-28 16:35:19,266 - stdatamodels.dynamicdq - WARNING - Keyword UAZ_WELL_NOT_DEFINED does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-07-28 16:35:19,266 - stdatamodels.dynamicdq - WARNING - Keyword UAZ_MASTER_MASK does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-07-28 16:35:19,324 - stpipe.step - INFO - Step linearity done
# 2026-07-28 16:35:19,517 - stpipe.step - INFO - Step dark_current running with args (<RampModel(2, 15, 320, 320) from jw01386003001_0310a_00001_nrcalong_uncal.fits>,).
# 2026-07-28 16:35:19,518 - stpipe.step - INFO - Step skipped.
# 2026-07-28 16:35:19,708 - stpipe.step - INFO - Step charge_migration running with args (<RampModel(2, 15, 320, 320) from jw01386003001_0310a_00001_nrcalong_uncal.fits>,).
# 2026-07-28 16:35:19,709 - stpipe.step - INFO - Step skipped.
# 2026-07-28 16:35:19,901 - stpipe.step - INFO - Step jump running with args (<RampModel(2, 15, 320, 320) from jw01386003001_0310a_00001_nrcalong_uncal.fits>,).
# 2026-07-28 16:35:19,902 - jwst.jump.jump_step - INFO - CR rejection threshold = 4 sigma
# 2026-07-28 16:35:19,903 - jwst.jump.jump_step - INFO - Maximum cores to use = half
# 2026-07-28 16:35:19,906 - jwst.jump.jump_step - INFO - Using GAIN reference file: /home/runner/crds/references/jwst/nircam/jwst_nircam_gain_0097.fits
# 2026-07-28 16:35:19,909 - jwst.jump.jump_step - INFO - Using READNOISE reference file: /home/runner/crds/references/jwst/nircam/jwst_nircam_readnoise_0284.fits
# 2026-07-28 16:35:19,936 - jwst.jump.jump_step - INFO - Extracting gain subarray to match science data
# 2026-07-28 16:35:19,950 - stcal.jump.jump - INFO - Executing two-point difference method
# 2026-07-28 16:35:19,951 - stcal.jump.jump - INFO - Creating 2 processes for jump detection
# 2026-07-28 16:35:20,387 - stcal.jump.jump - INFO - Flagging Snowballs
# 2026-07-28 16:35:20,717 - stcal.jump.jump - INFO - Total snowballs = 273
# 2026-07-28 16:35:20,718 - stcal.jump.jump - INFO - Total elapsed time = 0.767198 sec
# 2026-07-28 16:35:20,730 - jwst.jump.jump_step - INFO - The execution time in seconds: 0.827396
# 2026-07-28 16:35:20,733 - stpipe.step - INFO - Step jump done
# 2026-07-28 16:35:20,924 - stpipe.step - INFO - Step picture_frame running with args (<RampModel(2, 15, 320, 320) from jw01386003001_0310a_00001_nrcalong_uncal.fits>,).
# 2026-07-28 16:35:20,925 - stpipe.step - INFO - Step skipped.
# 2026-07-28 16:35:21,116 - stpipe.step - INFO - Step clean_flicker_noise running with args (<RampModel(2, 15, 320, 320) from jw01386003001_0310a_00001_nrcalong_uncal.fits>,).
# 2026-07-28 16:35:21,117 - stpipe.step - INFO - Step skipped.
# 2026-07-28 16:35:21,311 - stpipe.step - INFO - Step persistence running with args (<RampModel(2, 15, 320, 320) from jw01386003001_0310a_00001_nrcalong_uncal.fits>,).
# 2026-07-28 16:35:21,312 - stpipe.step - INFO - Step skipped.
# 2026-07-28 16:35:21,508 - stpipe.step - INFO - Step ramp_fit running with args (<RampModel(2, 15, 320, 320) from jw01386003001_0310a_00001_nrcalong_uncal.fits>,).
# 2026-07-28 16:35:21,514 - jwst.ramp_fitting.ramp_fit_step - INFO - Using READNOISE reference file: /home/runner/crds/references/jwst/nircam/jwst_nircam_readnoise_0284.fits
# 2026-07-28 16:35:21,514 - jwst.ramp_fitting.ramp_fit_step - INFO - Using GAIN reference file: /home/runner/crds/references/jwst/nircam/jwst_nircam_gain_0097.fits
# 2026-07-28 16:35:21,541 - jwst.ramp_fitting.ramp_fit_step - INFO - Extracting gain subarray to match science data
# 2026-07-28 16:35:21,550 - jwst.ramp_fitting.ramp_fit_step - INFO - Using algorithm = OLS_C
# 2026-07-28 16:35:21,550 - jwst.ramp_fitting.ramp_fit_step - INFO - Using weighting = optimal
# 2026-07-28 16:35:21,552 - stcal.ramp_fitting.ols_fit - INFO - Number of multiprocessing slices: 1
# 2026-07-28 16:35:21,717 - stcal.ramp_fitting.ols_fit - INFO - Ramp Fitting C Time: 0.16419768333435059
# 2026-07-28 16:35:21,855 - stpipe.step - INFO - Step ramp_fit done
# 2026-07-28 16:35:22,054 - stpipe.step - INFO - Step gain_scale running with args (<ImageModel(320, 320) from jw01386003001_0310a_00001_nrcalong_uncal.fits>,).
# 2026-07-28 16:35:22,058 - jwst.gain_scale.gain_scale_step - INFO - Using GAIN reference file: /home/runner/crds/references/jwst/nircam/jwst_nircam_gain_0097.fits
# 2026-07-28 16:35:22,073 - jwst.gain_scale.gain_scale_step - INFO - GAINFACT not found in gain reference file
# 2026-07-28 16:35:22,074 - jwst.gain_scale.gain_scale_step - INFO - Step will be skipped
# 2026-07-28 16:35:22,077 - stpipe.step - INFO - Step gain_scale done
# 2026-07-28 16:35:22,267 - stpipe.step - INFO - Step gain_scale running with args (<CubeModel(2, 320, 320) from jw01386003001_0310a_00001_nrcalong_uncal.fits>,).
# 2026-07-28 16:35:22,271 - jwst.gain_scale.gain_scale_step - INFO - Using GAIN reference file: /home/runner/crds/references/jwst/nircam/jwst_nircam_gain_0097.fits
# 2026-07-28 16:35:22,285 - jwst.gain_scale.gain_scale_step - INFO - GAINFACT not found in gain reference file
# 2026-07-28 16:35:22,286 - jwst.gain_scale.gain_scale_step - INFO - Step will be skipped
# 2026-07-28 16:35:22,289 - stpipe.step - INFO - Step gain_scale done
# 2026-07-28 16:35:22,343 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386003001_0310a_00001_nrcalong_rateints.fits
# 2026-07-28 16:35:22,344 - jwst.pipeline.calwebb_detector1 - INFO - ... ending calwebb_detector1
# 2026-07-28 16:35:22,345 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1584.pmap
# 2026-07-28 16:35:22,394 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386003001_0310a_00001_nrcalong_rate.fits
# 2026-07-28 16:35:22,395 - stpipe.step - INFO - Step Detector1Pipeline done
# 2026-07-28 16:35:22,395 - jwst.stpipe.core - INFO - Results used jwst version: 3.0.0

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.0f} seconds")
print(f"Runtime for Detector1: {time1 - time_det1:0.0f} seconds")
# Out:
# Runtime so far: 79 seconds
# Runtime for Detector1: 74 seconds

# %% [markdown]
# ### Exploring the data
#
# Identify `*_rateints.fits` files and verify which pipeline steps were run and
# which calibration reference files were applied.
#
# The header contains information about which calibration steps were
# completed and skipped and which reference files were used to process the
# data.

# %%
if dodet1:
    # find rate files
    rate_files = sorted(glob.glob(os.path.join(det1_dir, '*_rateints.fits')))

    # Read in file as datamodel
    rate_f = datamodels.open(rate_files[0])

    # Check which steps were run
    rate_f.meta.cal_step.instance
# Out:
# {'charge_migration': 'SKIPPED',
#  'clean_flicker_noise': 'SKIPPED',
#  'dq_init': 'COMPLETE',
#  'gain_scale': 'SKIPPED',
#  'group_scale': 'SKIPPED',
#  'ipc': 'SKIPPED',
#  'jump': 'COMPLETE',
#  'linearity': 'COMPLETE',
#  'persistence': 'SKIPPED',
#  'picture_frame': 'SKIPPED',
#  'ramp_fit': 'COMPLETE',
#  'refpix': 'COMPLETE',
#  'saturation': 'COMPLETE',
#  'superbias': 'COMPLETE'}

# %% [markdown]
# For this particular rate file, show which reference files were used to calibrate the dataset. Note that these files will be different for each NIRCam detector.

# %%
if dodet1:
    rate_f.meta.ref_file.instance
# Out:
# {'crds': {'context_used': 'jwst_1584.pmap', 'sw_version': '13.2.7'},
#  'gain': {'name': 'crds://jwst_nircam_gain_0097.fits'},
#  'linearity': {'name': 'crds://jwst_nircam_linearity_0052.fits'},
#  'mask': {'name': 'crds://jwst_nircam_mask_0076.fits'},
#  'readnoise': {'name': 'crds://jwst_nircam_readnoise_0284.fits'},
#  'saturation': {'name': 'crds://jwst_nircam_saturation_0097.fits'},
#  'superbias': {'name': 'crds://jwst_nircam_superbias_0229.fits'}}

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ## 6. Image2 Pipeline
#
# In the [Image2 stage ](https://jwst-pipeline.readthedocs.io/en/latest/jwst/pipeline/calwebb_image2.html) of the science calibration pipeline,
# calibrated unrectified data products are created (`*_cal.fits` or
# `*_calints.fits` files, depending on whether the input files are
# `*_rate.fits` or `*_rateints.fits`). For the coronagraphy pipeline, we use the `_rateints.fits` files as input.
#
# In this pipeline processing stage, the [world coordinate system (WCS)](https://jwst-pipeline.readthedocs.io/en/latest/jwst/assign_wcs/index.html#assign-wcs-step)
# is assigned, the data are [flat fielded](https://jwst-pipeline.readthedocs.io/en/latest/jwst/flatfield/index.html#flatfield-step),
# and a [photometric calibration](https://jwst-pipeline.readthedocs.io/en/latest/jwst/photom/index.html#photom-step)
# is applied to convert from units of countrate (ADU/s) to surface brightness (MJy/sr).

# %%
time_image2 = time.perf_counter()

# %%
# Set up a dictionary to define how the Image2 pipeline should be configured.

# Boilerplate dictionary setup
image2dict = {}
image2dict['assign_wcs'], image2dict['flat_field'] = {}, {}
image2dict['photom'], image2dict['resample'] = {}, {}

# Overrides for whether or not certain steps should be skipped (example)
#image2dict['resample']['skip'] = False

# Overrides for various reference files
# Files should be in the base local directory or provide full path
#image2dict['assign_wcs']['override_distortion'] = 'myfile.asdf'  # Spatial distortion (ASDF file)
#image2dict['assign_wcs']['override_filteroffset'] = 'myfile.asdf'  # Imager filter offsets (ASDF file)
#image2dict['assign_wcs']['override_specwcs'] = 'myfile.asdf'  # Spectral distortion (ASDF file)
#image2dict['assign_wcs']['override_wavelengthrange'] = 'myfile.asdf'  # Wavelength channel mapping (ASDF file)
#image2dict['flat_field']['override_flat'] = 'myfile.fits'  # Pixel flatfield
#image2dict['photom']['override_photom'] = 'myfile.fits'  # Photometric calibration array

# %% [markdown]
# Find and sort all of the input files, ensuring use of absolute paths.

# %%
sstring = os.path.join(det1_dir, 'jw*rateints.fits')  # Use files from the detector1 output folder
rate_files = sorted(glob.glob(sstring))
rate_files = [os.path.abspath(fname) for fname in rate_files]

print(f"Found  {len(rate_files)} science files")
# Out:
# Found  11 science files

# %%
# List rate files
rate_files
# Out:
# ['/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386001001_0310e_00001_nrcalong_rateints.fits',
#  '/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386001001_0310e_00002_nrcalong_rateints.fits',
#  '/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386001001_0310e_00003_nrcalong_rateints.fits',
#  '/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386001001_0310e_00004_nrcalong_rateints.fits',
#  '/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386001001_0310e_00005_nrcalong_rateints.fits',
#  '/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386001001_0310e_00006_nrcalong_rateints.fits',
#  '/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386001001_0310e_00007_nrcalong_rateints.fits',
#  '/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386001001_0310e_00008_nrcalong_rateints.fits',
#  '/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386001001_0310e_00009_nrcalong_rateints.fits',
#  '/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386002001_0310a_00001_nrcalong_rateints.fits',
#  '/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386003001_0310a_00001_nrcalong_rateints.fits']

# %% [markdown]
# Run the Image2 pipeline on all of the rateints files.

# %%
# Run Image2 stage of pipeline, specifying:
# output directory to save *_calints.fits files
# save_results flag set to True so the calints files are saved

if doimage2:
    for rate in rate_files:
        cal_result = Image2Pipeline.call(rate, output_dir=image2_dir, steps=image2dict, save_results=True)
else:
    print("Skipping Image2 processing.")
# Out:
# 2026-07-28 16:35:22,547 - CRDS - INFO -  Syncing 1 files
# 2026-07-28 16:35:22,548 - CRDS - INFO -  Fetching  /home/runner/crds/references/jwst/nircam/jwst_nircam_pars-resamplestep_0001.asdf    1.1 K bytes  (1 / 1 files) (0 / 1.1 K bytes)
# 2026-07-28 16:35:22,596 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /home/runner/crds/references/jwst/nircam/jwst_nircam_pars-resamplestep_0001.asdf
# 2026-07-28 16:35:22,607 - CRDS - INFO -  Syncing 1 files
# 2026-07-28 16:35:22,608 - CRDS - INFO -  Fetching  /home/runner/crds/references/jwst/nircam/jwst_nircam_pars-image2pipeline_0003.asdf    1.7 K bytes  (1 / 1 files) (0 / 1.7 K bytes)
# 2026-07-28 16:35:22,650 - stpipe.pipeline - INFO - PARS-IMAGE2PIPELINE parameters found: /home/runner/crds/references/jwst/nircam/jwst_nircam_pars-image2pipeline_0003.asdf
# 2026-07-28 16:35:22,662 - stpipe.step - INFO - Image2Pipeline instance created.
# 2026-07-28 16:35:22,663 - stpipe.step - INFO - BackgroundStep instance created.
# 2026-07-28 16:35:22,664 - stpipe.step - INFO - AssignWcsStep instance created.
# 2026-07-28 16:35:22,665 - stpipe.step - INFO - FlatFieldStep instance created.
# 2026-07-28 16:35:22,666 - stpipe.step - INFO - PhotomStep instance created.
# 2026-07-28 16:35:22,667 - stpipe.step - INFO - ResampleStep instance created.
# 2026-07-28 16:35:22,863 - stpipe.step - INFO - Step Image2Pipeline running with args ('/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386001001_0310e_00001_nrcalong_rateints.fits',).
# 2026-07-28 16:35:22,871 - stpipe.step - INFO - Step Image2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_bsub: False
#   steps:
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bkg_list: None
#       save_combined_background: False
#       sigma: 3.0
#       maxiters: None
#       soss_source_percentile: 35.0
#       soss_bkg_percentile: None
#       wfss_mmag_extract: None
#       wfss_mask: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#       nrs_ifu_slice_wcs: False
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       apply_time_correction: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
#       propagate_dq: False
#       pixmap_stepsize: 1.0
#       pixmap_order: 1
# 2026-07-28 16:35:22,895 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386001001_0310e_00001_nrcalong_rateints.fits' reftypes = ['area', 'camera', 'chromcorr', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange']
# 2026-07-28 16:35:22,899 - CRDS - INFO -  Syncing 5 files
# 2026-07-28 16:35:22,900 - CRDS - INFO -  Fetching  /home/runner/crds/references/jwst/nircam/jwst_nircam_area_0042.fits   16.8 M bytes  (1 / 5 files) (0 / 67.2 M bytes)
# 2026-07-28 16:35:23,436 - CRDS - INFO -  Fetching  /home/runner/crds/references/jwst/nircam/jwst_nircam_distortion_0325.asdf   16.0 K bytes  (2 / 5 files) (16.8 M / 67.2 M bytes)
# 2026-07-28 16:35:23,488 - CRDS - INFO -  Fetching  /home/runner/crds/references/jwst/nircam/jwst_nircam_filteroffset_0007.asdf   11.4 K bytes  (3 / 5 files) (16.8 M / 67.2 M bytes)
# 2026-07-28 16:35:23,540 - CRDS - INFO -  Fetching  /home/runner/crds/references/jwst/nircam/jwst_nircam_flat_0465.fits   50.4 M bytes  (4 / 5 files) (16.8 M / 67.2 M bytes)
# 2026-07-28 16:35:24,322 - CRDS - INFO -  Fetching  /home/runner/crds/references/jwst/nircam/jwst_nircam_photom_0168.fits   40.3 K bytes  (5 / 5 files) (67.2 M / 67.2 M bytes)
# 2026-07-28 16:35:24,403 - stpipe.pipeline - INFO - Prefetch for AREA reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_area_0042.fits'.
# 2026-07-28 16:35:24,404 - stpipe.pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2026-07-28 16:35:24,405 - stpipe.pipeline - INFO - Prefetch for CHROMCORR reference file is 'N/A'.
# 2026-07-28 16:35:24,405 - stpipe.pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2026-07-28 16:35:24,406 - stpipe.pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2026-07-28 16:35:24,406 - stpipe.pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2026-07-28 16:35:24,406 - stpipe.pipeline - INFO - Prefetch for DISTORTION reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_distortion_0325.asdf'.
# 2026-07-28 16:35:24,407 - stpipe.pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2026-07-28 16:35:24,408 - stpipe.pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_filteroffset_0007.asdf'.
# 2026-07-28 16:35:24,408 - stpipe.pipeline - INFO - Prefetch for FLAT reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_flat_0465.fits'.
# 2026-07-28 16:35:24,409 - stpipe.pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2026-07-28 16:35:24,409 - stpipe.pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2026-07-28 16:35:24,410 - stpipe.pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2026-07-28 16:35:24,410 - stpipe.pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2026-07-28 16:35:24,411 - stpipe.pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2026-07-28 16:35:24,411 - stpipe.pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2026-07-28 16:35:24,412 - stpipe.pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2026-07-28 16:35:24,412 - stpipe.pipeline - INFO - Prefetch for PHOTOM reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_photom_0168.fits'.
# 2026-07-28 16:35:24,413 - stpipe.pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2026-07-28 16:35:24,414 - stpipe.pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2026-07-28 16:35:24,415 - stpipe.pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2026-07-28 16:35:24,415 - stpipe.pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2026-07-28 16:35:24,416 - jwst.pipeline.calwebb_image2 - INFO - Starting calwebb_image2 ...
# 2026-07-28 16:35:24,417 - jwst.pipeline.calwebb_image2 - INFO - Processing product /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386001001_0310e_00001_nrcalong
# 2026-07-28 16:35:24,417 - jwst.pipeline.calwebb_image2 - INFO - Working on input /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386001001_0310e_00001_nrcalong_rateints.fits ...
# 2026-07-28 16:35:24,684 - stpipe.step - INFO - Step assign_wcs running with args (<CubeModel(2, 320, 320) from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386001001_0310e_00001_nrcalong_image2pipeline.fits>,).
# 2026-07-28 16:35:24,834 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  209.562561117 -42.102276941 209.569633886 -42.104183188 209.572145314 -42.099000305 209.565073487 -42.097082446
# 2026-07-28 16:35:24,835 - jwst.assign_wcs.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  209.562561117 -42.102276941 209.569633886 -42.104183188 209.572145314 -42.099000305 209.565073487 -42.097082446
# 2026-07-28 16:35:24,835 - jwst.assign_wcs.assign_wcs - INFO - COMPLETED assign_wcs
# 2026-07-28 16:35:24,869 - stpipe.step - INFO - Step assign_wcs done
# 2026-07-28 16:35:25,062 - stpipe.step - INFO - Step flat_field running with args (<CubeModel(2, 320, 320) from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386001001_0310e_00001_nrcalong_image2pipeline.fits>,).
# 2026-07-28 16:35:25,166 - jwst.flatfield.flat_field_step - INFO - Using FLAT reference file: /home/runner/crds/references/jwst/nircam/jwst_nircam_flat_0465.fits
# 2026-07-28 16:35:25,166 - jwst.flatfield.flat_field_step - INFO - No reference found for type FFLAT
# 2026-07-28 16:35:25,167 - jwst.flatfield.flat_field_step - INFO - No reference found for type SFLAT
# 2026-07-28 16:35:25,167 - jwst.flatfield.flat_field_step - INFO - No reference found for type DFLAT
# 2026-07-28 16:35:25,168 - jwst.flatfield.flat_field - INFO - Extracting matching subarray from flat
# 2026-07-28 16:35:25,224 - stpipe.step - INFO - Step flat_field done
# 2026-07-28 16:35:25,416 - stpipe.step - INFO - Step photom running with args (<CubeModel(2, 320, 320) from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386001001_0310e_00001_nrcalong_image2pipeline.fits>,).
# 2026-07-28 16:35:25,429 - jwst.photom.photom_step - INFO - Using photom reference file: /home/runner/crds/references/jwst/nircam/jwst_nircam_photom_0168.fits
# 2026-07-28 16:35:25,430 - jwst.photom.photom_step - INFO - Using area reference file: /home/runner/crds/references/jwst/nircam/jwst_nircam_area_0042.fits
# 2026-07-28 16:35:25,430 - jwst.photom.photom - INFO - Using instrument: NIRCAM
# 2026-07-28 16:35:25,431 - jwst.photom.photom - INFO -  detector: NRCALONG
# 2026-07-28 16:35:25,431 - jwst.photom.photom - INFO -  exp_type: NRC_CORON
# 2026-07-28 16:35:25,432 - jwst.photom.photom - INFO -  filter: F444W
# 2026-07-28 16:35:25,432 - jwst.photom.photom - INFO -  pupil: MASKRND
# 2026-07-28 16:35:25,480 - jwst.photom.photom - INFO - Pixel area map copied to output.
# 2026-07-28 16:35:25,481 - jwst.photom.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from AREA reference file.
# 2026-07-28 16:35:25,482 - jwst.photom.photom - INFO - Matching to subarray: SUB320A335R
# 2026-07-28 16:35:25,483 - jwst.photom.photom - INFO - PHOTMJSR value: 2.486
# 2026-07-28 16:35:25,512 - stpipe.step - INFO - Step photom done
# 2026-07-28 16:35:25,513 - jwst.pipeline.calwebb_image2 - INFO - Finished processing product /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386001001_0310e_00001_nrcalong
# 2026-07-28 16:35:25,514 - jwst.pipeline.calwebb_image2 - INFO - ... ending calwebb_image2
# 2026-07-28 16:35:25,514 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1584.pmap
# 2026-07-28 16:35:25,621 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386001001_0310e_00001_nrcalong_calints.fits
# 2026-07-28 16:35:25,622 - stpipe.step - INFO - Step Image2Pipeline done
# 2026-07-28 16:35:25,622 - jwst.stpipe.core - INFO - Results used jwst version: 3.0.0
# 2026-07-28 16:35:25,648 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /home/runner/crds/references/jwst/nircam/jwst_nircam_pars-resamplestep_0001.asdf
# 2026-07-28 16:35:25,658 - stpipe.pipeline - INFO - PARS-IMAGE2PIPELINE parameters found: /home/runner/crds/references/jwst/nircam/jwst_nircam_pars-image2pipeline_0003.asdf
# 2026-07-28 16:35:25,669 - stpipe.step - INFO - Image2Pipeline instance created.
# 2026-07-28 16:35:25,670 - stpipe.step - INFO - BackgroundStep instance created.
# 2026-07-28 16:35:25,671 - stpipe.step - INFO - AssignWcsStep instance created.
# 2026-07-28 16:35:25,672 - stpipe.step - INFO - FlatFieldStep instance created.
# 2026-07-28 16:35:25,673 - stpipe.step - INFO - PhotomStep instance created.
# 2026-07-28 16:35:25,674 - stpipe.step - INFO - ResampleStep instance created.
# 2026-07-28 16:35:25,871 - stpipe.step - INFO - Step Image2Pipeline running with args ('/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386001001_0310e_00002_nrcalong_rateints.fits',).
# 2026-07-28 16:35:25,879 - stpipe.step - INFO - Step Image2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_bsub: False
#   steps:
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bkg_list: None
#       save_combined_background: False
#       sigma: 3.0
#       maxiters: None
#       soss_source_percentile: 35.0
#       soss_bkg_percentile: None
#       wfss_mmag_extract: None
#       wfss_mask: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#       nrs_ifu_slice_wcs: False
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       apply_time_correction: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
#       propagate_dq: False
#       pixmap_stepsize: 1.0
#       pixmap_order: 1
# 2026-07-28 16:35:25,901 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386001001_0310e_00002_nrcalong_rateints.fits' reftypes = ['area', 'camera', 'chromcorr', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange']
# 2026-07-28 16:35:25,905 - stpipe.pipeline - INFO - Prefetch for AREA reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_area_0042.fits'.
# 2026-07-28 16:35:25,906 - stpipe.pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2026-07-28 16:35:25,906 - stpipe.pipeline - INFO - Prefetch for CHROMCORR reference file is 'N/A'.
# 2026-07-28 16:35:25,907 - stpipe.pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2026-07-28 16:35:25,907 - stpipe.pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2026-07-28 16:35:25,908 - stpipe.pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2026-07-28 16:35:25,908 - stpipe.pipeline - INFO - Prefetch for DISTORTION reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_distortion_0325.asdf'.
# 2026-07-28 16:35:25,909 - stpipe.pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2026-07-28 16:35:25,910 - stpipe.pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_filteroffset_0007.asdf'.
# 2026-07-28 16:35:25,911 - stpipe.pipeline - INFO - Prefetch for FLAT reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_flat_0465.fits'.
# 2026-07-28 16:35:25,911 - stpipe.pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2026-07-28 16:35:25,912 - stpipe.pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2026-07-28 16:35:25,912 - stpipe.pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2026-07-28 16:35:25,913 - stpipe.pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2026-07-28 16:35:25,913 - stpipe.pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2026-07-28 16:35:25,913 - stpipe.pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2026-07-28 16:35:25,914 - stpipe.pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2026-07-28 16:35:25,915 - stpipe.pipeline - INFO - Prefetch for PHOTOM reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_photom_0168.fits'.
# 2026-07-28 16:35:25,915 - stpipe.pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2026-07-28 16:35:25,916 - stpipe.pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2026-07-28 16:35:25,916 - stpipe.pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2026-07-28 16:35:25,917 - stpipe.pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2026-07-28 16:35:25,917 - jwst.pipeline.calwebb_image2 - INFO - Starting calwebb_image2 ...
# 2026-07-28 16:35:25,918 - jwst.pipeline.calwebb_image2 - INFO - Processing product /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386001001_0310e_00002_nrcalong
# 2026-07-28 16:35:25,918 - jwst.pipeline.calwebb_image2 - INFO - Working on input /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386001001_0310e_00002_nrcalong_rateints.fits ...
# 2026-07-28 16:35:26,185 - stpipe.step - INFO - Step assign_wcs running with args (<CubeModel(2, 320, 320) from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386001001_0310e_00002_nrcalong_image2pipeline.fits>,).
# 2026-07-28 16:35:26,304 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  209.562554217 -42.102275101 209.569626986 -42.104181351 209.572138417 -42.098998468 209.565066592 -42.097080608
# 2026-07-28 16:35:26,305 - jwst.assign_wcs.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  209.562554217 -42.102275101 209.569626986 -42.104181351 209.572138417 -42.098998468 209.565066592 -42.097080608
# 2026-07-28 16:35:26,305 - jwst.assign_wcs.assign_wcs - INFO - COMPLETED assign_wcs
# 2026-07-28 16:35:26,336 - stpipe.step - INFO - Step assign_wcs done
# 2026-07-28 16:35:26,536 - stpipe.step - INFO - Step flat_field running with args (<CubeModel(2, 320, 320) from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386001001_0310e_00002_nrcalong_image2pipeline.fits>,).
# 2026-07-28 16:35:26,614 - jwst.flatfield.flat_field_step - INFO - Using FLAT reference file: /home/runner/crds/references/jwst/nircam/jwst_nircam_flat_0465.fits
# 2026-07-28 16:35:26,614 - jwst.flatfield.flat_field_step - INFO - No reference found for type FFLAT
# 2026-07-28 16:35:26,615 - jwst.flatfield.flat_field_step - INFO - No reference found for type SFLAT
# 2026-07-28 16:35:26,615 - jwst.flatfield.flat_field_step - INFO - No reference found for type DFLAT
# 2026-07-28 16:35:26,616 - jwst.flatfield.flat_field - INFO - Extracting matching subarray from flat
# 2026-07-28 16:35:26,673 - stpipe.step - INFO - Step flat_field done
# 2026-07-28 16:35:26,878 - stpipe.step - INFO - Step photom running with args (<CubeModel(2, 320, 320) from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386001001_0310e_00002_nrcalong_image2pipeline.fits>,).
# 2026-07-28 16:35:26,885 - jwst.photom.photom_step - INFO - Using photom reference file: /home/runner/crds/references/jwst/nircam/jwst_nircam_photom_0168.fits
# 2026-07-28 16:35:26,885 - jwst.photom.photom_step - INFO - Using area reference file: /home/runner/crds/references/jwst/nircam/jwst_nircam_area_0042.fits
# 2026-07-28 16:35:26,886 - jwst.photom.photom - INFO - Using instrument: NIRCAM
# 2026-07-28 16:35:26,887 - jwst.photom.photom - INFO -  detector: NRCALONG
# 2026-07-28 16:35:26,887 - jwst.photom.photom - INFO -  exp_type: NRC_CORON
# 2026-07-28 16:35:26,887 - jwst.photom.photom - INFO -  filter: F444W
# 2026-07-28 16:35:26,888 - jwst.photom.photom - INFO -  pupil: MASKRND
# 2026-07-28 16:35:26,933 - jwst.photom.photom - INFO - Pixel area map copied to output.
# 2026-07-28 16:35:26,934 - jwst.photom.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from AREA reference file.
# 2026-07-28 16:35:26,934 - jwst.photom.photom - INFO - Matching to subarray: SUB320A335R
# 2026-07-28 16:35:26,936 - jwst.photom.photom - INFO - PHOTMJSR value: 2.486
# 2026-07-28 16:35:26,965 - stpipe.step - INFO - Step photom done
# 2026-07-28 16:35:26,965 - jwst.pipeline.calwebb_image2 - INFO - Finished processing product /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386001001_0310e_00002_nrcalong
# 2026-07-28 16:35:26,966 - jwst.pipeline.calwebb_image2 - INFO - ... ending calwebb_image2
# 2026-07-28 16:35:26,967 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1584.pmap
# 2026-07-28 16:35:27,064 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386001001_0310e_00002_nrcalong_calints.fits
# 2026-07-28 16:35:27,065 - stpipe.step - INFO - Step Image2Pipeline done
# 2026-07-28 16:35:27,065 - jwst.stpipe.core - INFO - Results used jwst version: 3.0.0
# 2026-07-28 16:35:27,092 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /home/runner/crds/references/jwst/nircam/jwst_nircam_pars-resamplestep_0001.asdf
# 2026-07-28 16:35:27,102 - stpipe.pipeline - INFO - PARS-IMAGE2PIPELINE parameters found: /home/runner/crds/references/jwst/nircam/jwst_nircam_pars-image2pipeline_0003.asdf
# 2026-07-28 16:35:27,113 - stpipe.step - INFO - Image2Pipeline instance created.
# 2026-07-28 16:35:27,114 - stpipe.step - INFO - BackgroundStep instance created.
# 2026-07-28 16:35:27,115 - stpipe.step - INFO - AssignWcsStep instance created.
# 2026-07-28 16:35:27,116 - stpipe.step - INFO - FlatFieldStep instance created.
# 2026-07-28 16:35:27,117 - stpipe.step - INFO - PhotomStep instance created.
# 2026-07-28 16:35:27,118 - stpipe.step - INFO - ResampleStep instance created.
# 2026-07-28 16:35:27,315 - stpipe.step - INFO - Step Image2Pipeline running with args ('/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386001001_0310e_00003_nrcalong_rateints.fits',).
# 2026-07-28 16:35:27,322 - stpipe.step - INFO - Step Image2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_bsub: False
#   steps:
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bkg_list: None
#       save_combined_background: False
#       sigma: 3.0
#       maxiters: None
#       soss_source_percentile: 35.0
#       soss_bkg_percentile: None
#       wfss_mmag_extract: None
#       wfss_mask: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#       nrs_ifu_slice_wcs: False
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       apply_time_correction: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
#       propagate_dq: False
#       pixmap_stepsize: 1.0
#       pixmap_order: 1
# 2026-07-28 16:35:27,345 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386001001_0310e_00003_nrcalong_rateints.fits' reftypes = ['area', 'camera', 'chromcorr', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange']
# 2026-07-28 16:35:27,349 - stpipe.pipeline - INFO - Prefetch for AREA reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_area_0042.fits'.
# 2026-07-28 16:35:27,349 - stpipe.pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2026-07-28 16:35:27,350 - stpipe.pipeline - INFO - Prefetch for CHROMCORR reference file is 'N/A'.
# 2026-07-28 16:35:27,350 - stpipe.pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2026-07-28 16:35:27,351 - stpipe.pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2026-07-28 16:35:27,351 - stpipe.pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2026-07-28 16:35:27,352 - stpipe.pipeline - INFO - Prefetch for DISTORTION reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_distortion_0325.asdf'.
# 2026-07-28 16:35:27,352 - stpipe.pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2026-07-28 16:35:27,353 - stpipe.pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_filteroffset_0007.asdf'.
# 2026-07-28 16:35:27,354 - stpipe.pipeline - INFO - Prefetch for FLAT reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_flat_0465.fits'.
# 2026-07-28 16:35:27,354 - stpipe.pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2026-07-28 16:35:27,355 - stpipe.pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2026-07-28 16:35:27,355 - stpipe.pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2026-07-28 16:35:27,356 - stpipe.pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2026-07-28 16:35:27,357 - stpipe.pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2026-07-28 16:35:27,357 - stpipe.pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2026-07-28 16:35:27,357 - stpipe.pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2026-07-28 16:35:27,358 - stpipe.pipeline - INFO - Prefetch for PHOTOM reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_photom_0168.fits'.
# 2026-07-28 16:35:27,358 - stpipe.pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2026-07-28 16:35:27,359 - stpipe.pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2026-07-28 16:35:27,359 - stpipe.pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2026-07-28 16:35:27,360 - stpipe.pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2026-07-28 16:35:27,360 - jwst.pipeline.calwebb_image2 - INFO - Starting calwebb_image2 ...
# 2026-07-28 16:35:27,361 - jwst.pipeline.calwebb_image2 - INFO - Processing product /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386001001_0310e_00003_nrcalong
# 2026-07-28 16:35:27,361 - jwst.pipeline.calwebb_image2 - INFO - Working on input /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386001001_0310e_00003_nrcalong_rateints.fits ...
# 2026-07-28 16:35:27,630 - stpipe.step - INFO - Step assign_wcs running with args (<CubeModel(2, 320, 320) from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386001001_0310e_00003_nrcalong_image2pipeline.fits>,).
# 2026-07-28 16:35:27,748 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  209.562557777 -42.102271682 209.569630544 -42.104177934 209.572141977 -42.098995052 209.565070154 -42.097077189
# 2026-07-28 16:35:27,749 - jwst.assign_wcs.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  209.562557777 -42.102271682 209.569630544 -42.104177934 209.572141977 -42.098995052 209.565070154 -42.097077189
# 2026-07-28 16:35:27,750 - jwst.assign_wcs.assign_wcs - INFO - COMPLETED assign_wcs
# 2026-07-28 16:35:27,781 - stpipe.step - INFO - Step assign_wcs done
# 2026-07-28 16:35:27,980 - stpipe.step - INFO - Step flat_field running with args (<CubeModel(2, 320, 320) from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386001001_0310e_00003_nrcalong_image2pipeline.fits>,).
# 2026-07-28 16:35:28,053 - jwst.flatfield.flat_field_step - INFO - Using FLAT reference file: /home/runner/crds/references/jwst/nircam/jwst_nircam_flat_0465.fits
# 2026-07-28 16:35:28,054 - jwst.flatfield.flat_field_step - INFO - No reference found for type FFLAT
# 2026-07-28 16:35:28,055 - jwst.flatfield.flat_field_step - INFO - No reference found for type SFLAT
# 2026-07-28 16:35:28,055 - jwst.flatfield.flat_field_step - INFO - No reference found for type DFLAT
# 2026-07-28 16:35:28,056 - jwst.flatfield.flat_field - INFO - Extracting matching subarray from flat
# 2026-07-28 16:35:28,112 - stpipe.step - INFO - Step flat_field done
# 2026-07-28 16:35:28,324 - stpipe.step - INFO - Step photom running with args (<CubeModel(2, 320, 320) from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386001001_0310e_00003_nrcalong_image2pipeline.fits>,).
# 2026-07-28 16:35:28,331 - jwst.photom.photom_step - INFO - Using photom reference file: /home/runner/crds/references/jwst/nircam/jwst_nircam_photom_0168.fits
# 2026-07-28 16:35:28,332 - jwst.photom.photom_step - INFO - Using area reference file: /home/runner/crds/references/jwst/nircam/jwst_nircam_area_0042.fits
# 2026-07-28 16:35:28,332 - jwst.photom.photom - INFO - Using instrument: NIRCAM
# 2026-07-28 16:35:28,333 - jwst.photom.photom - INFO -  detector: NRCALONG
# 2026-07-28 16:35:28,333 - jwst.photom.photom - INFO -  exp_type: NRC_CORON
# 2026-07-28 16:35:28,334 - jwst.photom.photom - INFO -  filter: F444W
# 2026-07-28 16:35:28,334 - jwst.photom.photom - INFO -  pupil: MASKRND
# 2026-07-28 16:35:28,378 - jwst.photom.photom - INFO - Pixel area map copied to output.
# 2026-07-28 16:35:28,378 - jwst.photom.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from AREA reference file.
# 2026-07-28 16:35:28,379 - jwst.photom.photom - INFO - Matching to subarray: SUB320A335R
# 2026-07-28 16:35:28,381 - jwst.photom.photom - INFO - PHOTMJSR value: 2.486
# 2026-07-28 16:35:28,410 - stpipe.step - INFO - Step photom done
# 2026-07-28 16:35:28,411 - jwst.pipeline.calwebb_image2 - INFO - Finished processing product /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386001001_0310e_00003_nrcalong
# 2026-07-28 16:35:28,411 - jwst.pipeline.calwebb_image2 - INFO - ... ending calwebb_image2
# 2026-07-28 16:35:28,412 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1584.pmap
# 2026-07-28 16:35:28,509 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386001001_0310e_00003_nrcalong_calints.fits
# 2026-07-28 16:35:28,510 - stpipe.step - INFO - Step Image2Pipeline done
# 2026-07-28 16:35:28,510 - jwst.stpipe.core - INFO - Results used jwst version: 3.0.0
# 2026-07-28 16:35:28,537 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /home/runner/crds/references/jwst/nircam/jwst_nircam_pars-resamplestep_0001.asdf
# 2026-07-28 16:35:28,547 - stpipe.pipeline - INFO - PARS-IMAGE2PIPELINE parameters found: /home/runner/crds/references/jwst/nircam/jwst_nircam_pars-image2pipeline_0003.asdf
# 2026-07-28 16:35:28,558 - stpipe.step - INFO - Image2Pipeline instance created.
# 2026-07-28 16:35:28,559 - stpipe.step - INFO - BackgroundStep instance created.
# 2026-07-28 16:35:28,561 - stpipe.step - INFO - AssignWcsStep instance created.
# 2026-07-28 16:35:28,562 - stpipe.step - INFO - FlatFieldStep instance created.
# 2026-07-28 16:35:28,563 - stpipe.step - INFO - PhotomStep instance created.
# 2026-07-28 16:35:28,564 - stpipe.step - INFO - ResampleStep instance created.
# 2026-07-28 16:35:28,771 - stpipe.step - INFO - Step Image2Pipeline running with args ('/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386001001_0310e_00004_nrcalong_rateints.fits',).
# 2026-07-28 16:35:28,778 - stpipe.step - INFO - Step Image2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_bsub: False
#   steps:
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bkg_list: None
#       save_combined_background: False
#       sigma: 3.0
#       maxiters: None
#       soss_source_percentile: 35.0
#       soss_bkg_percentile: None
#       wfss_mmag_extract: None
#       wfss_mask: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#       nrs_ifu_slice_wcs: False
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       apply_time_correction: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
#       propagate_dq: False
#       pixmap_stepsize: 1.0
#       pixmap_order: 1
# 2026-07-28 16:35:28,801 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386001001_0310e_00004_nrcalong_rateints.fits' reftypes = ['area', 'camera', 'chromcorr', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange']
# 2026-07-28 16:35:28,805 - stpipe.pipeline - INFO - Prefetch for AREA reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_area_0042.fits'.
# 2026-07-28 16:35:28,805 - stpipe.pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2026-07-28 16:35:28,806 - stpipe.pipeline - INFO - Prefetch for CHROMCORR reference file is 'N/A'.
# 2026-07-28 16:35:28,806 - stpipe.pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2026-07-28 16:35:28,807 - stpipe.pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2026-07-28 16:35:28,807 - stpipe.pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2026-07-28 16:35:28,808 - stpipe.pipeline - INFO - Prefetch for DISTORTION reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_distortion_0325.asdf'.
# 2026-07-28 16:35:28,809 - stpipe.pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2026-07-28 16:35:28,809 - stpipe.pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_filteroffset_0007.asdf'.
# 2026-07-28 16:35:28,810 - stpipe.pipeline - INFO - Prefetch for FLAT reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_flat_0465.fits'.
# 2026-07-28 16:35:28,810 - stpipe.pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2026-07-28 16:35:28,811 - stpipe.pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2026-07-28 16:35:28,811 - stpipe.pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2026-07-28 16:35:28,812 - stpipe.pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2026-07-28 16:35:28,812 - stpipe.pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2026-07-28 16:35:28,813 - stpipe.pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2026-07-28 16:35:28,813 - stpipe.pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2026-07-28 16:35:28,813 - stpipe.pipeline - INFO - Prefetch for PHOTOM reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_photom_0168.fits'.
# 2026-07-28 16:35:28,814 - stpipe.pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2026-07-28 16:35:28,814 - stpipe.pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2026-07-28 16:35:28,815 - stpipe.pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2026-07-28 16:35:28,815 - stpipe.pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2026-07-28 16:35:28,816 - jwst.pipeline.calwebb_image2 - INFO - Starting calwebb_image2 ...
# 2026-07-28 16:35:28,817 - jwst.pipeline.calwebb_image2 - INFO - Processing product /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386001001_0310e_00004_nrcalong
# 2026-07-28 16:35:28,817 - jwst.pipeline.calwebb_image2 - INFO - Working on input /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386001001_0310e_00004_nrcalong_rateints.fits ...
# 2026-07-28 16:35:29,084 - stpipe.step - INFO - Step assign_wcs running with args (<CubeModel(2, 320, 320) from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386001001_0310e_00004_nrcalong_image2pipeline.fits>,).
# 2026-07-28 16:35:29,201 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  209.562563720 -42.102271829 209.569636488 -42.104178080 209.572147920 -42.098995198 209.565076096 -42.097077336
# 2026-07-28 16:35:29,202 - jwst.assign_wcs.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  209.562563720 -42.102271829 209.569636488 -42.104178080 209.572147920 -42.098995198 209.565076096 -42.097077336
# 2026-07-28 16:35:29,203 - jwst.assign_wcs.assign_wcs - INFO - COMPLETED assign_wcs
# 2026-07-28 16:35:29,234 - stpipe.step - INFO - Step assign_wcs done
# 2026-07-28 16:35:29,432 - stpipe.step - INFO - Step flat_field running with args (<CubeModel(2, 320, 320) from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386001001_0310e_00004_nrcalong_image2pipeline.fits>,).
# 2026-07-28 16:35:29,507 - jwst.flatfield.flat_field_step - INFO - Using FLAT reference file: /home/runner/crds/references/jwst/nircam/jwst_nircam_flat_0465.fits
# 2026-07-28 16:35:29,508 - jwst.flatfield.flat_field_step - INFO - No reference found for type FFLAT
# 2026-07-28 16:35:29,508 - jwst.flatfield.flat_field_step - INFO - No reference found for type SFLAT
# 2026-07-28 16:35:29,509 - jwst.flatfield.flat_field_step - INFO - No reference found for type DFLAT
# 2026-07-28 16:35:29,509 - jwst.flatfield.flat_field - INFO - Extracting matching subarray from flat
# 2026-07-28 16:35:29,566 - stpipe.step - INFO - Step flat_field done
# 2026-07-28 16:35:29,766 - stpipe.step - INFO - Step photom running with args (<CubeModel(2, 320, 320) from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386001001_0310e_00004_nrcalong_image2pipeline.fits>,).
# 2026-07-28 16:35:29,773 - jwst.photom.photom_step - INFO - Using photom reference file: /home/runner/crds/references/jwst/nircam/jwst_nircam_photom_0168.fits
# 2026-07-28 16:35:29,774 - jwst.photom.photom_step - INFO - Using area reference file: /home/runner/crds/references/jwst/nircam/jwst_nircam_area_0042.fits
# 2026-07-28 16:35:29,774 - jwst.photom.photom - INFO - Using instrument: NIRCAM
# 2026-07-28 16:35:29,775 - jwst.photom.photom - INFO -  detector: NRCALONG
# 2026-07-28 16:35:29,775 - jwst.photom.photom - INFO -  exp_type: NRC_CORON
# 2026-07-28 16:35:29,775 - jwst.photom.photom - INFO -  filter: F444W
# 2026-07-28 16:35:29,776 - jwst.photom.photom - INFO -  pupil: MASKRND
# 2026-07-28 16:35:29,821 - jwst.photom.photom - INFO - Pixel area map copied to output.
# 2026-07-28 16:35:29,822 - jwst.photom.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from AREA reference file.
# 2026-07-28 16:35:29,823 - jwst.photom.photom - INFO - Matching to subarray: SUB320A335R
# 2026-07-28 16:35:29,824 - jwst.photom.photom - INFO - PHOTMJSR value: 2.486
# 2026-07-28 16:35:29,853 - stpipe.step - INFO - Step photom done
# 2026-07-28 16:35:29,854 - jwst.pipeline.calwebb_image2 - INFO - Finished processing product /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386001001_0310e_00004_nrcalong
# 2026-07-28 16:35:29,854 - jwst.pipeline.calwebb_image2 - INFO - ... ending calwebb_image2
# 2026-07-28 16:35:29,855 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1584.pmap
# 2026-07-28 16:35:29,952 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386001001_0310e_00004_nrcalong_calints.fits
# 2026-07-28 16:35:29,953 - stpipe.step - INFO - Step Image2Pipeline done
# ...
# 2026-07-28 16:35:37,497 - jwst.pipeline.calwebb_image2 - INFO - Working on input /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386002001_0310a_00001_nrcalong_rateints.fits ...
# 2026-07-28 16:35:37,765 - stpipe.step - INFO - Step assign_wcs running with args (<CubeModel(2, 320, 320) from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386002001_0310a_00001_nrcalong_image2pipeline.fits>,).
# 2026-07-28 16:35:37,883 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  201.144088025 -51.505952662 201.152504439 -51.507883699 201.155537236 -51.502709582 201.147122265 -51.500766999
# 2026-07-28 16:35:37,884 - jwst.assign_wcs.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  201.144088025 -51.505952662 201.152504439 -51.507883699 201.155537236 -51.502709582 201.147122265 -51.500766999
# 2026-07-28 16:35:37,885 - jwst.assign_wcs.assign_wcs - INFO - COMPLETED assign_wcs
# 2026-07-28 16:35:37,915 - stpipe.step - INFO - Step assign_wcs done
# 2026-07-28 16:35:38,114 - stpipe.step - INFO - Step flat_field running with args (<CubeModel(2, 320, 320) from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386002001_0310a_00001_nrcalong_image2pipeline.fits>,).
# 2026-07-28 16:35:38,187 - jwst.flatfield.flat_field_step - INFO - Using FLAT reference file: /home/runner/crds/references/jwst/nircam/jwst_nircam_flat_0465.fits
# 2026-07-28 16:35:38,188 - jwst.flatfield.flat_field_step - INFO - No reference found for type FFLAT
# 2026-07-28 16:35:38,188 - jwst.flatfield.flat_field_step - INFO - No reference found for type SFLAT
# 2026-07-28 16:35:38,189 - jwst.flatfield.flat_field_step - INFO - No reference found for type DFLAT
# 2026-07-28 16:35:38,189 - jwst.flatfield.flat_field - INFO - Extracting matching subarray from flat
# 2026-07-28 16:35:38,246 - stpipe.step - INFO - Step flat_field done
# 2026-07-28 16:35:38,447 - stpipe.step - INFO - Step photom running with args (<CubeModel(2, 320, 320) from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386002001_0310a_00001_nrcalong_image2pipeline.fits>,).
# 2026-07-28 16:35:38,454 - jwst.photom.photom_step - INFO - Using photom reference file: /home/runner/crds/references/jwst/nircam/jwst_nircam_photom_0168.fits
# 2026-07-28 16:35:38,454 - jwst.photom.photom_step - INFO - Using area reference file: /home/runner/crds/references/jwst/nircam/jwst_nircam_area_0042.fits
# 2026-07-28 16:35:38,455 - jwst.photom.photom - INFO - Using instrument: NIRCAM
# 2026-07-28 16:35:38,455 - jwst.photom.photom - INFO -  detector: NRCALONG
# 2026-07-28 16:35:38,456 - jwst.photom.photom - INFO -  exp_type: NRC_CORON
# 2026-07-28 16:35:38,456 - jwst.photom.photom - INFO -  filter: F444W
# 2026-07-28 16:35:38,456 - jwst.photom.photom - INFO -  pupil: MASKRND
# 2026-07-28 16:35:38,501 - jwst.photom.photom - INFO - Pixel area map copied to output.
# 2026-07-28 16:35:38,502 - jwst.photom.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from AREA reference file.
# 2026-07-28 16:35:38,502 - jwst.photom.photom - INFO - Matching to subarray: SUB320A335R
# 2026-07-28 16:35:38,504 - jwst.photom.photom - INFO - PHOTMJSR value: 2.486
# 2026-07-28 16:35:38,533 - stpipe.step - INFO - Step photom done
# 2026-07-28 16:35:38,534 - jwst.pipeline.calwebb_image2 - INFO - Finished processing product /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386002001_0310a_00001_nrcalong
# 2026-07-28 16:35:38,535 - jwst.pipeline.calwebb_image2 - INFO - ... ending calwebb_image2
# 2026-07-28 16:35:38,535 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1584.pmap
# 2026-07-28 16:35:38,632 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386002001_0310a_00001_nrcalong_calints.fits
# 2026-07-28 16:35:38,633 - stpipe.step - INFO - Step Image2Pipeline done
# 2026-07-28 16:35:38,633 - jwst.stpipe.core - INFO - Results used jwst version: 3.0.0
# 2026-07-28 16:35:38,659 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /home/runner/crds/references/jwst/nircam/jwst_nircam_pars-resamplestep_0001.asdf
# 2026-07-28 16:35:38,670 - stpipe.pipeline - INFO - PARS-IMAGE2PIPELINE parameters found: /home/runner/crds/references/jwst/nircam/jwst_nircam_pars-image2pipeline_0003.asdf
# 2026-07-28 16:35:38,681 - stpipe.step - INFO - Image2Pipeline instance created.
# 2026-07-28 16:35:38,682 - stpipe.step - INFO - BackgroundStep instance created.
# 2026-07-28 16:35:38,683 - stpipe.step - INFO - AssignWcsStep instance created.
# 2026-07-28 16:35:38,684 - stpipe.step - INFO - FlatFieldStep instance created.
# 2026-07-28 16:35:38,685 - stpipe.step - INFO - PhotomStep instance created.
# 2026-07-28 16:35:38,687 - stpipe.step - INFO - ResampleStep instance created.
# 2026-07-28 16:35:38,884 - stpipe.step - INFO - Step Image2Pipeline running with args ('/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386003001_0310a_00001_nrcalong_rateints.fits',).
# 2026-07-28 16:35:38,891 - stpipe.step - INFO - Step Image2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_bsub: False
#   steps:
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bkg_list: None
#       save_combined_background: False
#       sigma: 3.0
#       maxiters: None
#       soss_source_percentile: 35.0
#       soss_bkg_percentile: None
#       wfss_mmag_extract: None
#       wfss_mask: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#       nrs_ifu_slice_wcs: False
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       apply_time_correction: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
#       propagate_dq: False
#       pixmap_stepsize: 1.0
#       pixmap_order: 1
# 2026-07-28 16:35:38,913 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386003001_0310a_00001_nrcalong_rateints.fits' reftypes = ['area', 'camera', 'chromcorr', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange']
# 2026-07-28 16:35:38,917 - stpipe.pipeline - INFO - Prefetch for AREA reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_area_0042.fits'.
# 2026-07-28 16:35:38,918 - stpipe.pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2026-07-28 16:35:38,918 - stpipe.pipeline - INFO - Prefetch for CHROMCORR reference file is 'N/A'.
# 2026-07-28 16:35:38,919 - stpipe.pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2026-07-28 16:35:38,920 - stpipe.pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2026-07-28 16:35:38,920 - stpipe.pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2026-07-28 16:35:38,921 - stpipe.pipeline - INFO - Prefetch for DISTORTION reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_distortion_0325.asdf'.
# 2026-07-28 16:35:38,921 - stpipe.pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2026-07-28 16:35:38,922 - stpipe.pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_filteroffset_0007.asdf'.
# 2026-07-28 16:35:38,922 - stpipe.pipeline - INFO - Prefetch for FLAT reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_flat_0465.fits'.
# 2026-07-28 16:35:38,923 - stpipe.pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2026-07-28 16:35:38,924 - stpipe.pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2026-07-28 16:35:38,924 - stpipe.pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2026-07-28 16:35:38,925 - stpipe.pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2026-07-28 16:35:38,925 - stpipe.pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2026-07-28 16:35:38,926 - stpipe.pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2026-07-28 16:35:38,927 - stpipe.pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2026-07-28 16:35:38,927 - stpipe.pipeline - INFO - Prefetch for PHOTOM reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_photom_0168.fits'.
# 2026-07-28 16:35:38,927 - stpipe.pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2026-07-28 16:35:38,928 - stpipe.pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2026-07-28 16:35:38,929 - stpipe.pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2026-07-28 16:35:38,929 - stpipe.pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2026-07-28 16:35:38,930 - jwst.pipeline.calwebb_image2 - INFO - Starting calwebb_image2 ...
# 2026-07-28 16:35:38,930 - jwst.pipeline.calwebb_image2 - INFO - Processing product /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386003001_0310a_00001_nrcalong
# 2026-07-28 16:35:38,931 - jwst.pipeline.calwebb_image2 - INFO - Working on input /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386003001_0310a_00001_nrcalong_rateints.fits ...
# 2026-07-28 16:35:39,198 - stpipe.step - INFO - Step assign_wcs running with args (<CubeModel(2, 320, 320) from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386003001_0310a_00001_nrcalong_image2pipeline.fits>,).
# 2026-07-28 16:35:39,316 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  201.143789784 -51.505284453 201.151533175 -51.508102622 201.155974175 -51.503338798 201.148235232 -51.500509406
# 2026-07-28 16:35:39,317 - jwst.assign_wcs.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  201.143789784 -51.505284453 201.151533175 -51.508102622 201.155974175 -51.503338798 201.148235232 -51.500509406
# 2026-07-28 16:35:39,317 - jwst.assign_wcs.assign_wcs - INFO - COMPLETED assign_wcs
# 2026-07-28 16:35:39,349 - stpipe.step - INFO - Step assign_wcs done
# 2026-07-28 16:35:39,548 - stpipe.step - INFO - Step flat_field running with args (<CubeModel(2, 320, 320) from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386003001_0310a_00001_nrcalong_image2pipeline.fits>,).
# 2026-07-28 16:35:39,619 - jwst.flatfield.flat_field_step - INFO - Using FLAT reference file: /home/runner/crds/references/jwst/nircam/jwst_nircam_flat_0465.fits
# 2026-07-28 16:35:39,620 - jwst.flatfield.flat_field_step - INFO - No reference found for type FFLAT
# 2026-07-28 16:35:39,621 - jwst.flatfield.flat_field_step - INFO - No reference found for type SFLAT
# 2026-07-28 16:35:39,622 - jwst.flatfield.flat_field_step - INFO - No reference found for type DFLAT
# 2026-07-28 16:35:39,622 - jwst.flatfield.flat_field - INFO - Extracting matching subarray from flat
# 2026-07-28 16:35:39,679 - stpipe.step - INFO - Step flat_field done
# 2026-07-28 16:35:39,876 - stpipe.step - INFO - Step photom running with args (<CubeModel(2, 320, 320) from /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386003001_0310a_00001_nrcalong_image2pipeline.fits>,).
# 2026-07-28 16:35:39,883 - jwst.photom.photom_step - INFO - Using photom reference file: /home/runner/crds/references/jwst/nircam/jwst_nircam_photom_0168.fits
# 2026-07-28 16:35:39,883 - jwst.photom.photom_step - INFO - Using area reference file: /home/runner/crds/references/jwst/nircam/jwst_nircam_area_0042.fits
# 2026-07-28 16:35:39,884 - jwst.photom.photom - INFO - Using instrument: NIRCAM
# 2026-07-28 16:35:39,884 - jwst.photom.photom - INFO -  detector: NRCALONG
# 2026-07-28 16:35:39,885 - jwst.photom.photom - INFO -  exp_type: NRC_CORON
# 2026-07-28 16:35:39,885 - jwst.photom.photom - INFO -  filter: F444W
# 2026-07-28 16:35:39,886 - jwst.photom.photom - INFO -  pupil: MASKRND
# 2026-07-28 16:35:39,930 - jwst.photom.photom - INFO - Pixel area map copied to output.
# 2026-07-28 16:35:39,930 - jwst.photom.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from AREA reference file.
# 2026-07-28 16:35:39,931 - jwst.photom.photom - INFO - Matching to subarray: SUB320A335R
# 2026-07-28 16:35:39,933 - jwst.photom.photom - INFO - PHOTMJSR value: 2.486
# 2026-07-28 16:35:39,962 - stpipe.step - INFO - Step photom done
# 2026-07-28 16:35:39,962 - jwst.pipeline.calwebb_image2 - INFO - Finished processing product /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage1/jw01386003001_0310a_00001_nrcalong
# 2026-07-28 16:35:39,963 - jwst.pipeline.calwebb_image2 - INFO - ... ending calwebb_image2
# 2026-07-28 16:35:39,963 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1584.pmap
# 2026-07-28 16:35:40,061 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386003001_0310a_00001_nrcalong_calints.fits
# 2026-07-28 16:35:40,062 - stpipe.step - INFO - Step Image2Pipeline done
# 2026-07-28 16:35:40,062 - jwst.stpipe.core - INFO - Results used jwst version: 3.0.0

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.0f} seconds")
print(f"Runtime for Image2: {time1 - time_image2:0.0f} seconds")
# Out:
# Runtime so far: 97 seconds
# Runtime for Image2: 18 seconds

# %% [markdown]
# ### Verify which pipeline steps were run

# %%
if doimage2:
    # Identify *_cal.fits file products
    cal_files = sorted(glob.glob(os.path.join(image2_dir, '*_calints.fits')))

    # Select first file to gather information
    cal_f = datamodels.open(cal_files[0])

    # Check which steps were run:
    cal_f.meta.cal_step.instance
# Out:
# {'assign_wcs': 'COMPLETE',
#  'charge_migration': 'SKIPPED',
#  'clean_flicker_noise': 'SKIPPED',
#  'dq_init': 'COMPLETE',
#  'flat_field': 'COMPLETE',
#  'gain_scale': 'SKIPPED',
#  'group_scale': 'SKIPPED',
#  'ipc': 'SKIPPED',
#  'jump': 'COMPLETE',
#  'linearity': 'COMPLETE',
#  'persistence': 'SKIPPED',
#  'photom': 'COMPLETE',
#  'picture_frame': 'SKIPPED',
#  'ramp_fit': 'COMPLETE',
#  'refpix': 'COMPLETE',
#  'saturation': 'COMPLETE',
#  'superbias': 'COMPLETE'}

# %% [markdown]
# Check which reference files were used to calibrate the first file. Some of these will be detector-dependent.

# %%
if doimage2:
    cal_f.meta.ref_file.instance
# Out:
# {'area': {'name': 'crds://jwst_nircam_area_0042.fits'},
#  'camera': {'name': 'N/A'},
#  'chromcorr': {'name': 'N/A'},
#  'collimator': {'name': 'N/A'},
#  'crds': {'context_used': 'jwst_1584.pmap', 'sw_version': '13.2.7'},
#  'dflat': {'name': 'N/A'},
#  'disperser': {'name': 'N/A'},
#  'distortion': {'name': 'crds://jwst_nircam_distortion_0325.asdf'},
#  'fflat': {'name': 'N/A'},
#  'filteroffset': {'name': 'crds://jwst_nircam_filteroffset_0007.asdf'},
#  'flat': {'name': 'crds://jwst_nircam_flat_0465.fits'},
#  'fore': {'name': 'N/A'},
#  'fpa': {'name': 'N/A'},
#  'gain': {'name': 'crds://jwst_nircam_gain_0097.fits'},
#  'ifufore': {'name': 'N/A'},
#  'ifupost': {'name': 'N/A'},
#  'ifuslicer': {'name': 'N/A'},
#  'linearity': {'name': 'crds://jwst_nircam_linearity_0052.fits'},
#  'mask': {'name': 'crds://jwst_nircam_mask_0076.fits'},
#  'msa': {'name': 'N/A'},
#  'ote': {'name': 'N/A'},
#  'photom': {'name': 'crds://jwst_nircam_photom_0168.fits'},
#  'readnoise': {'name': 'crds://jwst_nircam_readnoise_0284.fits'},
#  'regions': {'name': 'N/A'},
#  'saturation': {'name': 'crds://jwst_nircam_saturation_0097.fits'},
#  'sflat': {'name': 'N/A'},
#  'specwcs': {'name': 'N/A'},
#  'superbias': {'name': 'crds://jwst_nircam_superbias_0229.fits'},
#  'wavelengthrange': {'name': 'N/A'}}

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ## 7. Coron3 Pipeline
#
# In the [Coron3 stage](https://jwst-pipeline.readthedocs.io/en/latest/jwst/pipeline/calwebb_coron3.html) of the calibration pipeline, the `*_calints.fits` files from the reference PSF images are aligned and subtracted from the science PSF images, and the PSF-subtracted science images are combined into a single undistorted product.
#
# First, we need to create [Associations](https://jwst-pipeline.readthedocs.io/en/latest/jwst/associations/overview.html), to inform the pipeline which files are the reference and science PSFs.
#
# By default, the `Coron3` stage of the pipeline performs the following steps on NIRCam data:
# - [outlier_detection](https://jwst-pipeline.readthedocs.io/en/latest/jwst/outlier_detection/index.html#outlier-detection-step) - flags outlier pixels in all input images.
# - [stack_refs](https://jwst-pipeline.readthedocs.io/en/latest/jwst/stack_refs/index.html#stack-refs-step) - stacks all of the reference PSF images together into a single product.
# - [align_refs](https://jwst-pipeline.readthedocs.io/en/latest/jwst/align_refs/index.html#align-refs-step) - aligns all of the reference PSF images to the science target images.
# - [klip](https://jwst-pipeline.readthedocs.io/en/latest/jwst/klip/index.html#klip-step) - fits and subtracts a PSF from each science target image.
# - [resample](https://jwst-pipeline.readthedocs.io/en/latest/jwst/resample/index.html#resample-step) - combines all of the PSF-subtracted science images into a single undistorted product.

# %%
time_coron3 = time.perf_counter()

# %%
# Set up a dictionary to define how the Coron3 pipeline should be configured

# Boilerplate dictionary setup
coron3dict = {}
coron3dict['outlier_detection'], coron3dict['stack_refs'], coron3dict['align_refs'] = {}, {}, {}
coron3dict['klip'], coron3dict['resample'] = {}, {}

# Overrides for whether or not certain steps should be skipped (example)
#coron3dict['outlier_detection']['skip'] = True

# Reduce the SNR required for a pixel to be flagged as an outlier
#coron3dict['outlier_detection']['snr'] = '4.5 3.5'

# Define which pixels types are bad based on the images' data quality arrays 
# (only DO_NOT_USE by default). New bad pixels can be flagged in the images' data 
# quality arrays to avoid issues with the psf alignment or subtraction steps.
#coron3dict['align_refs']['bad_bits'] = 'DO_NOT_USE, OTHER_BAD_PIXEL'

# %% [markdown]
# Find and sort all of the input files, ensuring use of absolute paths.

# %%
# Science Files need the calints.fits files
sstring = os.path.join(image2_dir, '*_calints.fits')

# Identify calints files
cal_files = sorted(glob.glob(os.path.join(image2_dir, '*_calints.fits')))

# Expand the relative paths into absolute paths
cal_files = [os.path.abspath(fname) for fname in cal_files]

print(f'Found {len(cal_files)} science files to process')
# Out:
# Found 11 science files to process

# %% [markdown]
# ### Create Association File
#
# An association file lists the files to calibrate together in `Stage3` of the pipeline. For the `Coron3` pipeline, the reference and science psfs must be specified in the association file. Note that association files are available for download from MAST, with filenames of `*_asn.json`. Here we show how to create an association file to point to the data products created in the steps above. This is useful in cases where you want to work with a set of data that is different than that in the association files from MAST.
#
# Using the `associations.asn_from_list` command and `Asn_lv3NRCCoron` helps identify the PSF reference from the science PSF using the header information in the files.

# %%
# List of data to use
print('\nList of calints files to use:')
cal_files
# Out:
# List of calints files to use:
# ['/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386001001_0310e_00001_nrcalong_calints.fits',
#  '/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386001001_0310e_00002_nrcalong_calints.fits',
#  '/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386001001_0310e_00003_nrcalong_calints.fits',
#  '/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386001001_0310e_00004_nrcalong_calints.fits',
#  '/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386001001_0310e_00005_nrcalong_calints.fits',
#  '/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386001001_0310e_00006_nrcalong_calints.fits',
#  '/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386001001_0310e_00007_nrcalong_calints.fits',
#  '/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386001001_0310e_00008_nrcalong_calints.fits',
#  '/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386001001_0310e_00009_nrcalong_calints.fits',
#  '/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386002001_0310a_00001_nrcalong_calints.fits',
#  '/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage2/jw01386003001_0310a_00001_nrcalong_calints.fits']

# %%
#Create a function creates the association file we need for the coron3pipeline.
def create_coron3_asn(cal_files, coron3_dir, forced_ref_files=None):
    """
    Create an association file for the Coron3 pipeline.

    Parameters
    ----------
    cal_files : list
        List of calibrated input files to be processed in the Coron3 pipeline. These should be the
        *_calints.fits files created by the Image2 pipeline.
    coron3_dir : str
        Directory where the association file will be saved.
    forced_ref_files : list, optional
        List of reference PSF files to be included in the association file. If not provided,
        the function will attempt to identify reference PSF files from the input cal_files based on header
        information.
    Returns
    -------
    asn_filename : str
        The filename of the created association file.
    asn : jwst.associations.Association
        The created association object.
    """
    # Add catch for if no forced reference files are provided
    if forced_ref_files is None:
        forced_ref_files = []

    # Look through the input files for exptype SCIENCE to set default output names
    product_name = 'L3product'
    for file in cal_files:
        hdr = fits.getheader(file)
        if not hdr['IS_PSF']:
            product_name = hdr['TARGNAME'].replace(" ", "") + "-" + hdr['FILTER']

    # Combine cal_files with any forced PSF files
    all_files = list(cal_files) + forced_ref_files

    asn_filename = os.path.join(coron3_dir, product_name + '.json')
    asn = asn_from_list.asn_from_list(all_files, rule=Asn_Lv3NRCCoron,
                                      product_name=product_name)

    # Assign exptype based on header, but force forced_psf_files to 'psf'
    forced_ref_set = set(os.path.abspath(f) for f in forced_ref_files)
    for member in asn['products'][0]['members']:
        if os.path.abspath(member['expname']) in forced_ref_set:
            member['exptype'] = 'psf'
        elif fits.getheader(member['expname'])['IS_PSF']:
            member['exptype'] = 'psf'
        else:
            member['exptype'] = 'science'

    # Level 3 coronagraphic associations require at least one PSF
    # Validates the association for this case.
    asn.validity['has_psf']['validated'] = True  # set to True since psfs were added to the asn above
    asn['asn_type'] = 'coron3'
    with open(asn_filename, 'w') as outfile:
        outfile.write(asn.dump()[1])

    return asn_filename, asn

# %%
asn_filename, asn = create_coron3_asn(cal_files, coron3_dir)
# Out:
# /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages/jwst/associations/association.py:232: UserWarning: Input association file contains path information; note that this can complicate usage and/or sharing of such files.
#   warnings.warn(err_str, UserWarning, stacklevel=1)

# %% [markdown]
# ### Run Coron3 stage of the pipeline
#
# The `Coron3` stage of the pipeline will produce the following outputs:
# - a `_crf.fits` file produced by the `outlier_detection` step for each input image, where the `DQ` array marks the pixels flagged as outliers.
# - a `_psfstack` image containing a stack of all of the reference PSF images.
# - a `_psfalign` image for each science PSF, where the reference PSFs have been aligned to the science PSF.
# - a `_psfsub` image for each science PSF, where the aligned reference PSFs have been subtracted from the science PSF.
# - a final combined, undistorted PSF-subtracted image with suffix `_i2d.fits`.

# %%
# Run Coron3 stage of pipeline, specifying:
# output directory to save output files
# save_results flag set to True so the files are saved

if docoron3:
    result = Coron3Pipeline.call(asn_filename,
                                 output_dir=coron3_dir,
                                 steps=coron3dict,
                                 save_results=True)
else:
    print("Skipping Coron3 processing.")
# Out:
# 2026-07-28 16:35:40,353 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /home/runner/crds/references/jwst/nircam/jwst_nircam_pars-resamplestep_0001.asdf
# 2026-07-28 16:35:40,366 - stpipe.step - INFO - Coron3Pipeline instance created.
# 2026-07-28 16:35:40,367 - stpipe.step - INFO - StackRefsStep instance created.
# 2026-07-28 16:35:40,368 - stpipe.step - INFO - AlignRefsStep instance created.
# 2026-07-28 16:35:40,369 - stpipe.step - INFO - KlipStep instance created.
# 2026-07-28 16:35:40,371 - stpipe.step - INFO - OutlierDetectionStep instance created.
# 2026-07-28 16:35:40,372 - stpipe.step - INFO - ResampleStep instance created.
# 2026-07-28 16:35:40,576 - stpipe.step - INFO - Step Coron3Pipeline running with args ('/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3/HD116434-F444W.json',).
# 2026-07-28 16:35:40,583 - stpipe.step - INFO - Step Coron3Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: i2d
#   search_output_file: True
#   input_dir: ''
#   steps:
#     stack_refs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     align_refs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       median_box_length: 3
#       bad_bits: DO_NOT_USE
#     klip:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       truncate: 50
#     outlier_detection:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: False
#       input_dir: ''
#       weight_type: ivm
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       maskpt: 0.7
#       snr: 5.0 4.0
#       scale: 1.2 0.7
#       backg: 0.0
#       kernel_size: 7 7
#       threshold_percent: 99.8
#       rolling_window_width: 25
#       ifu_second_check: False
#       save_intermediate_results: False
#       resample_data: True
#       good_bits: ~DO_NOT_USE
#       in_memory: True
#       pixmap_stepsize: 1.0
#       pixmap_order: 1
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
#       propagate_dq: False
#       pixmap_stepsize: 1.0
#       pixmap_order: 1
# 2026-07-28 16:35:40,585 - jwst.pipeline.calwebb_coron3 - INFO - Starting calwebb_coron3 ...
# 2026-07-28 16:35:42,016 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386001001_0310e_00001_nrcalong_calints.fits' reftypes = ['psfmask']
# 2026-07-28 16:35:42,028 - CRDS - INFO -  Syncing 1 files
# 2026-07-28 16:35:42,028 - CRDS - INFO -  Fetching  /home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits  420.5 K bytes  (1 / 1 files) (0 / 420.5 K bytes)
# 2026-07-28 16:35:42,148 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits'.
# 2026-07-28 16:35:42,150 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386001001_0310e_00002_nrcalong_calints.fits' reftypes = ['psfmask']
# 2026-07-28 16:35:42,153 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits'.
# 2026-07-28 16:35:42,155 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386001001_0310e_00003_nrcalong_calints.fits' reftypes = ['psfmask']
# 2026-07-28 16:35:42,157 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits'.
# 2026-07-28 16:35:42,159 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386001001_0310e_00004_nrcalong_calints.fits' reftypes = ['psfmask']
# 2026-07-28 16:35:42,162 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits'.
# 2026-07-28 16:35:42,163 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386001001_0310e_00005_nrcalong_calints.fits' reftypes = ['psfmask']
# 2026-07-28 16:35:42,166 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits'.
# 2026-07-28 16:35:42,167 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386001001_0310e_00006_nrcalong_calints.fits' reftypes = ['psfmask']
# 2026-07-28 16:35:42,170 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits'.
# 2026-07-28 16:35:42,171 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386001001_0310e_00007_nrcalong_calints.fits' reftypes = ['psfmask']
# 2026-07-28 16:35:42,174 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits'.
# 2026-07-28 16:35:42,176 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386001001_0310e_00008_nrcalong_calints.fits' reftypes = ['psfmask']
# 2026-07-28 16:35:42,179 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits'.
# 2026-07-28 16:35:42,180 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386001001_0310e_00009_nrcalong_calints.fits' reftypes = ['psfmask']
# 2026-07-28 16:35:42,183 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits'.
# 2026-07-28 16:35:42,184 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386002001_0310a_00001_nrcalong_calints.fits' reftypes = ['psfmask']
# 2026-07-28 16:35:42,187 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits'.
# 2026-07-28 16:35:42,189 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386003001_0310a_00001_nrcalong_calints.fits' reftypes = ['psfmask']
# 2026-07-28 16:35:42,191 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits'.
# 2026-07-28 16:35:42,483 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(2, 320, 320) from jw01386001001_0310e_00001_nrcalong_calints.fits>,).
# 2026-07-28 16:35:42,484 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-07-28 16:35:42,485 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-07-28 16:35:42,492 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-07-28 16:35:42,568 - jwst.outlier_detection.utils - INFO - 2 pixels marked as outliers
# 2026-07-28 16:35:42,685 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3/jw01386001001_0310e_00001_nrcalong_a3001_crfints.fits
# 2026-07-28 16:35:42,686 - stpipe.step - INFO - Step outlier_detection done
# 2026-07-28 16:35:42,912 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(2, 320, 320) from jw01386001001_0310e_00002_nrcalong_calints.fits>,).
# 2026-07-28 16:35:42,912 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-07-28 16:35:42,913 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-07-28 16:35:42,920 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-07-28 16:35:42,994 - jwst.outlier_detection.utils - INFO - 0 pixels marked as outliers
# 2026-07-28 16:35:43,097 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3/jw01386001001_0310e_00002_nrcalong_a3001_crfints.fits
# 2026-07-28 16:35:43,098 - stpipe.step - INFO - Step outlier_detection done
# 2026-07-28 16:35:43,326 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(2, 320, 320) from jw01386001001_0310e_00003_nrcalong_calints.fits>,).
# 2026-07-28 16:35:43,326 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-07-28 16:35:43,327 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-07-28 16:35:43,333 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-07-28 16:35:43,409 - jwst.outlier_detection.utils - INFO - 0 pixels marked as outliers
# 2026-07-28 16:35:43,512 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3/jw01386001001_0310e_00003_nrcalong_a3001_crfints.fits
# 2026-07-28 16:35:43,512 - stpipe.step - INFO - Step outlier_detection done
# 2026-07-28 16:35:43,734 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(2, 320, 320) from jw01386001001_0310e_00004_nrcalong_calints.fits>,).
# 2026-07-28 16:35:43,735 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-07-28 16:35:43,735 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-07-28 16:35:43,742 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-07-28 16:35:43,817 - jwst.outlier_detection.utils - INFO - 5 pixels marked as outliers
# 2026-07-28 16:35:43,920 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3/jw01386001001_0310e_00004_nrcalong_a3001_crfints.fits
# 2026-07-28 16:35:43,921 - stpipe.step - INFO - Step outlier_detection done
# 2026-07-28 16:35:44,141 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(2, 320, 320) from jw01386001001_0310e_00005_nrcalong_calints.fits>,).
# 2026-07-28 16:35:44,142 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-07-28 16:35:44,142 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-07-28 16:35:44,149 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-07-28 16:35:44,225 - jwst.outlier_detection.utils - INFO - 0 pixels marked as outliers
# 2026-07-28 16:35:44,330 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3/jw01386001001_0310e_00005_nrcalong_a3001_crfints.fits
# 2026-07-28 16:35:44,330 - stpipe.step - INFO - Step outlier_detection done
# 2026-07-28 16:35:44,554 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(2, 320, 320) from jw01386001001_0310e_00006_nrcalong_calints.fits>,).
# 2026-07-28 16:35:44,554 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-07-28 16:35:44,555 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-07-28 16:35:44,562 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-07-28 16:35:44,635 - jwst.outlier_detection.utils - INFO - 2 pixels marked as outliers
# 2026-07-28 16:35:44,739 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3/jw01386001001_0310e_00006_nrcalong_a3001_crfints.fits
# 2026-07-28 16:35:44,740 - stpipe.step - INFO - Step outlier_detection done
# 2026-07-28 16:35:44,961 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(2, 320, 320) from jw01386001001_0310e_00007_nrcalong_calints.fits>,).
# 2026-07-28 16:35:44,961 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-07-28 16:35:44,962 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-07-28 16:35:44,968 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-07-28 16:35:45,043 - jwst.outlier_detection.utils - INFO - 2 pixels marked as outliers
# 2026-07-28 16:35:45,148 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3/jw01386001001_0310e_00007_nrcalong_a3001_crfints.fits
# 2026-07-28 16:35:45,148 - stpipe.step - INFO - Step outlier_detection done
# 2026-07-28 16:35:45,372 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(2, 320, 320) from jw01386001001_0310e_00008_nrcalong_calints.fits>,).
# 2026-07-28 16:35:45,373 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-07-28 16:35:45,374 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-07-28 16:35:45,381 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-07-28 16:35:45,456 - jwst.outlier_detection.utils - INFO - 2 pixels marked as outliers
# 2026-07-28 16:35:45,561 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3/jw01386001001_0310e_00008_nrcalong_a3001_crfints.fits
# 2026-07-28 16:35:45,561 - stpipe.step - INFO - Step outlier_detection done
# 2026-07-28 16:35:45,784 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(2, 320, 320) from jw01386001001_0310e_00009_nrcalong_calints.fits>,).
# 2026-07-28 16:35:45,785 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-07-28 16:35:45,786 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-07-28 16:35:45,792 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-07-28 16:35:45,867 - jwst.outlier_detection.utils - INFO - 7 pixels marked as outliers
# 2026-07-28 16:35:45,972 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3/jw01386001001_0310e_00009_nrcalong_a3001_crfints.fits
# 2026-07-28 16:35:45,973 - stpipe.step - INFO - Step outlier_detection done
# 2026-07-28 16:35:46,203 - stpipe.step - INFO - Step stack_refs running with args (<jwst.datamodels.container.ModelContainer object at 0x7fa6cb5d4190>,).
# 2026-07-28 16:35:46,207 - jwst.coron.stack_refs - INFO -  Adding psf member 1 to output stack
# 2026-07-28 16:35:46,209 - jwst.coron.stack_refs - INFO -  Adding psf member 2 to output stack
# 2026-07-28 16:35:46,210 - jwst.coron.stack_refs - INFO -  Adding psf member 3 to output stack
# 2026-07-28 16:35:46,212 - jwst.coron.stack_refs - INFO -  Adding psf member 4 to output stack
# 2026-07-28 16:35:46,213 - jwst.coron.stack_refs - INFO -  Adding psf member 5 to output stack
# 2026-07-28 16:35:46,214 - jwst.coron.stack_refs - INFO -  Adding psf member 6 to output stack
# 2026-07-28 16:35:46,215 - jwst.coron.stack_refs - INFO -  Adding psf member 7 to output stack
# 2026-07-28 16:35:46,216 - jwst.coron.stack_refs - INFO -  Adding psf member 8 to output stack
# 2026-07-28 16:35:46,217 - jwst.coron.stack_refs - INFO -  Adding psf member 9 to output stack
# 2026-07-28 16:35:46,280 - stpipe.step - INFO - Step stack_refs done
# 2026-07-28 16:35:46,356 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3/HD116434-F444W_psfstack.fits
# 2026-07-28 16:35:46,584 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(2, 320, 320) from jw01386002001_0310a_00001_nrcalong_calints.fits>,).
# 2026-07-28 16:35:46,585 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-07-28 16:35:46,585 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-07-28 16:35:46,592 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-07-28 16:35:46,666 - jwst.outlier_detection.utils - INFO - 59 pixels marked as outliers
# 2026-07-28 16:35:46,770 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3/jw01386002001_0310a_00001_nrcalong_a3001_crfints.fits
# 2026-07-28 16:35:46,771 - stpipe.step - INFO - Step outlier_detection done
# 2026-07-28 16:35:46,996 - stpipe.step - INFO - Step align_refs running with args (<CubeModel(2, 320, 320) from jw01386002001_0310a_00001_nrcalong_a3001_crfints.fits>, <CubeModel(18, 320, 320) from HD116434-F444W_psfstack.fits>).
# 2026-07-28 16:35:47,051 - jwst.coron.align_refs_step - INFO - Using PSFMASK reference file /home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits
# 2026-07-28 16:35:53,198 - stpipe.step - INFO - Step align_refs done
# 2026-07-28 16:35:53,275 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3/jw01386002001_0310a_00001_nrcalong_a3001_psfalign.fits
# 2026-07-28 16:35:53,502 - stpipe.step - INFO - Step klip running with args (<CubeModel(2, 320, 320) from jw01386002001_0310a_00001_nrcalong_a3001_crfints.fits>, <CubeModel(18, 320, 320) from jw01386002001_0310a_00001_nrcalong_a3001_psfalign.fits>).
# 2026-07-28 16:35:53,503 - jwst.coron.klip_step - INFO - KL transform truncation = 50
# 2026-07-28 16:35:53,558 - stpipe.step - INFO - Step klip done
# 2026-07-28 16:35:53,682 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3/jw01386002001_0310a_00001_nrcalong_a3001_psfsub.fits
# 2026-07-28 16:35:54,105 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(2, 320, 320) from jw01386003001_0310a_00001_nrcalong_calints.fits>,).
# 2026-07-28 16:35:54,106 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-07-28 16:35:54,106 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-07-28 16:35:54,113 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-07-28 16:35:54,187 - jwst.outlier_detection.utils - INFO - 8 pixels marked as outliers
# 2026-07-28 16:35:54,292 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3/jw01386003001_0310a_00001_nrcalong_a3001_crfints.fits
# 2026-07-28 16:35:54,292 - stpipe.step - INFO - Step outlier_detection done
# 2026-07-28 16:35:54,520 - stpipe.step - INFO - Step align_refs running with args (<CubeModel(2, 320, 320) from jw01386003001_0310a_00001_nrcalong_a3001_crfints.fits>, <CubeModel(18, 320, 320) from HD116434-F444W_psfstack.fits>).
# 2026-07-28 16:35:54,532 - jwst.coron.align_refs_step - INFO - Using PSFMASK reference file /home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits
# 2026-07-28 16:36:00,827 - stpipe.step - INFO - Step align_refs done
# 2026-07-28 16:36:00,905 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3/jw01386003001_0310a_00001_nrcalong_a3001_psfalign.fits
# 2026-07-28 16:36:01,129 - stpipe.step - INFO - Step klip running with args (<CubeModel(2, 320, 320) from jw01386003001_0310a_00001_nrcalong_a3001_crfints.fits>, <CubeModel(18, 320, 320) from jw01386003001_0310a_00001_nrcalong_a3001_psfalign.fits>).
# 2026-07-28 16:36:01,130 - jwst.coron.klip_step - INFO - KL transform truncation = 50
# 2026-07-28 16:36:01,183 - stpipe.step - INFO - Step klip done
# 2026-07-28 16:36:01,307 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3/jw01386003001_0310a_00001_nrcalong_a3001_psfsub.fits
# 2026-07-28 16:36:01,732 - stpipe.step - INFO - Step resample running with args (<jwst.datamodels.library.ModelLibrary object at 0x7fa6d0872210>,).
# 2026-07-28 16:36:01,771 - jwst.resample.resample_utils - INFO - Pixel scale ratio (pscale_out/pscale_in): 1.0
# 2026-07-28 16:36:01,772 - jwst.resample.resample_utils - INFO - Computed output pixel scale: 0.06241843100947447 arcsec.
# 2026-07-28 16:36:01,782 - stcal.resample.resample - INFO - Output pixel scale: 0.06241843100947447 arcsec.
# 2026-07-28 16:36:01,783 - stcal.resample.resample - INFO - Driz parameter kernel: square
# 2026-07-28 16:36:01,783 - stcal.resample.resample - INFO - Driz parameter pixfrac: 1.0
# 2026-07-28 16:36:01,784 - stcal.resample.resample - INFO - Driz parameter fillval: NAN
# 2026-07-28 16:36:01,784 - stcal.resample.resample - INFO - Driz parameter weight_type: exptime
# 2026-07-28 16:36:01,785 - jwst.resample.resample - INFO - Resampling science and variance data
# 2026-07-28 16:36:01,824 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-07-28 16:36:01,839 - stcal.resample.resample - INFO - Drizzling (320, 320) --> (371, 370)
# 2026-07-28 16:36:01,854 - stcal.resample.resample - INFO - Drizzling (320, 320) --> (371, 370)
# 2026-07-28 16:36:01,868 - stcal.resample.resample - INFO - Drizzling (320, 320) --> (371, 370)
# 2026-07-28 16:36:01,974 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-07-28 16:36:01,989 - stcal.resample.resample - INFO - Drizzling (320, 320) --> (371, 370)
# 2026-07-28 16:36:02,004 - stcal.resample.resample - INFO - Drizzling (320, 320) --> (371, 370)
# 2026-07-28 16:36:02,019 - stcal.resample.resample - INFO - Drizzling (320, 320) --> (371, 370)
# 2026-07-28 16:36:02,074 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-07-28 16:36:02,093 - stcal.resample.resample - INFO - Drizzling (320, 320) --> (371, 370)
# 2026-07-28 16:36:02,109 - stcal.resample.resample - INFO - Drizzling (320, 320) --> (371, 370)
# 2026-07-28 16:36:02,126 - stcal.resample.resample - INFO - Drizzling (320, 320) --> (371, 370)
# 2026-07-28 16:36:02,183 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-07-28 16:36:02,202 - stcal.resample.resample - INFO - Drizzling (320, 320) --> (371, 370)
# 2026-07-28 16:36:02,218 - stcal.resample.resample - INFO - Drizzling (320, 320) --> (371, 370)
# 2026-07-28 16:36:02,235 - stcal.resample.resample - INFO - Drizzling (320, 320) --> (371, 370)
# 2026-07-28 16:36:02,318 - jwst.resample.resample - INFO - Assigning output S_REGION: POLYGON ICRS  201.155907488 -51.503410342 201.155954311 -51.503331537 201.155310626 -51.503096235 201.155537236 -51.502709582 201.152053283 -51.501905410 201.148256380 -51.500517139 201.148233038 -51.500511763 201.147840975 -51.500932942 201.147122265 -51.500766999 201.145645072 -51.503291750 201.143789784 -51.505284453 201.144358015 -51.505491287 201.144088025 -51.505952662 201.148248791 -51.506907392 201.151533175 -51.508102622 201.151872451 -51.507738724 201.152504439 -51.507883699 201.153803776 -51.505667112
# 2026-07-28 16:36:02,323 - stpipe.step - INFO - Step resample done
# 2026-07-28 16:36:02,687 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3/HD116434-F444W_i2d.fits
# 2026-07-28 16:36:02,688 - jwst.pipeline.calwebb_coron3 - INFO - ...ending calwebb_coron3
# 2026-07-28 16:36:02,699 - stpipe.step - INFO - Step Coron3Pipeline done
# 2026-07-28 16:36:02,699 - jwst.stpipe.core - INFO - Results used jwst version: 3.0.0

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.0f} seconds")
print(f"Runtime for Coron3: {time1 - time_coron3:0.0f} seconds")
# Out:
# Runtime so far: 120 seconds
# Runtime for Coron3: 22 seconds

# %% [markdown]
# ### Verify which pipeline steps were run

# %%
# Identify *_i2d file and open as datamodel
if docoron3:
    i2d_file = os.path.join(coron3_dir, asn_filename.replace('.json', '_i2d.fits'))
    i2d_model = datamodels.open(i2d_file)
    step_check_model = i2d_model

    # Check which steps were run.
    step_check_model.meta.cal_step.instance
# Out:
# {'assign_wcs': 'COMPLETE',
#  'charge_migration': 'SKIPPED',
#  'clean_flicker_noise': 'SKIPPED',
#  'dq_init': 'COMPLETE',
#  'flat_field': 'COMPLETE',
#  'gain_scale': 'SKIPPED',
#  'group_scale': 'SKIPPED',
#  'ipc': 'SKIPPED',
#  'jump': 'COMPLETE',
#  'klip': 'COMPLETE',
#  'linearity': 'COMPLETE',
#  'outlier_detection': 'COMPLETE',
#  'persistence': 'SKIPPED',
#  'photom': 'COMPLETE',
#  'picture_frame': 'SKIPPED',
#  'ramp_fit': 'COMPLETE',
#  'refpix': 'COMPLETE',
#  'resample': 'COMPLETE',
#  'saturation': 'COMPLETE',
#  'superbias': 'COMPLETE'}

# %% [markdown]
# Check which reference files were used to calibrate the dataset

# %%
if docoron3:
    step_check_model.meta.ref_file.instance
# Out:
# {'area': {'name': 'crds://jwst_nircam_area_0042.fits'},
#  'camera': {'name': 'N/A'},
#  'chromcorr': {'name': 'N/A'},
#  'collimator': {'name': 'N/A'},
#  'crds': {'context_used': 'jwst_1584.pmap', 'sw_version': '13.2.7'},
#  'dflat': {'name': 'N/A'},
#  'disperser': {'name': 'N/A'},
#  'distortion': {'name': 'crds://jwst_nircam_distortion_0325.asdf'},
#  'fflat': {'name': 'N/A'},
#  'filteroffset': {'name': 'crds://jwst_nircam_filteroffset_0007.asdf'},
#  'flat': {'name': 'crds://jwst_nircam_flat_0465.fits'},
#  'fore': {'name': 'N/A'},
#  'fpa': {'name': 'N/A'},
#  'gain': {'name': 'crds://jwst_nircam_gain_0097.fits'},
#  'ifufore': {'name': 'N/A'},
#  'ifupost': {'name': 'N/A'},
#  'ifuslicer': {'name': 'N/A'},
#  'linearity': {'name': 'crds://jwst_nircam_linearity_0052.fits'},
#  'mask': {'name': 'crds://jwst_nircam_mask_0076.fits'},
#  'msa': {'name': 'N/A'},
#  'ote': {'name': 'N/A'},
#  'photom': {'name': 'crds://jwst_nircam_photom_0168.fits'},
#  'readnoise': {'name': 'crds://jwst_nircam_readnoise_0284.fits'},
#  'regions': {'name': 'N/A'},
#  'saturation': {'name': 'crds://jwst_nircam_saturation_0097.fits'},
#  'sflat': {'name': 'N/A'},
#  'specwcs': {'name': 'N/A'},
#  'superbias': {'name': 'crds://jwst_nircam_superbias_0229.fits'},
#  'wavelengthrange': {'name': 'N/A'}}

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ## 8. Visualize the final PSF subtracted images
#
# Below we show each individual psf-subtracted science roll and integration, as well as the final combined PSF-subtracted image from the `Coron3` pipeline run:

# %%
# Inspect the psf-subtracted images generated in the coron3 pipeline run
if docoron3:
    files = sorted(glob.glob(os.path.join(coron3_dir, '*_psfsub.fits')))
    grid = plt.GridSpec(2, 4, hspace=0.3, wspace=0.3)
    fig = plt.figure(figsize=(14, 7))

    # Plot the psf-subtracted science images for each roll and integration
    for roll in range(len(files)):
        data = fits.getdata(files[roll])
        for integ in range(data.shape[0]):
            data_int = data[integ]
            ax = fig.add_subplot(grid[roll, integ])
            ax.imshow(data_int, vmin=-1, vmax=5, origin='lower', cmap='coolwarm')
            ax.set_title('Roll {} Int {}'.format(roll + 1, integ + 1))

    # Plot the final combined psf-subtracted science image
    i2d_file = os.path.join(coron3_dir, asn_filename.replace('.json', '_i2d.fits'))
    ax = fig.add_subplot(grid[0:2, 2:4])
    data = fits.getdata(i2d_file)
    ax.imshow(data, vmin=-1, vmax=5, origin='lower', cmap='coolwarm')
    ax.set_title('Combined')
# Out:
# Text(0.5, 1.0, 'Roll 1 Int 1')
# Text(0.5, 1.0, 'Roll 1 Int 2')
# Text(0.5, 1.0, 'Roll 2 Int 1')
# Text(0.5, 1.0, 'Roll 2 Int 2')
# Text(0.5, 1.0, 'Combined')

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ## 9.-Advanced Usage- PSF Reference Library
# ------------------
# In the above sections, we processed a single observation of a science target and its associated PSF reference target. However, the JWST archive contains many observations of NIRCam coronagraphic PSF reference targets that could be used to construct a larger library of reference PSFs for improved PSF subtraction, or in some cases, a formal PSF reference may not have been assigned.. In this section, we'll show how to assemble multiple observations of different PSF reference targets into a single association that can be used for PSF subtraction, without any of the original PSF references being used.
#
# First we need to query the MAST database for potential references, and to do so we will make use of functions held within **TBD**.

# %%
download_coron_references=None

# Check PSF library functions code is available to import
if importlib.util.find_spec("coron_psflib_functions") is None:
    print("Could not find `coron_psflib_functions.py` on the Python path or in the current project. Please ensure you have the latest pipeline notebook installation, or download `coron_psflib_functions.py` from the notebook repository directly.")
else:
    from coron_psflib_functions import download_coron_references
    print("Imported `coron_psflib_functions.py` successfully")
# Out:
# Imported `coron_psflib_functions.py` successfully

# %%
# If the relevant psflib functions were found and docoron3_psflib is True, proceed with PSF reference library
if download_coron_references and docoron3_psflib:
    # In this case we'll skip to the stage 2 products to avoid manual reprocessing.
    additional_ref_dir = os.path.join(data_dir, 'ObsRef/stage2/')

    # We also need to provide the current calibrated science and reference files we're using so that we can match an appropriate reference and avoid duplicates.
    # If necessary, additional lists of files can be included in the concatentation.
    current_files = np.concatenate([cal_files])

    # Run function to download the files
    calhdr = fits.getheader(cal_files[0])
    download_coron_references(cal_files, download_dir=additional_ref_dir, num_refs=2, subarray=calhdr['SUBARRAY'], verbose=True)
# Out:
# MAST query parameters:
# {'columns': 'filename, productLevel, filter, coronmsk, targname, duration, effexptm, effinttm, exp_type, bkgdtarg, bstrtime, is_psf, nexposur, nframes, nints, numdthpt, obs_id, observtn, obslabel, pi_name, program, subarray, template, title, visit_id, visitsta, vststart_mjd, isRestricted, publicReleaseDate_mjd', 'filters': [{'paramName': 'template', 'values': ['NIRCam Coronagraphic Imaging']}, {'paramName': 'productLevel', 'values': ['2b']}, {'paramName': 'filter', 'values': ['F444W']}, {'paramName': 'coronmsk', 'values': ['MASKA335R']}, {'paramName': 'category', 'values': ['ERS', 'GTO', 'GO', 'DD']}, {'paramName': 'exp_type', 'values': ['NRC_CORON', 'MIR_LYOT', 'MIR_4QPM']}, {'paramName': 'is_psf', 'values': ['t']}, {'paramName': 'bkgdtarg', 'values': ['f']}, {'paramName': 'subarray', 'values': ['SUB320A335R']}]}
# Filtered out 9 rows matching provided science files from MAST results
#  DOWNLOAD SUCCESSFUL: /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/ObsRef/stage2/jw01194003001_03105_00001_nrcalong_calints.fits
#  DOWNLOAD SUCCESSFUL: /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/ObsRef/stage2/jw01194003001_03105_00002_nrcalong_calints.fits
#  DOWNLOAD SUCCESSFUL: /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/ObsRef/stage2/jw01194003001_03105_00003_nrcalong_calints.fits
#  DOWNLOAD SUCCESSFUL: /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/ObsRef/stage2/jw01194003001_03105_00004_nrcalong_calints.fits
#  DOWNLOAD SUCCESSFUL: /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/ObsRef/stage2/jw01194003001_03105_00005_nrcalong_calints.fits
#  DOWNLOAD SUCCESSFUL: /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/ObsRef/stage2/jw01411026001_03109_00001_nrcalong_calints.fits
#  DOWNLOAD SUCCESSFUL: /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/ObsRef/stage2/jw01411026001_03109_00002_nrcalong_calints.fits
#  DOWNLOAD SUCCESSFUL: /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/ObsRef/stage2/jw01411026001_03109_00003_nrcalong_calints.fits
#  DOWNLOAD SUCCESSFUL: /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/ObsRef/stage2/jw01411026001_03109_00004_nrcalong_calints.fits
#  DOWNLOAD SUCCESSFUL: /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/ObsRef/stage2/jw01411026001_03109_00005_nrcalong_calints.fits

# %% [markdown]
# Now that we have some files downloaded, we can simply add them to the reference target files list.

# %%
# Gather the filenames of the downloaded additional reference files.
if download_coron_references and docoron3_psflib:
    sstring = os.path.join(additional_ref_dir, 'jw*calints.fits')
    additional_ref_targ_files = sorted(glob.glob(sstring))

# %% [markdown]
# And run the Coron3 pipeline using the same settings as before using the call method.

# %%
if download_coron_references and docoron3_psflib:
    # We want to remove the dedicated reference from our cal files/association to explore how well a non-contemporaneous library can perform.
    # We can do this by filtering the association that was generated for the standard Coron3 calculation for 'science' files only

    # Get filenames from asn where exp_type = 'science'
    sci_files = [member['expname'] for member in asn['products'][0]['members'] if member['exptype'] == 'science']

    # Create association file and run the pipeline
    psflib_asn_filename, psflib_asn = create_coron3_asn(sci_files, coron3_psflib_dir, forced_ref_files=additional_ref_targ_files)
    Coron3Pipeline.call(psflib_asn_filename, steps=coron3dict, save_results=True, output_dir=coron3_psflib_dir)
else:
    print('Skipping coron3 processing')
# Out:
# /home/runner/micromamba/envs/ci-env/lib/python3.13/site-packages/jwst/associations/association.py:232: UserWarning: Input association file contains path information; note that this can complicate usage and/or sharing of such files.
#   warnings.warn(err_str, UserWarning, stacklevel=1)
# 2026-07-28 16:36:08,505 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /home/runner/crds/references/jwst/nircam/jwst_nircam_pars-resamplestep_0001.asdf
# 2026-07-28 16:36:08,518 - stpipe.step - INFO - Coron3Pipeline instance created.
# 2026-07-28 16:36:08,519 - stpipe.step - INFO - StackRefsStep instance created.
# 2026-07-28 16:36:08,520 - stpipe.step - INFO - AlignRefsStep instance created.
# 2026-07-28 16:36:08,521 - stpipe.step - INFO - KlipStep instance created.
# 2026-07-28 16:36:08,523 - stpipe.step - INFO - OutlierDetectionStep instance created.
# 2026-07-28 16:36:08,524 - stpipe.step - INFO - ResampleStep instance created.
# 2026-07-28 16:36:08,761 - stpipe.step - INFO - Step Coron3Pipeline running with args ('/home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3_psflib/HD116434-F444W.json',).
# 2026-07-28 16:36:08,768 - stpipe.step - INFO - Step Coron3Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3_psflib/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: i2d
#   search_output_file: True
#   input_dir: ''
#   steps:
#     stack_refs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     align_refs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       median_box_length: 3
#       bad_bits: DO_NOT_USE
#     klip:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       truncate: 50
#     outlier_detection:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: False
#       input_dir: ''
#       weight_type: ivm
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       maskpt: 0.7
#       snr: 5.0 4.0
#       scale: 1.2 0.7
#       backg: 0.0
#       kernel_size: 7 7
#       threshold_percent: 99.8
#       rolling_window_width: 25
#       ifu_second_check: False
#       save_intermediate_results: False
#       resample_data: True
#       good_bits: ~DO_NOT_USE
#       in_memory: True
#       pixmap_stepsize: 1.0
#       pixmap_order: 1
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
#       propagate_dq: False
#       pixmap_stepsize: 1.0
#       pixmap_order: 1
# 2026-07-28 16:36:08,771 - jwst.pipeline.calwebb_coron3 - INFO - Starting calwebb_coron3 ...
# 2026-07-28 16:36:10,334 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01194003001_03105_00001_nrcalong_calints.fits' reftypes = ['psfmask']
# 2026-07-28 16:36:10,338 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits'.
# 2026-07-28 16:36:10,340 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01194003001_03105_00002_nrcalong_calints.fits' reftypes = ['psfmask']
# 2026-07-28 16:36:10,343 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits'.
# 2026-07-28 16:36:10,344 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01194003001_03105_00003_nrcalong_calints.fits' reftypes = ['psfmask']
# 2026-07-28 16:36:10,347 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits'.
# 2026-07-28 16:36:10,348 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01194003001_03105_00004_nrcalong_calints.fits' reftypes = ['psfmask']
# 2026-07-28 16:36:10,351 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits'.
# 2026-07-28 16:36:10,352 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01194003001_03105_00005_nrcalong_calints.fits' reftypes = ['psfmask']
# 2026-07-28 16:36:10,355 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits'.
# 2026-07-28 16:36:10,357 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01411026001_03109_00001_nrcalong_calints.fits' reftypes = ['psfmask']
# 2026-07-28 16:36:10,360 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits'.
# 2026-07-28 16:36:10,361 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01411026001_03109_00002_nrcalong_calints.fits' reftypes = ['psfmask']
# 2026-07-28 16:36:10,364 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits'.
# 2026-07-28 16:36:10,365 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01411026001_03109_00003_nrcalong_calints.fits' reftypes = ['psfmask']
# 2026-07-28 16:36:10,368 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits'.
# 2026-07-28 16:36:10,370 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01411026001_03109_00004_nrcalong_calints.fits' reftypes = ['psfmask']
# 2026-07-28 16:36:10,372 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits'.
# 2026-07-28 16:36:10,374 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01411026001_03109_00005_nrcalong_calints.fits' reftypes = ['psfmask']
# 2026-07-28 16:36:10,376 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits'.
# 2026-07-28 16:36:10,378 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386002001_0310a_00001_nrcalong_calints.fits' reftypes = ['psfmask']
# 2026-07-28 16:36:10,381 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits'.
# 2026-07-28 16:36:10,383 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw01386003001_0310a_00001_nrcalong_calints.fits' reftypes = ['psfmask']
# 2026-07-28 16:36:10,385 - stpipe.pipeline - INFO - Prefetch for PSFMASK reference file is '/home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits'.
# 2026-07-28 16:36:10,705 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(5, 320, 320) from jw01194003001_03105_00001_nrcalong_calints.fits>,).
# 2026-07-28 16:36:10,705 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-07-28 16:36:10,706 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-07-28 16:36:10,714 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-07-28 16:36:10,805 - jwst.outlier_detection.utils - INFO - 16 pixels marked as outliers
# 2026-07-28 16:36:10,910 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3_psflib/jw01194003001_03105_00001_nrcalong_a3001_crfints.fits
# 2026-07-28 16:36:10,911 - stpipe.step - INFO - Step outlier_detection done
# 2026-07-28 16:36:11,157 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(5, 320, 320) from jw01194003001_03105_00002_nrcalong_calints.fits>,).
# 2026-07-28 16:36:11,158 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-07-28 16:36:11,159 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-07-28 16:36:11,166 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-07-28 16:36:11,254 - jwst.outlier_detection.utils - INFO - 7 pixels marked as outliers
# 2026-07-28 16:36:11,359 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3_psflib/jw01194003001_03105_00002_nrcalong_a3001_crfints.fits
# 2026-07-28 16:36:11,360 - stpipe.step - INFO - Step outlier_detection done
# 2026-07-28 16:36:11,603 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(5, 320, 320) from jw01194003001_03105_00003_nrcalong_calints.fits>,).
# 2026-07-28 16:36:11,603 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-07-28 16:36:11,604 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-07-28 16:36:11,611 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-07-28 16:36:11,699 - jwst.outlier_detection.utils - INFO - 14 pixels marked as outliers
# 2026-07-28 16:36:11,805 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3_psflib/jw01194003001_03105_00003_nrcalong_a3001_crfints.fits
# 2026-07-28 16:36:11,805 - stpipe.step - INFO - Step outlier_detection done
# 2026-07-28 16:36:12,052 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(5, 320, 320) from jw01194003001_03105_00004_nrcalong_calints.fits>,).
# 2026-07-28 16:36:12,053 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-07-28 16:36:12,054 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-07-28 16:36:12,060 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-07-28 16:36:12,148 - jwst.outlier_detection.utils - INFO - 12 pixels marked as outliers
# 2026-07-28 16:36:12,255 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3_psflib/jw01194003001_03105_00004_nrcalong_a3001_crfints.fits
# 2026-07-28 16:36:12,256 - stpipe.step - INFO - Step outlier_detection done
# 2026-07-28 16:36:12,505 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(5, 320, 320) from jw01194003001_03105_00005_nrcalong_calints.fits>,).
# 2026-07-28 16:36:12,505 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-07-28 16:36:12,506 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-07-28 16:36:12,513 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-07-28 16:36:12,600 - jwst.outlier_detection.utils - INFO - 15 pixels marked as outliers
# 2026-07-28 16:36:12,707 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3_psflib/jw01194003001_03105_00005_nrcalong_a3001_crfints.fits
# 2026-07-28 16:36:12,708 - stpipe.step - INFO - Step outlier_detection done
# 2026-07-28 16:36:12,958 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(4, 320, 320) from jw01411026001_03109_00001_nrcalong_calints.fits>,).
# 2026-07-28 16:36:12,959 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-07-28 16:36:12,959 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-07-28 16:36:12,966 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-07-28 16:36:13,047 - jwst.outlier_detection.utils - INFO - 24 pixels marked as outliers
# 2026-07-28 16:36:13,151 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3_psflib/jw01411026001_03109_00001_nrcalong_a3001_crfints.fits
# 2026-07-28 16:36:13,152 - stpipe.step - INFO - Step outlier_detection done
# 2026-07-28 16:36:13,403 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(4, 320, 320) from jw01411026001_03109_00002_nrcalong_calints.fits>,).
# 2026-07-28 16:36:13,404 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-07-28 16:36:13,404 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-07-28 16:36:13,411 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-07-28 16:36:13,493 - jwst.outlier_detection.utils - INFO - 26 pixels marked as outliers
# 2026-07-28 16:36:13,599 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3_psflib/jw01411026001_03109_00002_nrcalong_a3001_crfints.fits
# 2026-07-28 16:36:13,599 - stpipe.step - INFO - Step outlier_detection done
# 2026-07-28 16:36:13,845 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(4, 320, 320) from jw01411026001_03109_00003_nrcalong_calints.fits>,).
# 2026-07-28 16:36:13,846 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-07-28 16:36:13,847 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-07-28 16:36:13,853 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-07-28 16:36:13,940 - jwst.outlier_detection.utils - INFO - 46 pixels marked as outliers
# 2026-07-28 16:36:14,047 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3_psflib/jw01411026001_03109_00003_nrcalong_a3001_crfints.fits
# 2026-07-28 16:36:14,048 - stpipe.step - INFO - Step outlier_detection done
# 2026-07-28 16:36:14,301 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(4, 320, 320) from jw01411026001_03109_00004_nrcalong_calints.fits>,).
# 2026-07-28 16:36:14,302 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-07-28 16:36:14,302 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-07-28 16:36:14,309 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-07-28 16:36:14,392 - jwst.outlier_detection.utils - INFO - 28 pixels marked as outliers
# 2026-07-28 16:36:14,502 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3_psflib/jw01411026001_03109_00004_nrcalong_a3001_crfints.fits
# 2026-07-28 16:36:14,502 - stpipe.step - INFO - Step outlier_detection done
# 2026-07-28 16:36:14,750 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(4, 320, 320) from jw01411026001_03109_00005_nrcalong_calints.fits>,).
# 2026-07-28 16:36:14,751 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-07-28 16:36:14,751 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-07-28 16:36:14,758 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-07-28 16:36:14,840 - jwst.outlier_detection.utils - INFO - 21 pixels marked as outliers
# 2026-07-28 16:36:14,947 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3_psflib/jw01411026001_03109_00005_nrcalong_a3001_crfints.fits
# 2026-07-28 16:36:14,948 - stpipe.step - INFO - Step outlier_detection done
# 2026-07-28 16:36:15,198 - stpipe.step - INFO - Step stack_refs running with args (<jwst.datamodels.container.ModelContainer object at 0x7fa6caa5d150>,).
# 2026-07-28 16:36:15,202 - jwst.coron.stack_refs - INFO -  Adding psf member 1 to output stack
# 2026-07-28 16:36:15,206 - jwst.coron.stack_refs - INFO -  Adding psf member 2 to output stack
# 2026-07-28 16:36:15,207 - jwst.coron.stack_refs - INFO -  Adding psf member 3 to output stack
# 2026-07-28 16:36:15,209 - jwst.coron.stack_refs - INFO -  Adding psf member 4 to output stack
# 2026-07-28 16:36:15,210 - jwst.coron.stack_refs - INFO -  Adding psf member 5 to output stack
# 2026-07-28 16:36:15,212 - jwst.coron.stack_refs - INFO -  Adding psf member 6 to output stack
# 2026-07-28 16:36:15,213 - jwst.coron.stack_refs - INFO -  Adding psf member 7 to output stack
# 2026-07-28 16:36:15,214 - jwst.coron.stack_refs - INFO -  Adding psf member 8 to output stack
# 2026-07-28 16:36:15,215 - jwst.coron.stack_refs - INFO -  Adding psf member 9 to output stack
# 2026-07-28 16:36:15,217 - jwst.coron.stack_refs - INFO -  Adding psf member 10 to output stack
# 2026-07-28 16:36:15,279 - stpipe.step - INFO - Step stack_refs done
# 2026-07-28 16:36:15,359 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3_psflib/HD116434-F444W_psfstack.fits
# 2026-07-28 16:36:15,614 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(2, 320, 320) from jw01386002001_0310a_00001_nrcalong_calints.fits>,).
# 2026-07-28 16:36:15,615 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-07-28 16:36:15,615 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-07-28 16:36:15,622 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-07-28 16:36:15,696 - jwst.outlier_detection.utils - INFO - 59 pixels marked as outliers
# 2026-07-28 16:36:15,802 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3_psflib/jw01386002001_0310a_00001_nrcalong_a3001_crfints.fits
# 2026-07-28 16:36:15,803 - stpipe.step - INFO - Step outlier_detection done
# 2026-07-28 16:36:16,055 - stpipe.step - INFO - Step align_refs running with args (<CubeModel(2, 320, 320) from jw01386002001_0310a_00001_nrcalong_a3001_crfints.fits>, <CubeModel(45, 320, 320) from HD116434-F444W_psfstack.fits>).
# 2026-07-28 16:36:16,060 - jwst.coron.align_refs_step - INFO - Using PSFMASK reference file /home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits
# 2026-07-28 16:36:31,802 - stpipe.step - INFO - Step align_refs done
# 2026-07-28 16:36:31,882 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3_psflib/jw01386002001_0310a_00001_nrcalong_a3001_psfalign.fits
# 2026-07-28 16:36:32,139 - stpipe.step - INFO - Step klip running with args (<CubeModel(2, 320, 320) from jw01386002001_0310a_00001_nrcalong_a3001_crfints.fits>, <CubeModel(45, 320, 320) from jw01386002001_0310a_00001_nrcalong_a3001_psfalign.fits>).
# 2026-07-28 16:36:32,140 - jwst.coron.klip_step - INFO - KL transform truncation = 50
# 2026-07-28 16:36:32,357 - stpipe.step - INFO - Step klip done
# 2026-07-28 16:36:32,481 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3_psflib/jw01386002001_0310a_00001_nrcalong_a3001_psfsub.fits
# 2026-07-28 16:36:32,935 - stpipe.step - INFO - Step outlier_detection running with args (<CubeModel(2, 320, 320) from jw01386003001_0310a_00001_nrcalong_calints.fits>,).
# 2026-07-28 16:36:32,936 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: coron
# 2026-07-28 16:36:32,936 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-07-28 16:36:32,943 - jwst.outlier_detection.utils - INFO - Computing median
# 2026-07-28 16:36:33,016 - jwst.outlier_detection.utils - INFO - 8 pixels marked as outliers
# 2026-07-28 16:36:33,124 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3_psflib/jw01386003001_0310a_00001_nrcalong_a3001_crfints.fits
# 2026-07-28 16:36:33,124 - stpipe.step - INFO - Step outlier_detection done
# 2026-07-28 16:36:33,380 - stpipe.step - INFO - Step align_refs running with args (<CubeModel(2, 320, 320) from jw01386003001_0310a_00001_nrcalong_a3001_crfints.fits>, <CubeModel(45, 320, 320) from HD116434-F444W_psfstack.fits>).
# 2026-07-28 16:36:33,389 - jwst.coron.align_refs_step - INFO - Using PSFMASK reference file /home/runner/crds/references/jwst/nircam/jwst_nircam_psfmask_0211.fits
# 2026-07-28 16:36:48,458 - stpipe.step - INFO - Step align_refs done
# 2026-07-28 16:36:48,538 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3_psflib/jw01386003001_0310a_00001_nrcalong_a3001_psfalign.fits
# 2026-07-28 16:36:48,785 - stpipe.step - INFO - Step klip running with args (<CubeModel(2, 320, 320) from jw01386003001_0310a_00001_nrcalong_a3001_crfints.fits>, <CubeModel(45, 320, 320) from jw01386003001_0310a_00001_nrcalong_a3001_psfalign.fits>).
# 2026-07-28 16:36:48,786 - jwst.coron.klip_step - INFO - KL transform truncation = 50
# 2026-07-28 16:36:48,991 - stpipe.step - INFO - Step klip done
# 2026-07-28 16:36:49,115 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3_psflib/jw01386003001_0310a_00001_nrcalong_a3001_psfsub.fits
# 2026-07-28 16:36:49,563 - stpipe.step - INFO - Step resample running with args (<jwst.datamodels.library.ModelLibrary object at 0x7fa6cdfbbe10>,).
# 2026-07-28 16:36:49,602 - jwst.resample.resample_utils - INFO - Pixel scale ratio (pscale_out/pscale_in): 1.0
# 2026-07-28 16:36:49,603 - jwst.resample.resample_utils - INFO - Computed output pixel scale: 0.06241843100947447 arcsec.
# 2026-07-28 16:36:49,613 - stcal.resample.resample - INFO - Output pixel scale: 0.06241843100947447 arcsec.
# 2026-07-28 16:36:49,614 - stcal.resample.resample - INFO - Driz parameter kernel: square
# 2026-07-28 16:36:49,614 - stcal.resample.resample - INFO - Driz parameter pixfrac: 1.0
# 2026-07-28 16:36:49,615 - stcal.resample.resample - INFO - Driz parameter fillval: NAN
# 2026-07-28 16:36:49,615 - stcal.resample.resample - INFO - Driz parameter weight_type: exptime
# 2026-07-28 16:36:49,616 - jwst.resample.resample - INFO - Resampling science and variance data
# 2026-07-28 16:36:49,664 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-07-28 16:36:49,688 - stcal.resample.resample - INFO - Drizzling (320, 320) --> (371, 370)
# 2026-07-28 16:36:49,709 - stcal.resample.resample - INFO - Drizzling (320, 320) --> (371, 370)
# 2026-07-28 16:36:49,731 - stcal.resample.resample - INFO - Drizzling (320, 320) --> (371, 370)
# 2026-07-28 16:36:49,856 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-07-28 16:36:49,878 - stcal.resample.resample - INFO - Drizzling (320, 320) --> (371, 370)
# 2026-07-28 16:36:49,900 - stcal.resample.resample - INFO - Drizzling (320, 320) --> (371, 370)
# 2026-07-28 16:36:49,921 - stcal.resample.resample - INFO - Drizzling (320, 320) --> (371, 370)
# 2026-07-28 16:36:49,996 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-07-28 16:36:50,022 - stcal.resample.resample - INFO - Drizzling (320, 320) --> (371, 370)
# 2026-07-28 16:36:50,046 - stcal.resample.resample - INFO - Drizzling (320, 320) --> (371, 370)
# 2026-07-28 16:36:50,070 - stcal.resample.resample - INFO - Drizzling (320, 320) --> (371, 370)
# 2026-07-28 16:36:50,146 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-07-28 16:36:50,172 - stcal.resample.resample - INFO - Drizzling (320, 320) --> (371, 370)
# 2026-07-28 16:36:50,196 - stcal.resample.resample - INFO - Drizzling (320, 320) --> (371, 370)
# 2026-07-28 16:36:50,220 - stcal.resample.resample - INFO - Drizzling (320, 320) --> (371, 370)
# 2026-07-28 16:36:50,311 - jwst.resample.resample - INFO - Assigning output S_REGION: POLYGON ICRS  201.155907488 -51.503410342 201.155954311 -51.503331537 201.155310626 -51.503096235 201.155537236 -51.502709582 201.152053283 -51.501905410 201.148256380 -51.500517139 201.148233038 -51.500511763 201.147840975 -51.500932942 201.147122265 -51.500766999 201.145645072 -51.503291750 201.143789784 -51.505284453 201.144358015 -51.505491287 201.144088025 -51.505952662 201.148248791 -51.506907392 201.151533175 -51.508102622 201.151872451 -51.507738724 201.152504439 -51.507883699 201.153803776 -51.505667112
# 2026-07-28 16:36:50,315 - stpipe.step - INFO - Step resample done
# 2026-07-28 16:36:50,674 - stpipe.step - INFO - Saved model in /home/runner/work/jwst-pipeline-notebooks/jwst-pipeline-notebooks/notebooks/NIRCAM/Coronagraphy/nrc_coron_demo_data/stage3_psflib/HD116434-F444W_i2d.fits
# 2026-07-28 16:36:50,675 - jwst.pipeline.calwebb_coron3 - INFO - ...ending calwebb_coron3
# 2026-07-28 16:36:50,689 - stpipe.step - INFO - Step Coron3Pipeline done
# 2026-07-28 16:36:50,689 - jwst.stpipe.core - INFO - Results used jwst version: 3.0.0

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ## 10.-Advanced Usage- Examine the output
# ------------------
# Here we'll plot the data from the larger library to see what our source looks like and whether the subtraction improved.

# %%
# Inspect the psf-subtracted images generated in the coron3 pipeline run
if download_coron_references and docoron3_psflib:
    files = sorted(glob.glob(os.path.join(coron3_psflib_dir, '*_psfsub.fits')))
    grid = plt.GridSpec(2, 4, hspace=0.3, wspace=0.3)
    fig = plt.figure(figsize=(14, 7))

    # Plot the psf-subtracted science images for each roll and integration
    for roll in range(len(files)):
        data = fits.getdata(files[roll])
        for integ in range(data.shape[0]):
            data_int = data[integ]
            ax = fig.add_subplot(grid[roll, integ])
            ax.imshow(data_int, vmin=-1, vmax=5, origin='lower', cmap='coolwarm')
            ax.set_title('Roll {} Int {}'.format(roll + 1, integ + 1))

    # Plot the final combined psf-subtracted science image
    i2d_file = os.path.join(coron3_psflib_dir, psflib_asn_filename.replace('.json', '_i2d.fits'))
    ax = fig.add_subplot(grid[0:2, 2:4])
    data = fits.getdata(i2d_file)
    ax.imshow(data, vmin=-1, vmax=5, origin='lower', cmap='coolwarm')
    ax.set_title('Combined')
# Out:
# Text(0.5, 1.0, 'Roll 1 Int 1')
# Text(0.5, 1.0, 'Roll 1 Int 2')
# Text(0.5, 1.0, 'Roll 2 Int 1')
# Text(0.5, 1.0, 'Roll 2 Int 2')
# Text(0.5, 1.0, 'Combined')

# %% [markdown]
# This looks excellent already, we've achieved a broadly similar subtraction without using the dedicated reference at all. We can get a quick quantitative estimate of the comparison between the dedicated reference versus the library by plotting the profiles of the annular standard deviation as a function of separation from the coronagraph center. This is analogous to a contrast curve, but without the normalization for the stellar peak flux. As our science target hasn't changed, this is a suitable proxy for the improvement in contrast.

# %%
def compute_stdev_curves(i2d_file_orig, i2d_file_psflib, mask_circle=None):
    """
    Compute 5-sigma standard deviation curves for two i2d FITS files using CRPIX as center.

    Parameters
    ----------
    i2d_file_orig : str
        Path to the original i2d FITS file.
    i2d_file_psflib : str
        Path to the large-library i2d FITS file.
    mask_circle : tuple, optional
        A tuple of (x, y, radius) in pixels defining a circular region to set
        to NaN before computing the stdev curves. x and y are the center
        of the circle in pixel coordinates (0-indexed).

    Returns
    -------
    radii_arcsec : np.ndarray
        Radii in arcseconds for the stdev curve.
    stdev_orig : np.ndarray
        5-sigma stdev curve for the original library.
    stdev_psflib : np.ndarray
        5-sigma stdev curve for the larger library.
    """

    def load_i2d(filepath):
        with fits.open(filepath) as hdul:
            data = hdul['SCI'].data.astype(float)
            hdr = hdul['SCI'].header
            # CRPIX is 1-indexed, convert to 0-indexed
            cx = hdr.get('CRPIX1', data.shape[1] / 2) - 1
            cy = hdr.get('CRPIX2', data.shape[0] / 2) - 1
            pixelscale = np.sqrt(hdr.get('PIXAR_A2'))
        return data, cx, cy, pixelscale

    def apply_circle_mask(data, mask_circle):
        if mask_circle is not None:
            mx, my, mr = mask_circle
            y, x = np.indices(data.shape)
            dist = np.sqrt((x - mx)**2 + (y - my)**2)
            data = data.copy()
            data[dist <= mr] = np.nan
        return data

    def radial_5sigma_stdev(data, cx, cy):
        y, x = np.indices(data.shape)
        r = np.sqrt((x - cx)**2 + (y - cy)**2).astype(int)

        max_r = int(np.min([cx, cy, data.shape[1] - cx, data.shape[0] - cy]))
        radii = np.arange(1, max_r)
        stdev = np.full(len(radii), np.nan)

        for i, radius in enumerate(radii):
            annulus_mask = r == radius
            annulus_values = data[annulus_mask]
            # Remove NaNs
            annulus_values = annulus_values[np.isfinite(annulus_values)]
            if len(annulus_values) > 2:
                stdev[i] = 5.0 * np.nanstd(annulus_values)

        return radii, stdev

    # Load data
    data_orig, cx_orig, cy_orig, pixelscale_orig = load_i2d(i2d_file_orig)
    data_psflib, cx_psflib, cy_psflib, pixelscale_psflib = load_i2d(i2d_file_psflib)
    if pixelscale_orig != pixelscale_psflib:
        raise ValueError("Pixel scales of the two i2d files do not match.")
    else:
        pixelscale = pixelscale_orig

    # Apply circular mask if provided
    data_orig = apply_circle_mask(data_orig, mask_circle)
    data_psflib = apply_circle_mask(data_psflib, mask_circle)

    # Compute stdev curves
    radii_orig, stdev_orig = radial_5sigma_stdev(data_orig, cx_orig, cy_orig)
    radii_psflib, stdev_psflib = radial_5sigma_stdev(data_psflib, cx_psflib, cy_psflib)

    # Use the shorter of the two radius arrays for comparison
    min_len = min(len(radii_orig), len(radii_psflib))
    radii_arcsec = radii_orig[:min_len] * pixelscale

    return radii_arcsec, stdev_orig[:min_len], stdev_psflib[:min_len]

# %%
if download_coron_references and docoron3_psflib:
    # Look for *i2d file in the original coron3 output directory
    i2d_file_orig = sorted(glob.glob(os.path.join(coron3_dir, '*_i2d.fits')))[0]
    i2d_file_psflib = sorted(glob.glob(os.path.join(coron3_psflib_dir, '*_i2d.fits')))[0]

    # Run the stdev calculation, applying a circular mask to reduce the impact of the bright inner planet, HIP 65426 b
    radii_arcsec, stdev_orig, stdev_psflib = compute_stdev_curves(i2d_file_orig, i2d_file_psflib, mask_circle=(165, 207, 15))

    # Make plot of the stdev curves and relative residuals in second panel
    fig, ax = plt.subplots(2, 1, figsize=(8, 6), sharex=True, gridspec_kw={'height_ratios': [3,1]})
    ax[0].plot(radii_arcsec, stdev_orig, label='Dedicated Reference')
    ax[0].plot(radii_arcsec, stdev_psflib, label='PSF Library')
    ax[0].set_yscale('log')
    ax[0].set_ylabel('5$\\sigma$ Annular Standard Deviation')
    ax[0].set_xlim(0, 5)
    ax[0].legend()
    ax[1].plot(radii_arcsec, stdev_orig/stdev_psflib, label='Dedicated / Library')
    ax[1].axhline(1, color='gray', linestyle='--')
    ax[1].set_xlabel('Separation (arcsec)')
    ax[1].set_ylabel('Noise Reduction Factor')
    ax[1].set_xlim(0, 5)
    ax[1].legend()
    plt.tight_layout()
# Out:
# Text(0, 0.5, '5$\\sigma$ Annular Standard Deviation')
# (0.0, 5.0)
# Text(0.5, 0, 'Separation (arcsec)')
# Text(0, 0.5, 'Noise Reduction Factor')
# (0.0, 5.0)

# %% [markdown]
# The subtracted images and curves show that the dedicated reference provides a  better subtraction at most separations compared to the library, but the library still performs very well and is still able to recover the central planet, HIP 65426 b. The most significant differences occur at the closest separations, where the dedicated reference has a better subtraction, likely owing to it being a better match for the PSF of the science target. In some cases, where the contemporaneous reference is a less ideal match, a library may offer significant advantages in capturing the full scope of PSF diversity, and improve the overall contrast sensitivity. Furthermore, while the contemporaneous reference was excluded from the library for this example, this is not truly necessary, and overall contrast improvements may be obtained by combining both contemporaneous and library references.

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# <img style="float: center;" src='https://github.com/spacetelescope/jwst-pipeline-notebooks/raw/main/_static/stsci_footer.png' alt="stsci_logo" width="400px"/>
